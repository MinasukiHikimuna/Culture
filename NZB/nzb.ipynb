# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

from NZB.search import NZBSearch

searcher = NZBSearch()
results = searcher.search("sexart 24 01 03")
results
# Out:
# shape: (3, 7)
# ┌──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ title        ┆ size        ┆ link        ┆ category_id ┆ category_na ┆ item_url    ┆ api_name    │
# │ ---          ┆ ---         ┆ ---         ┆ ---         ┆ me          ┆ ---         ┆ ---         │
# │ str          ┆ i64         ┆ str         ┆ str         ┆ ---         ┆ str         ┆ str         │
# │              ┆             ┆             ┆             ┆ str         ┆             ┆             │
# ╞══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ SexArt.24.01 ┆ 24291202413 ┆ https://dru ┆ 6020        ┆ XXX/WMV     ┆ https://dru ┆ drunkenslug │
# │ .03.Fanta.Si ┆             ┆ nkenslug.co ┆             ┆             ┆ nkenslug.co ┆             │
# │ e.And.…      ┆             ┆ m/getnzb…   ┆             ┆             ┆ m/detail…   ┆             │
# ...
