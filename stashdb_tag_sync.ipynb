# %%
import polars as pl
import dotenv
import os
from libraries.client_stashapp import get_stashapp_client
from libraries.StashDbClient import StashDbClient

# Format a StashDB ID for use as an aliasin Stash
stashdb_id_alias_prefix = "StashDB ID: "
def format_stashdb_id(id):
    return f"{stashdb_id_alias_prefix}{id}"

def contains_cjk(text):
    """Check if text contains CJK (Chinese, Japanese, Korean) characters."""
    # Unicode ranges for CJK characters
    cjk_ranges = [
        (0x4E00, 0x9FFF),   # CJK Unified Ideographs
        (0x3040, 0x309F),   # Hiragana
        (0x30A0, 0x30FF),   # Katakana
        (0x3400, 0x4DBF),   # CJK Unified Ideographs Extension A
        (0xF900, 0xFAFF),   # CJK Compatibility Ideographs
        (0xAC00, 0xD7AF),   # Korean Hangul Syllables
    ]
    
    return any(any(ord(char) >= start and ord(char) <= end 
               for start, end in cjk_ranges) 
               for char in text)


dotenv.load_dotenv()

stash = get_stashapp_client()

stashbox_client = StashDbClient(
    os.getenv("STASHDB_ENDPOINT"),
    os.getenv("STASHDB_API_KEY"),
)
# Out:
# dUsing stash (v0.27.2-37-g0621d871) endpoint at http://localhost:6969/graphql
# dPersisting Connection to Stash with ApiKey...

# %% [markdown]
# # Merging tags

# %%
to_be_merged_tag = stash.find_tag({ "name": "Standing Double Penetration" })
target_tag = stash.find_tag({ "name": "Standing Sex (DP)" })

print(to_be_merged_tag)
print("=>")
print(target_tag)
print()

scenes = stash.find_scenes({ "tags": { "value": [to_be_merged_tag['id']], "modifier": "INCLUDES" }}, fragment="id title tags { id name }")
galleries = stash.find_galleries({ "tags": { "value": [to_be_merged_tag['id']], "modifier": "INCLUDES" }}, fragment="id title tags { id name }")
images = stash.find_images({ "tags": { "value": [to_be_merged_tag['id']], "modifier": "INCLUDES" }}, fragment="id title tags { id name }")
markers = stash.find_scene_markers({ "tags": { "value": [to_be_merged_tag['id']], "modifier": "INCLUDES" }}, fragment="id scene { id title } title primary_tag { id name } tags { id name }")

print(f"Scenes: {len(scenes)}")
print(f"Markers: {len(markers)}")
print(f"Galleries: {len(galleries)}")
print(f"Images: {len(images)}")
# Out:
# {'id': '7178', 'name': 'Standing Double Penetration', 'description': 'A female performer having vaginal and anal penetrative sex simultaneously while standing up', 'aliases': ['DP - Standing', 'Standing DP', 'Standing.Double.Penetration'], 'ignore_auto_tag': False, 'created_at': '2024-04-23T12:52:25Z', 'updated_at': '2024-09-19T07:58:21+03:00', 'favorite': False, 'image_path': 'http://localhost:6969/tag/7178/image?t=1726721901&default=true', 'scene_count': 6, 'scene_marker_count': 2, 'image_count': 0, 'gallery_count': 0, 'performer_count': 0, 'studio_count': 0, 'group_count': 0, 'parents': [{'id': '7753'}], 'children': [], 'parent_count': 1, 'child_count': 0}
# =>
# {'id': '7993', 'name': 'Standing Sex (DP)', 'description': '', 'aliases': ['StashDB ID: 01eb4084-62ac-498c-9115-43fd709c23ca'], 'ignore_auto_tag': False, 'created_at': '2025-01-26T17:44:27+02:00', 'updated_at': '2025-01-26T17:44:27+02:00', 'favorite': False, 'image_path': 'http://localhost:6969/tag/7993/image?t=1737906267&default=true', 'scene_count': 0, 'scene_marker_count': 0, 'image_count': 0, 'gallery_count': 0, 'performer_count': 0, 'studio_count': 0, 'group_count': 0, 'parents': [], 'children': [], 'parent_count': 0, 'child_count': 0}
#
# Scenes: 6
# Markers: 2
# Galleries: 0
# Images: 0

# %%
# Update scenes
for scene in scenes:
    scene_id = scene['id']
    current_scene_tag_ids = [tag['id'] for tag in scene['tags']]
    update_scene_tag_ids = [tag_id for tag_id in current_scene_tag_ids if tag_id != to_be_merged_tag['id']] + [target_tag['id']]
    stash.update_scene({ "id": scene_id, "tag_ids": update_scene_tag_ids })
    print(f"Updated scene {scene_id} with tag {target_tag['name']}")
# Out:
# Updated scene 6969 with tag Standing Sex (DP)
# Updated scene 10995 with tag Standing Sex (DP)
# Updated scene 11069 with tag Standing Sex (DP)
# Updated scene 13778 with tag Standing Sex (DP)
# Updated scene 2770 with tag Standing Sex (DP)
# Updated scene 11742 with tag Standing Sex (DP)

# %%
# Update markers
for marker in markers:
    marker_id = marker['id']
    current_marker_tag_ids = [tag['id'] for tag in marker['tags']]
    update_marker_tag_ids = [tag_id for tag_id in current_marker_tag_ids if tag_id != to_be_merged_tag['id']] + [target_tag['id']]
    stash.update_scene_marker({ "id": marker_id, "title": target_tag["name"], "primary_tag_id": target_tag['id'] })
    print(f"Updated marker {marker_id} with tag {target_tag['name']} for scene {marker['scene']['title']} (ID: {marker['scene']['id']})")
# Out:
# Updated marker 62786 with tag Standing Sex (DP) for scene The Dinner Party (ID: 11069)
# Updated marker 61698 with tag Standing Sex (DP) for scene ZZ Confidential (ID: 10995)

# %%
# Update galleries
for gallery in galleries:
    gallery_id = gallery['id']
    current_gallery_tag_ids = [tag['id'] for tag in gallery['tags']]
    update_gallery_tag_ids = [tag_id for tag_id in current_gallery_tag_ids if tag_id != to_be_merged_tag['id']] + [target_tag['id']]
    stash.update_gallery({ "id": gallery_id, "tag_ids": update_gallery_tag_ids })
    print(f"Updated gallery {gallery_id} with tag {target_tag['name']}")

# %%
# Update images
for image in images:
    image_id = image['id']
    current_image_tag_ids = [tag['id'] for tag in image['tags']]
    update_image_tag_ids = [tag_id for tag_id in current_image_tag_ids if tag_id != to_be_merged_tag['id']] + [target_tag['id']]
    stash.update_image({ "id": image_id, "tag_ids": update_image_tag_ids })
    print(f"Updated image {image_id} with tag {target_tag['name']}")

# %%
stash.destroy_tag(to_be_merged_tag['id'])

# %% [markdown]
# # Syncing tags from StashDB to Stash

# %%
stashdb_tags = stashbox_client.query_tags()

# %%
# Get tags from StashDB
df_stashdb_tags = pl.DataFrame(stashdb_tags)

df_stashdb_tags = df_stashdb_tags.with_columns(
    pl.col("category").map_elements(lambda x: x['id'] if x else None, return_dtype=pl.Utf8).alias("category_id"),
    pl.col("category").map_elements(lambda x: x['name'] if x else None, return_dtype=pl.Utf8).alias("category_name"),
    pl.col("category").map_elements(lambda x: x['description'] if x else None, return_dtype=pl.Utf8).alias("category_description"),
    pl.col("category").map_elements(lambda x: x['group'] if x else None, return_dtype=pl.Utf8).alias("category_group"),
).drop("category")

df_stashdb_tags
# Out:
# shape: (2_756, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ descripti ┆ aliases   ┆ … ┆ category_ ┆ category_ ┆ category_ ┆ category │
# │ ---       ┆ ---       ┆ on        ┆ ---       ┆   ┆ id        ┆ name      ┆ descripti ┆ _group   │
# │ str       ┆ str       ┆ ---       ┆ list[str] ┆   ┆ ---       ┆ ---       ┆ on        ┆ ---      │
# │           ┆           ┆ str       ┆           ┆   ┆ str       ┆ str       ┆ ---       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 9441c3ad- ┆ 120 FPS   ┆ Scenes    ┆ ["120帧"] ┆ … ┆ ef4ae6d1- ┆ Shot Type ┆ Technical ┆ SCENE    │
# │ 41d2-4d6e ┆           ┆ offered   ┆           ┆   ┆ d13c-4195 ┆           ┆ details   ┆          │
# │ -bc97-54a ┆           ┆ at 120    ┆           ┆   ┆ -b47e-f24 ┆           ┆ of how a  ┆          │
# │ d8c…      ┆           ┆ frames p… ┆           ┆   ┆ 5e4…      ┆           ┆ vid…      ┆          │
# │ 42d9e5c4- ┆ 12K       ┆ Scenes    ┆ ["12K",   ┆ … ┆ 7f4ddc1b- ┆ Misc      ┆ Informati ┆ SCENE    │
# │ 1a1d-4c93 ┆ Available ┆ offered   ┆ "12K      ┆   ┆ 8169-4d5b ┆           ┆ on about  ┆          │
# │ -bf47-908 ┆           ┆ in a reso ┆ Shemale   ┆   ┆ -b764-04a ┆           ┆ the video ┆          │
# │ 6f2…      ┆           ┆ lution…   ┆ VR        ┆   ┆ d07…      ┆           ┆ it…       ┆          │
# │           ┆           ┆           ┆ Porn",…   ┆   ┆           ┆           ┆           ┆          │
# │ 8534d108- ┆ 18+       ┆ Primary   ┆ ["18      ┆ … ┆ b40e08dd- ┆ Age Group ┆ Implied   ┆ PEOPLE   │
# │ 1f4c-42f9 ┆           ┆ performer ┆ Plus",    ┆   ┆ 314e-40ca ┆           ┆ age       ┆          │
# │ -8caa-5ca ┆           ┆ (not      ┆ "Over     ┆   ┆ -8fdb-bf7 ┆           ┆ ranges    ┆          │
# │ 906…      ┆           ┆ charact…  ┆ 18"]      ┆   ┆ 541…      ┆           ┆ for       ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ charact…  ┆          │
# │ 103a1f16- ┆ 180°      ┆ Virtual   ┆ ["180",   ┆ … ┆ ef4ae6d1- ┆ Shot Type ┆ Technical ┆ SCENE    │
# │ 83e1-4b9f ┆           ┆ reality   ┆ "180      ┆   ┆ d13c-4195 ┆           ┆ details   ┆          │
# │ -ab14-e85 ┆           ┆ scenes    ┆ FOV", …   ┆   ┆ -b47e-f24 ┆           ┆ of how a  ┆          │
# │ e04…      ┆           ┆ with a …  ┆ "VR180"]  ┆   ┆ 5e4…      ┆           ┆ vid…      ┆          │
# │ 6cd87d98- ┆ 1800s     ┆ Inspired  ┆ ["1800's" ┆ … ┆ 0319d5d6- ┆ Themes    ┆ Events,   ┆ SCENE    │
# │ eea8-4b97 ┆           ┆ by the    ┆ , "19th   ┆   ┆ a07f-4e0d ┆           ┆ contexts, ┆          │
# │ -9db9-aa3 ┆           ┆ history   ┆ Century", ┆   ┆ -809d-c09 ┆           ┆ or        ┆          │
# │ 8a9…      ┆           ┆ and cu…   ┆ … "…      ┆   ┆ fb1…      ┆           ┆ fetishes  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ …         ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ e7f1f848- ┆ Young Man ┆ Male      ┆ ["Young   ┆ … ┆ b40e08dd- ┆ Age Group ┆ Implied   ┆ PEOPLE   │
# │ 4350-4bda ┆ (22–30)   ┆ presented ┆ Guy",     ┆   ┆ 314e-40ca ┆           ┆ age       ┆          │
# │ -925c-b01 ┆           ┆ as        ┆ "Young    ┆   ┆ -8fdb-bf7 ┆           ┆ ranges    ┆          │
# │ 235…      ┆           ┆ generally ┆ Male", …  ┆   ┆ 541…      ┆           ┆ for       ┆          │
# │           ┆           ┆ yo…       ┆ …         ┆   ┆           ┆           ┆ charact…  ┆          │
# │ 84ba8ef1- ┆ Young     ┆ Female    ┆ ["Chick", ┆ … ┆ b40e08dd- ┆ Age Group ┆ Implied   ┆ PEOPLE   │
# │ 084c-46f8 ┆ Woman     ┆ character ┆ "Woman    ┆   ┆ 314e-40ca ┆           ┆ age       ┆          │
# │ -b352-311 ┆ (22–30)   ┆ presented ┆ (20-29)", ┆   ┆ -8fdb-bf7 ┆           ┆ ranges    ┆          │
# │ 54f…      ┆           ┆ as …      ┆ … "…      ┆   ┆ 541…      ┆           ┆ for       ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ charact…  ┆          │
# │ 6c0a2824- ┆ Zentai    ┆ Skin-tigh ┆ ["Zentai  ┆ … ┆ dc566ccc- ┆ Clothing  ┆ Articles  ┆ PEOPLE   │
# │ acd2-4b64 ┆           ┆ t garment ┆ Suit"]    ┆   ┆ 0584-41d8 ┆           ┆ or styles ┆          │
# │ -9a2c-634 ┆           ┆ that      ┆           ┆   ┆ -b9f5-4d8 ┆           ┆ of        ┆          │
# │ bd9…      ┆           ┆ covers…   ┆           ┆   ┆ 680…      ┆           ┆ clothing… ┆          │
# │ bed78871- ┆ Zip Front ┆ A dress   ┆ ["Zipper  ┆ … ┆ dc566ccc- ┆ Clothing  ┆ Articles  ┆ PEOPLE   │
# │ 9bb8-40c2 ┆ Dress     ┆ where the ┆ Dress"]   ┆   ┆ 0584-41d8 ┆           ┆ or styles ┆          │
# │ -97b1-347 ┆           ┆ zipper    ┆           ┆   ┆ -b9f5-4d8 ┆           ┆ of        ┆          │
# │ c43…      ┆           ┆ runs …    ┆           ┆   ┆ 680…      ┆           ┆ clothing… ┆          │
# │ 4225e72e- ┆ Zipper    ┆ Series of ┆ ["Body    ┆ … ┆ bc5f4d70- ┆ Accessori ┆ Notable   ┆ ACTION   │
# │ 2ddc-4e18 ┆           ┆ clothespi ┆ Zipper",  ┆   ┆ c5f3-4cd6 ┆ es        ┆ devices   ┆          │
# │ -945b-6f8 ┆           ┆ ns        ┆ "Clothesp ┆   ┆ -bc60-d44 ┆           ┆ or        ┆          │
# │ 731…      ┆           ┆ attached… ┆ in Zi…    ┆   ┆ 700…      ┆           ┆ materials ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ d…        ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df_stashdb_tags.write_json("H:\\Parquet Data\\StashDB\\stashdb_tags.json")

# %%
# Get tags from Stash
stash_tags = stash.find_tags()
df_stash_tags = pl.DataFrame(stash_tags)
df_stash_tags = df_stash_tags.with_columns(
    pl.col("aliases").map_elements(
        lambda aliases: next(
            (alias[len(stashdb_id_alias_prefix):] for alias in aliases if isinstance(alias, str) and alias.startswith(stashdb_id_alias_prefix)),
            None
        ),
        return_dtype=pl.Utf8
    ).alias("stashdb_id")
)
df_stash_tags
# Out:
# shape: (2_955, 21)
# ┌──────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ id   ┆ name       ┆ descriptio ┆ aliases    ┆ … ┆ children   ┆ parent_co ┆ child_cou ┆ stashdb_i │
# │ ---  ┆ ---        ┆ n          ┆ ---        ┆   ┆ ---        ┆ unt       ┆ nt        ┆ d         │
# │ str  ┆ str        ┆ ---        ┆ list[str]  ┆   ┆ list[struc ┆ ---       ┆ ---       ┆ ---       │
# │      ┆            ┆ str        ┆            ┆   ┆ t[1]]      ┆ i64       ┆ i64       ┆ str       │
# ╞══════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 5045 ┆ 2D         ┆ 3D or VR   ┆ ["2-D",    ┆ … ┆ []         ┆ 1         ┆ 0         ┆ 1257be8b- │
# │      ┆ Available  ┆ scenes     ┆ "2D", …    ┆   ┆            ┆           ┆           ┆ d1ec-4cb1 │
# │      ┆            ┆ that offer ┆ "Two-Dimen ┆   ┆            ┆           ┆           ┆ -bb22-bee │
# │      ┆            ┆ a m…       ┆ sion…      ┆   ┆            ┆           ┆           ┆ b89…      │
# │ 5049 ┆ 3D         ┆ Offered in ┆ ["3-D",    ┆ … ┆ []         ┆ 1         ┆ 0         ┆ 52992c2c- │
# │      ┆ Available  ┆ a format   ┆ "3D", …    ┆   ┆            ┆           ┆           ┆ 4617-4540 │
# │      ┆            ┆ with a     ┆ "Three-Dim ┆   ┆            ┆           ┆           ┆ -8ca4-291 │
# │      ┆            ┆ thr…       ┆ ensi…      ┆   ┆            ┆           ┆           ┆ e9c…      │
# │ 5050 ┆ 3K         ┆ Scenes     ┆ ["1600p",  ┆ … ┆ []         ┆ 1         ┆ 0         ┆ c3794d99- │
# │      ┆ Available  ┆ offered in ┆ "3K VP9",  ┆   ┆            ┆           ┆           ┆ 1b5b-47b3 │
# │      ┆            ┆ a resoluti ┆ …          ┆   ┆            ┆           ┆           ┆ -86f7-75f │
# │      ┆            ┆ on…        ┆ "StashDB…  ┆   ┆            ┆           ┆           ┆ f2d…      │
# │ 5051 ┆ 3rd Person ┆ Features a ┆ ["3rd      ┆ … ┆ []         ┆ 1         ┆ 0         ┆ f562975c- │
# │      ┆ Narrative  ┆ storyline  ┆ Person Per ┆   ┆            ┆           ┆           ┆ e209-464c │
# │      ┆            ┆ with fict… ┆ spective", ┆   ┆            ┆           ┆           ┆ -83ed-8ac │
# │      ┆            ┆            ┆ "St…       ┆   ┆            ┆           ┆           ┆ 18e…      │
# │ 5053 ┆ 4:3 Aspect ┆ Footage    ┆ ["1.33:1", ┆ … ┆ []         ┆ 1         ┆ 0         ┆ 6958c8ed- │
# │      ┆ Ratio      ┆ shot in a  ┆ "1.33:1    ┆   ┆            ┆           ┆           ┆ 1948-46d2 │
# │      ┆            ┆ 4:3        ┆ Aspect     ┆   ┆            ┆           ┆           ┆ -89e0-cb4 │
# │      ┆            ┆ (1.33:1)…  ┆ Rati…      ┆   ┆            ┆           ┆           ┆ 891…      │
# │ …    ┆ …          ┆ …          ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 7559 ┆ Young Man  ┆ Male       ┆ ["StashDB  ┆ … ┆ []         ┆ 1         ┆ 0         ┆ e7f1f848- │
# │      ┆ (22–30)    ┆ presented  ┆ ID: e7f1f8 ┆   ┆            ┆           ┆           ┆ 4350-4bda │
# │      ┆            ┆ as         ┆ 48-4350-4b ┆   ┆            ┆           ┆           ┆ -925c-b01 │
# │      ┆            ┆ generally  ┆ …          ┆   ┆            ┆           ┆           ┆ 235…      │
# │      ┆            ┆ yo…        ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 7560 ┆ Young      ┆ Female     ┆ ["Chick",  ┆ … ┆ []         ┆ 1         ┆ 0         ┆ 84ba8ef1- │
# │      ┆ Woman      ┆ character  ┆ "StashDB   ┆   ┆            ┆           ┆           ┆ 084c-46f8 │
# │      ┆ (22–30)    ┆ presented  ┆ ID:        ┆   ┆            ┆           ┆           ┆ -b352-311 │
# │      ┆            ┆ as …       ┆ 84ba8ef…   ┆   ┆            ┆           ┆           ┆ 54f…      │
# │ 7563 ┆ Zentai     ┆ Skin-tight ┆ ["StashDB  ┆ … ┆ []         ┆ 1         ┆ 0         ┆ 6c0a2824- │
# │      ┆            ┆ garment    ┆ ID: 6c0a28 ┆   ┆            ┆           ┆           ┆ acd2-4b64 │
# │      ┆            ┆ that       ┆ 24-acd2-4b ┆   ┆            ┆           ┆           ┆ -9a2c-634 │
# │      ┆            ┆ covers…    ┆ …          ┆   ┆            ┆           ┆           ┆ bd9…      │
# │ 7564 ┆ Zip Front  ┆ A dress    ┆ ["StashDB  ┆ … ┆ []         ┆ 1         ┆ 0         ┆ bed78871- │
# │      ┆ Dress      ┆ where the  ┆ ID: bed788 ┆   ┆            ┆           ┆           ┆ 9bb8-40c2 │
# │      ┆            ┆ zipper     ┆ 71-9bb8-40 ┆   ┆            ┆           ┆           ┆ -97b1-347 │
# │      ┆            ┆ runs …     ┆ …          ┆   ┆            ┆           ┆           ┆ c43…      │
# │ 7565 ┆ Zipper     ┆ Series of  ┆ ["Body     ┆ … ┆ []         ┆ 1         ┆ 0         ┆ 4225e72e- │
# │      ┆            ┆ clothespin ┆ Zipper",   ┆   ┆            ┆           ┆           ┆ 2ddc-4e18 │
# │      ┆            ┆ s          ┆ "Clothespi ┆   ┆            ┆           ┆           ┆ -945b-6f8 │
# │      ┆            ┆ attached…  ┆ n Zi…      ┆   ┆            ┆           ┆           ┆ 731…      │
# └──────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
# Merge df_stashdb_tags and df_stash_tags based on the 'name' column
merged_df = df_stashdb_tags.join(df_stash_tags, left_on='id', right_on='stashdb_id', how='full', suffix='_stash')

# Identify matching and non-matching tags
matching_tags = merged_df.filter(pl.col('id').is_not_null() & pl.col('id_stash').is_not_null())
stashdb_only_tags = merged_df.filter(pl.col('id_stash').is_null())
stash_only_tags = merged_df.filter(pl.col('id').is_null())

# Display results
print(f"Total matching tags: {len(matching_tags)}")
print(f"Tags only in StashDB: {len(stashdb_only_tags)}")
print(f"Tags only in Stash: {len(stash_only_tags)}")

merged_df
# Out:
# Total matching tags: 2557
# Tags only in StashDB: 199
# Tags only in Stash: 398
# shape: (3_154, 32)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ descripti ┆ aliases   ┆ … ┆ children  ┆ parent_co ┆ child_cou ┆ stashdb_ │
# │ ---       ┆ ---       ┆ on        ┆ ---       ┆   ┆ ---       ┆ unt       ┆ nt        ┆ id       │
# │ str       ┆ str       ┆ ---       ┆ list[str] ┆   ┆ list[stru ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ str       ┆           ┆   ┆ ct[1]]    ┆ i64       ┆ i64       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1257be8b- ┆ 2D        ┆ 3D or VR  ┆ ["2-D",   ┆ … ┆ []        ┆ 1         ┆ 0         ┆ 1257be8b │
# │ d1ec-4cb1 ┆ Available ┆ scenes    ┆ "2D", …   ┆   ┆           ┆           ┆           ┆ -d1ec-4c │
# │ -bb22-bee ┆           ┆ that      ┆ "Two-Dime ┆   ┆           ┆           ┆           ┆ b1-bb22- │
# │ b89…      ┆           ┆ offer a   ┆ nsion…    ┆   ┆           ┆           ┆           ┆ beeb89…  │
# │           ┆           ┆ m…        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 52992c2c- ┆ 3D        ┆ Offered   ┆ ["3-D",   ┆ … ┆ []        ┆ 1         ┆ 0         ┆ 52992c2c │
# │ 4617-4540 ┆ Available ┆ in a      ┆ "3D", …   ┆   ┆           ┆           ┆           ┆ -4617-45 │
# │ -8ca4-291 ┆           ┆ format    ┆ "Three-Di ┆   ┆           ┆           ┆           ┆ 40-8ca4- │
# │ e9c…      ┆           ┆ with a    ┆ mensi…    ┆   ┆           ┆           ┆           ┆ 291e9c…  │
# │           ┆           ┆ thr…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ c3794d99- ┆ 3K        ┆ Scenes    ┆ ["1600p", ┆ … ┆ []        ┆ 1         ┆ 0         ┆ c3794d99 │
# │ 1b5b-47b3 ┆ Available ┆ offered   ┆ "3K VP9", ┆   ┆           ┆           ┆           ┆ -1b5b-47 │
# │ -86f7-75f ┆           ┆ in a reso ┆ … "3KVR"] ┆   ┆           ┆           ┆           ┆ b3-86f7- │
# │ f2d…      ┆           ┆ lution…   ┆           ┆   ┆           ┆           ┆           ┆ 75ff2d…  │
# │ f562975c- ┆ 3rd       ┆ Features  ┆ ["3rd     ┆ … ┆ []        ┆ 1         ┆ 0         ┆ f562975c │
# │ e209-464c ┆ Person    ┆ a         ┆ Person    ┆   ┆           ┆           ┆           ┆ -e209-46 │
# │ -83ed-8ac ┆ Narrative ┆ storyline ┆ Perspecti ┆   ┆           ┆           ┆           ┆ 4c-83ed- │
# │ 18e…      ┆           ┆ with      ┆ ve", "Th… ┆   ┆           ┆           ┆           ┆ 8ac18e…  │
# │           ┆           ┆ fict…     ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 6958c8ed- ┆ 4:3       ┆ Footage   ┆ ["1.33:1" ┆ … ┆ []        ┆ 1         ┆ 0         ┆ 6958c8ed │
# │ 1948-46d2 ┆ Aspect    ┆ shot in a ┆ , "1.33:1 ┆   ┆           ┆           ┆           ┆ -1948-46 │
# │ -89e0-cb4 ┆ Ratio     ┆ 4:3       ┆ Aspect    ┆   ┆           ┆           ┆           ┆ d2-89e0- │
# │ 891…      ┆           ┆ (1.33:1)… ┆ Rati…     ┆   ┆           ┆           ┆           ┆ cb4891…  │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 283d982a- ┆ Blowjob   ┆ A visual  ┆ []        ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 2399-46f3 ┆ Sandwich  ┆ "sandwich ┆           ┆   ┆           ┆           ┆           ┆          │
# │ -a540-370 ┆           ┆ " effect  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 7c7…      ┆           ┆ dur…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2d951585- ┆ Cum       ┆ Performin ┆ ["Cum     ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ eb5a-48e3 ┆ Covered   ┆ g oral    ┆ Covered   ┆   ┆           ┆           ┆           ┆          │
# │ -b633-ee8 ┆ Blowjob   ┆ sex to a  ┆ Sucking", ┆   ┆           ┆           ┆           ┆          │
# │ 1f9…      ┆           ┆ third…    ┆ "Cum-C…   ┆   ┆           ┆           ┆           ┆          │
# │ a83eba6d- ┆ Train (Pe ┆ Group sex ┆ ["Anal    ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ ec4e-4692 ┆ netration ┆ act where ┆ Train",   ┆   ┆           ┆           ┆           ┆          │
# │ -b648-406 ┆ Chain)    ┆ one       ┆ "Lucky    ┆   ┆           ┆           ┆           ┆          │
# │ 0d6…      ┆           ┆ perfor…   ┆ Pierre",… ┆   ┆           ┆           ┆           ┆          │
# │ 59e97272- ┆ African   ┆ Speaks    ┆ ["Accent  ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 623d-4e14 ┆ Accent    ┆ with an   ┆ (African) ┆   ┆           ┆           ┆           ┆          │
# │ -8b33-36d ┆           ┆ accent    ┆ "]        ┆   ┆           ┆           ┆           ┆          │
# │ e55…      ┆           ┆ native t… ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0c852929- ┆ AI Model  ┆ Performer ┆ ["AI Perf ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 6335-464e ┆           ┆ created   ┆ ormer",   ┆   ┆           ┆           ┆           ┆          │
# │ -bf35-7ad ┆           ┆ by AI or  ┆ "Deepfake ┆   ┆           ┆           ┆           ┆          │
# │ 699…      ┆           ┆ dee…      ┆ "]        ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
my_very_own_tags_parent_tag = stash.find_tag({ "name": "My Very Own Tags" })

df_stash_only_tags = df_stash_tags.filter(
    pl.col("id").is_in(stash_only_tags.select("id_stash").unique())
).filter(
    # Check if the tag doesn't have "My Very Own Tags" as parent
    pl.col("parents").map_elements(
        lambda parents: not any(parent.get('id') == my_very_own_tags_parent_tag['id'] for parent in parents),
        return_dtype=pl.Boolean
    )
).filter(
    ~pl.col("name").str.starts_with("Category:") & 
    ~pl.col("name").str.starts_with("Category Group:") & 
    ~pl.col("name").str.starts_with("AI_") & 
    ~pl.col("name").str.ends_with("_AI") &
    ~pl.col("name").str.starts_with("Data Quality Issue") & 
    ~pl.col("name").str.starts_with("Duplicate") & 
    ~pl.col("name").str.starts_with("Galleries") & 
    ~pl.col("name").str.starts_with("Group Makeup")
).select("id", "name", "aliases")
df_stash_only_tags
# Out:
# shape: (246, 3)
# ┌──────┬─────────────────────┬─────────────────────────────────┐
# │ id   ┆ name                ┆ aliases                         │
# │ ---  ┆ ---                 ┆ ---                             │
# │ str  ┆ str                 ┆ list[str]                       │
# ╞══════╪═════════════════════╪═════════════════════════════════╡
# │ 7994 ┆ 12K Available       ┆ ["12K", "12K Shemale VR Porn",… │
# │ 7995 ┆ Abandonment Play    ┆ []                              │
# │ 7996 ┆ Aerial Cowgirl      ┆ ["Keiran's Cowboy"]             │
# │ 7997 ┆ African Accent      ┆ ["Accent (African)"]            │
# │ 7998 ┆ Against Glass       ┆ ["Against Window", "Against th… │
# │ …    ┆ …                   ┆ …                               │
# │ 7967 ┆ Verified: Locations ┆ []                              │
# │ 8188 ┆ Virgin (Roleplay)   ┆ []                              │
# │ 8189 ┆ Visible Marks       ┆ []                              │
# │ 7666 ┆ Wet (Genitals)      ┆ []                              │
# │ 8190 ┆ White Top           ┆ []                              │
# └──────┴─────────────────────┴─────────────────────────────────┘

# %% [markdown]
# # Create category groups

# %%
# Get all unique category groups from StashDB tags
category_groups = df_stashdb_tags.select('category_group').drop_nulls().unique().to_series().to_list()

# Display the category groups
print("Unique category groups in StashDB:")
for group in sorted(category_groups):
    print(f"- {group}")
    tag_name = f"Category Group: {group}"
    existing_tag = stash.find_tag(tag_name)
    if existing_tag is None:
        stash.create_tag({
            "name": tag_name,
            "description": f"StashDB category group: {group}",
        })
        print(f"Created tag: {tag_name}")
    else:
        print(f"Tag already exists: {tag_name}")
# Out:
# Unique category groups in StashDB:
# - ACTION
# Tag already exists: Category Group: ACTION
# - PEOPLE
# Tag already exists: Category Group: PEOPLE
# - SCENE
# Tag already exists: Category Group: SCENE

# %% [markdown]
# # Create categories

# %%
# Get all unique categories from StashDB tags
unique_categories = df_stashdb_tags.select(['category_id', 'category_name', 'category_group', 'category_description']).drop_nulls().unique()

# Display the unique categories
print("Unique categories in StashDB:")
for category in unique_categories.iter_rows(named=True):
    print(f"- Name: {category['category_name'] or 'N/A'}")
    print(f"  ID: {category['category_id']}")
    print(f"  Group: {category['category_group'] or 'N/A'}")
    print(f"  Description: {category['category_description'] or 'N/A'}")
    print()

# Create tags for each unique category in Stash
for category in unique_categories.iter_rows(named=True):
    name = category['category_name']
    group = category['category_group']
    description = category['category_description']
    
    category_tag = stash.find_tag(f"Category: {name}")
    if category_tag is None:
        category_group_tag = stash.find_tag(f"Category Group: {group}")
        
        category_tag = stash.create_tag({
            "name": f"Category: {name}",
            "description": f"StashDB category: {name}",
            "parent_ids": [category_group_tag['id']] if category_group_tag else None,
        })
        print(f"Created category tag: {name}")
    else:
        aliases = ["StashDB ID: " + category['category_id']]
        stash.update_tag({ "id": category_tag['id'], "aliases": aliases })
        print(f"Updated category tag: {name}")
# Out:
# Unique categories in StashDB:
# - Name: Misc
#   ID: 7f4ddc1b-8169-4d5b-b764-04ad074c84a8
#   Group: SCENE
#   Description: Information about the video itself rather than its content, or various descriptors that do not fit other tag categories.
#
# - Name: Breasts
#   ID: be3adc0c-a3fe-40bf-98a7-5eacd9fb89fe
#   Group: PEOPLE
#   Description: Various descriptions of a performer's breasts or nipples, often regarding size.
#
# - Name: Group Makeup
#   ID: c456b6a1-75c4-41d1-8d87-08d7e062c7d8
#   Group: SCENE
#   Description: Number of scene partners and often their genders.
#
# - Name: Height
#   ID: 5c08369e-bbd9-4ea4-8c9f-081412408cd8
#   Group: PEOPLE
#   Description: Defined ranges of a performer's height, separated by gender.
#
# - Name: Hair Style
#   ID: ab179fb8-aa2f-4c75-86cf-0166dd8d8136
#   Group: PEOPLE
#   Description: Various descriptions of hair styles, cuts, textures, and lengths.
#
# - Name: Locations
#   ID: 33e17fdb-57df-42da-af42-42acad2245c6
#   Group: SCENE
#   Description: Where the action takes place.
#
# - Name: Tattoos
#   ID: f7f6bb51-51c3-48c6-b890-eb10a6e09bcf
#   Group: PEOPLE
#   Description: Various types of permanent tattoos.
#
# - Name: Clothing
#   ID: dc566ccc-0584-41d8-b9f5-4d8680b890c1
#   Group: PEOPLE
#   Description: Articles or styles of clothing worn by a performer that is featured in the scene.
#
# - Name: Acts
#   ID: feca7511-ac91-42c0-a032-8fb8f34350bc
#   Group: ACTION
#   Description: Various sexual acts or positions, excluding typical "finishers".
#
# - Name: Surfaces
#   ID: 3925214e-c2ec-4296-a0f5-1db061e83ba2
#   Group: SCENE
#   Description: What the action takes place on top of, often furniture of some kind.
#
# - Name: Orientation
#   ID: 617eb8cc-842f-4368-80d2-8584c0cc6618
#   Group: SCENE
#   Description: Broad categories of sex/gender combinations, often aligning more closely to traditional marketing terms than real-world sexual orientations.
#
# - Name: Finishers
#   ID: 939c769b-7c41-4a04-983e-5a30a8c949ea
#   Group: ACTION
#   Description: Acts that typically end a scene, often involving ejaculation or orgasm.
#
# - Name: Skin Tone
#   ID: 6d007228-58b9-44ac-9bf8-0a0e8a049241
#   Group: PEOPLE
#   Description: Various skin tones, colorations, or other notable features.
#
# - Name: Ass
#   ID: 90db3f8b-12ad-42c7-9fa5-a45d75cb1f66
#   Group: PEOPLE
#   Description: Various descriptions of a performer's backside, often regarding size.
#
# - Name: Age Group
#   ID: b40e08dd-314e-40ca-8fdb-bf7541b3e30f
#   Group: PEOPLE
#   Description: Implied age ranges for characters, not performers.
#
# - Name: Relations
#   ID: d4541992-1837-4233-be8c-6a0ad657d6c8
#   Group: SCENE
#   Description: How characters know each other, including casual, romantic, professional, and familial relationships.
#
# - Name: Piercings
#   ID: 8095fe3e-371f-4c2e-b1b6-b801ab330402
#   Group: PEOPLE
#   Description: Various types of body piercings.
#
# - Name: Hair Color
#   ID: fdc60263-77f6-4a7f-bb79-1f5e85abe9ca
#   Group: PEOPLE
#   Description: Hair colors for featured performers, including wigs and dyes.
#
# - Name: Moods
#   ID: 0a3acb7c-5e7e-4954-9e23-a966a7bc23b1
#   Group: SCENE
#   Description: A character's emotions, a performer's style, or the overall tone of the scene.
#
# - Name: Accessories
#   ID: bc5f4d70-c5f3-4cd6-bc60-d44700f005a6
#   Group: ACTION
#   Description: Notable devices or materials directly involved in the action.
#
# - Name: Roles
#   ID: c423ad76-53f3-45a2-a865-87ee1904f315
#   Group: SCENE
#   Description: Common character archetypes or personalities.
#
# - Name: Motivations
#   ID: 9f14a75e-5482-4d11-9796-d8836cc9c1fa
#   Group: SCENE
#   Description: What motivates the characters into starting the action.
#
# - Name: Genitals
#   ID: 9bd1d55e-d7c4-4b7c-a66f-96ec52b7af08
#   Group: PEOPLE
#   Description: Various descriptions of a performer's genitals or pubic hair, often regarding size.
#
# - Name: Face
#   ID: ce09c0f1-06e3-4f13-a5f6-7c5f93d85af9
#   Group: PEOPLE
#   Description: Various descriptions of a performer's facial features.
#
# - Name: Themes
#   ID: 0319d5d6-a07f-4e0d-809d-c09fb132691b
#   Group: SCENE
#   Description: Events, contexts, or fetishes often featured in scenes.
#
# - Name: Body Type
#   ID: 20c82f8a-4f2b-412a-8047-934eeb6c32e7
#   Group: PEOPLE
#   Description: Various descriptions of body fat, body shape, body hair, or muscle tone.
#
# - Name: Shot Type
#   ID: ef4ae6d1-d13c-4195-b47e-f245e49051a6
#   Group: SCENE
#   Description: Technical details of how a video is filmed or edited.
#
# - Name: Race
#   ID: 95be690d-36f9-42dc-bf15-248136e40e18
#   Group: PEOPLE
#   Description: Broad categories for a performer's racial background.
#
# Updated category tag: Misc
# Updated category tag: Breasts
# Updated category tag: Group Makeup
# Updated category tag: Height
# Updated category tag: Hair Style
# Updated category tag: Locations
# Updated category tag: Tattoos
# Updated category tag: Clothing
# Updated category tag: Acts
# Updated category tag: Surfaces
# Updated category tag: Orientation
# Updated category tag: Finishers
# Updated category tag: Skin Tone
# Updated category tag: Ass
# Updated category tag: Age Group
# Updated category tag: Relations
# Updated category tag: Piercings
# Updated category tag: Hair Color
# Updated category tag: Moods
# Updated category tag: Accessories
# Updated category tag: Roles
# Updated category tag: Motivations
# Updated category tag: Genitals
# Updated category tag: Face
# Updated category tag: Themes
# Updated category tag: Body Type
# Updated category tag: Shot Type
# Updated category tag: Race

# %% [markdown]
# # Update descriptions

# %%
# Create records of tags that need updates
description_update_records = []

for row in df_stash_tags.iter_rows(named=True):
    stash_tag_name = row['name']
    stashdb_tag = df_stashdb_tags.filter(pl.col('name') == stash_tag_name)
    
    if not stashdb_tag.is_empty():
        stashdb_tag = stashdb_tag.to_dicts()[0]
        
        # Check if description needs updating
        if stashdb_tag['description'] != row['description']:
            description_update_records.append({
                'tag_id': row['id'],
                'name': stash_tag_name,
                'field': 'description',
                'current_value': row['description'] or '',  # Handle None values
                'proposed_value': stashdb_tag['description'] or '',
            })
        
df_description_updates = pl.DataFrame(description_update_records).sort(['name', 'field']).filter(pl.col('current_value') != pl.col('proposed_value'))
df_description_updates
# Out:
# shape: (8, 5)
# ┌────────┬────────────────────────┬─────────────┬─────────────────────────┬────────────────────────┐
# │ tag_id ┆ name                   ┆ field       ┆ current_value           ┆ proposed_value         │
# │ ---    ┆ ---                    ┆ ---         ┆ ---                     ┆ ---                    │
# │ str    ┆ str                    ┆ str         ┆ str                     ┆ str                    │
# ╞════════╪════════════════════════╪═════════════╪═════════════════════════╪════════════════════════╡
# │ 5161   ┆ Asian on White         ┆ description ┆                         ┆ White women having sex │
# │        ┆                        ┆             ┆                         ┆ with As…               │
# │ 5776   ┆ English Language       ┆ description ┆                         ┆ Scene shows            │
# │        ┆                        ┆             ┆                         ┆ performer(s) speak…    │
# │ 6154   ┆ Hitchhiker             ┆ description ┆                         ┆ Character asking       │
# │        ┆                        ┆             ┆                         ┆ strangers for…         │
# │ 6581   ┆ No Underwear           ┆ description ┆ A performer going       ┆ A performer going      │
# │        ┆                        ┆             ┆ without thei…           ┆ without thei…          │
# │ 7993   ┆ Standing Sex (DP)      ┆ description ┆                         ┆ A female performer     │
# │        ┆                        ┆             ┆                         ┆ having vagi…           │
# │ 7380   ┆ Train (Rail Transport) ┆ description ┆ At least some of the    ┆ Some of the action     │
# │        ┆                        ┆             ┆ action ta…              ┆ takes place…           │
# │ 7446   ┆ Unshaven               ┆ description ┆                         ┆ Performers with hair   │
# │        ┆                        ┆             ┆                         ┆ on their …             │
# │ 7562   ┆ Violet Wand            ┆ description ┆                         ┆ Wand or rod designed   │
# │        ┆                        ┆             ┆                         ┆ to delive…             │
# └────────┴────────────────────────┴─────────────┴─────────────────────────┴────────────────────────┘

# %%
for row in df_description_updates.iter_rows(named=True):
    print(row['name'])
    print(row['current_value'])
    print(row['proposed_value'])
    print()

    update_data = {
        "id": row['tag_id'],
        "description": row['proposed_value']
    }
    try:
        stash.update_tag(update_data)
        print(f"Updated tag: {row['name']}")
    except Exception as e:
        print(f"Error updating tag {row['name']}: {e}")
# Out:
# Asian on White
#
# White women having sex with Asian Male(s)
#
# Updated tag: Asian on White
# English Language
#
# Scene shows performer(s) speaking English.
#
# Updated tag: English Language
# Hitchhiker
#
# Character asking strangers for a ride in their car
#
# Updated tag: Hitchhiker
# No Underwear
# A performer going without their underwear, i.e without their panties.
# A performer going without their underwear, i.e without their underpants or panties.
#
# Updated tag: No Underwear
# Standing Sex (DP)
#
# A female performer having vaginal and anal penetrative sex simultaneously while standing up
#
# Updated tag: Standing Sex (DP)
# Train (Rail Transport)
# At least some of the action takes place on a train or light rail vehicle.
# Some of the action takes place on a train or light rail vehicle.
#
# Updated tag: Train (Rail Transport)
# Unshaven
#
# Performers with hair on their genitals.
#
# Updated tag: Unshaven
# Violet Wand
#
# Wand or rod designed to deliver a focused electrical stimulation to a performer.
#
# Updated tag: Violet Wand

# %% [markdown]
# # Update aliases

# %%
# Create records of tags that need updates
alias_update_records = []

for row in df_stash_tags.iter_rows(named=True):
    stash_tag_name = row['name']
    stashdb_tag = df_stashdb_tags.filter(pl.col('name') == stash_tag_name)
    
    if not stashdb_tag.is_empty():
        stashdb_tag = stashdb_tag.to_dicts()[0]
        
        # Get current aliases and separate StashDB ID aliases
        current_aliases = set(row['aliases']) if row['aliases'] else set()
        current_stashdb_ids = {alias for alias in current_aliases 
                             if alias.startswith(stashdb_id_alias_prefix)}
        current_regular_aliases = current_aliases - current_stashdb_ids
        
        # Get proposed aliases from StashDB, excluding CJK
        proposed_aliases = {alias for alias in (stashdb_tag['aliases'] or []) 
                          if not contains_cjk(alias)}
        
        # Check if regular aliases need updating
        if current_regular_aliases != proposed_aliases:
            # Keep exactly one StashDB ID alias if it exists
            final_stashdb_id = next(iter(current_stashdb_ids)) if current_stashdb_ids else None
            
            # Combine proposed aliases with StashDB ID
            final_aliases = proposed_aliases
            if final_stashdb_id:
                final_aliases.add(final_stashdb_id)
            
            # Calculate differences for display
            to_add = proposed_aliases - current_regular_aliases
            to_remove = current_regular_aliases - proposed_aliases
            
            # Only proceed if there are changes
            if to_add or to_remove:
                # Format difference string
                diff_parts = []
                if to_add:
                    diff_parts.append(f"+ {', '.join(sorted(to_add))}")
                if to_remove:
                    diff_parts.append(f"- {', '.join(sorted(to_remove))}")
                
                alias_update_records.append({
                    'tag_id': row['id'],
                    'name': stash_tag_name,
                    'current_aliases': ', '.join(sorted(current_aliases)),
                    'proposed_aliases': ', '.join(sorted(final_aliases)),
                    'differences': ' | '.join(diff_parts),
                    'current_list': sorted(current_aliases),
                    'proposed_list': sorted(final_aliases)
                })

# Create DataFrame and sort by name
df_alias_updates = pl.DataFrame(alias_update_records).sort('name')

# Print summary
print(f"Found {len(df_alias_updates)} tags with non-CJK alias updates")
print("\nSample of proposed updates:")
print(df_alias_updates.select(['name', 'current_aliases', 'proposed_aliases', 'differences']).head())

df_alias_updates
# Out:
# Found 17 tags with non-CJK alias updates
#
# Sample of proposed updates:
# shape: (5, 4)
# ┌─────────────────────┬─────────────────────────┬─────────────────────────┬────────────────────────┐
# │ name                ┆ current_aliases         ┆ proposed_aliases        ┆ differences            │
# │ ---                 ┆ ---                     ┆ ---                     ┆ ---                    │
# │ str                 ┆ str                     ┆ str                     ┆ str                    │
# ╞═════════════════════╪═════════════════════════╪═════════════════════════╪════════════════════════╡
# │ Asian on White      ┆ StashDB ID:             ┆ AMWF, Asian Male White  ┆ + AMWF, Asian Male     │
# │                     ┆ ca8f709f-14b2-4ba4…     ┆ Woman, …                ┆ White Woman…           │
# │ Close Up Missionary ┆ Intimate Missionary,    ┆ Closeup Missionary,     ┆ + Closeup Missionary,  │
# │                     ┆ StashDB I…              ┆ Intimate M…             ┆ StashDB …              │
# │ Dry Humping         ┆ Genital Rubbing,        ┆ Cock Rubbing Pussy,     ┆ + Cock Rubbing Pussy,  │
# │                     ┆ Outercourse, …          ┆ Genital Ru…             ┆ StashDB …              │
# │ English Language    ┆ StashDB ID:             ┆ English, English        ┆ + English, English     │
# │                     ┆ 2262dfb9-fc07-4930…     ┆ Speaking, Eng…          ┆ Speaking, E…           │
# │ Headband            ┆ StashDB ID:             ┆ Alice Band, Hair Band,  ┆ + Alice Band, Hair     │
# │                     ┆ bd857ec2-5993-43eb…     ┆ Head Ba…                ┆ Band, Head …           │
# └─────────────────────┴─────────────────────────┴─────────────────────────┴────────────────────────┘
# shape: (17, 7)
# ┌────────┬──────────────┬──────────────┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ tag_id ┆ name         ┆ current_alia ┆ proposed_ali ┆ differences  ┆ current_list ┆ proposed_lis │
# │ ---    ┆ ---          ┆ ses          ┆ ases         ┆ ---          ┆ ---          ┆ t            │
# │ str    ┆ str          ┆ ---          ┆ ---          ┆ str          ┆ list[str]    ┆ ---          │
# │        ┆              ┆ str          ┆ str          ┆              ┆              ┆ list[str]    │
# ╞════════╪══════════════╪══════════════╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ 5161   ┆ Asian on     ┆ StashDB ID:  ┆ AMWF, Asian  ┆ + AMWF,      ┆ ["StashDB    ┆ ["AMWF",     │
# │        ┆ White        ┆ ca8f709f-14b ┆ Male White   ┆ Asian Male   ┆ ID: ca8f709f ┆ "Asian Male  │
# │        ┆              ┆ 2-4ba4…      ┆ Woman, …     ┆ White Woman… ┆ -14b2-4b…    ┆ White Wom…   │
# │ 5491   ┆ Close Up     ┆ Intimate     ┆ Closeup      ┆ + Closeup    ┆ ["Intimate   ┆ ["Closeup    │
# │        ┆ Missionary   ┆ Missionary,  ┆ Missionary,  ┆ Missionary,  ┆ Missionary", ┆ Missionary", │
# │        ┆              ┆ StashDB I…   ┆ Intimate M…  ┆ StashDB …    ┆ "Stash…      ┆ "Intima…     │
# │ 5741   ┆ Dry Humping  ┆ Genital      ┆ Cock Rubbing ┆ + Cock       ┆ ["Genital    ┆ ["Cock       │
# │        ┆              ┆ Rubbing,     ┆ Pussy,       ┆ Rubbing      ┆ Rubbing",    ┆ Rubbing      │
# │        ┆              ┆ Outercourse, ┆ Genital Ru…  ┆ Pussy,       ┆ "Outercour…  ┆ Pussy",      │
# │        ┆              ┆ …            ┆              ┆ StashDB …    ┆              ┆ "Genita…     │
# │ 5776   ┆ English      ┆ StashDB ID:  ┆ English,     ┆ + English,   ┆ ["StashDB    ┆ ["English",  │
# │        ┆ Language     ┆ 2262dfb9-fc0 ┆ English      ┆ English      ┆ ID: 2262dfb9 ┆ "English     │
# │        ┆              ┆ 7-4930…      ┆ Speaking,    ┆ Speaking, E… ┆ -fc07-49…    ┆ Speaking"…   │
# │        ┆              ┆              ┆ Eng…         ┆              ┆              ┆              │
# │ 6130   ┆ Headband     ┆ StashDB ID:  ┆ Alice Band,  ┆ + Alice      ┆ ["StashDB    ┆ ["Alice      │
# │        ┆              ┆ bd857ec2-599 ┆ Hair Band,   ┆ Band, Hair   ┆ ID: bd857ec2 ┆ Band", "Hair │
# │        ┆              ┆ 3-43eb…      ┆ Head Ba…     ┆ Band, Head … ┆ -5993-43…    ┆ Band", … …   │
# │ …      ┆ …            ┆ …            ┆ …            ┆ …            ┆ …            ┆ …            │
# │ 7047   ┆ Sideboob     ┆ StashDB ID:  ┆ Side Boob,   ┆ + Side Boob, ┆ ["StashDB    ┆ ["Side       │
# │        ┆              ┆ 0bfc3c9a-3e6 ┆ Side-Boob,   ┆ Side-Boob,   ┆ ID: 0bfc3c9a ┆ Boob",       │
# │        ┆              ┆ 9-4c46…      ┆ StashDB …    ┆ StashD…      ┆ -3e69-4c…    ┆ "Side-Boob", │
# │        ┆              ┆              ┆              ┆              ┆              ┆ "St…         │
# │ 7993   ┆ Standing Sex ┆ StashDB ID:  ┆ DP -         ┆ + DP -       ┆ ["StashDB    ┆ ["DP -       │
# │        ┆ (DP)         ┆ 01eb4084-62a ┆ Standing,    ┆ Standing,    ┆ ID: 01eb4084 ┆ Standing",   │
# │        ┆              ┆ c-498c…      ┆ Standing     ┆ Standing     ┆ -62ac-49…    ┆ "Standing    │
# │        ┆              ┆              ┆ (DP), …      ┆ (DP)…        ┆              ┆ (D…          │
# │ 6620   ┆ Train (Oral  ┆ Daisychain,  ┆ Daisy Chain, ┆ + Daisy      ┆ ["Daisychain ┆ ["Daisy      │
# │        ┆ Sex)         ┆ StashDB ID:  ┆ Daisychain,  ┆ Chain, Oral  ┆ ", "StashDB  ┆ Chain", "Dai │
# │        ┆              ┆ 6ed47d…      ┆ Oral …       ┆ Train, Sta…  ┆ ID: 6e…      ┆ sychain", …  │
# │ 7446   ┆ Unshaven     ┆ StashDB ID:  ┆ StashDB ID:  ┆ + StashDB    ┆ ["StashDB    ┆ ["StashDB    │
# │        ┆              ┆ bfdaae00-8cb ┆ bfdaae00-8cb ┆ ID: bfdaae00 ┆ ID: bfdaae00 ┆ ID: bfdaae00 │
# │        ┆              ┆ f-4843…      ┆ f-4843…      ┆ -8cbf-48…    ┆ -8cbf-48…    ┆ -8cbf-48…    │
# │ 7562   ┆ Violet Wand  ┆ StashDB ID:  ┆ Electro      ┆ + Electro    ┆ ["StashDB    ┆ ["Electro    │
# │        ┆              ┆ 1649e0e9-7d4 ┆ Wand,        ┆ Wand,        ┆ ID: 1649e0e9 ┆ Wand",       │
# │        ┆              ┆ 1-4c87…      ┆ StashDB ID:  ┆ StashDB ID:  ┆ -7d41-4c…    ┆ "StashDB ID: │
# │        ┆              ┆              ┆ 1649…        ┆ 16…          ┆              ┆ …            │
# └────────┴──────────────┴──────────────┴──────────────┴──────────────┴──────────────┴──────────────┘

# %%
for row in df_alias_updates.iter_rows(named=True):
    update_data = {
        "id": row['tag_id'],
        "aliases": row['proposed_list']
    }
    try:
        stash.update_tag(update_data)
        print(f"Updated tag: {row['name']}")
    except Exception as e:
        print(f"Error updating tag {row['name']}: {e}")
# Out:
# Updated tag: Asian on White
# Updated tag: Close Up Missionary
# Updated tag: Dry Humping
# Updated tag: English Language
# Updated tag: Headband
# Updated tag: Hitchhiker
# Updated tag: Kissing - POV
# Updated tag: Legs Up Missionary
# Updated tag: Missionary
# Updated tag: Mixed - POV
# Updated tag: No Underwear
# Updated tag: Pussy Rubbing
# Updated tag: Sideboob
# Updated tag: Standing Sex (DP)
# Updated tag: Train (Oral Sex)
# Updated tag: Unshaven
# Updated tag: Violet Wand

# %% [markdown]
# # Clean out the CJK aliases from existing tags

# %%
# First add a column with cleaned aliases
df_stash_tags = df_stash_tags.with_columns(
    pl.col('aliases').map_elements(lambda x: [alias for alias in x if not contains_cjk(alias)], return_dtype=pl.List(pl.Utf8)).alias('cleaned_aliases')
)

# Find tags where current aliases differ from cleaned aliases
tags_to_update = df_stash_tags.filter(pl.col('aliases') != pl.col('cleaned_aliases'))

print(f"Found {len(tags_to_update)} tags with CJK aliases to remove")
print("\nSample of changes to make:")
print(tags_to_update.select([
    'name',
    'aliases',
    'cleaned_aliases'
]).head())

# Optional: Apply the updates
def apply_alias_cleanup(tags_df):
    for row in tags_df.iter_rows(named=True):
        update_data = {
            'id': row['id'],
            'aliases': row['cleaned_aliases']
        }
        
        try:
            stash.update_tag(update_data)
            print(f"Updated aliases for {row['name']}")
        except Exception as e:
            print(f"Error updating {row['name']}: {e}")

# Uncomment to apply the updates:
apply_alias_cleanup(tags_to_update)

tags_to_update_for_review = tags_to_update.select(['name', 'aliases', 'cleaned_aliases'])
tags_to_update_for_review
# Out:
# Found 0 tags with CJK aliases to remove
#
# Sample of changes to make:
# shape: (0, 3)
# ┌──────┬───────────┬─────────────────┐
# │ name ┆ aliases   ┆ cleaned_aliases │
# │ ---  ┆ ---       ┆ ---             │
# │ str  ┆ list[str] ┆ list[str]       │
# ╞══════╪═══════════╪═════════════════╡
# └──────┴───────────┴─────────────────┘
# shape: (0, 3)
# ┌──────┬───────────┬─────────────────┐
# │ name ┆ aliases   ┆ cleaned_aliases │
# │ ---  ┆ ---       ┆ ---             │
# │ str  ┆ list[str] ┆ list[str]       │
# ╞══════╪═══════════╪═════════════════╡
# └──────┴───────────┴─────────────────┘

# %% [markdown]
# # Create new tags

# %%
stashdb_only_tags = df_stashdb_tags.filter(~pl.col('id').is_in(df_stash_tags.select('stashdb_id').to_series()))
stashdb_only_tags
# Out:
# shape: (199, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ descripti ┆ aliases   ┆ … ┆ category_ ┆ category_ ┆ category_ ┆ category │
# │ ---       ┆ ---       ┆ on        ┆ ---       ┆   ┆ id        ┆ name      ┆ descripti ┆ _group   │
# │ str       ┆ str       ┆ ---       ┆ list[str] ┆   ┆ ---       ┆ ---       ┆ on        ┆ ---      │
# │           ┆           ┆ str       ┆           ┆   ┆ str       ┆ str       ┆ ---       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 42d9e5c4- ┆ 12K       ┆ Scenes    ┆ ["12K",   ┆ … ┆ 7f4ddc1b- ┆ Misc      ┆ Informati ┆ SCENE    │
# │ 1a1d-4c93 ┆ Available ┆ offered   ┆ "12K      ┆   ┆ 8169-4d5b ┆           ┆ on about  ┆          │
# │ -bf47-908 ┆           ┆ in a reso ┆ Shemale   ┆   ┆ -b764-04a ┆           ┆ the video ┆          │
# │ 6f2…      ┆           ┆ lution…   ┆ VR        ┆   ┆ d07…      ┆           ┆ it…       ┆          │
# │           ┆           ┆           ┆ Porn",…   ┆   ┆           ┆           ┆           ┆          │
# │ d9804601- ┆ Abandonme ┆ When a    ┆ []        ┆ … ┆ 0319d5d6- ┆ Themes    ┆ Events,   ┆ SCENE    │
# │ fabb-4d22 ┆ nt Play   ┆ submissiv ┆           ┆   ┆ a07f-4e0d ┆           ┆ contexts, ┆          │
# │ -b996-a28 ┆           ┆ e is left ┆           ┆   ┆ -809d-c09 ┆           ┆ or        ┆          │
# │ 4b0…      ┆           ┆ on t…     ┆           ┆   ┆ fb1…      ┆           ┆ fetishes  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ …         ┆          │
# │ a98c64b8- ┆ Aerial    ┆ Cowgirl   ┆ ["Keiran' ┆ … ┆ feca7511- ┆ Acts      ┆ Various   ┆ ACTION   │
# │ 0564-44dc ┆ Cowgirl   ┆ position  ┆ s         ┆   ┆ ac91-42c0 ┆           ┆ sexual    ┆          │
# │ -b19e-582 ┆           ┆ with      ┆ Cowboy"]  ┆   ┆ -a032-8fb ┆           ┆ acts or   ┆          │
# │ 751…      ┆           ┆ receiver… ┆           ┆   ┆ 8f3…      ┆           ┆ positio…  ┆          │
# │ 59e97272- ┆ African   ┆ Speaks    ┆ ["Accent  ┆ … ┆ 7f4ddc1b- ┆ Misc      ┆ Informati ┆ SCENE    │
# │ 623d-4e14 ┆ Accent    ┆ with an   ┆ (African) ┆   ┆ 8169-4d5b ┆           ┆ on about  ┆          │
# │ -8b33-36d ┆           ┆ accent    ┆ "]        ┆   ┆ -b764-04a ┆           ┆ the video ┆          │
# │ e55…      ┆           ┆ native t… ┆           ┆   ┆ d07…      ┆           ┆ it…       ┆          │
# │ 6f2dde49- ┆ Against   ┆ Performer ┆ ["Against ┆ … ┆ feca7511- ┆ Acts      ┆ Various   ┆ ACTION   │
# │ 5c9a-495d ┆ Glass     ┆ is        ┆ Window",  ┆   ┆ ac91-42c0 ┆           ┆ sexual    ┆          │
# │ -b58f-e20 ┆           ┆ pressed   ┆ "Against  ┆   ┆ -a032-8fb ┆           ┆ acts or   ┆          │
# │ eab…      ┆           ┆ against   ┆ th…       ┆   ┆ 8f3…      ┆           ┆ positio…  ┆          │
# │           ┆           ┆ g…        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 9f24125b- ┆ Unconscio ┆ Features  ┆ []        ┆ … ┆ 0319d5d6- ┆ Themes    ┆ Events,   ┆ SCENE    │
# │ 8cb5-40b0 ┆ us        ┆ at least  ┆           ┆   ┆ a07f-4e0d ┆           ┆ contexts, ┆          │
# │ -8826-6b6 ┆           ┆ one       ┆           ┆   ┆ -809d-c09 ┆           ┆ or        ┆          │
# │ e7f…      ┆           ┆ characte… ┆           ┆   ┆ fb1…      ┆           ┆ fetishes  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ …         ┆          │
# │ 165ac407- ┆ Vaginal   ┆ Plug      ┆ ["Plugged ┆ … ┆ bc5f4d70- ┆ Accessori ┆ Notable   ┆ ACTION   │
# │ 9a7e-4603 ┆ Plug      ┆ designed  ┆ Pussy",   ┆   ┆ c5f3-4cd6 ┆ es        ┆ devices   ┆          │
# │ -a2ee-5b3 ┆           ┆ to be     ┆ "Pussy    ┆   ┆ -bc60-d44 ┆           ┆ or        ┆          │
# │ e38…      ┆           ┆ inserted  ┆ Plug"…    ┆   ┆ 700…      ┆           ┆ materials ┆          │
# │           ┆           ┆ v…        ┆           ┆   ┆           ┆           ┆ d…        ┆          │
# │ 7717e720- ┆ Virgin    ┆ Performer ┆ []        ┆ … ┆ c423ad76- ┆ Roles     ┆ Common    ┆ SCENE    │
# │ ee78-4ba0 ┆ (Roleplay ┆ who       ┆           ┆   ┆ 53f3-45a2 ┆           ┆ character ┆          │
# │ -a650-b2a ┆ )         ┆ pretends  ┆           ┆   ┆ -a865-87e ┆           ┆ archetype ┆          │
# │ 9db…      ┆           ┆ to be a…  ┆           ┆   ┆ e19…      ┆           ┆ s or…     ┆          │
# │ c1e4c23c- ┆ Visible   ┆ Visible   ┆ []        ┆ … ┆ 7f4ddc1b- ┆ Misc      ┆ Informati ┆ SCENE    │
# │ 623b-4014 ┆ Marks     ┆ results   ┆           ┆   ┆ 8169-4d5b ┆           ┆ on about  ┆          │
# │ -8eb2-986 ┆           ┆ of rough  ┆           ┆   ┆ -b764-04a ┆           ┆ the video ┆          │
# │ d95…      ┆           ┆ sex o…    ┆           ┆   ┆ d07…      ┆           ┆ it…       ┆          │
# │ c8359b33- ┆ White Top ┆ White     ┆ []        ┆ … ┆ 95be690d- ┆ Race      ┆ Broad cat ┆ PEOPLE   │
# │ ee64-470f ┆           ┆ performer ┆           ┆   ┆ 36f9-42dc ┆           ┆ egories   ┆          │
# │ -98dc-808 ┆           ┆ sexually  ┆           ┆   ┆ -bf15-248 ┆           ┆ for a     ┆          │
# │ 73a…      ┆           ┆ penet…    ┆           ┆   ┆ 136…      ┆           ┆ perform…  ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Create tags in Stash which exist in StashDB but not in Stash
stashdb_only_tags = df_stashdb_tags.filter(~pl.col('id').is_in(df_stash_tags.select('stashdb_id').to_series()))

print(f"Number of tags in StashDB but not in Stash: {len(stashdb_only_tags)}")

new_tags = []
for stashdb_tag in stashdb_only_tags.iter_rows(named=True):
    # Check if the tag already exists in Stash
    existing_tag = stash.find_tag(stashdb_tag['name'])
    if existing_tag:
        # Check if the tag exists due to an alias
        if stashdb_tag['name'] in existing_tag['aliases']:
            print(f"Tag already exists due to alias: {stashdb_tag['name']}")
        else:
            print(f"Tag already exists: {stashdb_tag['name']}")
        continue
    
    # Find the category tag if it exists
    category_tag = None
    if stashdb_tag['category_name']:
        category_tag = stash.find_tag(f"Category: {stashdb_tag['category_name']}")
    
    # Prepare the tag data
    tag_data = {
        "name": stashdb_tag['name'],
        "description": stashdb_tag['description'],
    }
    
    # Add aliases if they exist
    if stashdb_tag['aliases']:
        tag_data["aliases"] = stashdb_tag['aliases'] + ["StashDB ID: " + stashdb_tag['id']]
    else:
        tag_data["aliases"] = ["StashDB ID: " + stashdb_tag['id']]
    
    # Add parent category if it exists
    if category_tag:
        tag_data["parent_ids"] = [category_tag['id']]
    
    new_tags.append(tag_data)

new_tags_df = pl.DataFrame(new_tags)
new_tags_df
# Out:
# Number of tags in StashDB but not in Stash: 199
# shape: (199, 4)
# ┌───────────────────┬────────────────────────────────┬────────────────────────────────┬────────────┐
# │ name              ┆ description                    ┆ aliases                        ┆ parent_ids │
# │ ---               ┆ ---                            ┆ ---                            ┆ ---        │
# │ str               ┆ str                            ┆ list[str]                      ┆ list[str]  │
# ╞═══════════════════╪════════════════════════════════╪════════════════════════════════╪════════════╡
# │ 12K Available     ┆ Scenes offered in a            ┆ ["12K", "12K Shemale VR        ┆ ["7752"]   │
# │                   ┆ resolution…                    ┆ Porn",…                        ┆            │
# │ Abandonment Play  ┆ When a submissive is left on   ┆ ["StashDB ID:                  ┆ ["7751"]   │
# │                   ┆ t…                             ┆ d9804601-fabb-4d…              ┆            │
# │ Aerial Cowgirl    ┆ Cowgirl position with          ┆ ["Keiran's Cowboy", "StashDB   ┆ ["7753"]   │
# │                   ┆ receiver…                      ┆ I…                             ┆            │
# │ African Accent    ┆ Speaks with an accent native   ┆ ["Accent (African)", "StashDB  ┆ ["7752"]   │
# │                   ┆ t…                             ┆ …                              ┆            │
# │ Against Glass     ┆ Performer is pressed against   ┆ ["Against Window", "Against    ┆ ["7753"]   │
# │                   ┆ g…                             ┆ th…                            ┆            │
# │ …                 ┆ …                              ┆ …                              ┆ …          │
# │ Unconscious       ┆ Features at least one          ┆ ["StashDB ID:                  ┆ ["7751"]   │
# │                   ┆ characte…                      ┆ 9f24125b-8cb5-40…              ┆            │
# │ Vaginal Plug      ┆ Plug designed to be inserted   ┆ ["Plugged Pussy", "Pussy       ┆ ["7760"]   │
# │                   ┆ v…                             ┆ Plug"…                         ┆            │
# │ Virgin (Roleplay) ┆ Performer who pretends to be   ┆ ["StashDB ID:                  ┆ ["7756"]   │
# │                   ┆ a…                             ┆ 7717e720-ee78-4b…              ┆            │
# │ Visible Marks     ┆ Visible results of rough sex   ┆ ["StashDB ID:                  ┆ ["7752"]   │
# │                   ┆ o…                             ┆ c1e4c23c-623b-40…              ┆            │
# │ White Top         ┆ White performer sexually       ┆ ["StashDB ID:                  ┆ ["7764"]   │
# │                   ┆ penet…                         ┆ c8359b33-ee64-47…              ┆            │
# └───────────────────┴────────────────────────────────┴────────────────────────────────┴────────────┘

# %%
for tag in new_tags_df.iter_rows(named=True):
    # Create the tag in Stash
    try:
        new_tag = stash.create_tag(tag)
        print(f"Created tag: {new_tag['name']}")
    except Exception as e:
        print(f"Error creating tag: {e}")

print(f"Created {len(new_tags_df)} new tags in Stash.")
# Out:
# Created tag: 12K Available
# Created tag: Abandonment Play
# Created tag: Aerial Cowgirl
# Created tag: African Accent
# Created tag: Against Glass
# Created tag: AI Model
# Created tag: Anal Cowgirl - POV
# Created tag: Anal Doggy Style - POV
# Created tag: Anal Missionary - POV
# Created tag: Anal Reverse Cowgirl - POV
# Created tag: Asian Top
# Created tag: Ass Smelling
# Created tag: Baggy Shirt
# Created tag: BBC Dildo
# Created tag: Begging to Cum
# Created tag: Big Penis Humiliation
# Created tag: Black Top
# Created tag: Blowjob Sandwich
# Created tag: Blue Hair (Female)
# Created tag: Bolt-Ons
# Created tag: Boudoir
# Created tag: Breast Fetish
# Created tag: British Accent
# Created tag: Bunched Up Skirt
# Created tag: Cameraman
# Created tag: Capture
# Created tag: Chemical Play
# Created tag: Chinese Accent
# Created tag: Clavicle Piercing
# Created tag: Cleave Gag
# Created tag: Closed Missionary
# Created tag: Clothes Removal
# Created tag: Construction Site
# Created tag: Coveralls
# Created tag: Crawling
# Created tag: Cruising
# Created tag: Cuckold - POV
# Created tag: Cum Covered Blowjob
# Created tag: Cum Covered Titjob
# Created tag: Cum Snorting
# Created tag: Czech Language
# Created tag: Dangling
# Created tag: Dark Lipstick
# Created tag: Delivery Driver
# Created tag: Dildo Blowjob
# Created tag: Dildo Footjob
# Created tag: Dildo Gag
# Created tag: Dildo Handjob
# Created tag: Dildo Panties
# Created tag: Dildo Riding
# Created tag: Dirty Ass to Mouth
# Created tag: Dirty Ass to Other's Mouth
# Created tag: Disgust
# Created tag: Doggy Style (DAP)
# Created tag: Douching
# Created tag: Dry Orgasm
# Created tag: Ear Piercing
# Created tag: Eastern European Accent
# Created tag: Eightsome (BBBBBBGG)
# Created tag: Emergency Medical Technician
# Created tag: Encasement Footjob
# Created tag: English Subtitles
# Created tag: Entryway
# Created tag: Erect Clit
# Created tag: European Accent
# Created tag: Eye Makeup
# Created tag: Feet in Face During Blowjob
# Created tag: Feet in Face During Fingering
# Created tag: Feet in Face During Footjob
# Created tag: Feet in Face During Handjob
# Created tag: Feet in Face During Sex
# Created tag: Feet Teasing
# Created tag: Female Ruined Orgasm
# Created tag: Fictional Character
# Created tag: Firefighter
# Created tag: First Rimjob Experience
# Created tag: First Squirting Experience
# Created tag: Fivesome (BBBBG)
# Created tag: Floral Crown
# Created tag: Footjob Only
# Created tag: French Accent
# Created tag: French Language
# Created tag: Full Body Glory Hole
# Created tag: German Accent
# Created tag: German Language
# Created tag: Green Hair (Female)
# Created tag: Hand and Penis (DAP)
# Created tag: Heels Fetish
# Created tag: Heels Removal
# Created tag: Hip Piercing
# Created tag: Horse Dildo
# Created tag: Hungarian Language
# Created tag: Impact Play
# Created tag: In Laws
# Created tag: Interrogation
# Created tag: Inverted Face Fuck
# Created tag: Italian Accent
# Created tag: Italian Language
# Created tag: Japanese Accent
# Created tag: Japanese Language
# Created tag: Jockey Position
# Created tag: Kissing During Footjob
# Created tag: Kissing During Handjob
# Created tag: Korean Accent
# Created tag: Landing Strip
# Created tag: Landlord
# Created tag: Latin American Accent
# Created tag: Leather Belt Bondage
# Created tag: Little Black Dress
# Created tag: Loincloth
# Created tag: Male Flight Attendant
# Created tag: Male Waiter
# Created tag: Martial Arts
# Created tag: Masturbation During Blowjob
# Created tag: Members Only
# Created tag: Mexican Accent
# Created tag: Mexico
# Created tag: Missionary (DAP)
# Created tag: Mouth Fingering
# Created tag: Multiple Creampies
# Created tag: Mythical Character
# Created tag: Non-American Accent
# Created tag: Nude Interview
# Created tag: Observer
# Created tag: On Standby
# Created tag: Other Person's Son
# Created tag: Pantyhose Removal
# Created tag: Panty Sniffing
# Created tag: Patient
# Created tag: Peekaboo Bra
# Created tag: Pendant Necklace
# Created tag: Pink Hair (Female)
# Created tag: Pink Hair (Male)
# Created tag: Portuguese Language
# Created tag: Posthumous Release
# Created tag: Post-Scene Interview
# Created tag: Pre-Scene Interview
# Created tag: Prince Albert
# Created tag: Purple Hair (Female)
# Created tag: Pussy Impact Play
# Created tag: Pussy to Other's Mouth
# Created tag: PVC
# Created tag: Rabbit Vibrator
# Created tag: Reporter
# Created tag: Ruined Cumshot
# Created tag: Ruined Orgasm Instruction
# Created tag: Russian Language
# Created tag: Safewording
# Created tag: Salesman
# Created tag: SD Only
# Created tag: Servant
# Created tag: Sevensome (BBBBBBG)
# Created tag: Sevensome (BBBBBGG)
# Created tag: Sexual Harassment
# Created tag: Shaved
# Created tag: Shaved Armpits
# Created tag: Shaved Arms
# Created tag: Shibari
# Created tag: Shoe Fetish
# Created tag: Shoe Smelling
# Created tag: Shoes Removal
# Created tag: Smell Fetish
# Created tag: Smooth Legs
# Created tag: Sock Smelling
# Created tag: Socks Removal
# Created tag: Spanish Language
# Created tag: Spiked Cockring
# Created tag: Spit As Lube
# Created tag: Split Leaning Forward
# Created tag: Stand and Carry (DAP)
# Created tag: Stand and Carry (DVP)
# Created tag: Stealthing Roleplay
# Created tag: Step Cousin
# Created tag: Strap-On (DP)
# Created tag: Strip Search
# Created tag: Supernatural
# Created tag: Suspension
# Created tag: Tape Bondage
# Created tag: Teammates
# Created tag: Thighjob to Completion
# Created tag: Tit Impact Play
# Created tag: Titjob While Other's Blowjob
# Created tag: Tits Touching Tits
# Created tag: Torpedo Tits
# Created tag: Toy Masturbation
# Created tag: Train (Participant Queue)
# Created tag: Train (Penetration Chain)
# Created tag: Train (Rimming)
# Created tag: Trans Creampie
# Created tag: Transgender (Female)
# Created tag: Transgender (Male)
# Created tag: Transgender (Non-Binary)
# Created tag: Trans - POV
# Created tag: Tricked
# Created tag: Unconscious
# Created tag: Vaginal Plug
# Created tag: Virgin (Roleplay)
# Created tag: Visible Marks
# Created tag: White Top
# Created 199 new tags in Stash.
