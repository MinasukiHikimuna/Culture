# %%
import polars as pl
from libraries.client_stashapp import StashAppClientPolars

client = StashAppClientPolars()
df_studios = client.get_studios()
df_studios
# Out:
# dUsing stash (v0.27.2-37-g0621d871) endpoint at http://localhost:6969/graphql
# dPersisting Connection to Stash with ApiKey...
# shape: (1_283, 6)
# ┌────────────────┬────────────────┬────────────────┬───────────────┬───────────────┬───────────────┐
# │ stash_studios_ ┆ stash_studios_ ┆ stash_studios_ ┆ stash_studios ┆ stash_studios ┆ stash_studios │
# │ id             ┆ name           ┆ url            ┆ _parent_studi ┆ _parent_studi ┆ _parent_studi │
# │ ---            ┆ ---            ┆ ---            ┆ o_id          ┆ o_na…         ┆ o_ur…         │
# │ i64            ┆ str            ┆ str            ┆ ---           ┆ ---           ┆ ---           │
# │                ┆                ┆                ┆ i64           ┆ str           ┆ str           │
# ╞════════════════╪════════════════╪════════════════╪═══════════════╪═══════════════╪═══════════════╡
# │ 404            ┆ 1 Pass for All ┆ https://1passf ┆ null          ┆ null          ┆ null          │
# │                ┆ Sites          ┆ orallsites.com ┆               ┆               ┆               │
# │ 644            ┆ 1By-Day        ┆ https://1by-da ┆ 436           ┆ DDF Network   ┆ https://ddfne │
# │                ┆                ┆ y.com          ┆               ┆               ┆ twork.com     │
# │ 522            ┆ 2 Chicks Same  ┆ https://naught ┆ 621           ┆ Naughty       ┆ https://www.n │
# │                ┆ Time           ┆ yamerica.com   ┆               ┆ America       ┆ aughtyamerica │
# │                ┆                ┆                ┆               ┆               ┆ .com…         │
# │ 53             ┆ 3rd Degree     ┆ https://3rddeg ┆ 232           ┆ Dogfart       ┆ https://dogfa │
# │                ┆                ┆ ree.com        ┆               ┆ Network       ┆ rtnetwork.com │
# │ 1124           ┆ 3rd Degree     ┆ https://zeroto ┆ null          ┆ null          ┆ null          │
# │                ┆ Films          ┆ lerancefilms.c ┆               ┆               ┆               │
# │                ┆                ┆ om             ┆               ┆               ┆               │
# │ …              ┆ …              ┆ …              ┆ …             ┆ …             ┆ …             │
# │ 1021           ┆ Zebra Girls    ┆ https://www.ze ┆ 232           ┆ Dogfart       ┆ https://dogfa │
# │                ┆                ┆ bragirls.com/  ┆               ┆ Network       ┆ rtnetwork.com │
# │ 505            ┆ Zero Tolerance ┆ https://www.ze ┆ null          ┆ null          ┆ null          │
# │                ┆ Films          ┆ rotolerancefil ┆               ┆               ┆               │
# │                ┆                ┆ ms…            ┆               ┆               ┆               │
# │ 428            ┆ Zoliboy        ┆                ┆ 427           ┆ 21 Sextreme   ┆ https://www.2 │
# │                ┆                ┆                ┆               ┆ (Network)     ┆ 1sextreme.com │
# │ 521            ┆ ZTOD           ┆                ┆ 505           ┆ Zero          ┆ https://www.z │
# │                ┆                ┆                ┆               ┆ Tolerance     ┆ erotolerancef │
# │                ┆                ┆                ┆               ┆ Films         ┆ ilms…         │
# │ 116            ┆ ZZ Series      ┆ https://www.br ┆ 463           ┆ Brazzers      ┆ https://www.b │
# │                ┆                ┆ azzers.com/sit ┆               ┆               ┆ razzers.com   │
# │                ┆                ┆ e/…            ┆               ┆               ┆               │
# └────────────────┴────────────────┴────────────────┴───────────────┴───────────────┴───────────────┘

# %%
# Prefix all columns with "stash_studios_"
df_studios = df_studios.select(pl.col("*").name.prefix("stash_studios_"))

# %%
client.find_scenes_by_oshash(["97ed93adf4fb2b89"])
