# %%
import polars as pl
import dotenv
import os
import sys

sys.path.append(os.path.dirname(os.path.abspath("")))

from libraries.client_stashapp import get_stashapp_client, StashAppClient
from libraries.StashDbClient import StashDbClient


# Format a StashDB ID for use as an aliasin Stash
stashdb_id_alias_prefix = "StashDB ID: "


def format_stashdb_id(id):
    return f"{stashdb_id_alias_prefix}{id}"


def contains_cjk(text):
    """Check if text contains CJK (Chinese, Japanese, Korean) characters."""
    # Unicode ranges for CJK characters
    cjk_ranges = [
        (0x4E00, 0x9FFF),  # CJK Unified Ideographs
        (0x3040, 0x309F),  # Hiragana
        (0x30A0, 0x30FF),  # Katakana
        (0x3400, 0x4DBF),  # CJK Unified Ideographs Extension A
        (0xF900, 0xFAFF),  # CJK Compatibility Ideographs
        (0xAC00, 0xD7AF),  # Korean Hangul Syllables
    ]

    return any(
        any(ord(char) >= start and ord(char) <= end for start, end in cjk_ranges)
        for char in text
    )


dotenv.load_dotenv()

stash = get_stashapp_client()
stash_client = StashAppClient()

stashbox_client = StashDbClient(
    os.getenv("STASHDB_ENDPOINT"),
    os.getenv("STASHDB_API_KEY"),
)
# Out:
# dUsing stash (v0.28.1-89-g642b0f22) endpoint at http://localhost:6969/graphql
# dUsing stash (v0.28.1-89-g642b0f22) endpoint at http://localhost:6969/graphql

# %%
stashdb_tags = stashbox_client.query_tags()

# %%
df_stashdb_tags = pl.DataFrame(stashdb_tags)

df_stashdb_tags = df_stashdb_tags.with_columns(
    pl.col("category")
    .map_elements(lambda x: x["id"] if x else None, return_dtype=pl.Utf8)
    .alias("category_id"),
    pl.col("category")
    .map_elements(lambda x: x["name"] if x else None, return_dtype=pl.Utf8)
    .alias("category_name"),
    pl.col("category")
    .map_elements(lambda x: x["description"] if x else None, return_dtype=pl.Utf8)
    .alias("category_description"),
    pl.col("category")
    .map_elements(lambda x: x["group"] if x else None, return_dtype=pl.Utf8)
    .alias("category_group"),
).drop("category")

df_stashdb_tags
# Out:
# shape: (2_850, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ descripti ┆ aliases   ┆ … ┆ category_ ┆ category_ ┆ category_ ┆ category │
# │ ---       ┆ ---       ┆ on        ┆ ---       ┆   ┆ id        ┆ name      ┆ descripti ┆ _group   │
# │ str       ┆ str       ┆ ---       ┆ list[str] ┆   ┆ ---       ┆ ---       ┆ on        ┆ ---      │
# │           ┆           ┆ str       ┆           ┆   ┆ str       ┆ str       ┆ ---       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 9441c3ad- ┆ 120 FPS   ┆ Scenes    ┆ ["120帧"] ┆ … ┆ ef4ae6d1- ┆ Shot Type ┆ Technical ┆ SCENE    │
# │ 41d2-4d6e ┆           ┆ offered   ┆           ┆   ┆ d13c-4195 ┆           ┆ details   ┆          │
# │ -bc97-54a ┆           ┆ at 120    ┆           ┆   ┆ -b47e-f24 ┆           ┆ of how a  ┆          │
# │ d8c…      ┆           ┆ frames p… ┆           ┆   ┆ 5e4…      ┆           ┆ vid…      ┆          │
# │ 42d9e5c4- ┆ 12K       ┆ Scenes    ┆ ["12K",   ┆ … ┆ 7f4ddc1b- ┆ Misc      ┆ Informati ┆ SCENE    │
# │ 1a1d-4c93 ┆ Available ┆ offered   ┆ "12K      ┆   ┆ 8169-4d5b ┆           ┆ on about  ┆          │
# │ -bf47-908 ┆           ┆ in a reso ┆ Shemale   ┆   ┆ -b764-04a ┆           ┆ the video ┆          │
# │ 6f2…      ┆           ┆ lution…   ┆ VR        ┆   ┆ d07…      ┆           ┆ it…       ┆          │
# │           ┆           ┆           ┆ Porn",…   ┆   ┆           ┆           ┆           ┆          │
# │ 8534d108- ┆ 18+       ┆ Primary   ┆ ["18      ┆ … ┆ b40e08dd- ┆ Age Group ┆ Implied   ┆ PEOPLE   │
# │ 1f4c-42f9 ┆           ┆ performer ┆ Plus",    ┆   ┆ 314e-40ca ┆           ┆ age       ┆          │
# │ -8caa-5ca ┆           ┆ (not      ┆ "Over     ┆   ┆ -8fdb-bf7 ┆           ┆ ranges    ┆          │
# │ 906…      ┆           ┆ charact…  ┆ 18"]      ┆   ┆ 541…      ┆           ┆ for       ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ charact…  ┆          │
# │ 103a1f16- ┆ 180°      ┆ Virtual   ┆ ["180",   ┆ … ┆ ef4ae6d1- ┆ Shot Type ┆ Technical ┆ SCENE    │
# │ 83e1-4b9f ┆           ┆ reality   ┆ "180      ┆   ┆ d13c-4195 ┆           ┆ details   ┆          │
# │ -ab14-e85 ┆           ┆ scenes    ┆ FOV", …   ┆   ┆ -b47e-f24 ┆           ┆ of how a  ┆          │
# │ e04…      ┆           ┆ with a …  ┆ "VR180"]  ┆   ┆ 5e4…      ┆           ┆ vid…      ┆          │
# │ 6cd87d98- ┆ 1800s     ┆ Inspired  ┆ ["1800's" ┆ … ┆ 0319d5d6- ┆ Themes    ┆ Events,   ┆ SCENE    │
# │ eea8-4b97 ┆           ┆ by the    ┆ , "19th   ┆   ┆ a07f-4e0d ┆           ┆ contexts, ┆          │
# │ -9db9-aa3 ┆           ┆ history   ┆ Century", ┆   ┆ -809d-c09 ┆           ┆ or        ┆          │
# │ 8a9…      ┆           ┆ and cu…   ┆ … "…      ┆   ┆ fb1…      ┆           ┆ fetishes  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ …         ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ e7f1f848- ┆ Young Man ┆ Male      ┆ ["Young   ┆ … ┆ b40e08dd- ┆ Age Group ┆ Implied   ┆ PEOPLE   │
# │ 4350-4bda ┆ (22–30)   ┆ presented ┆ Guy",     ┆   ┆ 314e-40ca ┆           ┆ age       ┆          │
# │ -925c-b01 ┆           ┆ as        ┆ "Young    ┆   ┆ -8fdb-bf7 ┆           ┆ ranges    ┆          │
# │ 235…      ┆           ┆ generally ┆ Male", …  ┆   ┆ 541…      ┆           ┆ for       ┆          │
# │           ┆           ┆ yo…       ┆ …         ┆   ┆           ┆           ┆ charact…  ┆          │
# │ 84ba8ef1- ┆ Young     ┆ Female    ┆ ["Chick", ┆ … ┆ b40e08dd- ┆ Age Group ┆ Implied   ┆ PEOPLE   │
# │ 084c-46f8 ┆ Woman     ┆ character ┆ "Woman    ┆   ┆ 314e-40ca ┆           ┆ age       ┆          │
# │ -b352-311 ┆ (22–30)   ┆ presented ┆ (20-29)", ┆   ┆ -8fdb-bf7 ┆           ┆ ranges    ┆          │
# │ 54f…      ┆           ┆ as …      ┆ … "…      ┆   ┆ 541…      ┆           ┆ for       ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ charact…  ┆          │
# │ 6c0a2824- ┆ Zentai    ┆ Skin-tigh ┆ ["Zentai  ┆ … ┆ dc566ccc- ┆ Clothing  ┆ Articles  ┆ PEOPLE   │
# │ acd2-4b64 ┆           ┆ t garment ┆ Suit"]    ┆   ┆ 0584-41d8 ┆           ┆ or styles ┆          │
# │ -9a2c-634 ┆           ┆ that      ┆           ┆   ┆ -b9f5-4d8 ┆           ┆ of        ┆          │
# │ bd9…      ┆           ┆ covers…   ┆           ┆   ┆ 680…      ┆           ┆ clothing… ┆          │
# │ bed78871- ┆ Zip Front ┆ A dress   ┆ ["Zipper  ┆ … ┆ dc566ccc- ┆ Clothing  ┆ Articles  ┆ PEOPLE   │
# │ 9bb8-40c2 ┆ Dress     ┆ where the ┆ Dress"]   ┆   ┆ 0584-41d8 ┆           ┆ or styles ┆          │
# │ -97b1-347 ┆           ┆ zipper    ┆           ┆   ┆ -b9f5-4d8 ┆           ┆ of        ┆          │
# │ c43…      ┆           ┆ runs …    ┆           ┆   ┆ 680…      ┆           ┆ clothing… ┆          │
# │ 4225e72e- ┆ Zipper    ┆ Series of ┆ ["Body    ┆ … ┆ bc5f4d70- ┆ Accessori ┆ Notable   ┆ ACTION   │
# │ 2ddc-4e18 ┆           ┆ clothespi ┆ Zipper",  ┆   ┆ c5f3-4cd6 ┆ es        ┆ devices   ┆          │
# │ -945b-6f8 ┆           ┆ ns        ┆ "Clothesp ┆   ┆ -bc60-d44 ┆           ┆ or        ┆          │
# │ 731…      ┆           ┆ attached… ┆ in Zi…    ┆   ┆ 700…      ┆           ┆ materials ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ d…        ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df_stashdb_tags.write_json("H:\\Parquet Data\\StashDB\\stashdb_tags.json")

# %%
# Get tags from Stash
stash_tags = stash.find_tags()
df_stash_tags = pl.DataFrame(stash_tags)
df_stash_tags = df_stash_tags.with_columns(
    pl.col("aliases")
    .map_elements(
        lambda aliases: next(
            (
                alias[len(stashdb_id_alias_prefix) :]
                for alias in aliases
                if isinstance(alias, str) and alias.startswith(stashdb_id_alias_prefix)
            ),
            None,
        ),
        return_dtype=pl.Utf8,
    )
    .alias("stashdb_id")
)
df_stash_tags
# Out:
# shape: (3_251, 22)
# ┌──────┬────────────┬───────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ id   ┆ name       ┆ sort_name ┆ descriptio ┆ … ┆ children   ┆ parent_cou ┆ child_cou ┆ stashdb_i │
# │ ---  ┆ ---        ┆ ---       ┆ n          ┆   ┆ ---        ┆ nt         ┆ nt        ┆ d         │
# │ str  ┆ str        ┆ str       ┆ ---        ┆   ┆ list[struc ┆ ---        ┆ ---       ┆ ---       │
# │      ┆            ┆           ┆ str        ┆   ┆ t[1]]      ┆ i64        ┆ i64       ┆ str       │
# ╞══════╪════════════╪═══════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 5045 ┆ 2D         ┆           ┆ 3D or VR   ┆ … ┆ []         ┆ 1          ┆ 0         ┆ 1257be8b- │
# │      ┆ Available  ┆           ┆ scenes     ┆   ┆            ┆            ┆           ┆ d1ec-4cb1 │
# │      ┆            ┆           ┆ that offer ┆   ┆            ┆            ┆           ┆ -bb22-bee │
# │      ┆            ┆           ┆ a m…       ┆   ┆            ┆            ┆           ┆ b89…      │
# │ 5049 ┆ 3D         ┆           ┆ Offered in ┆ … ┆ []         ┆ 1          ┆ 0         ┆ 52992c2c- │
# │      ┆ Available  ┆           ┆ a format   ┆   ┆            ┆            ┆           ┆ 4617-4540 │
# │      ┆            ┆           ┆ with a     ┆   ┆            ┆            ┆           ┆ -8ca4-291 │
# │      ┆            ┆           ┆ thr…       ┆   ┆            ┆            ┆           ┆ e9c…      │
# │ 5050 ┆ 3K         ┆           ┆ Scenes     ┆ … ┆ []         ┆ 1          ┆ 0         ┆ c3794d99- │
# │      ┆ Available  ┆           ┆ offered in ┆   ┆            ┆            ┆           ┆ 1b5b-47b3 │
# │      ┆            ┆           ┆ a resoluti ┆   ┆            ┆            ┆           ┆ -86f7-75f │
# │      ┆            ┆           ┆ on…        ┆   ┆            ┆            ┆           ┆ f2d…      │
# │ 5051 ┆ 3rd Person ┆           ┆ Features a ┆ … ┆ []         ┆ 1          ┆ 0         ┆ f562975c- │
# │      ┆ Narrative  ┆           ┆ storyline  ┆   ┆            ┆            ┆           ┆ e209-464c │
# │      ┆            ┆           ┆ with fict… ┆   ┆            ┆            ┆           ┆ -83ed-8ac │
# │      ┆            ┆           ┆            ┆   ┆            ┆            ┆           ┆ 18e…      │
# │ 5053 ┆ 4:3 Aspect ┆           ┆ Footage    ┆ … ┆ []         ┆ 1          ┆ 0         ┆ 6958c8ed- │
# │      ┆ Ratio      ┆           ┆ shot in a  ┆   ┆            ┆            ┆           ┆ 1948-46d2 │
# │      ┆            ┆           ┆ 4:3        ┆   ┆            ┆            ┆           ┆ -89e0-cb4 │
# │      ┆            ┆           ┆ (1.33:1)…  ┆   ┆            ┆            ┆           ┆ 891…      │
# │ …    ┆ …          ┆ …         ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ 7559 ┆ Young Man  ┆           ┆ Male       ┆ … ┆ []         ┆ 1          ┆ 0         ┆ e7f1f848- │
# │      ┆ (22–30)    ┆           ┆ presented  ┆   ┆            ┆            ┆           ┆ 4350-4bda │
# │      ┆            ┆           ┆ as         ┆   ┆            ┆            ┆           ┆ -925c-b01 │
# │      ┆            ┆           ┆ generally  ┆   ┆            ┆            ┆           ┆ 235…      │
# │      ┆            ┆           ┆ yo…        ┆   ┆            ┆            ┆           ┆           │
# │ 7560 ┆ Young      ┆           ┆ Female     ┆ … ┆ []         ┆ 1          ┆ 0         ┆ 84ba8ef1- │
# │      ┆ Woman      ┆           ┆ character  ┆   ┆            ┆            ┆           ┆ 084c-46f8 │
# │      ┆ (22–30)    ┆           ┆ presented  ┆   ┆            ┆            ┆           ┆ -b352-311 │
# │      ┆            ┆           ┆ as …       ┆   ┆            ┆            ┆           ┆ 54f…      │
# │ 7563 ┆ Zentai     ┆           ┆ Skin-tight ┆ … ┆ []         ┆ 1          ┆ 0         ┆ 6c0a2824- │
# │      ┆            ┆           ┆ garment    ┆   ┆            ┆            ┆           ┆ acd2-4b64 │
# │      ┆            ┆           ┆ that       ┆   ┆            ┆            ┆           ┆ -9a2c-634 │
# │      ┆            ┆           ┆ covers…    ┆   ┆            ┆            ┆           ┆ bd9…      │
# │ 7564 ┆ Zip Front  ┆           ┆ A dress    ┆ … ┆ []         ┆ 1          ┆ 0         ┆ bed78871- │
# │      ┆ Dress      ┆           ┆ where the  ┆   ┆            ┆            ┆           ┆ 9bb8-40c2 │
# │      ┆            ┆           ┆ zipper     ┆   ┆            ┆            ┆           ┆ -97b1-347 │
# │      ┆            ┆           ┆ runs …     ┆   ┆            ┆            ┆           ┆ c43…      │
# │ 7565 ┆ Zipper     ┆           ┆ Series of  ┆ … ┆ []         ┆ 1          ┆ 0         ┆ 4225e72e- │
# │      ┆            ┆           ┆ clothespin ┆   ┆            ┆            ┆           ┆ 2ddc-4e18 │
# │      ┆            ┆           ┆ s          ┆   ┆            ┆            ┆           ┆ -945b-6f8 │
# │      ┆            ┆           ┆ attached…  ┆   ┆            ┆            ┆           ┆ 731…      │
# └──────┴────────────┴───────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
# Merge df_stashdb_tags and df_stash_tags based on the 'name' column
merged_df = df_stashdb_tags.join(
    df_stash_tags, left_on="id", right_on="stashdb_id", how="full", suffix="_stash"
)

# Identify matching and non-matching tags
matching_tags = merged_df.filter(
    pl.col("id").is_not_null() & pl.col("id_stash").is_not_null()
)
stashdb_only_tags = merged_df.filter(pl.col("id_stash").is_null())
stash_only_tags = merged_df.filter(pl.col("id").is_null())

# Display results
print(f"Total matching tags: {len(matching_tags)}")
print(f"Tags only in StashDB: {len(stashdb_only_tags)}")
print(f"Tags only in Stash: {len(stash_only_tags)}")

merged_df
# Out:
# Total matching tags: 2773
# Tags only in StashDB: 77
# Tags only in Stash: 478
# shape: (3_328, 33)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ name      ┆ descripti ┆ aliases   ┆ … ┆ children  ┆ parent_co ┆ child_cou ┆ stashdb_ │
# │ ---       ┆ ---       ┆ on        ┆ ---       ┆   ┆ ---       ┆ unt       ┆ nt        ┆ id       │
# │ str       ┆ str       ┆ ---       ┆ list[str] ┆   ┆ list[stru ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ str       ┆           ┆   ┆ ct[1]]    ┆ i64       ┆ i64       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1257be8b- ┆ 2D        ┆ 3D or VR  ┆ ["2-D",   ┆ … ┆ []        ┆ 1         ┆ 0         ┆ 1257be8b │
# │ d1ec-4cb1 ┆ Available ┆ scenes    ┆ "2D", …   ┆   ┆           ┆           ┆           ┆ -d1ec-4c │
# │ -bb22-bee ┆           ┆ that      ┆ "Two-Dime ┆   ┆           ┆           ┆           ┆ b1-bb22- │
# │ b89…      ┆           ┆ offer a   ┆ nsion…    ┆   ┆           ┆           ┆           ┆ beeb89…  │
# │           ┆           ┆ m…        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 52992c2c- ┆ 3D        ┆ Offered   ┆ ["3-D",   ┆ … ┆ []        ┆ 1         ┆ 0         ┆ 52992c2c │
# │ 4617-4540 ┆ Available ┆ in a      ┆ "3D", …   ┆   ┆           ┆           ┆           ┆ -4617-45 │
# │ -8ca4-291 ┆           ┆ format    ┆ "Three-Di ┆   ┆           ┆           ┆           ┆ 40-8ca4- │
# │ e9c…      ┆           ┆ with a    ┆ mensi…    ┆   ┆           ┆           ┆           ┆ 291e9c…  │
# │           ┆           ┆ thr…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ c3794d99- ┆ 3K        ┆ Scenes    ┆ ["1600p", ┆ … ┆ []        ┆ 1         ┆ 0         ┆ c3794d99 │
# │ 1b5b-47b3 ┆ Available ┆ offered   ┆ "3K VP9", ┆   ┆           ┆           ┆           ┆ -1b5b-47 │
# │ -86f7-75f ┆           ┆ in a reso ┆ … "3KVR"] ┆   ┆           ┆           ┆           ┆ b3-86f7- │
# │ f2d…      ┆           ┆ lution…   ┆           ┆   ┆           ┆           ┆           ┆ 75ff2d…  │
# │ f562975c- ┆ 3rd       ┆ Features  ┆ ["3rd     ┆ … ┆ []        ┆ 1         ┆ 0         ┆ f562975c │
# │ e209-464c ┆ Person    ┆ a         ┆ Person    ┆   ┆           ┆           ┆           ┆ -e209-46 │
# │ -83ed-8ac ┆ Narrative ┆ storyline ┆ Perspecti ┆   ┆           ┆           ┆           ┆ 4c-83ed- │
# │ 18e…      ┆           ┆ with      ┆ ve", "Th… ┆   ┆           ┆           ┆           ┆ 8ac18e…  │
# │           ┆           ┆ fict…     ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 6958c8ed- ┆ 4:3       ┆ Footage   ┆ ["1.33:1" ┆ … ┆ []        ┆ 1         ┆ 0         ┆ 6958c8ed │
# │ 1948-46d2 ┆ Aspect    ┆ shot in a ┆ , "1.33:1 ┆   ┆           ┆           ┆           ┆ -1948-46 │
# │ -89e0-cb4 ┆ Ratio     ┆ 4:3       ┆ Aspect    ┆   ┆           ┆           ┆           ┆ d2-89e0- │
# │ 891…      ┆           ┆ (1.33:1)… ┆ Rati…     ┆   ┆           ┆           ┆           ┆ cb4891…  │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ c17d8324- ┆ Blowjob   ┆ A fucking ┆ ["automat ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 03c4-46ab ┆ Machine   ┆ machine   ┆ ic        ┆   ┆           ┆           ┆           ┆          │
# │ -a0e8-a4a ┆           ┆ modified  ┆ blowjob   ┆   ┆           ┆           ┆           ┆          │
# │ 7b0…      ┆           ┆ to …      ┆ machine", ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ …         ┆   ┆           ┆           ┆           ┆          │
# │ d0503307- ┆ Cum in    ┆ Cuming    ┆ ["Cum in  ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 4f04-41f3 ┆ Chastity  ┆ while     ┆ Cage"]    ┆   ┆           ┆           ┆           ┆          │
# │ -bb52-0a2 ┆           ┆ wearing a ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 88f…      ┆           ┆ chastit…  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ cfc9d4d5- ┆ Fangs     ┆ Performer ┆ ["Fang"]  ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 2003-4d43 ┆           ┆ has       ┆           ┆   ┆           ┆           ┆           ┆          │
# │ -99eb-bc7 ┆           ┆ elongated ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2f1…      ┆           ┆ inciso…   ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 468fa590- ┆ Forced    ┆ Forced    ┆ ["forced  ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ e8ee-4b5c ┆ Feminizat ┆ feminizat ┆ fem"]     ┆   ┆           ┆           ┆           ┆          │
# │ -91bd-8ef ┆ ion       ┆ ion is a  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ a48…      ┆           ┆ fetis…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ e8173200- ┆ Unlocking ┆ Chastity  ┆ ["Chastit ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 4e1a-4feb ┆ Chastity  ┆ device    ┆ y         ┆   ┆           ┆           ┆           ┆          │
# │ -8d0c-dbf ┆           ┆ gets      ┆ Release"] ┆   ┆           ┆           ┆           ┆          │
# │ d80…      ┆           ┆ removed   ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ o…        ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
my_very_own_tags_parent_tag = stash.find_tag({"name": "My Very Own Tags"})

df_stash_only_tags = (
    df_stash_tags.filter(
        pl.col("id").is_in(stash_only_tags.select("id_stash").unique().to_series().to_list())
    )
    .filter(
        # Check if the tag doesn't have "My Very Own Tags" as parent
        pl.col("parents").map_elements(
            lambda parents: not any(
                parent.get("id") == my_very_own_tags_parent_tag["id"]
                for parent in parents
            ),
            return_dtype=pl.Boolean,
        )
    )
    .filter(
        ~pl.col("name").str.starts_with("Category:")
        & ~pl.col("name").str.starts_with("Category Group:")
        & ~pl.col("name").str.starts_with("AI_")
        & ~pl.col("name").str.ends_with("_AI")
        & ~pl.col("name").str.starts_with("Data Quality Issue")
        & ~pl.col("name").str.starts_with("Duplicate")
        & ~pl.col("name").str.starts_with("Galleries")
        & ~pl.col("name").str.starts_with("Group Makeup")
    )
    .select("id", "name", "aliases", "scene_count")
)
df_stash_only_tags
# Out:
# shape: (129, 4)
# ┌──────┬──────────────────────────────┬───────────┬─────────────┐
# │ id   ┆ name                         ┆ aliases   ┆ scene_count │
# │ ---  ┆ ---                          ┆ ---       ┆ ---         │
# │ str  ┆ str                          ┆ list[str] ┆ i64         │
# ╞══════╪══════════════════════════════╪═══════════╪═════════════╡
# │ 8792 ┆ Accidental Nipple Exposure   ┆ []        ┆ 1           │
# │ 8552 ┆ AI                           ┆ []        ┆ 0           │
# │ 8800 ┆ Armpit Job                   ┆ []        ┆ 1           │
# │ 8793 ┆ Background Moaning           ┆ []        ┆ 1           │
# │ 8788 ┆ Boobs Jiggling Against Boobs ┆ []        ┆ 1           │
# │ …    ┆ …                            ┆ …         ┆ …           │
# │ 8796 ┆ Vaginal Insertion            ┆ []        ┆ 5           │
# │ 7967 ┆ Verified: Locations          ┆ []        ┆ 21          │
# │ 8797 ┆ Vibrators                    ┆ []        ┆ 7           │
# │ 7666 ┆ Wet (Genitals)               ┆ []        ┆ 5           │
# │ 8730 ┆ Wet Clothes                  ┆ []        ┆ 1           │
# └──────┴──────────────────────────────┴───────────┴─────────────┘

# %% [markdown]
# # Delete tags which originated from StashDB but have no scenes

# %%
# Delete tags which originated from StashDB but have no scenes
df_previous_stashdb_tags = df_stash_only_tags.explode("aliases").filter(
    pl.col("aliases").str.starts_with("StashDB ID: ")
).filter(
    pl.col("scene_count") == 0
)
df_previous_stashdb_tags
# Out:
# shape: (34, 4)
# ┌──────┬────────────────────┬─────────────────────────────────┬─────────────┐
# │ id   ┆ name               ┆ aliases                         ┆ scene_count │
# │ ---  ┆ ---                ┆ ---                             ┆ ---         │
# │ str  ┆ str                ┆ str                             ┆ i64         │
# ╞══════╪════════════════════╪═════════════════════════════════╪═════════════╡
# │ 5756 ┆ Edgy               ┆ StashDB ID: 9673720a-3ae0-4cfb… ┆ 0           │
# │ 6110 ┆ Hand Rail          ┆ StashDB ID: 3d58274a-6a82-4fb3… ┆ 0           │
# │ 6134 ┆ Headstand          ┆ StashDB ID: 0fe40fde-ebd2-4f3b… ┆ 0           │
# │ 6258 ┆ Kink-POV-Gay       ┆ StashDB ID: b1760d3d-e3ef-4054… ┆ 0           │
# │ 6492 ┆ Motorcycle Fucking ┆ StashDB ID: fcab90fb-529c-4419… ┆ 0           │
# │ …    ┆ …                  ┆ …                               ┆ …           │
# │ 7163 ┆ Squats             ┆ StashDB ID: 25047e52-b834-4888… ┆ 0           │
# │ 7254 ┆ Svelte             ┆ StashDB ID: a222d4a8-d9a7-4c5e… ┆ 0           │
# │ 7262 ┆ Sweeping           ┆ StashDB ID: 988ffc2c-9a03-42df… ┆ 0           │
# │ 7370 ┆ Totem              ┆ StashDB ID: 8ebdccc4-bf1a-4408… ┆ 0           │
# │ 7372 ┆ Touching Pussy     ┆ StashDB ID: 7bf48f07-8277-4cd6… ┆ 0           │
# └──────┴────────────────────┴─────────────────────────────────┴─────────────┘

# %%
tag_ids = sorted(df_previous_stashdb_tags.select("id").unique().to_series().to_list())
len(tag_ids)

stash.destroy_tags(tag_ids)
