# %%
from libraries import browser

# Example usage
success = browser.open_or_update_tab("https://stash.chiefsclub.com")
print(f"Operation {'succeeded' if success else 'failed'}")
# Out:
# Got response from Chrome: 200
# Found 3 pages
# Checking page: https://www.wikipedia.org/
# Checking page: https://example.com/
# Checking page: chrome-extension://fmkadmapgofadopljbjfkapdkoienihi/build/background.js
# No existing tab found, creating new one
# Create tab response: {"id":1,"result":{"targetId":"B5A131A6821538E991A241DF6C22E2C4"}}
# Operation succeeded
