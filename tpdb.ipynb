# %%
import pandas as pd
import stashapi.log as log
from stashapi.stashapp import StashInterface
from dotenv import load_dotenv
import os

# Load the .env file
load_dotenv()

# Get the API key
api_key = os.getenv("ApiKey")

stash = StashInterface(
    {
        "scheme": "http",
        "host": "fraktal.auvilankuja.fi",
        "port": "9999",
        "logger": log,
        "ApiKey": api_key
    }
)
# Out:
# d Using stash (v0.25.1-0) endpoint at http://fraktal.auvilankuja.fi:9999/graphql

# %%
json_scenes = stash.find_scenes(
    {
        "stash_id_endpoint": {
            "endpoint": "https://theporndb.net/graphql",
            "modifier": "IS_NULL",
            "stash_id": ""
        }
    },
    filter={
        "per_page": 10, "page": 1, "sort": "path", "direction": "DESC"
    }
)

print(json_scenes)

# Create DataFrame with specific columns
df_stash_scenes = pd.DataFrame({
    'id': [item['id'] for item in json_scenes],
    'title': [item['title'] for item in json_scenes],
    'code': [item['code'] for item in json_scenes],
    'details': [item['details'] for item in json_scenes],
    'urls': [item['urls'] for item in json_scenes],
    'date': [item['date'] for item in json_scenes],
    'duration': [item['files'][0]['duration'] for item in json_scenes],
    'created_at': [item['created_at'] for item in json_scenes],
    'updated_at': [item['updated_at'] for item in json_scenes],
    'phash': [next((fp['value'] for fp in item['files'][0]['fingerprints'] if fp['type'] == 'phash'), None) for item in json_scenes],
    'stash_ids': [item['stash_ids'] for item in json_scenes],
})

df_stash_scenes
# Out:
# [{'id': '16422', 'title': 'Young natural small tits lesbians', 'code': '', 'details': "Lesbian lovers Alexis Crystal and Sunny Honey are strolling slowly down a forest trail, young, in love, and free. The sun shines warmly on their soft skin as they breathe the calming aroma of fresh foliage, their worries and cares carried away with the summer breeze. Standing in a close embrace, the lovely ladies slowly allow their hands to explore every inch of the other's body, from small tits to firm, round asses. A playful spank from Alexis sends the two babes on their way home, and once they have reached the bedroom they can no longer hold their desire at bay. Alexis strips Sunny slowly, teasingly, creating an anticipation in her lover that is finally released by a finger in Sunny's wet pussy. Alexis then removes her own dress as Sunny quivers in sweet orgasm. She lies Sunny down on the bed then mounts her lover's face, riding Sunny's tongue until she explodes in passionate orgasm!", 'director': '', 'urls': ['https://www.lesbea.com/scene/4232191/young-natural-small-tits-lesbians'], 'date': '2017-09-23', 'rating100': None, 'organized': True, 'o_counter': 0, 'interactive': False, 'interactive_speed': None, 'captions': None, 'created_at': '2024-03-29T09:25:23Z', 'updated_at': '2024-03-30T20:52:23Z', 'last_played_at': None, 'resume_time': 0, 'play_duration': 0, 'play_count': 0, 'play_history': [], 'o_history': [], 'files': [{'id': '215570', 'path': '/videos_z/Sexy Hub꞉ Lesbea – 2017-09-23 –  – Young Natural Small Tits Lesbians – Alexis Crystal, Sunny Honey [96e842a9a199aaf8].mp4', 'basename': 'Sexy Hub꞉ Lesbea – 2017-09-23 –  – Young Natural Small Tits Lesbians – Alexis Crystal, Sunny Honey [96e842a9a199aaf8].mp4', 'parent_folder_id': '1736', 'zip_file_id': None, 'mod_time': '2017-09-23T14:08:46Z', 'size': 1153074128, 'fingerprints': [{'type': 'oshash', 'value': '5e8d0fc2ad2645d6'}, {'type': 'phash', 'value': 'a62c22293cdfd3c6'}], 'format': 'mp4', 'width': 1920, 'height': 1080, 'duration': 1480.58, 'video_codec': 'h264', 'audio_codec': 'aac', 'frame_rate': 25, 'bit_rate': 6230408, 'created_at': '2024-03-29T09:25:23Z', 'updated_at': '2024-04-28T03:43:07Z'}], 'paths': {'screenshot': 'http://fraktal.auvilankuja.fi:9999/scene/16422/screenshot?t=1711831943', 'preview': 'http://fraktal.auvilankuja.fi:9999/scene/16422/preview', 'stream': 'http://fraktal.auvilankuja.fi:9999/scene/16422/stream?apikey=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1aWQiOiJzdGFzaCIsInN1YiI6IkFQSUtleSIsImlhdCI6MTcwOTU0Mzk2Mn0.oQxeczmukk1u-gyfB-S_ucJ-OMYiWtx8pIbU7XdQrdg', 'webp': 'http://fraktal.auvilankuja.fi:9999/scene/16422/webp', 'vtt': 'http://fraktal.auvilankuja.fi:9999/scene/5e8d0fc2ad2645d6_thumbs.vtt', 'sprite': 'http://fraktal.auvilankuja.fi:9999/scene/5e8d0fc2ad2645d6_sprite.jpg', 'funscript': 'http://fraktal.auvilankuja.fi:9999/scene/16422/funscript', 'interactive_heatmap': 'http://fraktal.auvilankuja.fi:9999/scene/16422/interactive_heatmap', 'caption': 'http://fraktal.auvilankuja.fi:9999/scene/16422/caption'}, 'scene_markers': [], 'galleries': [], 'studio': {'id': '374'}, 'movies': [], 'tags': [], 'performers': [{'id': '139'}, {'id': '2275'}], 'stash_ids': [{'endpoint': 'https://stashdb.org/graphql', 'stash_id': 'f1928e77-66fe-4d3e-b751-1ecf7f87d361'}], 'sceneStreams': [{'url': 'http://fraktal.auvilankuja.fi:9999/scene/16422/stream?apikey=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1aWQiOiJzdGFzaCIsInN1YiI6IkFQSUtleSIsImlhdCI6MTcwOTU0Mzk2Mn0.oQxeczmukk1u-gyfB-S_ucJ-OMYiWtx8pIbU7XdQrdg', 'mime_type': 'video/mp4', 'label': 'Direct stream'}, {'url': 'http://fraktal.auvilankuja.fi:9999/scene/16422/stream.mp4?apikey=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1aWQiOiJzdGFzaCIsInN1YiI6IkFQSUtleSIsImlhdCI6MTcwOTU0Mzk2Mn0.oQxeczmukk1u-gyfB-S_ucJ-OMYiWtx8pIbU7XdQrdg&resolution=ORIGINAL', 'mime_type': 'video/mp4', 'label': 'MP4'}, {'url': 'http://fraktal.auvilankuja.fi:9999/scene/16422/stream.mp4?apikey=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1aWQiOiJzdGFzaCIsInN1YiI6IkFQSUtleSIsIm ...
#       id                                              title    code  \
# 0  16422                  Young natural small tits lesbians
# 1  15186                   Kyler Worships Your Perfect Dick
# 2  15160                   Sensual Massage from Kyler Quinn
# 3  15203  My Stepsister And Her Girlfriend Swallow My Cu...  144063
# 4  15193    Karla Kush fucking in the desk with her tattoos   18533
# 5  14873                                     Sexual Release
# 6  14872                                        Never Alone
# 7  14871                                            My Loft
# 8  14870                                         Mes Perles
# 9  14869                           Sunglasses And Stockings
#
#                                              details  \
# 0  Lesbian lovers Alexis Crystal and Sunny Honey ...
# 1  Only VRedging can bring you oral action like t...
# 2  The majority of people think that only men cho...
# 3  Nikki Nutz and his stepsister Zazie hang out t...
# 4  Karla Kush decides it's time to help her boss ...
# 5
# 6
# 7
# 8
# 9
#
#                                                 urls        date  duration  \
# 0  [https://www.lesbea.com/scene/4232191/young-na...  2017-09-23   1480.58
# 1  [https://www.sexlikereal.com/scenes/kyler-wors...  2022-04-29   2002.85
# 2  [https://realjamvr.com/virtualreality/scene/id...  2022-10-30   2900.83
# 3  [https://cumswappingsis.com/video/watch/144063...  2022-03-19   1946.40
# 4  [https://www.naughtyamerica.com/scene/karla-ku...  2014-09-08   2604.31
# 5  [https://www.thelifeerotic.com/model/charlotta...  2015-03-06    928.22
# 6  [https://www.thelifeerotic.com/model/charlotta...  2015-02-22    765.56
# 7  [https://www.thelifeerotic.com/model/charlotta...  2015-02-15    597.01
# 8  [https://www.thelifeerotic.com/model/charlotta...  2015-02-03    764.52
# 9  [https://www.thelifeerotic.com/model/charlotta...  2014-11-09    660.05
#
#              created_at            updated_at             phash  \
# 0  2024-03-29T09:25:23Z  2024-03-30T20:52:23Z  a62c22293cdfd3c6
# 1  2024-03-08T07:35:08Z  2024-03-08T13:42:31Z  dd20758378e6a578
# 2  2024-03-07T08:01:34Z  2024-04-09T06:49:30Z  dca518cd92bcc3b8
# 3  2024-03-08T08:52:59Z  2024-03-08T13:22:20Z  96e1cbcca6f44992
# 4  2024-03-08T07:35:10Z  2024-03-08T16:10:59Z  a7dd9ec285a099d8
# 5  2024-02-20T06:19:59Z  2024-02-26T05:51:07Z  855c799c569d49a9
# 6  2024-02-20T06:19:59Z  2024-02-26T05:51:09Z  bd3e4e901cccc363
# 7  2024-02-20T06:19:59Z  2024-02-26T05:51:10Z  b036363770d96987
# 8  2024-02-20T06:19:59Z  2024-02-26T05:51:11Z  fc0f8087a9b036cf
# 9  2024-02-20T06:19:59Z  2024-02-26T05:51:12Z  c682f89379d3ac92
#
#                                            stash_ids
# 0  [{'endpoint': 'https://stashdb.org/graphql', '...
# 1  [{'endpoint': 'https://stashdb.org/graphql', '...
# 2  [{'endpoint': 'https://stashdb.org/graphql', '...
# 3  [{'endpoint': 'https://stashdb.org/graphql', '...
# 4  [{'endpoint': 'https://stashdb.org/graphql', '...
# 5  [{'endpoint': 'https://stashdb.org/graphql', '...
# 6  [{'endpoint': 'https://stashdb.org/graphql', '...
# 7  [{'endpoint': 'https://stashdb.org/graphql', '...
# 8  [{'endpoint': 'https://stashdb.org/graphql', '...
# 9  [{'endpoint': 'https://stashdb.org/graphql', '...

# %%
fingerprint_list
# Out:
# [[{'hash': 'ad7d1590f99a0e92', 'algorithm': 'PHASH'}],
#  [{'hash': 'a62c22293cdfd3c6', 'algorithm': 'PHASH'}],
#  [{'hash': 'dd20758378e6a578', 'algorithm': 'PHASH'}],
#  [{'hash': 'dca518cd92bcc3b8', 'algorithm': 'PHASH'}],
#  [{'hash': '96e1cbcca6f44992', 'algorithm': 'PHASH'}],
#  [{'hash': 'a7dd9ec285a099d8', 'algorithm': 'PHASH'}],
#  [{'hash': '855c799c569d49a9', 'algorithm': 'PHASH'}],
#  [{'hash': 'bd3e4e901cccc363', 'algorithm': 'PHASH'}],
#  [{'hash': 'b036363770d96987', 'algorithm': 'PHASH'}],
#  [{'hash': 'fc0f8087a9b036cf', 'algorithm': 'PHASH'}]]

# %%
import requests
import pandas as pd
import dotenv
import os

dotenv.load_dotenv()

api_key = os.getenv("TPDB_API_KEY")
host = os.getenv("TPDB_ENDPOINT")

# Define the headers, including any necessary authentication
headers = {
    "Content-Type": "application/json",
    "ApiKey": api_key,
}

with open('stashdb-graphql/findScenesBySceneFingerprints.graphql', 'r') as file:
    query = file.read()

variables = {
    "fingerprints": fingerprint_list
}

# Execute the query as before
response = requests.post(host, json={'query': query, 'variables': variables}, headers=headers)
if (response.status_code != 200):
    print(response.text)

df_stash_tpdb_matches = pd.DataFrame(columns=["stash_scene", "tpdb_matches"])


data = response.json()
list_of_lists = data['data']['findScenesBySceneFingerprints']

# Preparing data for merging
matches = []
for i, match_list in enumerate(list_of_lists):
    matches.append({'index': i, 'matches': match_list})

df_matches = pd.DataFrame(matches)
df_matches
# Out:
#    index                                            matches
# 0      0  [{'id': '526db130-958a-4624-850b-f6bb68b56ab8'...
# 1      1  [{'id': 'acb8a3b3-2608-4c4b-8570-82e679b3816a'...
# 2      2                                                 []
# 3      3  [{'id': '61ba6920-9bea-44ea-93fc-34fa2bda75ce'...
# 4      4  [{'id': '470a8011-3210-49f0-b7ab-6488d2b97333'...
# 5      5  [{'id': 'bba51fc1-66a9-42b2-ae9d-eeba55a3d638'...
# 6      6  [{'id': 'dffe1a7d-4729-433e-ae65-71f2e8b0f012'...
# 7      7  [{'id': 'e22787b9-5fb4-4401-b092-d64ac66e1621'...
# 8      8  [{'id': '76224670-5d55-47db-b3d7-9b711322f81d'...
# 9      9  [{'id': '97c64815-f7b5-4fbe-8b4a-131d6bef29ff'...

# %%
df_matches['matches'][0][0]['fingerprints']
# Out:
# [{'hash': '5e8d0fc2ad2645d6', 'algorithm': 'OSHASH', 'duration': 1480},
#  {'hash': 'a62c22293cdfd3c6', 'algorithm': 'PHASH', 'duration': 1480},
#  {'hash': '1991de6178ba0a21', 'algorithm': 'OSHASH', 'duration': 1480},
#  {'hash': '2d31363130383336', 'algorithm': 'PHASH', 'duration': None},
#  {'hash': 'a62c32293c9fd3c6', 'algorithm': 'PHASH', 'duration': 1480},
#  {'hash': 'ae2ce226c0aab072', 'algorithm': 'OSHASH', 'duration': None}]

# %%
# Define a function that will be applied to each cell in the 'matches' column
def filter_fingerprints(match_list):
    # Iterate over all matches and filter out the fingerprints based on your criteria
    for match in match_list:
        match['fingerprints'] = [
            fp for fp in match['fingerprints']
            if fp['algorithm'] == 'PHASH' and fp['duration'] is not None
        ]
    return match_list

# Apply the function to the 'matches' column of the df_matches DataFrame
df_matches['matches'] = df_matches['matches'].apply(filter_fingerprints)

# %%
# Assume df_stash_scenes has been defined earlier in your workflow
df_stash_scenes['index'] = range(len(df_stash_scenes))  # Setting an index if not already present

# Merge the DataFrames on the 'index' column
df_stash_tpdb_matches = pd.merge(df_stash_scenes, df_matches, on='index', how='left')

# Rename columns for clarity
df_stash_tpdb_matches.rename(columns={'matches': 'tpdb_matches'}, inplace=True)

# Drop the temporary 'index' column if no longer needed
df_stash_tpdb_matches.drop(columns=['index'], inplace=True)

# %%
df_stash_tpdb_matches
# Out:
#       id                                              title    code  \
# 0  16422                  Young natural small tits lesbians
# 1  15186                   Kyler Worships Your Perfect Dick
# 2  15160                   Sensual Massage from Kyler Quinn
# 3  15203  My Stepsister And Her Girlfriend Swallow My Cu...  144063
# 4  15193    Karla Kush fucking in the desk with her tattoos   18533
# 5  14873                                     Sexual Release
# 6  14872                                        Never Alone
# 7  14871                                            My Loft
# 8  14870                                         Mes Perles
# 9  14869                           Sunglasses And Stockings
#
#                                              details  \
# 0  Lesbian lovers Alexis Crystal and Sunny Honey ...
# 1  Only VRedging can bring you oral action like t...
# 2  The majority of people think that only men cho...
# 3  Nikki Nutz and his stepsister Zazie hang out t...
# 4  Karla Kush decides it's time to help her boss ...
# 5
# 6
# 7
# 8
# 9
#
#                                                 urls        date  duration  \
# 0  [https://www.lesbea.com/scene/4232191/young-na...  2017-09-23   1480.58
# 1  [https://www.sexlikereal.com/scenes/kyler-wors...  2022-04-29   2002.85
# 2  [https://realjamvr.com/virtualreality/scene/id...  2022-10-30   2900.83
# 3  [https://cumswappingsis.com/video/watch/144063...  2022-03-19   1946.40
# 4  [https://www.naughtyamerica.com/scene/karla-ku...  2014-09-08   2604.31
# 5  [https://www.thelifeerotic.com/model/charlotta...  2015-03-06    928.22
# 6  [https://www.thelifeerotic.com/model/charlotta...  2015-02-22    765.56
# 7  [https://www.thelifeerotic.com/model/charlotta...  2015-02-15    597.01
# 8  [https://www.thelifeerotic.com/model/charlotta...  2015-02-03    764.52
# 9  [https://www.thelifeerotic.com/model/charlotta...  2014-11-09    660.05
#
#              created_at            updated_at             phash  \
# 0  2024-03-29T09:25:23Z  2024-03-30T20:52:23Z  a62c22293cdfd3c6
# 1  2024-03-08T07:35:08Z  2024-03-08T13:42:31Z  dd20758378e6a578
# 2  2024-03-07T08:01:34Z  2024-04-09T06:49:30Z  dca518cd92bcc3b8
# 3  2024-03-08T08:52:59Z  2024-03-08T13:22:20Z  96e1cbcca6f44992
# 4  2024-03-08T07:35:10Z  2024-03-08T16:10:59Z  a7dd9ec285a099d8
# 5  2024-02-20T06:19:59Z  2024-02-26T05:51:07Z  855c799c569d49a9
# 6  2024-02-20T06:19:59Z  2024-02-26T05:51:09Z  bd3e4e901cccc363
# 7  2024-02-20T06:19:59Z  2024-02-26T05:51:10Z  b036363770d96987
# 8  2024-02-20T06:19:59Z  2024-02-26T05:51:11Z  fc0f8087a9b036cf
# 9  2024-02-20T06:19:59Z  2024-02-26T05:51:12Z  c682f89379d3ac92
#
#                                            stash_ids  \
# 0  [{'endpoint': 'https://stashdb.org/graphql', '...
# 1  [{'endpoint': 'https://stashdb.org/graphql', '...
# 2  [{'endpoint': 'https://stashdb.org/graphql', '...
# 3  [{'endpoint': 'https://stashdb.org/graphql', '...
# 4  [{'endpoint': 'https://stashdb.org/graphql', '...
# 5  [{'endpoint': 'https://stashdb.org/graphql', '...
# 6  [{'endpoint': 'https://stashdb.org/graphql', '...
# 7  [{'endpoint': 'https://stashdb.org/graphql', '...
# 8  [{'endpoint': 'https://stashdb.org/graphql', '...
# 9  [{'endpoint': 'https://stashdb.org/graphql', '...
#
#                                         tpdb_matches  \
# 0  [{'id': '526db130-958a-4624-850b-f6bb68b56ab8'...
# 1  [{'id': 'acb8a3b3-2608-4c4b-8570-82e679b3816a'...
# 2                                                 []
# 3  [{'id': '61ba6920-9bea-44ea-93fc-34fa2bda75ce'...
# 4  [{'id': '470a8011-3210-49f0-b7ab-6488d2b97333'...
# 5  [{'id': 'bba51fc1-66a9-42b2-ae9d-eeba55a3d638'...
# 6  [{'id': 'dffe1a7d-4729-433e-ae65-71f2e8b0f012'...
# 7  [{'id': 'e22787b9-5fb4-4401-b092-d64ac66e1621'...
# 8  [{'id': '76224670-5d55-47db-b3d7-9b711322f81d'...
# 9  [{'id': '97c64815-f7b5-4fbe-8b4a-131d6bef29ff'...
#
#                                filtered_fingerprints
# 0  [{'hash': 'a62c22293cdfd3c6', 'algorithm': 'PH...
# 1  [{'hash': 'bd024d8d12edadd2', 'algorithm': 'PH...
# 2                                                 []
# 3  [{'hash': '96e1cbcca6f44992', 'algorithm': 'PH...
# 4  [{'hash': 'a5199fc3e5b089d8', 'algorithm': 'PH...
# 5  [{'hash': '855c799c569949e9', 'algorithm': 'PH...
# 6  [{'hash': 'bd3e4e901dccc343', 'algorithm': 'PH...
# 7  [{'hash': 'b036363770d96987', 'algorithm': 'PH...
# 8  [{'hash': 'fc0f8087a9b036cf', 'algorithm': 'PH...
# 9  [{'hash': 'c682f89379d3ac92', 'algorithm': 'PH...

# %%
df_stash_tpdb_matches.iloc[0]
# Out:
# id                                                                   16422
# title                                    Young natural small tits lesbians
# code
# details                  Lesbian lovers Alexis Crystal and Sunny Honey ...
# urls                     [https://www.lesbea.com/scene/4232191/young-na...
# date                                                            2017-09-23
# duration                                                           1480.58
# created_at                                            2024-03-29T09:25:23Z
# updated_at                                            2024-03-30T20:52:23Z
# phash                                                     a62c22293cdfd3c6
# stash_ids                [{'endpoint': 'https://stashdb.org/graphql', '...
# tpdb_matches             [{'id': '526db130-958a-4624-850b-f6bb68b56ab8'...
# filtered_fingerprints    [{'hash': 'a62c22293cdfd3c6', 'algorithm': 'PH...
# Name: 0, dtype: object

# %%
df_stash_tpdb_matches.iloc[0]['tpdb_matches']
# Out:
# [{'id': '526db130-958a-4624-850b-f6bb68b56ab8',
#   'title': 'Young Natural Small Tits Lesbians',
#   'details': "Lesbian lovers Alexis Crystal and Sunny Honey are strolling slowly down a forest trail, young, in love, and free. The sun shines warmly on their soft skin as they breathe the calming aroma of fresh foliage, their worries and cares carried away with the summer breeze. Standing in a close embrace, the lovely ladies slowly allow their hands to explore every inch of the other's body, from small tits to firm, round asses. A playful spank from Alexis sends the two babes on their way home, and once they have reached the bedroom they can no longer hold their desire at bay. Alexis strips Sunny slowly, teasingly, creating an anticipation in her lover that is finally released by a finger in Sunny's wet pussy. Alexis then removes her own dress as Sunny quivers in sweet orgasm. She lies Sunny down on the bed then mounts her lover's face, riding Sunny's tongue until she explodes in passionate orgasm!",
#   'date': '2017-09-23',
#   'urls': [{'url': 'https://sexyhub.com/scene/4232191/young-natural-small-tits-lesbians',
#     'site': None}],
#   'performers': [{'performer': {'id': '1b5898d3-8ae1-4e36-9779-9961a77eb261',
#      'name': 'Alexis Crystal',
#      'gender': 'FEMALE'},
#     'as': 'Alexis Crystal'},
#    {'performer': {'id': '586a955d-115e-43c1-b9d6-669eb7278fbd',
#      'name': 'Sunny Honey',
#      'gender': 'FEMALE'},
#     'as': 'Sunny Honey'}],
#   'duration': 1,
#   'director': None,
#   'code': '4232191',
#   'deleted': False,
#   'created': '2019-11-29T15:02:10+00:00',
#   'updated': '2022-10-16T11:03:40+00:00',
#   'fingerprints': [{'hash': 'a62c22293cdfd3c6',
#     'algorithm': 'PHASH',
#     'duration': 1480},
#    {'hash': 'a62c32293c9fd3c6', 'algorithm': 'PHASH', 'duration': 1480}]}]

# %%
new_stash_ids = df_stash_tpdb_matches['stash_ids'].values[0] + [{ "endpoint": "https://theporndb.net/graphql", "stash_id": str(df_stash_tpdb_matches["tpdb_matches"].values[0][0]["id"]) }]

new_stash_ids
# Out:
# [{'endpoint': 'https://stashdb.org/graphql',
#   'stash_id': 'f1928e77-66fe-4d3e-b751-1ecf7f87d361'},
#  {'endpoint': 'https://theporndb.net/graphql',
#   'stash_id': '526db130-958a-4624-850b-f6bb68b56ab8'}]

# %%
stash.update_scene({ "id": df_stash_tpdb_matches['id'].values[0], "stash_ids": new_stash_ids })
# Out:
# '16422'
