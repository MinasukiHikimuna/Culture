# %%
from libraries.client_stashapp import get_stashapp_client

stash = get_stashapp_client()
# Out:
# dUsing stash (v0.27.2-7-ge642cf32) endpoint at http://localhost:6969/graphql
# dPersisting Connection to Stash with ApiKey...

# %%
import pandas as pd

# Open parquet file
df = pd.read_parquet("H:\\Git\\scrapymetadata\\scrapymetadata\\xart_data.parquet")

# %%
# Get unique performers across all galleries
unique_performers = set()
for performers_list in df['performers'].dropna():
    unique_performers.update(performers_list)

# Convert to sorted list for display
unique_performers = sorted(list(unique_performers))

# %%
for performer in unique_performers:
    stash.create_performer({"name": f"X-Art: {performer}"})

# %%
# Create lookup table of X-Art performers from Stash
performer_lookup = {}
for performer in unique_performers:
    stash_name = f"X-Art: {performer}"
    result = stash.find_performers({"name": {"value": stash_name, "modifier": "EQUALS"}})
    if result and len(result) > 0:
        performer_lookup[performer] = result[0]["id"]
    else:
        print(f"Warning: Could not find Stash performer '{stash_name}'")

# %%
x_art_galleries = stash.find_galleries(fragment="id title date details performers { id name } urls files { id basename } image_count")
df_x_art_galleries = pd.DataFrame(x_art_galleries)
df_x_art_galleries['basename'] = df_x_art_galleries['files'].apply(lambda x: x[0]['basename'] if x and len(x) > 0 else None)
df_x_art_galleries = df_x_art_galleries[df_x_art_galleries['basename'].str.lower().str.contains("x-art".lower())].copy()

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:1234/v1",
    api_key="lum-studio"
)

system_prompt = """
Extract a release name from these poorly named zip files. Zip names may contain studio name X-Art in some variations. It might contain quality like lrg which means large. File names can contain performer names like silvie here. There can be multiple performers. Performer names and qualities and similar things should be removed. Only answer with the likely release name, no other text.

Examples:
X-Art - 2013-01-09 - Susie & Clover - Warm Inside.zip => Warm Inside
x-art hayden h the dressing room-lrg.zip: hayden h the dressing room => The Dressing Room
TayTO-X-Art.13.12.02.Scarlet.Lucky.Man.IMAGESET.zip: TayTO-X-Art.13.12.02 IMAGESET => Lucky Man
x-art_leila_carmen_christmas_vacation-lrg.zip => Christmas Vacation
"""

def get_release_name(zip_file_name):
    completion = client.chat.completions.create(
        model="meta-llama-3-8b-instruct",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": zip_file_name}
        ]
    )

    return completion.choices[0].message.content

# %%
# Create extracted_release_name column if it doesn't exist
if 'extracted_release_name' not in df_x_art_galleries.columns:
    df_x_art_galleries['extracted_release_name'] = ''

# Fill in extracted names for empty titles
for idx in df_x_art_galleries[df_x_art_galleries['title'] == ''].index:
    basename = df_x_art_galleries.loc[idx, 'basename']
    extracted_name = get_release_name(basename)
    df_x_art_galleries.loc[idx, 'extracted_release_name'] = extracted_name
    print(f"Extracted name for {basename}: {extracted_name}")
# Out:
# Extracted name for x-art brynn lexi three sisters-lrg.zip: Three Sisters
# Extracted name for x-art hayden h summer plaything-lrg.zip: Summer Plaything
# Extracted name for x-art hayden h the dressing room-lrg.zip: The Dressing Room
# Extracted name for x-art hayden pink and tight-lrg.zip: Pink And Tight
# Extracted name for x-art tori beach beauty-lrg.zip: Tori Beach Beauty
# Extracted name for x-art victoria exotic angel-lrg.zip: Exotic Angel
# Extracted name for x-art victoria melanie every mans desire-lrg.zip: Every Mans Desire
# Extracted name for x-art_jenny_fallen_angel-lrg.zip: Fallen Angel
# Extracted name for x-art_karina_bella_karina-lrg.zip: Karina
# Extracted name for x-art_karina_love_to_love_you-lrg.zip: Love to Love You
# Extracted name for x-art_kat_bound_to_please-lrg.zip: Bound to Please
# Extracted name for x-art_kat_translucence-lrg.zip: Translucence
# Extracted name for x-art_katka_bananas-lrg.zip: Bananas
# Extracted name for x-art_katka_mikah_my_best_friends_boyfriend-lrg.zip: My Best Friend's Boyfriend
# Extracted name for x-art_katka_sweet_surprise-lrg.zip: Sweet Surprise
# Extracted name for x-art_kato_long_legs_and_all-lrg.zip: Long Legs and All
# Extracted name for x-art_kato_party_girl-lrg.zip: Party Girl
# Extracted name for x-art_katrina_come_closer-lrg.zip: Come Closer
# Extracted name for x-art_katrina_perfectly_pink-lrg.zip: Perfectly Pink
# Extracted name for x-art_katrina_skin_and_stone-lrg.zip: Skin and Stone
# Extracted name for x-art_katrina_watch_me_cum-lrg.zip: Watch Me Cum
# Extracted name for x-art_katrina_watch_me_cum_ii-lrg.zip: Watch Me Cum II
# Extracted name for x-art_katy_high_school_sweetheart-lrg.zip: High School Sweetheart
# Extracted name for x-art_katy_pajamas_and_pink-lrg.zip: Pajamas and Pink
# Extracted name for x-art_kiley_pretty_baby-lrg.zip: Pretty Baby
# Extracted name for x-art_kitty_after_hours_111111-lrg.zip: After Hours
# Extracted name for x-art_klara_erotic_studio_nudes-lrg.zip: Erotic Studio Nudes
# Extracted name for x-art_kristen_girl_next_door-lrg.zip: Girl Next Door
# Extracted name for x-art_kristen_pink_on_the_inside-lrg.zip: Pink on the Inside
# Extracted name for x-art_kristi_my_little_secret-lrg.zip: My Little Secret
# Extracted name for x-art_kristi_pure_seduction-lrg.zip: Pure Seduction
# Extracted name for x-art_kristi_waiting_for_you-lrg.zip: Waiting for You
# Extracted name for x-art_lana_sexy_flexy-lrg.zip: Sexy Flexy
# Extracted name for x-art_leah_blue_rain-lrg.zip: Blue Rain
# Extracted name for x-art_leila_sex_on_the_beach-lrg.zip: Sex on the Beach
# Extracted name for x-art_leila_sex_with_passion-lrg.zip: Sex With Passion
# Extracted name for x-art_leila_think_pink-lrg.zip: Think Pink
# Extracted name for x-art_lexi_little_lexi-lrg.zip: Little Lexi
# Extracted name for x-art_lilly_bound_and_beautiful-lrg.zip: Bound and Beautiful
# Extracted name for x-art_liv_deep_purple-lrg.zip: Deep Purple
# Extracted name for x-art_liv_pure_perfection-lrg.zip: Pure Perfection
# Extracted name for x-art_malena_delicious-lrg.zip: Delicious
# Extracted name for x-art_malena_elle_hot_sauna-lrg.zip: Hot Sauna
# Extracted name for x-art_malena_elle_make_me_wet-lrg.zip: Make Me Wet
# Extracted name for x-art_malena_sunset_strip-lrg.zip: Sunset Strip
# Extracted name for x-art_marie_the_art_of_anal_sex-lrg.zip: The Art of Anal Sex
# Extracted name for x-art_maryjane_natural_beauty-lrg.zip: Natural Beauty
# Extracted name for x-art_megan_love_tunnel-lrg.zip: Love Tunnel
# Extracted name for x-art_megan_puffy_when_wet-lrg.zip: When Wet
# Extracted name for x-art_melanie_lovely_latina-lrg.zip: Lovely Latina
# Extracted name for x-art_scarlett_red_hot-lrg.zip: Red Hot
# Extracted name for x-art_shyla_jennings_tight-lrg.zip: Tight
# Extracted name for x-art_silvie_centerfold-lrg.zip: Centerfold
# Extracted name for x-art_silvie_morning_to_remember-lrg.zip: Morning to Remember
# Extracted name for x-art_silvie_pantyhose_fetish-lrg.zip: Pantyhose Fetish
# Extracted name for x-art_sofia_bella_sofia-lrg.zip: Sofia
# Extracted name for x-art_sofia_dripping_wet-lrg.zip: Dripping Wet
# Extracted name for x-art_sofia_flexible_ballerina-lrg.zip: Flexible Ballerina
# Extracted name for x-art_stacy_annemarie_summer_heat-lrg.zip: Summer Heat
# Extracted name for x-art_stacy_poolside_romp-lrg.zip: Poolside Romp
# Extracted name for x-art_stasha_puffy_nipples-lrg.zip: Puffy Nipples
# Extracted name for x-art_sunshine_supertight-lrg.zip: Supertight
# Extracted name for x-art_susie_cream_dream-lrg.zip: Cream Dream
# Extracted name for x-art_susie_so_sweet-lrg.zip: So Sweet
# Extracted name for x-art_tabitha_touch_of_perfection-lrg.zip: Touch of Perfection
# Extracted name for x-art_tara_luscious_lips-lrg.zip: Luscious Lips
# Extracted name for x-art_tatiana_the_voyeur-lrg.zip: The Voyeur
# Extracted name for x-art_tiffany_absolutely_gorgeous-lrg.zip: Absolutely Gorgeous
# Extracted name for x-art_tiffany_seaside_fantasy-lrg.zip: Seaside Fantasy
# Extracted name for x-art_tiffany_sex_with_a_supermodel-lrg.zip: Sex With A Supermodel
# Extracted name for x-art_veronica_rodriguez_latin_dream-lrg.zip: Latin Dream
# Extracted name for x-art_veronika_friends_with_benefits-lrg.zip: Friends with Benefits
# Extracted name for x-art_willow_alone_at_last-lrg.zip: Alone At Last

# %%
# Using .loc[] is safer for boolean indexing and avoids SettingWithCopyWarning
df_galleries = df.loc[df['type'] == "gallery"].copy()

# Merge directly with df_galleries instead of df since we only want gallery records
df_merged = pd.merge(df_x_art_galleries, df_galleries,
                     left_on=df_x_art_galleries['extracted_release_name'].str.lower(),
                     right_on=df_galleries['title'].str.lower(),
                     how='inner')

# %%
df_merged['image_count_diff'] = df_merged['image_count_x'] - df_merged['image_count_y']

# %%
for idx, row in df_merged.iterrows():
    url = row['url']

    stash_id = row['id']

    refreshed_gallery = stash.find_gallery(stash_id)

    existing_urls = refreshed_gallery["urls"]
    if url not in existing_urls:
        existing_urls.append(url)

    performer_ids = [performer_lookup[performer] for performer in row["performers_y"]]
    
    updated_gallery = {
        "id": stash_id,
        "title": row["title_y"],
        "date": row["date_y"],
        "details": row["description"],
        "performer_ids": performer_ids,
        "urls": existing_urls
    }
    
    stash.update_gallery(updated_gallery)

# %%
df[df['type'].eq("gallery") & df['title'].notnull() & df['title'].str.lower().str.contains("our style".lower())]
# Out:
#         type                                                url  \
# 328  gallery  https://www.x-art.com/galleries/Aperitif%20Our...
#
#                   title        date performers  \
# 328  Aperitif Our Style  2013-12-15  [Adriana]
#
#                                            description video_resolution  \
# 328  Enjoy this delicious kitchen romp between the ...             None
#
#                                                   html  image_count  \
# 328  <!doctype html>\n<html class="no-js" lang="en"...         69.0
#
#     image_resolution
# 328      4000 pixels
