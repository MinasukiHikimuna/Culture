# %%
# Create Stash app client

import pandas as pd
import dotenv
import os
from libraries.client_stashapp import get_stashapp_client
from libraries.StashDbClient import StashDbClient

dotenv.load_dotenv()

stash = get_stashapp_client()
STASHAPP_URL = os.getenv("STASHAPP_URL")

stashbox_client = StashDbClient(
    os.getenv("STASHDB_ENDPOINT"),
    os.getenv("STASHDB_API_KEY"),
)
# Out:
# dUsing stash (v0.27.1-0) endpoint at http://localhost:6969/graphql
# dPersisting Connection to Stash with ApiKey...

# %%
# Utility functions
def create_modified_filter(data_quality_filter):
    depth = data_quality_filter['object_filter']['tags']['value']['depth']
    included_tag_ids = [tag['id'] for tag in data_quality_filter['object_filter']['tags']['value']['items']]
    excluded_tag_ids = [tag['id'] for tag in data_quality_filter['object_filter']['tags']['value']['excluded']]

    # Create the modified filter
    modified_filter = {
        'tags': {
            'modifier': 'INCLUDES_ALL',
            'value': included_tag_ids,
            'depth': depth,
            'excludes': excluded_tag_ids,
        }
    }
    return modified_filter

def get_scene_count(filter):
    result = stash.call_GQL("""query FindScenes($scene_filter: SceneFilterType) {
        findScenes(scene_filter: $scene_filter) {
            count
        }
    }""", variables={"scene_filter": filter})
    return result['findScenes']['count']

# %%
# Get all saved filters
saved_filters = stash.call_GQL("""query FindSavedFilters {
    findSavedFilters {
        id
        mode
        name
        filter
        object_filter
        ui_options
    }
}""")

# %%
# Get all data quality filters
data_quality_filters = [filter for filter in saved_filters['findSavedFilters'] if 'data quality' in filter['name'].lower()]

# %%
data_quality_filters

# %%
# Loop through all data quality filters and print out name and count of matching scenes
sorted_data_quality_filters = sorted(data_quality_filters, key=lambda x: x['name'])
for filter in sorted_data_quality_filters:
    name = filter['name']
    modified_filter = create_modified_filter(filter)
    scene_count = get_scene_count(modified_filter)
    print(f"{name}: {scene_count} scenes")

# %%
twosome_lesbian_tags = stash.find_tag("Twosome (Lesbian)")
multiple_sex_scenes_tag = stash.find_tag("Multiple Sex Scenes In A Scene")
twosome_lesbian_scenes = stash.find_scenes({
    "tags": {"modifier": "INCLUDES_ALL", "value": [twosome_lesbian_tags['id']], "excludes": [multiple_sex_scenes_tag['id']]}
}, fragment="id title performers { id name gender } tags { id name }")

# %%
data_quality_issue_tag = stash.find_tag("Data Quality Issue")

# %%
all_scenes = stash.find_scenes({}, fragment="id title performers { id name gender } tags { id name }")
all_tags = stash.find_tags({}, fragment="id name description")

# %%
from abc import ABC, abstractmethod

class Rule(ABC):
    @abstractmethod
    def check(self, scene):
        pass
    
    def scene_has_any_tags(self, scene, tag_names):
        return any(tag['name'] in tag_names for tag in scene['tags'])

class GroupMakeUpRule(Rule):
    def __init__(self):
        self.tag_hierarchy = {
            "Solo": ["Solo Female", "Solo Male", "Solo Trans"],
            "Twosome": ["Twosome (Lesbian)", "Twosome (Straight)", "Twosome (Trans-Female)", "Twosome (Trans-Male)"],
            "Threesome": ["Threesome (Lesbian)", "Threesome (BBG)", "Threesome (BGG)"],
            "Foursome": ["Foursome (Lesbian)", "Foursome (BGGG)", "Foursome (BBGG)", "Foursome (BBBG)"],
        }
        self.special_rules = {
            "Solo Female": {
                "required_gender": ['FEMALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer']
            },
            "Solo Male": {
                "required_gender": ['MALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer']
            },
            "Solo Trans": {
                "required_gender": ['TRANS'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer']
            },
            "Twosome (Lesbian)": {
                "required_gender": ['FEMALE', 'FEMALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer']
            },
            "Twosome (Straight)": {
                "required_gender": ['FEMALE', 'MALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer', 'Missing Performer (Male)']
            },
            "Threesome (Lesbian)": {
                "required_gender": ['FEMALE', 'FEMALE', 'FEMALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer']
            },
            "Threesome (BBG)": {
                "required_gender": ['FEMALE', 'MALE', 'MALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer', 'Missing Performer (Male)']
            },
            "Threesome (BGG)": {
                "required_gender": ['FEMALE', 'FEMALE', 'MALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer', 'Missing Performer (Male)']
            },
            "Threesome (BBT)": {
                "required_gender": ['MALE', 'MALE', 'TRANSGENDER_FEMALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer']
            },
            "Threesome (BGT)": {
                "required_gender": ['MALE', 'FEMALE', 'TRANSGENDER_FEMALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer']
            },
            "Threesome (GGT)": {
                "required_gender": ['FEMALE', 'FEMALE', 'TRANSGENDER_FEMALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer']
            },
            "Threesome (GTT)": {
                "required_gender": ['FEMALE', 'TRANSGENDER_FEMALE', 'TRANSGENDER_FEMALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer']
            },
            "Threesome (Trans-Female)": {
                "required_gender": ['TRANSGENDER_FEMALE', 'TRANSGENDER_FEMALE', 'TRANSGENDER_FEMALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer']
            },
            "Foursome (BGGG)": {
                "required_gender": ['FEMALE', 'FEMALE', 'FEMALE', 'MALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer', 'Missing Performer (Male)']
            },
            "Foursome (BBGG)": {
                "required_gender": ['FEMALE', 'FEMALE', 'MALE', 'MALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer', 'Missing Performer (Male)']
            },
            "Foursome (BBBG)": {
                "required_gender": ['FEMALE', 'MALE', 'MALE', 'MALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer', 'Missing Performer (Male)']
            },
            "Foursome (Lesbian)": {
                "required_gender": ['FEMALE', 'FEMALE', 'FEMALE', 'FEMALE'],
                "exception_tags": ['Multiple Sex Scenes In A Scene', 'Non-Sex Performer']
            },
        }

    def check(self, scene):
        performer_genders = sorted([performer['gender'] for performer in scene['performers'] if performer['gender']])
        
        # Check tag hierarchy
        for parent_tag, child_tags in self.tag_hierarchy.items():
            if self.scene_has_any_tags(scene, child_tags) and not self.scene_has_any_tags(scene, [parent_tag]):
                return "Data Quality Issue: Group Makeup Specific But Not Generic"
            if self.scene_has_any_tags(scene, [parent_tag]) and not self.scene_has_any_tags(scene, child_tags):
                return "Data Quality Issue: Group Makeup Generic But Not Specific"

        # Check special rules
        for tag, rule in self.special_rules.items():
            if self.scene_has_any_tags(scene, [tag]):
                if 'required_gender' in rule and not self.scene_has_any_tags(scene, rule.get('exception_tags', [])):
                    if len(performer_genders) != len(rule['required_gender']):
                        return "Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup"
                    elif performer_genders != rule['required_gender']:
                        return "Data Quality Issue: Incorrect Performer Genders Compared To Group Makeup"

        return None

class FacialRule(Rule):
    def check(self, scene):
        if (
            self.scene_has_any_tags(scene, ["Solo Female", "Twosome (Lesbian)", "Threesome (Lesbian)"]) and
            self.scene_has_any_tags(scene, ['Facial']) and
            not self.scene_has_any_tags(scene, ['Fake Cum', 'Jerk Off Instruction', 'Multiple Sex Scenes In A Scene'])
        ):
            return "Data Quality Issue: Incorrect Facial Tag"
        return None


rules = [
    FacialRule(),
    GroupMakeUpRule(),
    # Add more rules here as needed
]

def check_tag_rules(scenes, rules):
    all_violating_scenes = []
    for rule in rules:
        violating_scenes = []
        for scene in scenes:
            result = rule.check(scene)
            if result:
                violating_scenes.append({
                    'id': scene['id'],
                    'title': scene['title'],
                    'tags': [tag['name'] for tag in scene['tags']],  # Extract tag names
                    'tag_to_apply': result
                })
        all_violating_scenes.extend(violating_scenes)
    return all_violating_scenes

violating_scenes = check_tag_rules(all_scenes, rules)

print(f"Found {len(violating_scenes)} scenes violating the tag rules:")
for scene in violating_scenes:
    print(f"{scene['title']} {STASHAPP_URL}/scenes/{scene['id']}")
    print(f"Tags: {', '.join(scene['tags'])}")
    print(f"Tag to apply: {scene['tag_to_apply']}")
    print()
    
    refreshed_scene = stash.find_scene(scene['id'], fragment="performers { id name gender } tags { id name }")
    tags = [tag['id'] for tag in refreshed_scene['tags']]
    new_tag = stash.find_tag({"name": scene['tag_to_apply'], "parent_ids": [data_quality_issue_tag['id']]}, create=True)
    tags.append(new_tag['id'])
    stash.update_scene({
        "id": scene['id'],
        "tag_ids": tags
    })
# Out:
# iCould not find tag with name='Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup' creating
# Found 1470 scenes violating the tag rules:
#  https://stash.chiefsclub.com/scenes/374
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/375
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/398
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/445
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/449
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/472
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/473
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/484
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/488
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/490
# Tags: AI_Tagged, Ass Licking_AI, Ass Penetration_AI, Fingering_AI, Grabbing Ass_AI, Grabbing Boobs_AI, Grabbing Hair/Head_AI, Kissing_AI, Missing: StashDB, Pussy Licking (Clearly Visible)_AI, Pussy Licking_AI, Pussy Rubbing_AI, Sucking Fingers_AI, Twosome, Twosome (Lesbian), Vaginal Fucking_AI, Vaginal Penetration_AI, Wet (Genitals)_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/530
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/596
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/633
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/753
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/754
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/772
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/782
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/784
# Tags: AI_Tagged, Blowjob_AI, Cum on Person_AI, Cumshot_AI, Grabbing Ass_AI, Grabbing Boobs_AI, Grabbing Hair/Head_AI, Handjob_AI, Kissing_AI, Licking Penis_AI, Missing: StashDB, Pussy Licking (Clearly Visible)_AI, Pussy Licking_AI, Twosome, Twosome (Straight), Vaginal Fucking_AI, Vaginal Penetration_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/806
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/837
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/851
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/863
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/885
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/927
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1014
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1016
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1020
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1070
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1075
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1084
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1085
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1086
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1190
# Tags: AI_Tagged, Anal Fucking_AI, Ass Penetration_AI, Ball Licking/Sucking_AI, Blowjob_AI, Cum on Person_AI, Cumshot_AI, Deepthroat_AI, Fingering_AI, Grabbing Ass_AI, Grabbing Boobs_AI, Grabbing Hair/Head_AI, Handjob_AI, Kissing_AI, Licking Penis_AI, Missing: StashDB, Pussy Licking (Clearly Visible)_AI, Pussy Licking_AI, Pussy Rubbing_AI, Threesome, Threesome (BGG), Titjob_AI, Vaginal Fucking_AI, Vaginal Penetration_AI, Wet (Genitals)_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1193
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1194
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1195
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1196
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1201
# Tags: AI_Tagged, Anal Fucking_AI, Ass Penetration_AI, Blowjob_AI, Cum on Person_AI, Cumshot_AI, Fingering_AI, Grabbing Ass_AI, Grabbing Boobs_AI, Grabbing Hair/Head_AI, Handjob_AI, Missing: StashDB, Pussy Licking (Clearly Visible)_AI, Pussy Licking_AI, Pussy Rubbing_AI, Sucking Fingers_AI, Twosome, Twosome (Straight), Vaginal Fucking_AI, Vaginal Penetration_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1204
# Tags: AI_Tagged, Ball Licking/Sucking_AI, Blowjob_AI, Grabbing Boobs_AI, Handjob_AI, Licking Penis_AI, Masturbation_AI, Missing: StashDB, Pussy Rubbing_AI, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1241
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1242
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1266
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1267
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1282
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1319
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1320
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1323
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1324
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1325
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1328
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1339
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1341
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1354
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1365
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1366
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1391
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1420
# Tags: 69_AI, AI_Tagged, Anal Fucking_AI, Ass Licking_AI, Ass Penetration_AI, Blowjob_AI, Cum on Person_AI, Cumshot_AI, Grabbing Ass_AI, Grabbing Boobs_AI, Grabbing Hair/Head_AI, Handjob_AI, Kissing_AI, Licking Penis_AI, Masturbation_AI, Missing: StashDB, Pussy Licking (Clearly Visible)_AI, Pussy Licking_AI, Pussy Rubbing_AI, Threesome, Threesome (BGG), Vaginal Fucking_AI, Vaginal Penetration_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1425
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1441
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1465
# Tags: AI_Tagged, Ass Penetration_AI, Blowjob_AI, Fingering_AI, Grabbing Ass_AI, Grabbing Hair/Head_AI, Handjob_AI, Kissing_AI, Missing: StashDB, Pussy Licking_AI, Twosome, Twosome (Straight), Vaginal Fucking_AI, Vaginal Penetration_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1466
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1468
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1469
# Tags: Foursome, Foursome (BGGG), Missing Performer (Female), Missing: StashDB
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1483
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1502
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1505
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1506
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1507
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1516
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1550
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1551
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1553
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1555
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1576
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1583
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1584
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1629
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1630
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1631
# Tags: 69_AI, AI_Tagged, Ass Licking_AI, Ass Penetration_AI, Blowjob_AI, Cum on Person_AI, Cumshot_AI, Deepthroat_AI, Double Penetration_AI, Fingering_AI, Grabbing Ass_AI, Grabbing Boobs_AI, Grabbing Hair/Head_AI, Handjob_AI, Kissing_AI, Masturbation_AI, Missing: StashDB, Pussy Licking (Clearly Visible)_AI, Pussy Licking_AI, Pussy Rubbing_AI, Twosome, Twosome (Straight), Vaginal Fucking_AI, Vaginal Penetration_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1632
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1659
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1665
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1679
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1716
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1717
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1718
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1719
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1722
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1723
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1724
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1725
# Tags: AI_Tagged, Anal Fucking_AI, Ass Penetration_AI, Ball Licking/Sucking_AI, Blowjob_AI, Fingering_AI, Grabbing Ass_AI, Grabbing Boobs_AI, Grabbing Hair/Head_AI, Handjob_AI, Licking Penis_AI, Missing: StashDB, Pussy Licking (Clearly Visible)_AI, Pussy Licking_AI, Twosome, Twosome (Straight), Undressing_AI, Vaginal Fucking_AI, Vaginal Penetration_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1726
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1752
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1753
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1754
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1798
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1825
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1935
# Tags: AI_Tagged, Ball Licking/Sucking_AI, Blowjob_AI, Cumshot_AI, Handjob_AI, Kissing_AI, Licking Penis_AI, Missing: StashDB, Sucking Fingers_AI, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1941
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1956
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/1975
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2122
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2123
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2124
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2147
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2188
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2202
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2204
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2206
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2240
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2244
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2246
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2247
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2256
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2277
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2278
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2279
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2281
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2282
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2298
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2300
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2374
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2433
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2461
# Tags: AI_Tagged, Anal Fucking_AI, Ass Penetration_AI, Blowjob_AI, Cum on Person_AI, Cumshot_AI, Deepthroat_AI, Fingering_AI, Grabbing Ass_AI, Grabbing Hair/Head_AI, Handjob_AI, Missing: StashDB, Pussy Licking_AI, Pussy Rubbing_AI, Twosome, Twosome (Straight), Vaginal Fucking_AI, Vaginal Penetration_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2494
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2495
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2500
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2560
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2610
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2977
# Tags: Missing: StashDB, Solo, Solo Trans
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/2984
# Tags: Missing: StashDB, Solo, Solo Trans
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3063
# Tags: Missing: StashDB, Solo, Solo Trans
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3064
# Tags: Missing: StashDB, Solo, Solo Trans
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3065
# Tags: Missing: StashDB, Solo, Solo Trans
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3102
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3127
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3135
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3136
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3140
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3141
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3142
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3150
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3151
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3152
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3153
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3155
# Tags: Foursome, Foursome (BBGG), Missing: StashDB
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3228
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3229
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3230
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3231
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3232
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3233
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3235
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3236
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3237
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3238
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3239
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3240
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3241
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3242
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3243
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3244
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3245
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3258
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3259
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3321
# Tags: Missing: StashDB, Mixed Race, Mixed Race Woman, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3322
# Tags: Missing: StashDB, Mixed Race, Mixed Race Woman, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3330
# Tags: Missing: StashDB, Mixed Race, Mixed Race Woman, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3427
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3428
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3430
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3438
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3441
# Tags: Missing: StashDB, Missing: TPDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3442
# Tags: Missing: StashDB, Missing: TPDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3446
# Tags: Missing: StashDB, Missing: TPDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3459
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3460
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3461
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3820
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3821
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3823
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3824
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3825
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3826
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3827
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3828
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3829
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3830
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3831
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3832
# Tags: 69_AI, AI_Tagged, Anal Fucking_AI, Ass Penetration_AI, Ball Licking/Sucking_AI, Blowjob_AI, Cumshot_AI, Fingering_AI, Grabbing Ass_AI, Grabbing Hair/Head_AI, Handjob_AI, Licking Penis_AI, Masturbation_AI, Missing: StashDB, Pussy Licking (Clearly Visible)_AI, Pussy Licking_AI, Pussy Rubbing_AI, Twosome, Twosome (Straight), Undressing_AI, Vaginal Fucking_AI, Vaginal Penetration_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3833
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3913
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3914
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3915
# Tags: AI_Tagged, Grabbing Boobs_AI, Handjob_AI, Missing: StashDB, Titjob_AI, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3918
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3919
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3922
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3924
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3925
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3926
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3927
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3928
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3966
# Tags: AI_Tagged, Ass_AI, Asshole_AI, Belly Button_AI, Boobs_AI, Face_AI, Fingering_AI, Fingers_AI, Grabbing Boobs_AI, Grabbing Hair/Head_AI, Lower Legs_AI, Masturbation_AI, Missing: StashDB, Nipples_AI, Pussy Rubbing_AI, Pussy_AI, Solo, Solo Female, Sucking Toy/Dildo_AI, Thighs_AI, Tongue_AI, Vaginal Penetration_AI, Vibrating_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/3967
# Tags: AI_Tagged, Ass_AI, Asshole_AI, Belly Button_AI, Boobs_AI, Face_AI, Feet_AI, Fingering_AI, Fingers_AI, Lower Legs_AI, Masturbation_AI, Missing: StashDB, Nipples_AI, Pussy Rubbing_AI, Pussy_AI, Solo, Solo Female, Thighs_AI, Vaginal Penetration_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4078
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4079
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4082
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4083
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4084
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4086
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4090
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4091
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4098
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4100
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4117
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4123
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4124
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4125
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4127
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4128
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4130
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4132
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4140
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4150
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4151
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4162
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4167
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4168
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4607
# Tags: 69_AI, AI_Tagged, Anal Fucking_AI, Ass Licking_AI, Ass Penetration_AI, Ball Licking/Sucking_AI, Blowjob_AI, Grabbing Ass_AI, Grabbing Boobs_AI, Grabbing Hair/Head_AI, Handjob_AI, Kissing_AI, Licking Penis_AI, Missing: StashDB, Pussy Licking_AI, Pussy Rubbing_AI, Tribbing/Scissoring_AI, Twosome, Twosome (Straight), Vaginal Fucking_AI, Vaginal Penetration_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4611
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4612
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4625
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4626
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4632
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4633
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4646
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4659
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/4660
# Tags: Missing: StashDB, Solo, Solo Female
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# ...
# Tag to apply: Data Quality Issue: Group Makeup Generic But Not Specific
#
# Tantric couple ritual https://stash.chiefsclub.com/scenes/22345
# Tags: Blond Hair, Hardcore, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Massage, Small Tits, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Performer Genders Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24212
# Tags: Missing Performer (Female), Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24213
# Tags: Missing Performer (Female), Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24214
# Tags: Missing Performer (Female), Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24215
# Tags: Missing Performer (Female), Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24216
# Tags: Missing Performer (Female), Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24217
# Tags: Missing Performer (Female), Missing: StashDB, Thong, Tickling, Topless, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24218
# Tags: Missing Performer (Female), Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24219
# Tags: Missing Performer (Female), Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24220
# Tags: Missing Performer (Female), Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24221
# Tags: Missing Performer (Female), Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24222
# Tags: Missing Performer (Female), Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24223
# Tags: Missing Performer (Female), Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24230
# Tags: Missing: StashDB, Threesome, Threesome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24231
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24232
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24233
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24237
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24238
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/24239
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Voracious 2 ep18 - I Am Foul And Corrupt https://stash.chiefsclub.com/scenes/23651
# Tags: Anal, Big Tits, Black, Blond Hair, Blowjob, Brown Hair, Deepthroat, Double Penetration (DP), Fingering, Foursome, Foursome (BGGG), Hardcore, Interracial, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Natural Tits, Open Mouth Facial, Pornstar, Pussy Fingering, Pussy Licking, Rimming, Toys
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Anouk Bound Gagged Machine-Fucked https://stash.chiefsclub.com/scenes/23741
# Tags: BDSM, Fetish, Fucking Machines, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Redistribution, Shoes, Stripper, Submission, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Anouk Chairbound Ballgagged Tit-Grabbed https://stash.chiefsclub.com/scenes/23742
# Tags: BDSM, Breast Play, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Redistribution, Shoes, Submission, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Anouk Chair-Tied Ballgagged Tit-Grabbed https://stash.chiefsclub.com/scenes/23743
# Tags: BDSM, Breast Play, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Redistribution, Submission, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Anouk Chair-Tied Cleavegagged Tit-Grabbed https://stash.chiefsclub.com/scenes/23744
# Tags: BDSM, Boots, Breast Play, Fetish, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Redistribution, Submission, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Anouk Immobilized Mouth-Stuffed Tapegagged https://stash.chiefsclub.com/scenes/23745
# Tags: BDSM, Boots, Fetish, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Redistribution, Submission, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Anouk Tied to Ladder Tit-Grabbed Nipple-Clamped https://stash.chiefsclub.com/scenes/23746
# Tags: BDSM, Boots, Breast Play, Fetish, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Redistribution, Submission, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Heavy Struggling Girl Controlled By Girl https://stash.chiefsclub.com/scenes/23747
# Tags: AI_Tagged, BDSM, Boots, Fetish, Grabbing Boobs_AI, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Redistribution, Submission, Twosome, Twosome (Lesbian), Undressing_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Darryl Hanah in This Ain't Fox News XXX https://stash.chiefsclub.com/scenes/1199
# Tags: Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Missy Monroe & Giner Lea in Anal Swine #1 https://stash.chiefsclub.com/scenes/1322
# Tags: Anal, Blond Hair, Hardcore, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Red Hair, Small Tits, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Adara Star & Kurious in Hot Showers #1 https://stash.chiefsclub.com/scenes/5424
# Tags: Markers: TPDB: Missing, Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Karla Kush in Hustler's Amateur Action #5 https://stash.chiefsclub.com/scenes/7043
# Tags: All Natural, Blond Hair, Blue Eyes, Facial, Hardcore, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Oral Sex, Short Woman, Small Tits, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Dping Dora https://stash.chiefsclub.com/scenes/1223
# Tags: Foursome, Foursome (BBBG), Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Missing: StashDB
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# She Was Froze and Fucked by the Doctors https://stash.chiefsclub.com/scenes/2205
# Tags: Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Rilynn & Roxi Milking https://stash.chiefsclub.com/scenes/5302
# Tags: Markers: TPDB: Missing, Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Candy Alexa & Georgia Lyall https://stash.chiefsclub.com/scenes/11828
# Tags: Markers: TPDB: Missing, Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Jim Slip's 3Rd Law https://stash.chiefsclub.com/scenes/12726
# Tags: Markers: TPDB: Missing, Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Babe Alert! https://stash.chiefsclub.com/scenes/15071
# Tags: Markers: TPDB: Missing, Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Crazed Nurse Threesome! https://stash.chiefsclub.com/scenes/15072
# Tags: Markers: TPDB: Missing, Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Jim Slip's 3Rd Law https://stash.chiefsclub.com/scenes/15073
# Tags: Markers: TPDB: Missing, Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Alexis Crystal : Gothic Maid-Interracial Threesome! https://stash.chiefsclub.com/scenes/9627
# Tags: Markers: TPDB: Missing, Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Alexis Crystal : Sex Cyborg-Interracial Creampie! https://stash.chiefsclub.com/scenes/9628
# Tags: Cosplay, Creampie, Doggy Style, Interracial, Markers: TPDB: Missing, Markers: timestamp.trade: Missing, Missionary, Ripping Clothes, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
# Alexis Crystal&Kyoko Makise:nurse-Interracial Foursome! https://stash.chiefsclub.com/scenes/22739
# Tags: Foursome, Foursome (BBGG), Markers: TPDB: Missing, Missing: StashDB
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/22877
# Tags: AI_Tagged, Blowjob_AI, Cum on Person_AI, Cumshot_AI, Grabbing Ass_AI, Grabbing Boobs_AI, Grabbing Hair/Head_AI, Handjob_AI, Licking Penis_AI, Masturbation_AI, Missing: StashDB, Pussy Rubbing_AI, Titjob_AI, Twosome, Twosome (Straight), Undressing_AI, Vaginal Penetration_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/22882
# Tags: AI_Tagged, Anal Fucking_AI, Ass Penetration_AI, Ball Licking/Sucking_AI, Blowjob_AI, Cum on Person_AI, Cumshot_AI, Deepthroat_AI, Grabbing Ass_AI, Grabbing Boobs_AI, Grabbing Hair/Head_AI, Handjob_AI, Licking Penis_AI, Masturbation_AI, Missing: StashDB, Pussy Rubbing_AI, Sucking Fingers_AI, Titjob_AI, Twosome, Twosome (Straight), Undressing_AI, Vaginal Fucking_AI, Vaginal Penetration_AI, Wet (Genitals)_AI
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/686
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18914
# Tags: Missing: StashDB, Twosome, Twosome (Lesbian)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18437
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18439
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18440
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18441
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18444
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18447
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18448
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18449
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18450
# Tags: Missing: StashDB, Threesome, Threesome (BGG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18451
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18452
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18453
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18454
# Tags: Missing: StashDB, Threesome, Threesome (BBG)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18455
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18456
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18457
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18460
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup
#
#  https://stash.chiefsclub.com/scenes/18461
# Tags: Missing: StashDB, Twosome, Twosome (Straight)
# Tag to apply: Data Quality Issue: Incorrect Number of Performers Compared To Group Makeup

# %%
# Check that all scenes have two performers who both have gender FEMALE
valid_scenes = []
invalid_scenes = []

for scene in twosome_lesbian_scenes:
    performers = scene['performers']
    if len(performers) == 2 and all(performer['gender'] == 'FEMALE' for performer in performers):
        valid_scenes.append(scene)
    else:
        invalid_scenes.append(scene)

print(f"Valid scenes: {len(valid_scenes)}")
print(f"Invalid scenes: {len(invalid_scenes)}")

if invalid_scenes:
    print("\nInvalid scenes:")
    for scene in invalid_scenes:
        print(f"ID: {scene['id']}")
        print(f"Title: {scene['title']}")
        print(f"Performers: {', '.join([f'{p['name']} ({p['gender']})' for p in scene['performers']])}")
        print()

# %%
behind_the_scenes_tag = stash.find_tag("Behind the Scenes")
category_group_makeup_tag = stash.find_tag("Category: Group Makeup")
compilation_tag = stash.find_tag("Compilation")
full_movie_tag = stash.find_tag("Full Movie")
incoming_performers_tag = stash.find_tag("StashDB: Incoming performers")

scenes_without_group_makeup = stash.find_scenes({
    "tags": {
        "modifier": "INCLUDES_ALL",
        "value": [],
        "excludes": [
            behind_the_scenes_tag['id'],
            category_group_makeup_tag['id'],
            compilation_tag['id'],
            full_movie_tag['id']
        ]
    },
    "stash_id_endpoint": {"endpoint": "https://stashdb.org/graphql", "modifier": "NOT_NULL"},
}, fragment="id title performers { id name gender stash_ids { stash_id endpoint } } tags { id name } stash_ids { stash_id endpoint }")

for scene in scenes_without_group_makeup:
    scene_stashbox_id = next(
                (
                    sid["stash_id"]
                    for sid in scene["stash_ids"]
                    if sid.get("endpoint") == 'https://stashdb.org/graphql'
                ),
                None,
            )
    stashbox_scene = stashbox_client.query_scenes(scene_stashbox_id)
    
    scene_performer_ids = set([
        next(
            (
                sid["stash_id"]
                for sid in performer["stash_ids"]
                if sid.get("endpoint") == 'https://stashdb.org/graphql'
            ),
            None
        )
        for performer in scene['performers']
    ])
    
    stashbox_scene_performers = set([performer['performer']['id'] for performer in stashbox_scene['data']['findScene']['performers']])
    
    if not scene_performer_ids.issuperset(stashbox_scene_performers):
        print(scene['id'], scene['title'])
        print(scene['performers'])
        print(stashbox_scene_performers)
        
        refreshed_scene = stash.find_scene(scene['id'], fragment="performers { id name gender } tags { id name }")
        tags = [tag['id'] for tag in refreshed_scene['tags']]
        tags.append(incoming_performers_tag['id'])
        stash.update_scene({
            "id": scene['id'],
            "tag_ids": tags
        })
        
        print()
