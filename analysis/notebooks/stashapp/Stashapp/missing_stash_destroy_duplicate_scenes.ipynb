# %%
import sys
from pathlib import Path

import polars as pl


sys.path.append(str(Path.cwd().parent))

from libraries.client_stashapp import StashAppClient, get_stashapp_client


stash = get_stashapp_client("MISSING_SDB_")
stash_client = StashAppClient("MISSING_SDB_")
# Out:
# dUsing stash (v0.28.1-89-g642b0f22) endpoint at http://localhost:6968/graphql
# dUsing stash (v0.28.1-89-g642b0f22) endpoint at http://localhost:6968/graphql

# %%
all_missing_scenes = stash.find_scenes(fragment="id title stash_ids { endpoint stash_id }")

# %%
# Verify data retrieval
print(f"Total scenes retrieved: {len(all_missing_scenes)}")
print(f"Sample scene: {all_missing_scenes[0] if all_missing_scenes else 'No scenes found'}")

# Show first few scenes with stash IDs to understand the structure
scenes_with_stash_ids = [scene for scene in all_missing_scenes if scene.get("stash_ids")]
print(f"Scenes with stash IDs: {len(scenes_with_stash_ids)}")
if scenes_with_stash_ids:
    print(f"Sample scene with stash IDs: {scenes_with_stash_ids[0]}")
# Out:
# Total scenes retrieved: 23623
# Sample scene: {'id': '2985', 'title': "Rocco's 3-Slut Anal & Fetish Fantasy", 'stash_ids': [{'endpoint': 'https://stashdb.org/graphql', 'stash_id': '35d03082-79d4-4fee-87f8-95bc2573a6dc'}]}
# Scenes with stash IDs: 23623
# Sample scene with stash IDs: {'id': '2985', 'title': "Rocco's 3-Slut Anal & Fetish Fantasy", 'stash_ids': [{'endpoint': 'https://stashdb.org/graphql', 'stash_id': '35d03082-79d4-4fee-87f8-95bc2573a6dc'}]}

# %%
# Create a flat list of all stash IDs with their associated scene information
stash_id_records = []

for scene in all_missing_scenes:
    scene_id = scene.get("id")
    scene_title = scene.get("title", "No Title")
    stash_ids = scene.get("stash_ids", [])

    for stash_id_obj in stash_ids:
        stash_id_records.append({
            "scene_id": scene_id,
            "scene_title": scene_title,
            "stash_id": stash_id_obj.get("stash_id"),
            "endpoint": stash_id_obj.get("endpoint")
        })

print(f"Total stash ID records: {len(stash_id_records)}")

# Create polars DataFrame
df_stash_ids = pl.DataFrame(stash_id_records)
print(f"DataFrame shape: {df_stash_ids.shape}")

df_stash_ids.head(10)
# Out:
# Total stash ID records: 23623
# DataFrame shape: (23623, 4)
# shape: (10, 4)
# ┌──────────┬─────────────────────────────┬────────────────────────────┬────────────────────────────┐
# │ scene_id ┆ scene_title                 ┆ stash_id                   ┆ endpoint                   │
# │ ---      ┆ ---                         ┆ ---                        ┆ ---                        │
# │ str      ┆ str                         ┆ str                        ┆ str                        │
# ╞══════════╪═════════════════════════════╪════════════════════════════╪════════════════════════════╡
# │ 2985     ┆ Rocco's 3-Slut Anal &       ┆ 35d03082-79d4-4fee-87f8-95 ┆ https://stashdb.org/graphq │
# │          ┆ Fetish F…                   ┆ bc25…                      ┆ l                          │
# │ 5035     ┆ Slutty Girls Love Rocco     ┆ 50b71b8c-6523-4eb9-97b2-00 ┆ https://stashdb.org/graphq │
# │          ┆                             ┆ 498f…                      ┆ l                          │
# │ 5533     ┆ 2 Threesomes: Anal, DP, Bi  ┆ afe3ba6c-7af8-4d03-b92a-39 ┆ https://stashdb.org/graphq │
# │          ┆ Gir…                        ┆ f5f5…                      ┆ l                          │
# │ 7914     ┆ Rocco's Intimate            ┆ 21dccfcf-fa6e-467f-bf1b-3d ┆ https://stashdb.org/graphq │
# │          ┆ Initiations #…              ┆ d84b…                      ┆ l                          │
# │ 7982     ┆ Rocco's Perfect Slaves #05  ┆ 3f3a6368-7020-464e-aa28-51 ┆ https://stashdb.org/graphq │
# │          ┆                             ┆ cec7…                      ┆ l                          │
# │ 11925    ┆ BONUS-Slutty Girls Love     ┆ 3dbaa1a2-d060-49ae-8d31-e2 ┆ https://stashdb.org/graphq │
# │          ┆ Rocco …                     ┆ d2c9…                      ┆ l                          │
# │ 11935    ┆ Rocco's Abbondanza:Big,     ┆ 527596c8-5e83-4c39-8cb8-2d ┆ https://stashdb.org/graphq │
# │          ┆ Natura…                     ┆ 2f5e…                      ┆ l                          │
# │ 12303    ┆ Anna, Mini & Rocco's Anal   ┆ 8c3cf4b1-8fde-4793-8e26-ce ┆ https://stashdb.org/graphq │
# │          ┆ Thre…                       ┆ 1af2…                      ┆ l                          │
# │ 12610    ┆ BONUS-Slutty Girls Love     ┆ 3dbaa1a2-d060-49ae-8d31-e2 ┆ https://stashdb.org/graphq │
# │          ┆ Rocco …                     ┆ d2c9…                      ┆ l                          │
# │ 12620    ┆ Rocco's Abbondanza:Big,     ┆ 527596c8-5e83-4c39-8cb8-2d ┆ https://stashdb.org/graphq │
# │          ┆ Natura…                     ┆ 2f5e…                      ┆ l                          │
# └──────────┴─────────────────────────────┴────────────────────────────┴────────────────────────────┘

# %%
# Find duplicate stash IDs
# Group by stash_id and endpoint, then count occurrences
duplicate_stash_ids = (
    df_stash_ids
    .group_by(["stash_id", "endpoint"])
    .agg([
        pl.len().alias("scene_count"),
        pl.col("scene_id").alias("scene_ids"),
        pl.col("scene_title").alias("scene_titles")
    ])
    .filter(pl.col("scene_count") > 1)
    .sort("scene_count", descending=True)
)

print(f"Found {len(duplicate_stash_ids)} duplicate stash_id/endpoint combinations")
print(f"Total scenes affected: {duplicate_stash_ids.select(pl.col('scene_count').len()).item()}")

duplicate_stash_ids
# Out:
# Found 470 duplicate stash_id/endpoint combinations
# Total scenes affected: 470
# shape: (470, 5)
# ┌─────────────────────┬────────────────────┬─────────────┬────────────────────┬────────────────────┐
# │ stash_id            ┆ endpoint           ┆ scene_count ┆ scene_ids          ┆ scene_titles       │
# │ ---                 ┆ ---                ┆ ---         ┆ ---                ┆ ---                │
# │ str                 ┆ str                ┆ u32         ┆ list[str]          ┆ list[str]          │
# ╞═════════════════════╪════════════════════╪═════════════╪════════════════════╪════════════════════╡
# │ 554aaa2c-06cd-4b24- ┆ https://stashdb.or ┆ 4           ┆ ["7587", "15010",  ┆ ["Master of        │
# │ bc54-824cea…        ┆ g/graphql          ┆             ┆ … "28170"]         ┆ Polygamy",         │
# │                     ┆                    ┆             ┆                    ┆ "Master…           │
# │ 3bdf233f-cb0d-4088- ┆ https://stashdb.or ┆ 4           ┆ ["2408", "4833", … ┆ ["Cum loving       │
# │ 819d-8d2c79…        ┆ g/graphql          ┆             ┆ "23571"]           ┆ bitches", "Cum lo… │
# │ 8e75e43f-cc86-4868- ┆ https://stashdb.or ┆ 3           ┆ ["2389", "4795",   ┆ ["Episode 9 -      │
# │ af3b-26501e…        ┆ g/graphql          ┆             ┆ "16670"]           ┆ Playing With The…  │
# │ f4d7c980-ec23-45a1- ┆ https://stashdb.or ┆ 3           ┆ ["21624", "23906", ┆ ["Practice Safe    │
# │ b533-b3dbbc…        ┆ g/graphql          ┆             ┆ "26708"]           ┆ Distancing", "…    │
# │ 3e89877e-b5f1-48f5- ┆ https://stashdb.or ┆ 3           ┆ ["2398", "4804",   ┆ ["Episode 1 -      │
# │ bdaa-d27713…        ┆ g/graphql          ┆             ┆ "16677"]           ┆ Battle Of The Se…  │
# │ …                   ┆ …                  ┆ …           ┆ …                  ┆ …                  │
# │ 13e45463-b6c2-4bf5- ┆ https://stashdb.or ┆ 2           ┆ ["10022", "25723"] ┆ ["Sorority Girls & │
# │ a405-5e9293…        ┆ g/graphql          ┆             ┆                    ┆ The Dean 2"…       │
# │ 9ef73e1f-6ac7-4071- ┆ https://stashdb.or ┆ 2           ┆ ["11938", "12623"] ┆ ["LOL-014",        │
# │ ab0a-d7c0cc…        ┆ g/graphql          ┆             ┆                    ┆ "LOL-014"]         │
# │ bd77ec56-39f5-44f0- ┆ https://stashdb.or ┆ 2           ┆ ["11871", "12556"] ┆ ["That video       │
# │ 9444-382d1c…        ┆ g/graphql          ┆             ┆                    ┆ finally started A… │
# │ 3aafd08f-d6e6-44bf- ┆ https://stashdb.or ┆ 2           ┆ ["11974", "12659"] ┆ ["SpunkyBee",      │
# │ 88eb-a81f66…        ┆ g/graphql          ┆             ┆                    ┆ "SpunkyBee"]       │
# │ 955fbdc7-9cd9-4090- ┆ https://stashdb.or ┆ 2           ┆ ["21098", "26674"] ┆ ["Sister Strap     │
# │ 88b0-7225cb…        ┆ g/graphql          ┆             ┆                    ┆ Sandwich", "Sis…   │
# └─────────────────────┴────────────────────┴─────────────┴────────────────────┴────────────────────┘

# %%
# Delete duplicate scenes, keeping the first scene in each group
scenes_to_delete = []
scenes_to_keep = []

# Iterate through each duplicate group
for row in duplicate_stash_ids.iter_rows(named=True):
    scene_ids = row["scene_ids"]
    scene_count = row["scene_count"]
    stash_id = row["stash_id"]

    # Keep the first scene, mark others for deletion
    keep_scene = scene_ids[0]
    delete_scenes = scene_ids[1:]

    scenes_to_keep.append(keep_scene)
    scenes_to_delete.extend(delete_scenes)

    print(f"Stash ID: {stash_id[:8]}... - Keeping scene {keep_scene}, deleting scenes: {delete_scenes}")

print("\nSummary:")
print(f"Total scenes to keep: {len(scenes_to_keep)}")
print(f"Total scenes to delete: {len(scenes_to_delete)}")
print(f"Total duplicate groups processed: {len(duplicate_stash_ids)}")

# Show the first few scenes to be deleted for verification
print(f"\nFirst 10 scenes to be deleted: {scenes_to_delete[:10]}")
# Out:
# Stash ID: 554aaa2c... - Keeping scene 7587, deleting scenes: ['15010', '18994', '28170']
# Stash ID: 3bdf233f... - Keeping scene 2408, deleting scenes: ['4833', '7995', '23571']
# Stash ID: 8e75e43f... - Keeping scene 2389, deleting scenes: ['4795', '16670']
# Stash ID: f4d7c980... - Keeping scene 21624, deleting scenes: ['23906', '26708']
# Stash ID: 3e89877e... - Keeping scene 2398, deleting scenes: ['4804', '16677']
# Stash ID: 20022766... - Keeping scene 2392, deleting scenes: ['4798', '16673']
# Stash ID: 7fc753c9... - Keeping scene 14098, deleting scenes: ['22145', '22878']
# Stash ID: 27e55214... - Keeping scene 2431, deleting scenes: ['11882', '12567']
# Stash ID: 0b982c26... - Keeping scene 2395, deleting scenes: ['4801', '16676']
# Stash ID: b5cdf343... - Keeping scene 2388, deleting scenes: ['4794', '16669']
# Stash ID: 9841ee75... - Keeping scene 2394, deleting scenes: ['4800', '16675']
# Stash ID: ffaddebc... - Keeping scene 2941, deleting scenes: ['8420', '10706']
# Stash ID: 9a1e774f... - Keeping scene 6106, deleting scenes: ['24544', '28167']
# Stash ID: f1c7b64e... - Keeping scene 2393, deleting scenes: ['4799', '16674']
# Stash ID: 3cb0d4ae... - Keeping scene 15154, deleting scenes: ['25002', '28700']
# Stash ID: 7be43f43... - Keeping scene 2390, deleting scenes: ['4796', '16671']
# Stash ID: 67fb80df... - Keeping scene 2391, deleting scenes: ['4797', '16672']
# Stash ID: aba7b60e... - Keeping scene 2940, deleting scenes: ['8418', '10705']
# Stash ID: 03daa764... - Keeping scene 8532, deleting scenes: ['10916', '28767']
# Stash ID: 571c7fa3... - Keeping scene 21540, deleting scenes: ['24840', '28522']
# Stash ID: be453125... - Keeping scene 11927, deleting scenes: ['12612']
# Stash ID: 80633f50... - Keeping scene 19097, deleting scenes: ['28635']
# Stash ID: 572ed08d... - Keeping scene 12000, deleting scenes: ['12685']
# Stash ID: 05caf048... - Keeping scene 16571, deleting scenes: ['27670']
# Stash ID: 36532566... - Keeping scene 24925, deleting scenes: ['28598']
# Stash ID: fecb4d2a... - Keeping scene 16703, deleting scenes: ['20069']
# Stash ID: 9a72b66a... - Keeping scene 11903, deleting scenes: ['12588']
# Stash ID: ec6eb95f... - Keeping scene 12056, deleting scenes: ['24764']
# Stash ID: 95a2fe8d... - Keeping scene 15601, deleting scenes: ['27694']
# Stash ID: adc45e89... - Keeping scene 11000, deleting scenes: ['24307']
# Stash ID: 5d971fdd... - Keeping scene 15594, deleting scenes: ['27686']
# Stash ID: 6accce0a... - Keeping scene 16303, deleting scenes: ['18817']
# Stash ID: f7ec086e... - Keeping scene 14241, deleting scenes: ['25563']
# Stash ID: 8c336751... - Keeping scene 15502, deleting scenes: ['27562']
# Stash ID: 4cea848b... - Keeping scene 14743, deleting scenes: ['23846']
# Stash ID: ea643296... - Keeping scene 11981, deleting scenes: ['12666']
# Stash ID: 21696179... - Keeping scene 8009, deleting scenes: ['25433']
# Stash ID: 1e77791c... - Keeping scene 11899, deleting scenes: ['12584']
# Stash ID: ce51e0a9... - Keeping scene 15585, deleting scenes: ['27677']
# Stash ID: 141c67ca... - Keeping scene 24973, deleting scenes: ['28664']
# Stash ID: f7bfd4bc... - Keeping scene 1604, deleting scenes: ['19080']
# Stash ID: aeb5d661... - Keeping scene 21908, deleting scenes: ['24918']
# Stash ID: 61ccb0d3... - Keeping scene 11968, deleting scenes: ['12653']
# Stash ID: 122693c9... - Keeping scene 863, deleting scenes: ['9976']
# Stash ID: b4f2b313... - Keeping scene 743, deleting scenes: ['17060']
# Stash ID: 1c2d2605... - Keeping scene 25029, deleting scenes: ['28772']
# Stash ID: 3218996e... - Keeping scene 11930, deleting scenes: ['12615']
# Stash ID: 7974b32e... - Keeping scene 8389, deleting scenes: ['18996']
# Stash ID: 272b4e33... - Keeping scene 23892, deleting scenes: ['26686']
# Stash ID: 63d10743... - Keeping scene 7824, deleting scenes: ['25322']
# Stash ID: 8e389b91... - Keeping scene 17181, deleting scenes: ['19680']
# Stash ID: 710131f4... - Keeping scene 11894, deleting scenes: ['12579']
# Stash ID: e20c73c6... - Keeping scene 19790, deleting scenes: ['21134']
# Stash ID: 469e7534... - Keeping scene 22941, deleting scenes: ['27342']
# Stash ID: 752391a1... - Keeping scene 19087, deleting scenes: ['21938']
# Stash ID: 1b0e3a43... - Keeping scene 9924, deleting scenes: ['24666']
# Stash ID: 3cb22417... - Keeping scene 11900, deleting scenes: ['12585']
# Stash ID: 41cb543f... - Keeping scene 2317, deleting scenes: ['19081']
# Stash ID: 5839434e... - Keeping scene 859, deleting scenes: ['9974']
# Stash ID: ed89697f... - Keeping scene 4944, deleting scenes: ['8166']
# Stash ID: 17eac9ce... - Keeping scene 11986, deleting scenes: ['12671']
# Stash ID: a8467b06... - Keeping scene 1692, deleting scenes: ['3970']
# Stash ID: cb74fe25... - Keeping scene 20475, deleting scenes: ['21023']
# Stash ID: 8dfe01a1... - Keeping scene 16135, deleting scenes: ['21604']
# Stash ID: 1ec67bfb... - Keeping scene 15690, deleting scenes: ['24475']
# Stash ID: b1d5d70d... - Keeping scene 8554, deleting scenes: ['28807']
# Stash ID: ea88b77b... - Keeping scene 11885, deleting scenes: ['12570']
# Stash ID: ac5eb6ce... - Keeping scene 11898, deleting scenes: ['12583']
# Stash ID: 45db0b12... - Keeping scene 25189, deleting scenes: ['27915']
# Stash ID: ffe1494c... - Keeping scene 9168, deleting scenes: ['19759']
# Stash ID: 78541a50... - Keeping scene 22125, deleting scenes: ['27962']
# Stash ID: 6a995732... - Keeping scene 11916, deleting scenes: ['12601']
# Stash ID: 37df35de... - Keeping scene 7410, deleting scenes: ['23487']
# Stash ID: c89463a2... - Keeping scene 19753, deleting scenes: ['25788']
# Stash ID: bde10da8... - Keeping scene 11868, deleting scenes: ['12553']
# Stash ID: 47b5786e... - Keeping scene 10711, deleting scenes: ['18160']
# Stash ID: b70accc9... - Keeping scene 16592, deleting scenes: ['27736']
# Stash ID: 9ff60833... - Keeping scene 11887, deleting scenes: ['12572']
# Stash ID: 843b5dd7... - Keeping scene 5057, deleting scenes: ['8250']
# Stash ID: 4cc3795b... - Keeping scene 5306, deleting scenes: ['8405']
# Stash ID: bf571056... - Keeping scene 11856, deleting scenes: ['12541']
# Stash ID: 6d1fbb9a... - Keeping scene 11999, deleting scenes: ['12684']
# Stash ID: 99f8b8a0... - Keeping scene 11947, deleting scenes: ['12632']
# Stash ID: 03265c6a... - Keeping scene 11921, deleting scenes: ['12606']
# Stash ID: 44886562... - Keeping scene 12377, deleting scenes: ['28827']
# Stash ID: 83aba1d3... - Keeping scene 4815, deleting scenes: ['16699']
# Stash ID: f326611e... - Keeping scene 1674, deleting scenes: ['28278']
# Stash ID: 868d8461... - Keeping scene 8565, deleting scenes: ['28844']
# Stash ID: 4eb553dd... - Keeping scene 19386, deleting scenes: ['20071']
# Stash ID: 96fddb8e... - Keeping scene 11952, deleting scenes: ['12637']
# Stash ID: 63b8fc51... - Keeping scene 11965, deleting scenes: ['12650']
# Stash ID: 60a96562... - Keeping scene 70, deleting scenes: ['24801']
# Stash ID: c0d8e419... - Keeping scene 12007, deleting scenes: ['12692']
# Stash ID: dd221972... - Keeping scene 4837, deleting scenes: ['8774']
# Stash ID: 4cb0ccad... - Keeping scene 789, deleting scenes: ['14773']
# Stash ID: 803c5716... - Keeping scene 15510, deleting scenes: ['15951']
# Stash ID: fd4fba65... - Keeping scene 16566, deleting scenes: ['27660']
# Stash ID: c9ee523e... - Keeping scene 11951, deleting scenes: ['12636']
# Stash ID: a5fadd70... - Keeping scene 11877, deleting scenes: ['12562']
# Stash ID: f2a5424e... - Keeping scene 3969, deleting scenes: ['24516']
# Stash ID: 5a0fa13e... - Keeping scene 16184, deleting scenes: ['23481']
# Stash ID: a053c431... - Keeping scene 11884, deleting scenes: ['12569']
# Stash ID: 2c467f0e... - Keeping scene 16558, deleting scenes: ['27627']
# Stash ID: affc17fc... - Keeping scene 15589, deleting scenes: ['27679']
# Stash ID: 3eb5ae4f... - Keeping scene 10168, deleting scenes: ['23888']
# Stash ID: de7c8282... - Keeping scene 16693, deleting scenes: ['20062']
# Stash ID: 77ea7b3e... - Keeping scene 11907, deleting scenes: ['12592']
# Stash ID: a3a868ed... - Keeping scene 16593, deleting scenes: ['27737']
# Stash ID: f53635f9... - Keeping scene 12341, deleting scenes: ['25024']
# Stash ID: 99912fef... - Keeping scene 23803, deleting scenes: ['28087']
# Stash ID: 1b8a5824... - Keeping scene 11969, deleting scenes: ['12654']
# Stash ID: 74438729... - Keeping scene 11960, deleting scenes: ['12645']
# Stash ID: b0b59130... - Keeping scene 25028, deleting scenes: ['28771']
# Stash ID: 36b5150c... - Keeping scene 15385, deleting scenes: ['24476']
# Stash ID: 6e6297d9... - Keeping scene 16630, deleting scenes: ['25727']
# Stash ID: dc9953f9... - Keeping scene 10019, deleting scenes: ['20479']
# Stash ID: e1cdac3c... - Keeping scene 10020, deleting scenes: ['17216']
# Stash ID: 24cc37dc... - Keeping scene 5491, deleting scenes: ['25853']
# Stash ID: bd84bdd9... - Keeping scene 24953, deleting scenes: ['28623']
# Stash ID: e0ca1137... - Keeping scene 11864, deleting scenes: ['12549']
# Stash ID: 61b5fb07... - Keeping scene 11950, deleting scenes: ['12635']
# Stash ID: a91010e5... - Keeping scene 17098, deleting scenes: ['23860']
# Stash ID: cb2d6f70... - Keeping scene 1167, deleting scenes: ['28185']
# Stash ID: 401b8452... - Keeping scene 11977, deleting scenes: ['12662']
# Stash ID: 86e153c4... - Keeping scene 21076, deleting scenes: ['21595']
# Stash ID: ebb0e22a... - Keeping scene 1265, deleting scenes: ['21050']
# Stash ID: 6bbb0ab4... - Keeping scene 11963, deleting scenes: ['12648']
# Stash ID: b704061b... - Keeping scene 16587, deleting scenes: ['27732']
# Stash ID: cb4be798... - Keeping scene 11891, deleting scenes: ['12576']
# Stash ID: 1d7caf6a... - Keeping scene 1285, deleting scenes: ['10064']
# Stash ID: 8dfc162a... - Keeping scene 8412, deleting scenes: ['24676']
# Stash ID: 882ac6d9... - Keeping scene 11862, deleting scenes: ['12547']
# Stash ID: 13e30af8... - Keeping scene 25839, deleting scenes: ['26728']
# Stash ID: 29aaef67... - Keeping scene 15807, deleting scenes: ['16421']
# Stash ID: 0a98d7aa... - Keeping scene 11998, deleting scenes: ['12683']
# Stash ID: 8846144c... - Keeping scene 11967, deleting scenes: ['12652']
# Stash ID: cbeaca17... - Keeping scene 11880, deleting scenes: ['12565']
# Stash ID: e003e679... - Keeping scene 18467, deleting scenes: ['28554']
# Stash ID: ab946a9a... - Keeping scene 8004, deleting scenes: ['14102']
# Stash ID: 7659cacd... - Keeping scene 11923, deleting scenes: ['12608']
# Stash ID: 363ca6b1... - Keeping scene 12001, deleting scenes: ['12686']
# Stash ID: 6b013626... - Keeping scene 223, deleting scenes: ['5839']
# Stash ID: 8a45c98c... - Keeping scene 11973, deleting scenes: ['12658']
# Stash ID: 0c6897a9... - Keeping scene 7818, deleting scenes: ['25313']
# Stash ID: 20a457f0... - Keeping scene 9272, deleting scenes: ['19327']
# Stash ID: 4847b6c1... - Keeping scene 16551, deleting scenes: ['27613']
# Stash ID: 78cae2f9... - Keeping scene 11948, deleting scenes: ['12633']
# Stash ID: 3e985b02... - Keeping scene 25899, deleting scenes: ['26780']
# Stash ID: de892944... - Keeping scene 738, deleting scenes: ['17048']
# Stash ID: 0d52d30f... - Keeping scene 4823, deleting scenes: ['25426']
# Stash ID: 32eff3c6... - Keeping scene 9331, deleting scenes: ['16248']
# Stash ID: 4a0f93a2... - Keeping scene 23347, deleting scenes: ['27281']
# Stash ID: e8494997... - Keeping scene 11883, deleting scenes: ['12568']
# Stash ID: 87e6268a... - Keeping scene 4858, deleting scenes: ['8053']
# Stash ID: 57a573ff... - Keeping scene 11979, deleting scenes: ['12664']
# Stash ID: be8db4bc... - Keeping scene 16796, deleting scenes: ['23606']
# Stash ID: 3320ba42... - Keeping scene 21004, deleting scenes: ['22627']
# Stash ID: a7dc9220... - Keeping scene 5760, deleting scenes: ['7926']
# Stash ID: a2dbc267... - Keeping scene 469, deleting scenes: ['11059']
# Stash ID: f16daf15... - Keeping scene 16550, deleting scenes: ['27612']
# Stash ID: 59441b1c... - Keeping scene 11945, deleting scenes: ['12630']
# Stash ID: 7078b49c... - Keeping scene 431, deleting scenes: ['10931']
# Stash ID: 7d12f934... - Keeping scene 11932, deleting scenes: ['12617']
# Stash ID: fab220ea... - Keeping scene 9288, deleting scenes: ['27948']
# Stash ID: 4c33dba0... - Keeping scene 11943, deleting scenes: ['12628']
# Stash ID: 0983fcbb... - Keeping scene 11992, deleting scenes: ['12677']
# Stash ID: 32bfe97f... - Keeping scene 9812, deleting scenes: ['23551']
# Stash ID: 676b0d43... - Keeping scene 25119, deleting scenes: ['25702']
# Stash ID: c3724800... - Keeping scene 11852, deleting scenes: ['12537']
# Stash ID: 030e783d... - Keeping scene 15131, deleting scenes: ['19965']
# Stash ID: 8e27c276... - Keeping scene 24330, deleting scenes: ['26994']
# Stash ID: ed3a7f68... - Keeping scene 5393, deleting scenes: ['26075']
# Stash ID: f7599872... - Keeping scene 11867, deleting scenes: ['12552']
# Stash ID: fc888ad2... - Keeping scene 11879, deleting scenes: ['12564']
# Stash ID: 8c5e2622... - Keeping scene 11919, deleting scenes: ['12604']
# Stash ID: 5e9ffa31... - Keeping scene 11941, deleting scenes: ['12626']
# Stash ID: 80078fbd... - Keeping scene 23903, deleting scenes: ['25173']
# Stash ID: 422fb1a5... - Keeping scene 19088, deleting scenes: ['21939']
# Stash ID: 7ab4ced1... - Keeping scene 11912, deleting scenes: ['12597']
# Stash ID: 6ad0472c... - Keeping scene 11869, deleting scenes: ['12554']
# Stash ID: 21122275... - Keeping scene 16586, deleting scenes: ['27731']
# Stash ID: b22d8197... - Keeping scene 19793, deleting scenes: ['21137']
# Stash ID: ab73a2dd... - Keeping scene 11861, deleting scenes: ['12546']
# Stash ID: 9f135c8f... - Keeping scene 3424, deleting scenes: ['24725']
# Stash ID: 0c6f0845... - Keeping scene 1847, deleting scenes: ['18659']
# Stash ID: 6d2a8693... - Keeping scene 11996, deleting scenes: ['12681']
# Stash ID: 098cdaa6... - Keeping scene 9285, deleting scenes: ['19365']
# Stash ID: 838bc8de... - Keeping scene 18462, deleting scenes: ['28537']
# Stash ID: 71241c16... - Keeping scene 11978, deleting scenes: ['12663']
# Stash ID: 7ce21c93... - Keeping scene 21754, deleting scenes: ['24501']
# Stash ID: d5a825be... - Keeping scene 2387, deleting scenes: ['4793']
# Stash ID: e526c287... - Keeping scene 11913, deleting scenes: ['12598']
# Stash ID: d5d135ff... - Keeping scene 11937, deleting scenes: ['12622']
# Stash ID: 2587187d... - Keeping scene 11993, deleting scenes: ['12678']
# Stash ID: 296506e4... - Keeping scene 20075, deleting scenes: ['27113']
# Stash ID: 786670d8... - Keeping scene 11906, deleting scenes: ['12591']
# Stash ID: 05c83e99... - Keeping scene 11970, deleting scenes: ['12655']
# Stash ID: 66d0a3d6... - Keeping scene 12058, deleting scenes: ['24767']
# Stash ID: b744ee39... - Keeping scene 12285, deleting scenes: ['24945']
# Stash ID: a85ec5ef... - Keeping scene 11954, deleting scenes: ['12639']
# Stash ID: 33a842bf... - Keeping scene 16568, deleting scenes: ['27661']
# Stash ID: 87e661bb... - Keeping scene 25897, deleting scenes: ['26778']
# Stash ID: cd878e2d... - Keeping scene 1954, deleting scenes: ['10431']
# Stash ID: 78056250... - Keeping scene 11991, deleting scenes: ['12676']
# Stash ID: 234e9e5e... - Keeping scene 12005, deleting scenes: ['12690']
# Stash ID: 5ada1785... - Keeping scene 5969, deleting scenes: ['14290']
# Stash ID: e3ff5539... - Keeping scene 16591, deleting scenes: ['27735']
# Stash ID: 12140b5f... - Keeping scene 16688, deleting scenes: ['27070']
# Stash ID: 798f82c7... - Keeping scene 3182, deleting scenes: ['18117']
# Stash ID: 0a60c48c... - Keeping scene 14889, deleting scenes: ['16101']
# Stash ID: 5abb9a86... - Keeping scene 80, deleting scenes: ['12195']
# Stash ID: 06430aec... - Keeping scene 12376, deleting scenes: ['25050']
# Stash ID: 72102240... - Keeping scene 3097, deleting scenes: ['19523']
# Stash ID: 4da1073e... - Keeping scene 8715, deleting scenes: ['24300']
# Stash ID: 5fba38a7... - Keeping scene 2375, deleting scenes: ['23465']
# Stash ID: 66ac2813... - Keeping scene 17130, deleting scenes: ['21015']
# Stash ID: 38f4b621... - Keeping scene 25, deleting scenes: ['28281']
# Stash ID: 902a1490... - Keeping scene 12009, deleting scenes: ['15013']
# Stash ID: 6c961d4e... - Keeping scene 11860, deleting scenes: ['12545']
# Stash ID: e987b11c... - Keeping scene 15597, deleting scenes: ['27691']
# Stash ID: b6a397d2... - Keeping scene 3946, deleting scenes: ['16795']
# Stash ID: 0019ccec... - Keeping scene 11910, deleting scenes: ['12595']
# Stash ID: cab76a4d... - Keeping scene 11850, deleting scenes: ['12535']
# Stash ID: c5c326b2... - Keeping scene 8702, deleting scenes: ['26830']
# Stash ID: 6d7787e5... - Keeping scene 16289, deleting scenes: ['18792']
# Stash ID: 9b3782c9... - Keeping scene 21672, deleting scenes: ['25243']
# Stash ID: 4d07492d... - Keeping scene 14742, deleting scenes: ['23845']
# Stash ID: d11de6b5... - Keeping scene 78, deleting scenes: ['12193']
# Stash ID: f5ae6c6d... - Keeping scene 11014, deleting scenes: ['24028']
# Stash ID: bd440005... - Keeping scene 11936, deleting scenes: ['12621']
# Stash ID: cda9451a... - Keeping scene 7975, deleting scenes: ['25424']
# Stash ID: 5f96ef61... - Keeping scene 12002, deleting scenes: ['12687']
# Stash ID: a6ed372b... - Keeping scene 458, deleting scenes: ['11031']
# Stash ID: 33f5badb... - Keeping scene 24845, deleting scenes: ['28526']
# Stash ID: cf528ffd... - Keeping scene 11983, deleting scenes: ['12668']
# Stash ID: 3967c6f4... - Keeping scene 8499, deleting scenes: ['28651']
# Stash ID: 03630878... - Keeping scene 11962, deleting scenes: ['12647']
# Stash ID: b535c020... - Keeping scene 16505, deleting scenes: ['27553']
# Stash ID: 9a57ef52... - Keeping scene 1658, deleting scenes: ['14724']
# Stash ID: fd3696c0... - Keeping scene 11866, deleting scenes: ['12551']
# Stash ID: 9ea9cede... - Keeping scene 8552, deleting scenes: ['28803']
# Stash ID: b4e12f54... - Keeping scene 17097, deleting scenes: ['23859']
# Stash ID: 164ea511... - Keeping scene 8586, deleting scenes: ['28883']
# Stash ID: 48e98a0d... - Keeping scene 8495, deleting scenes: ['24964']
# Stash ID: b036395c... - Keeping scene 11857, deleting scenes: ['12542']
# Stash ID: b8eb239e... - Keeping scene 24620, deleting scenes: ['28265']
# Stash ID: 8aa85611... - Keeping scene 2825, deleting scenes: ['21291']
# Stash ID: b031d83e... - Keeping scene 7817, deleting scenes: ['25312']
# Stash ID: 549b8068... - Keeping scene 12396, deleting scenes: ['26837']
# Stash ID: ddf408d9... - Keeping scene 2449, deleting scenes: ['4971']
# Stash ID: f6f61dde... - Keeping scene 11911, deleting scenes: ['12596']
# Stash ID: f64fc9d6... - Keeping scene 11982, deleting scenes: ['12667']
# Stash ID: 8bf8863d... - Keeping scene 7820, deleting scenes: ['25316']
# Stash ID: 68ce2280... - Keeping scene 11166, deleting scenes: ['24941']
# Stash ID: 37ebad49... - Keeping scene 15576, deleting scenes: ['27664']
# Stash ID: 3cd41886... - Keeping scene 11933, deleting scenes: ['12618']
# Stash ID: 5a7e6594... - Keeping scene 23178, deleting scenes: ['23694']
# Stash ID: be93f2a7... - Keeping scene 3422, deleting scenes: ['24722']
# Stash ID: ecd0fad0... - Keeping scene 11995, deleting scenes: ['12680']
# Stash ID: 271e8512... - Keeping scene 11972, deleting scenes: ['12657']
# Stash ID: 13c8de8a... - Keeping scene 11858, deleting scenes: ['12543']
# Stash ID: 457b1e43... - Keeping scene 15602, deleting scenes: ['27695']
# Stash ID: 497e4a1f... - Keeping scene 2044, deleting scenes: ['14795']
# Stash ID: 2c96ad1c... - Keeping scene 82, deleting scenes: ['24864']
# Stash ID: a1f560e3... - Keeping scene 18406, deleting scenes: ['28393']
# Stash ID: 37ac1a85... - Keeping scene 11623, deleting scenes: ['27344']
# Stash ID: 5063f41a... - Keeping scene 17099, deleting scenes: ['23861']
# Stash ID: 2ba0210d... - Keeping scene 2079, deleting scenes: ['21027']
# Stash ID: 9029fe3f... - Keeping scene 10733, deleting scenes: ['18173']
# Stash ID: 8970a19e... - Keeping scene 11940, deleting scenes: ['12625']
# Stash ID: c9c5ff62... - Keeping scene 81, deleting scenes: ['12196']
# Stash ID: ba5e4d12... - Keeping scene 11934, deleting scenes: ['12619']
# Stash ID: 2b7af2d6... - Keeping scene 15107, deleting scenes: ['28579']
# Stash ID: ae2234de... - Keeping scene 27123, deleting scenes: ['27957']
# Stash ID: 69850110... - Keeping scene 2933, deleting scenes: ['28363']
# Stash ID: c8586ca6... - Keeping scene 11897, deleting scenes: ['12582']
# Stash ID: 479cc501... - Keeping scene 3420, deleting scenes: ['24718']
# Stash ID: 0c9d4552... - Keeping scene 13790, deleting scenes: ['19384']
# Stash ID: 9a6e34a4... - Keeping scene 11872, deleting scenes: ['12557']
# Stash ID: c52c81ab... - Keeping scene 1919, deleting scenes: ['10397']
# Stash ID: d94fdc31... - Keeping scene 11886, deleting scenes: ['12571']
# Stash ID: de51db0f... - Keeping scene 11926, deleting scenes: ['12611']
# Stash ID: 2e20eaa9... - Keeping scene 23614, deleting scenes: ['29063']
# Stash ID: d3e33038... - Keeping scene 15584, deleting scenes: ['27673']
# Stash ID: 6432bb3b... - Keeping scene 11854, deleting scenes: ['12539']
# Stash ID: 5f993e64... - Keeping scene 11243, deleting scenes: ['16138']
# Stash ID: 231f3778... - Keeping scene 273, deleting scenes: ['15030']
# Stash ID: 82ee8785... - Keeping scene 2867, deleting scenes: ['8387']
# Stash ID: aff4caa5... - Keeping scene 11987, deleting scenes: ['12672']
# Stash ID: fb766bac... - Keeping scene 3439, deleting scenes: ['24736']
# Stash ID: 62758afb... - Keeping scene 11920, deleting scenes: ['12605']
# Stash ID: 356a128d... - Keeping scene 22918, deleting scenes: ['27326']
# Stash ID: f6a87b47... - Keeping scene 17111, deleting scenes: ['19657']
# Stash ID: 64eb4f9e... - Keeping scene 7733, deleting scenes: ['26736']
# Stash ID: e0e1233b... - Keeping scene 5285, deleting scenes: ['28296']
# Stash ID: ef3e8410... - Keeping scene 11953, deleting scenes: ['12638']
# Stash ID: 76cc2e8e... - Keeping scene 11893, deleting scenes: ['12578']
# Stash ID: fd054c30... - Keeping scene 11915, deleting scenes: ['12600']
# Stash ID: cc0ce8a8... - Keeping scene 8714, deleting scenes: ['24299']
# Stash ID: d378f39c... - Keeping scene 17420, deleting scenes: ['25815']
# Stash ID: c08b3220... - Keeping scene 2566, deleting scenes: ['5101']
# Stash ID: 1c28d5e8... - Keeping scene 9147, deleting scenes: ['25696']
# Stash ID: 7b3cae92... - Keeping scene 15248, deleting scenes: ['27478']
# Stash ID: a6111cc9... - Keeping scene 131, deleting scenes: ['18570']
# Stash ID: 583b607f... - Keeping scene 11859, deleting scenes: ['12544']
# Stash ID: 2e351efe... - Keeping scene 23180, deleting scenes: ['23697']
# Stash ID: bba23dd3... - Keeping scene 21448, deleting scenes: ['25111']
# Stash ID: c5fec07b... - Keeping scene 12342, deleting scenes: ['25025']
# Stash ID: 3d844631... - Keeping scene 11997, deleting scenes: ['12682']
# Stash ID: bcdb2258... - Keeping scene 591, deleting scenes: ['23607']
# Stash ID: 6a483142... - Keeping scene 11917, deleting scenes: ['12602']
# Stash ID: 6cf355e1... - Keeping scene 13892, deleting scenes: ['26569']
# Stash ID: 8ba4d642... - Keeping scene 11942, deleting scenes: ['12627']
# Stash ID: 035984e7... - Keeping scene 24827, deleting scenes: ['28505']
# Stash ID: c5def76e... - Keeping scene 21564, deleting scenes: ['26635']
# Stash ID: ae4a2213... - Keeping scene 17170, deleting scenes: ['19676']
# Stash ID: 757a1a2c... - Keeping scene 21582, deleting scenes: ['25145']
# Stash ID: a1625b53... - Keeping scene 17145, deleting scenes: ['19670']
# Stash ID: d09ce07f... - Keeping scene 11908, deleting scenes: ['12593']
# Stash ID: 7304b75e... - Keeping scene 25898, deleting scenes: ['26779']
# Stash ID: 0618e4fd... - Keeping scene 16585, deleting scenes: ['27730']
# Stash ID: c9790fe6... - Keeping scene 1916, deleting scenes: ['10396']
# Stash ID: 3dbaa1a2... - Keeping scene 11925, deleting scenes: ['12610']
# Stash ID: 9e7a7c15... - Keeping scene 6109, deleting scenes: ['24514']
# Stash ID: b97ff0de... - Keeping scene 5346, deleting scenes: ['28381']
# Stash ID: ee0d31a2... - Keeping scene 5360, deleting scenes: ['28391']
# Stash ID: e3892c23... - Keeping scene 16570, deleting scenes: ['27669']
# Stash ID: 72b4c7a2... - Keeping scene 9284, deleting scenes: ['27945']
# Stash ID: c7d79b73... - Keeping scene 1961, deleting scenes: ['10441']
# Stash ID: 4b027509... - Keeping scene 9222, deleting scenes: ['25238']
# Stash ID: 5d80485e... - Keeping scene 742, deleting scenes: ['17058']
# Stash ID: 81c872d0... - Keeping scene 15604, deleting scenes: ['27702']
# Stash ID: 71be121b... - Keeping scene 12003, deleting scenes: ['12688']
# Stash ID: 37e30661... - Keeping scene 11875, deleting scenes: ['12560']
# Stash ID: 527596c8... - Keeping scene 11935, deleting scenes: ['12620']
# Stash ID: d60ec91a... - Keeping scene 7974, deleting scenes: ['25423']
# Stash ID: a7a9c783... - Keeping scene 11929, deleting scenes: ['12614']
# Stash ID: 8dc427eb... - Keeping scene 11976, deleting scenes: ['12661']
# Stash ID: 5c4184f8... - Keeping scene 14372, deleting scenes: ['17714']
# Stash ID: 5a2dffe3... - Keeping scene 9312, deleting scenes: ['27982']
# Stash ID: 13e45463... - Keeping scene 10022, deleting scenes: ['25723']
# Stash ID: 9ef73e1f... - Keeping scene 11938, deleting scenes: ['12623']
# Stash ID: bd77ec56... - Keeping scene 11871, deleting scenes: ['12556']
# Stash ID: 3aafd08f... - Keeping scene 11974, deleting scenes: ['12659']
# Stash ID: 955fbdc7... - Keeping scene 21098, deleting scenes: ['26674']
#
# Summary:
# Total scenes to keep: 470
# Total scenes to delete: 492
# Total duplicate groups processed: 470
#
# First 10 scenes to be deleted: ['15010', '18994', '28170', '4833', '7995', '23571', '4795', '16670', '23906', '26708']

# %%
# APPLY STEP - Execute the deletions
# WARNING: This will permanently delete scenes from your database!
# Make sure you have a backup if needed

import time


deleted_scenes = []
failed_deletions = []

print(f"Starting deletion of {len(scenes_to_delete)} duplicate scenes...")
print("This may take a while...")

for i, scene_id in enumerate(scenes_to_delete):
    try:
        # Delete the scene
        result = stash.destroy_scene(scene_id)
        deleted_scenes.append(scene_id)

        if (i + 1) % 50 == 0:  # Progress update every 50 deletions
            print(f"Processed {i + 1}/{len(scenes_to_delete)} scenes...")

        # Small delay to avoid overwhelming the server
        time.sleep(0.1)

    except Exception as e:
        print(f"Failed to delete scene {scene_id}: {e!s}")
        failed_deletions.append({"scene_id": scene_id, "error": str(e)})

print("\n=== DELETION COMPLETE ===")
print(f"Successfully deleted: {len(deleted_scenes)} scenes")
print(f"Failed deletions: {len(failed_deletions)} scenes")

if failed_deletions:
    print("\nFailed deletions:")
    for failure in failed_deletions:
        print(f"  Scene {failure['scene_id']}: {failure['error']}")

print(f"\nTotal scenes that should remain: {len(scenes_to_keep)}")
print(f"Original duplicate groups: {len(duplicate_stash_ids)}")
print(f"Scenes deleted: {len(deleted_scenes)}")
print(f"Expected reduction: {len(scenes_to_delete)} scenes")
# Out:
# Starting deletion of 492 duplicate scenes...
# This may take a while...
# Processed 50/492 scenes...
# Processed 100/492 scenes...
# Processed 150/492 scenes...
# Processed 200/492 scenes...
# Processed 250/492 scenes...
# Processed 300/492 scenes...
# Processed 350/492 scenes...
# Processed 400/492 scenes...
# Processed 450/492 scenes...
#
# === DELETION COMPLETE ===
# Successfully deleted: 492 scenes
# Failed deletions: 0 scenes
#
# Total scenes that should remain: 470
# Original duplicate groups: 470
# Scenes deleted: 492
# Expected reduction: 492 scenes
