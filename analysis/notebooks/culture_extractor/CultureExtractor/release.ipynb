# %%
import os
import sys
from pathlib import Path

from dotenv import load_dotenv


sys.path.append(str(Path.cwd().parent))

load_dotenv()

# %%
from libraries import client_culture_extractor
from libraries.client_stashapp import StashAppClient, get_stashapp_client


# Culture Extractor
user = os.environ.get("CE_DB_USERNAME")
pw = os.environ.get("CE_DB_PASSWORD")
host = os.environ.get("CE_DB_HOST")
port = os.environ.get("CE_DB_PORT")
db = os.environ.get("CE_DB_NAME")

connection_string = f"dbname={db} user={user} password={pw} host={host} port={port}"

culture_extractor_client = client_culture_extractor.ClientCultureExtractor(
    connection_string
)


# StashApp
stash_client = StashAppClient()
stash_raw_client = get_stashapp_client()

# %%
culture_extractor_client.get_release_by_uuid("0195a774-6b62-76d2-916b-eb752d409c72")
# Out:
# shape: (1, 12)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ce_site_u ┆ ce_site_n ┆ ce_releas ┆ ce_releas ┆ … ┆ ce_releas ┆ ce_releas ┆ ce_releas ┆ ce_relea │
# │ uid       ┆ ame       ┆ e_uuid    ┆ e_date    ┆   ┆ e_created ┆ e_last_up ┆ e_availab ┆ se_json_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ dated     ┆ le_files  ┆ document │
# │ str       ┆ str       ┆ str       ┆ date      ┆   ┆ datetime[ ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ μs]       ┆ datetime[ ┆ str       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ μs]       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 01958921- ┆ Sexy Hub  ┆ 0195a774- ┆ 2013-09-3 ┆ … ┆ 2025-03-1 ┆ 2025-03-1 ┆ [{"file_t ┆ {"brand" │
# │ 1cab-74ba ┆           ┆ 6b62-76d2 ┆ 0         ┆   ┆ 8 04:13:0 ┆ 8 04:13:0 ┆ ype":     ┆ : "sexyh │
# │ -ba92-e7a ┆           ┆ -916b-eb7 ┆           ┆   ┆ 0.341917  ┆ 0.341917  ┆ "image",  ┆ ub", "br │
# │ e59…      ┆           ┆ 52d…      ┆           ┆   ┆           ┆           ┆ "conte…   ┆ andMet…  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
