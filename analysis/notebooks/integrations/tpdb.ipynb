# %%
import os

import pandas as pd
from stashapi import log
from dotenv import load_dotenv
from stashapi.stashapp import StashInterface


# Load the .env file
load_dotenv()

# Get the API key
api_key = os.getenv("ApiKey")

stash = StashInterface(
    {
        "scheme": "http",
        "host": "fraktal.auvilankuja.fi",
        "port": "9999",
        "logger": log,
        "ApiKey": api_key
    }
)
# Out:
# d Using stash (v0.25.1-0) endpoint at http://fraktal.auvilankuja.fi:9999/graphql

# %%
json_scenes = stash.find_scenes(
    {
        "stash_id_endpoint": {
            "endpoint": "https://theporndb.net/graphql",
            "modifier": "IS_NULL",
            "stash_id": ""
        }
    },
    filter={
        "per_page": 100, "page": 1, "sort": "path", "direction": "DESC"
    }
)

# Create DataFrame with specific columns
df_stash_scenes = pd.DataFrame({
    "id": [item["id"] for item in json_scenes],
    "title": [item["title"] for item in json_scenes],
    "code": [item["code"] for item in json_scenes],
    "details": [item["details"] for item in json_scenes],
    "urls": [item["urls"] for item in json_scenes],
    "date": [item["date"] for item in json_scenes],
    "duration": [item["files"][0]["duration"] for item in json_scenes],
    "created_at": [item["created_at"] for item in json_scenes],
    "updated_at": [item["updated_at"] for item in json_scenes],
    "phash": [next((fp["value"] for fp in item["files"][0]["fingerprints"] if fp["type"] == "phash"), None) for item in json_scenes],
    "stash_ids": [item["stash_ids"] for item in json_scenes],
})

df_stash_scenes
# Out:
#        id                             title                              code  \
# 0   15160  Sensual Massage from Kyler Quinn
# 1   14867                      Early Orgasm
# 2   14866                      My Fireplace
# 3   15201                       Explorers 2  EDF2FC333C00DA2449608D8F1A876E01
# 4   15182                 Under Your Skin 2  0E6B659277F50124F50401A92EBB3B27
# ..    ...                               ...                               ...
# 95   1854                  Delight Overdose
# 96  16290                     Size Matters!
# 97  15968                 A Lonely Stranger
# 98    721                      Under Attack                          lbffc4d5
# 99  16289                  Please Be Gentle                          xce08ecb
#
#                                               details  \
# 0   The majority of people think that only men cho...
# 1
# 2
# 3
# 4
# ..                                                ...
# 95
# 96
# 97
# 98
# 99
#
#                                                  urls        date  duration  \
# 0   [https://realjamvr.com/virtualreality/scene/id...  2022-10-30   2900.83
# 1   [https://www.thelifeerotic.com/model/charlotta...  2014-10-10    770.76
# 2   [https://www.thelifeerotic.com/model/charlotta...  2014-09-12    671.52
# 3   [https://www.straplez.com/model/candee-licious...  2023-07-13   2144.96
# 4   [https://www.straplez.com/model/casey-nohrman-...  2023-06-29   1785.02
# ..                                                ...         ...       ...
# 95  [https://www.data18.com/scenes/1122340, https:...  2013-07-03   1402.10
# 96  [https://www.data18.com/scenes/1120967, https:...  2013-06-18   1655.05
# 97  [https://venus.wowporn.com/film/k4e42009/a-lon...  2013-06-15   1059.12
# 98  [https://venus.wowporn.com/film/lbffc4d5/best-...  2013-05-22   1261.73
# 99  [https://venus.wowporn.com/film/xce08ecb/pleas...  2013-05-12   1546.28
#
#               created_at            updated_at             phash  \
# 0   2024-03-07T08:01:34Z  2024-04-09T06:49:30Z  dca518cd92bcc3b8
# 1   2024-02-20T06:19:58Z  2024-02-26T05:51:15Z  8e47626ecfd20695
# 2   2024-02-20T06:19:58Z  2024-02-26T05:51:16Z  d3259c212d58f796
# 3   2024-03-08T08:52:59Z  2024-03-08T13:22:09Z  cd1d3945dd62a263
# 4   2024-03-08T07:35:06Z  2024-03-08T13:40:26Z  815555dff68255a4
# ..                   ...                   ...               ...
# 95  2023-01-25T12:21:16Z  2024-02-15T11:48:27Z  edbb68213e28968e
# 96  2024-03-21T12:08:02Z  2024-03-22T13:01:47Z  c61af596e896e164
# 97  2024-03-17T04:29:55Z  2024-04-12T10:58:32Z  d3594dada1ce4272
# 98  2023-01-25T10:08:18Z  2023-02-28T08:24:36Z  8a622279c5d8dfc3
# 99  2024-03-21T12:08:02Z  2024-03-22T13:01:43Z  8e9a6293bf88d2c5
#
#                                             stash_ids
# 0   [{'endpoint': 'https://stashdb.org/graphql', '...
# 1   [{'endpoint': 'https://stashdb.org/graphql', '...
# 2   [{'endpoint': 'https://stashdb.org/graphql', '...
# 3   [{'endpoint': 'https://stashdb.org/graphql', '...
# 4   [{'endpoint': 'https://stashdb.org/graphql', '...
# ..                                                ...
# 95  [{'endpoint': 'https://stashdb.org/graphql', '...
# 96  [{'endpoint': 'https://stashdb.org/graphql', '...
# 97  [{'endpoint': 'https://stashdb.org/graphql', '...
# 98  [{'endpoint': 'https://stashdb.org/graphql', '...
# 99  [{'endpoint': 'https://stashdb.org/graphql', '...
#
# [100 rows x 11 columns]

# %%
fingerprint_list = [[{"algorithm": "PHASH", "hash": phash}] for phash in df_stash_scenes["phash"].tolist()]
fingerprint_list
# Out:
# [[{'algorithm': 'PHASH', 'hash': 'dca518cd92bcc3b8'}],
#  [{'algorithm': 'PHASH', 'hash': '8e47626ecfd20695'}],
#  [{'algorithm': 'PHASH', 'hash': 'd3259c212d58f796'}],
#  [{'algorithm': 'PHASH', 'hash': 'cd1d3945dd62a263'}],
#  [{'algorithm': 'PHASH', 'hash': '815555dff68255a4'}],
#  [{'algorithm': 'PHASH', 'hash': 'ce780e75680fb741'}],
#  [{'algorithm': 'PHASH', 'hash': 'fe733c4dacc0b580'}],
#  [{'algorithm': 'PHASH', 'hash': 'f0b6356cc5b201db'}],
#  [{'algorithm': 'PHASH', 'hash': 'f4db8404f2d474bc'}],
#  [{'algorithm': 'PHASH', 'hash': 'e6c6448173baf5a4'}],
#  [{'algorithm': 'PHASH', 'hash': '99f68fa7109497a1'}],
#  [{'algorithm': 'PHASH', 'hash': '92d74f307905f5a2'}],
#  [{'algorithm': 'PHASH', 'hash': 'a892976990e05f6f'}],
#  [{'algorithm': 'PHASH', 'hash': 'e6f3479514cc45e4'}],
#  [{'algorithm': 'PHASH', 'hash': 'c1f3a3d2d0921ce7'}],
#  [{'algorithm': 'PHASH', 'hash': '872a4538d656abd6'}],
#  [{'algorithm': 'PHASH', 'hash': 'b49618d9c9a3e6b2'}],
#  [{'algorithm': 'PHASH', 'hash': 'bb617ad5409db8a1'}],
#  [{'algorithm': 'PHASH', 'hash': 'b46d2700f93a7e86'}],
#  [{'algorithm': 'PHASH', 'hash': '98f1558b3299c7cc'}],
#  [{'algorithm': 'PHASH', 'hash': '934e829cd5c2a7e3'}],
#  [{'algorithm': 'PHASH', 'hash': 'c48897d8f93493c7'}],
#  [{'algorithm': 'PHASH', 'hash': 'e6a2c98515cbdba2'}],
#  [{'algorithm': 'PHASH', 'hash': 'f2a7d98822939d9c'}],
#  [{'algorithm': 'PHASH', 'hash': 'cc61b1ed97242d66'}],
#  [{'algorithm': 'PHASH', 'hash': 'bc16bf25d7c1c806'}],
#  [{'algorithm': 'PHASH', 'hash': 'c4d412efa8abf055'}],
#  [{'algorithm': 'PHASH', 'hash': 'ff086a8842c936fb'}],
#  [{'algorithm': 'PHASH', 'hash': 'd3279522ea571c47'}],
#  [{'algorithm': 'PHASH', 'hash': 'a69bb36893f36422'}],
#  [{'algorithm': 'PHASH', 'hash': '9a77f23754263348'}],
#  [{'algorithm': 'PHASH', 'hash': 'd7ac92577d8052ac'}],
#  [{'algorithm': 'PHASH', 'hash': 'df5d87cd3808980f'}],
#  [{'algorithm': 'PHASH', 'hash': '9feeb192118146ee'}],
#  [{'algorithm': 'PHASH', 'hash': 'cb7aa2338c08fec5'}],
#  [{'algorithm': 'PHASH', 'hash': 'c7c145030dc55ffc'}],
#  [{'algorithm': 'PHASH', 'hash': 'e12bf5c41055ad5d'}],
#  [{'algorithm': 'PHASH', 'hash': 'ed1b2a2dbec32912'}],
#  [{'algorithm': 'PHASH', 'hash': 'e8b838903cbb4de9'}],
#  [{'algorithm': 'PHASH', 'hash': '961625e96766149f'}],
#  [{'algorithm': 'PHASH', 'hash': '807dd5456ae7c057'}],
#  [{'algorithm': 'PHASH', 'hash': 'e2a6a3109d4faf38'}],
#  [{'algorithm': 'PHASH', 'hash': 'b1e2fc91a38964bc'}],
#  [{'algorithm': 'PHASH', 'hash': 'fbc58f80c3ea3843'}],
#  [{'algorithm': 'PHASH', 'hash': 'de151eb89cad98c2'}],
#  [{'algorithm': 'PHASH', 'hash': 'b5d8fcf10a806397'}],
#  [{'algorithm': 'PHASH', 'hash': 'ea2753b3c9c93492'}],
#  [{'algorithm': 'PHASH', 'hash': 'df6128137ce46e38'}],
#  [{'algorithm': 'PHASH', 'hash': 'a0c1f1884d7f0f3e'}],
#  [{'algorithm': 'PHASH', 'hash': 'a275f8ff5ea86002'}],
#  [{'algorithm': 'PHASH', 'hash': '8e8d42c203f7f9d4'}],
#  [{'algorithm': 'PHASH', 'hash': 'f4cd50f0bb64e432'}],
#  [{'algorithm': 'PHASH', 'hash': 'bdc00a7a85ae6dca'}],
#  [{'algorithm': 'PHASH', 'hash': 'e28a7c72ded98283'}],
#  [{'algorithm': 'PHASH', 'hash': '9309668679e2877b'}],
#  [{'algorithm': 'PHASH', 'hash': 'e97b709295bca1c2'}],
#  [{'algorithm': 'PHASH', 'hash': 'ad3802f89bd6643e'}],
#  [{'algorithm': 'PHASH', 'hash': 'df5a519e26e4d0b0'}],
#  [{'algorithm': 'PHASH', 'hash': 'd62702364f0b7d2d'}],
#  [{'algorithm': 'PHASH', 'hash': 'a13e9c3dfe441592'}],
#  [{'algorithm': 'PHASH', 'hash': 'dbd38d29a922d954'}],
#  [{'algorithm': 'PHASH', 'hash': 'acdf3baf4f230110'}],
#  [{'algorithm': 'PHASH', 'hash': 'a61e0b074578dfe8'}],
#  [{'algorithm': 'PHASH', 'hash': 'b9d931d963c89f40'}],
#  [{'algorithm': 'PHASH', 'hash': 'e2aca1d2aabad958'}],
#  [{'algorithm': 'PHASH', 'hash': '8adf186962df15a2'}],
#  [{'algorithm': 'PHASH', 'hash': 'd76b90a5270b90fc'}],
#  [{'algorithm': 'PHASH', 'hash': 'aa2206d18baf7fc4'}],
#  [{'algorithm': 'PHASH', 'hash': 'c05d87c8a08cefe7'}],
#  [{'algorithm': 'PHASH', 'hash': 'fd0bfa0d4c2c10fa'}],
#  [{'algorithm': 'PHASH', 'hash': 'd102a6bb463ed969'}],
#  [{'algorithm': 'PHASH', 'hash': 'e9c5c1b0f6d425a9'}],
#  [{'algorithm': 'PHASH', 'hash': 'bf5d9c2b492082cf'}],
#  [{'algorithm': 'PHASH', 'hash': '8b270b071bf243b7'}],
#  [{'algorithm': 'PHASH', 'hash': 'a06a15ea97f563a1'}],
#  [{'algorithm': 'PHASH', 'hash': 'e2396b8d4b547037'}],
#  [{'algorithm': 'PHASH', 'hash': '925643d2252d3d9f'}],
#  [{'algorithm': 'PHASH', 'hash': 'c022ecb226ed7ed1'}],
#  [{'algorithm': 'PHASH', 'hash': 'c9f1e3c983725067'}],
#  [{'algorithm': 'PHASH', 'hash': 'c7409b3f2e8cf270'}],
#  [{'algorithm': 'PHASH', 'hash': 'c41fc797659283e8'}],
#  [{'algorithm': 'PHASH', 'hash': 'a96aef239ba470a4'}],
#  [{'algorithm': 'PHASH', 'hash': '9b5469c9cc5c2e5a'}],
#  [{'algorithm': 'PHASH', 'hash': 'a03a117ab7d7a255'}],
#  [{'algorithm': 'PHASH', 'hash': 'e3734263398f2b4c'}],
#  [{'algorithm': 'PHASH', 'hash': 'f12b99a1157d5d0c'}],
#  [{'algorithm': 'PHASH', 'hash': 'cda99a91da976829'}],
#  [{'algorithm': 'PHASH', 'hash': 'd2f222a6f25c0d9d'}],
#  [{'algorithm': 'PHASH', 'hash': 'fb234243d7474666'}],
#  [{'algorithm': 'PHASH', 'hash': 'ff80702a6707d791'}],
#  [{'algorithm': 'PHASH', 'hash': 'ec5592aea6104d3f'}],
#  [{'algorithm': 'PHASH', 'hash': 'ea4c45cd6f61c0d5'}],
#  [{'algorithm': 'PHASH', 'hash': '9857a209707e3f27'}],
#  [{'algorithm': 'PHASH', 'hash': 'e71c62e752e0a89b'}],
#  [{'algorithm': 'PHASH', 'hash': '88e2b2b3c1ec369b'}],
#  [{'algorithm': 'PHASH', 'hash': 'edbb68213e28968e'}],
#  [{'algorithm': 'PHASH', 'hash': 'c61af596e896e164'}],
#  [{'algorithm': 'PHASH', 'hash': 'd3594dada1ce4272'}],
#  [{'algorithm': 'PHASH', 'hash': '8a622279c5d8dfc3'}],
#  [{'algorithm': 'PHASH', 'hash': '8e9a6293bf88d2c5'}]]

# %%
import os
from pathlib import Path

import dotenv
import pandas as pd
import requests


dotenv.load_dotenv()

api_key = os.getenv("TPDB_API_KEY")
host = os.getenv("TPDB_ENDPOINT")

# Define the headers, including any necessary authentication
headers = {
    "Content-Type": "application/json",
    "ApiKey": api_key,
}

with Path("stashdb-graphql/findScenesBySceneFingerprints.graphql").open("r") as file:
    query = file.read()

variables = {
    "fingerprints": fingerprint_list
}

# Execute the query as before
response = requests.post(host, json={"query": query, "variables": variables}, headers=headers)
if (response.status_code != 200):
    print(response.text)

data = response.json()
list_of_lists = data["data"]["findScenesBySceneFingerprints"]

# Preparing data for merging
matches = []
for i, match_list in enumerate(list_of_lists):
    matches.append({"index": i, "matches": match_list})

df_matches = pd.DataFrame(matches)
df_matches

# %%
# Define a function that will be applied to each cell in the 'matches' column
def filter_fingerprints(match_list):
    # Iterate over all matches and filter out the fingerprints based on your criteria
    for match in match_list:
        match["fingerprints"] = [
            fp for fp in match["fingerprints"]
            if fp["algorithm"] == "PHASH" and fp["duration"] is not None
        ]
    return match_list

# Apply the function to the 'matches' column of the df_matches DataFrame
df_matches["matches"] = df_matches["matches"].apply(filter_fingerprints)

# %%
# Assume df_stash_scenes has been defined earlier in your workflow
df_stash_scenes["index"] = range(len(df_stash_scenes))  # Setting an index if not already present

# Merge the DataFrames on the 'index' column
df_stash_tpdb_pairs = pd.merge(df_stash_scenes, df_matches, on="index", how="left")

# Rename columns for clarity
df_stash_tpdb_pairs.rename(columns={"matches": "tpdb_matches"}, inplace=True)

# Drop the temporary 'index' column if no longer needed
df_stash_tpdb_pairs.drop(columns=["index"], inplace=True)

# %%
df_stash_tpdb_pairs
# Out:
#        id                             title                              code  \
# 0   15160  Sensual Massage from Kyler Quinn
# 1   14867                      Early Orgasm
# 2   14866                      My Fireplace
# 3   15201                       Explorers 2  EDF2FC333C00DA2449608D8F1A876E01
# 4   15182                 Under Your Skin 2  0E6B659277F50124F50401A92EBB3B27
# ..    ...                               ...                               ...
# 95   1854                  Delight Overdose
# 96  16290                     Size Matters!
# 97  15968                 A Lonely Stranger
# 98    721                      Under Attack                          lbffc4d5
# 99  16289                  Please Be Gentle                          xce08ecb
#
#                                               details  \
# 0   The majority of people think that only men cho...
# 1
# 2
# 3
# 4
# ..                                                ...
# 95
# 96
# 97
# 98
# 99
#
#                                                  urls        date  duration  \
# 0   [https://realjamvr.com/virtualreality/scene/id...  2022-10-30   2900.83
# 1   [https://www.thelifeerotic.com/model/charlotta...  2014-10-10    770.76
# 2   [https://www.thelifeerotic.com/model/charlotta...  2014-09-12    671.52
# 3   [https://www.straplez.com/model/candee-licious...  2023-07-13   2144.96
# 4   [https://www.straplez.com/model/casey-nohrman-...  2023-06-29   1785.02
# ..                                                ...         ...       ...
# 95  [https://www.data18.com/scenes/1122340, https:...  2013-07-03   1402.10
# 96  [https://www.data18.com/scenes/1120967, https:...  2013-06-18   1655.05
# 97  [https://venus.wowporn.com/film/k4e42009/a-lon...  2013-06-15   1059.12
# 98  [https://venus.wowporn.com/film/lbffc4d5/best-...  2013-05-22   1261.73
# 99  [https://venus.wowporn.com/film/xce08ecb/pleas...  2013-05-12   1546.28
#
#               created_at            updated_at             phash  \
# 0   2024-03-07T08:01:34Z  2024-04-09T06:49:30Z  dca518cd92bcc3b8
# 1   2024-02-20T06:19:58Z  2024-02-26T05:51:15Z  8e47626ecfd20695
# 2   2024-02-20T06:19:58Z  2024-02-26T05:51:16Z  d3259c212d58f796
# 3   2024-03-08T08:52:59Z  2024-03-08T13:22:09Z  cd1d3945dd62a263
# 4   2024-03-08T07:35:06Z  2024-03-08T13:40:26Z  815555dff68255a4
# ..                   ...                   ...               ...
# 95  2023-01-25T12:21:16Z  2024-02-15T11:48:27Z  edbb68213e28968e
# 96  2024-03-21T12:08:02Z  2024-03-22T13:01:47Z  c61af596e896e164
# 97  2024-03-17T04:29:55Z  2024-04-12T10:58:32Z  d3594dada1ce4272
# 98  2023-01-25T10:08:18Z  2023-02-28T08:24:36Z  8a622279c5d8dfc3
# 99  2024-03-21T12:08:02Z  2024-03-22T13:01:43Z  8e9a6293bf88d2c5
#
#                                             stash_ids  \
# 0   [{'endpoint': 'https://stashdb.org/graphql', '...
# 1   [{'endpoint': 'https://stashdb.org/graphql', '...
# 2   [{'endpoint': 'https://stashdb.org/graphql', '...
# 3   [{'endpoint': 'https://stashdb.org/graphql', '...
# 4   [{'endpoint': 'https://stashdb.org/graphql', '...
# ..                                                ...
# 95  [{'endpoint': 'https://stashdb.org/graphql', '...
# 96  [{'endpoint': 'https://stashdb.org/graphql', '...
# 97  [{'endpoint': 'https://stashdb.org/graphql', '...
# 98  [{'endpoint': 'https://stashdb.org/graphql', '...
# 99  [{'endpoint': 'https://stashdb.org/graphql', '...
#
#                                          tpdb_matches
# 0                                                  []
# 1   [{'id': 'cf17698c-27e4-4f7e-8489-d1e36c694df0'...
# 2                                                  []
# 3                                                  []
# 4   [{'id': 'bec93462-c864-4737-9291-f9c6cc6e8129'...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97  [{'id': 'c8a93768-8254-4367-851b-2d7752ba06b2'...
# 98                                                 []
# 99                                                 []
#
# [100 rows x 12 columns]

# %%
mask = df_stash_tpdb_pairs["tpdb_matches"].apply(lambda matches: not matches)

df_stash_tpdb_possible_matches = df_stash_tpdb_pairs[~mask]
df_stash_tpdb_no_matches = df_stash_tpdb_pairs[mask]

# %%
df_stash_tpdb_possible_matches
# Out:
#        id                             title                              code  \
# 1   14867                      Early Orgasm
# 4   15182                 Under Your Skin 2  0E6B659277F50124F50401A92EBB3B27
# 5   15205                       The Catch 2
# 6   15194      Melissa Moore - Role Playing
# 9   15174
# 10  15173
# 17  15171                       Prey On Ass
# 19  15166          Wanna Fuck My Girlfriend                           8765871
# 24  15183  True Lesbian - Show Me Your Room
# 28  15971                       She Gets Me
# 47    622                      High On Love                          z0d00c06
# 49   2044                  More Than Enough                          x271a418
# 56  16304            Interaction Can Be Fun
# 62  15593                A Page In My Diary                          y7ec3f7d
# 64  16300                 I Had It Cumming?                          k31d31d1
# 67   1844                      May I Enter?                          p3e4c81d
# 71   1836               A Place With A View                          q256df21
# 72   1162                  Romantic Getaway
# 74   1843                   Are You Hungry?                          we905a51
# 77  16297                     Read Our Lips                          z1db25f1
# 80   1161               Slam My Puffy Pussy
# 81   2101                      Summer Fling
# 83    891            Love me from all sides
# 97  15968                 A Lonely Stranger
#
#                                               details  \
# 1
# 4
# 5
# 6   I travel a lot and every now and then I find m...
# 9
# 10
# 17  Karla Kush gets her ass toyed and fucked befor...
# 19  Beautiful redhead Holly Molly is busy deepthro...
# 24  Masie (Jay Taylor) is a suburban wife trapped ...
# 28
# 47
# 49
# 56
# 62  Hot and very naughty cutie Paula Shy is having...
# 64
# 67
# 71
# 72
# 74  This long-legged Swedish bitch came only to st...
# 77  Michelle and Silvie Read Our Lips at Wow Porn....
# 80  Slam My Puffy Pussy with this sexy big tits br...
# 81
# 83  Slender and beautiful girl Barbara Sweet is a ...
# 97
#
#                                                  urls        date  duration  \
# 1   [https://www.thelifeerotic.com/model/charlotta...  2014-10-10    770.76
# 4   [https://www.straplez.com/model/casey-nohrman-...  2023-06-29   1785.02
# 5   [https://www.straplez.com/model/tiffany-tatum-...  2022-12-15   1696.28
# 6   [https://www.tonightsgirlfriend.com/scene/meli...  2016-12-23   2577.57
# 9                                                  []        None   1972.48
# 10                                                 []        None   2014.08
# 17              [https://holed.com/video/prey-on-ass]  2020-02-18   2717.82
# 19  [https://www.fakehostel.com/scene/8765871/wann...  2023-05-30   1657.45
# 24  [https://www.girlsway.com/en/video/True-Lesbia...  2020-03-16   3932.76
# 28  [https://venus.wowgirls.com/film/g5cfd980/she-...  2018-12-10   2114.38
# 47  [https://venus.wowporn.com/film/z0d00c06/high-...  2016-05-16   1635.68
# 49  [https://venus.wowporn.com/film/x271a418/more-...  2016-03-18   2234.27
# 56  [https://venus.wowporn.com/film/jfcfded5/inter...  2014-07-25   1148.44
# 62  [https://venus.wowporn.com/film/y7ec3f7d/a-pag...  2014-05-30   1399.37
# 64  [https://venus.wowporn.com/film/k31d31d1/i-had...  2014-05-21   1731.74
# 67  [https://venus.wowporn.com/film/p3e4c81d/may-i...  2014-03-20   1625.44
# 71  [https://venus.wowporn.com/film/q256df21/a-pla...  2014-02-24   1330.69
# 72  [https://venus.wowporn.com/film/of94c003/roman...  2014-02-21   1474.93
# 74  [https://venus.wowporn.com/film/we905a51/are-y...  2014-02-01   1511.11
# 77  [https://venus.wowporn.com/film/z1db25f1/read-...  2013-12-22   1614.58
# 80  [https://venus.wowporn.com/film/t1a37c63/slam-...  2013-11-26   1325.59
# 81  [https://venus.wowporn.com/film/ve004547/summe...  2013-11-19   1650.92
# 83  [https://www.indexxx.com/set/603459/wowporn-ba...  2013-10-29   1381.91
# 97  [https://venus.wowporn.com/film/k4e42009/a-lon...  2013-06-15   1059.12
#
#               created_at            updated_at             phash  \
# 1   2024-02-20T06:19:58Z  2024-02-26T05:51:15Z  8e47626ecfd20695
# 4   2024-03-08T07:35:06Z  2024-03-08T13:40:26Z  815555dff68255a4
# 5   2024-03-08T08:53:00Z  2024-03-08T13:28:23Z  ce780e75680fb741
# 6   2024-03-08T07:35:11Z  2024-03-08T16:11:05Z  fe733c4dacc0b580
# 9   2024-03-08T07:34:56Z  2024-03-08T07:41:31Z  e6c6448173baf5a4
# 10  2024-03-08T07:34:56Z  2024-03-08T07:41:09Z  99f68fa7109497a1
# 17  2024-03-08T07:34:56Z  2024-04-09T06:55:09Z  bb617ad5409db8a1
# 19  2024-03-08T07:34:55Z  2024-04-09T06:55:13Z  98f1558b3299c7cc
# 24  2024-03-08T07:35:07Z  2024-03-08T13:40:35Z  cc61b1ed97242d66
# 28  2024-03-17T04:29:56Z  2024-04-12T10:58:27Z  d3279522ea571c47
# 47  2023-01-25T10:06:55Z  2024-01-31T05:52:10Z  df6128137ce46e38
# 49  2023-01-25T12:23:21Z  2024-04-23T13:27:23Z  a275f8ff5ea86002
# 56  2024-03-21T12:08:05Z  2024-03-31T05:06:33Z  ad3802f89bd6643e
# 62  2024-03-11T12:05:31Z  2024-03-11T16:24:54Z  a61e0b074578dfe8
# 64  2024-03-21T12:08:04Z  2024-03-27T04:05:01Z  e2aca1d2aabad958
# 67  2023-01-25T12:21:10Z  2024-02-15T11:48:31Z  aa2206d18baf7fc4
# 71  2023-01-25T12:21:07Z  2024-02-15T11:48:34Z  e9c5c1b0f6d425a9
# 72  2023-01-25T12:14:25Z  2023-01-25T14:33:39Z  bf5d9c2b492082cf
# 74  2023-01-25T12:21:10Z  2024-02-15T11:48:32Z  a06a15ea97f563a1
# 77  2024-03-21T12:08:04Z  2024-03-27T04:04:39Z  c022ecb226ed7ed1
# 80  2023-01-25T12:14:24Z  2023-02-28T08:24:52Z  c41fc797659283e8
# 81  2023-01-25T12:23:53Z  2024-02-15T11:48:16Z  a96aef239ba470a4
# 83  2023-01-25T10:10:25Z  2024-04-27T03:35:30Z  a03a117ab7d7a255
# 97  2024-03-17T04:29:55Z  2024-04-12T10:58:32Z  d3594dada1ce4272
#
#                                             stash_ids  \
# 1   [{'endpoint': 'https://stashdb.org/graphql', '...
# 4   [{'endpoint': 'https://stashdb.org/graphql', '...
# 5   [{'endpoint': 'https://stashdb.org/graphql', '...
# 6   [{'endpoint': 'https://stashdb.org/graphql', '...
# 9                                                  []
# 10                                                 []
# 17  [{'endpoint': 'https://stashdb.org/graphql', '...
# 19  [{'endpoint': 'https://stashdb.org/graphql', '...
# 24  [{'endpoint': 'https://stashdb.org/graphql', '...
# 28  [{'endpoint': 'https://stashdb.org/graphql', '...
# 47  [{'endpoint': 'https://stashdb.org/graphql', '...
# 49  [{'endpoint': 'https://stashdb.org/graphql', '...
# 56  [{'endpoint': 'https://stashdb.org/graphql', '...
# 62  [{'endpoint': 'https://stashdb.org/graphql', '...
# 64  [{'endpoint': 'https://stashdb.org/graphql', '...
# 67  [{'endpoint': 'https://stashdb.org/graphql', '...
# 71  [{'endpoint': 'https://stashdb.org/graphql', '...
# 72  [{'endpoint': 'https://stashdb.org/graphql', '...
# 74  [{'endpoint': 'https://stashdb.org/graphql', '...
# 77  [{'endpoint': 'https://stashdb.org/graphql', '...
# 80  [{'endpoint': 'https://stashdb.org/graphql', '...
# 81  [{'endpoint': 'https://stashdb.org/graphql', '...
# 83  [{'endpoint': 'https://stashdb.org/graphql', '...
# 97  [{'endpoint': 'https://stashdb.org/graphql', '...
#
#                                          tpdb_matches
# 1   [{'id': 'cf17698c-27e4-4f7e-8489-d1e36c694df0'...
# 4   [{'id': 'bec93462-c864-4737-9291-f9c6cc6e8129'...
# 5   [{'id': '90484f5c-c1f4-4f37-9f3d-7bcb0c5b271f'...
# 6   [{'id': '4de41359-9682-49a4-886e-95357d6dfb6b'...
# 9   [{'id': '9c1bdfbb-d0ca-422c-9126-575dd6f288b2'...
# 10  [{'id': '20843eec-6e96-421e-8347-4a5c83bd6e03'...
# 17  [{'id': '26274449-6c36-4c3c-b2f9-5c8c8940719d'...
# 19  [{'id': 'fcc9dc1a-aa42-4ed3-bf83-81aed3de3135'...
# 24  [{'id': '4e4c0e6b-f351-499f-b5c3-5f2ee9369757'...
# 28  [{'id': 'fb2ed2c7-e39c-4d7d-b609-2fad958352da'...
# 47  [{'id': '9861699e-0830-419d-b2fa-77deb7a495bb'...
# 49  [{'id': 'bbe68ab3-0ca7-4508-a1e5-c42f74a3ddfe'...
# 56  [{'id': '0d784ae8-a7ee-4fdd-8712-032b64e0a55a'...
# 62  [{'id': 'b028a438-be2f-49eb-812c-a9d405c1c358'...
# 64  [{'id': 'fb086ee1-9047-4827-80b2-d33941ec1d62'...
# 67  [{'id': 'd043bb86-a8f9-4b84-9b12-1b5f0a55508b'...
# 71  [{'id': '9ae00575-4f30-4b59-b999-c7cf769ebff6'...
# 72  [{'id': 'd1660eaa-908b-4f84-b35a-abe786d2efe3'...
# 74  [{'id': '4a443544-796f-481a-a907-b6d9f551dc8a'...
# 77  [{'id': 'ece726fa-6e67-410e-ac53-7ccc3145fa92'...
# 80  [{'id': '916dfa85-dfeb-426d-bdea-b64e2a564b13'...
# 81  [{'id': 'e052a018-1310-4fa1-882d-32d64cc725c6'...
# 83  [{'id': '67e13f78-6496-40e4-8e03-495e41d0d00d'...
# 97  [{'id': 'c8a93768-8254-4367-851b-2d7752ba06b2'...

# %%
max_duration_difference = 3

# Assuming 'duration' column exists in df_stash_tpdb_possible_matches
def duration_match(tpdb_matches, stash_duration):
    return any(
        abs(match["duration"] - stash_duration) <= max_duration_difference
        for match in tpdb_matches
    )

# Apply this function row-wise
promising_matches_mask = df_stash_tpdb_possible_matches.apply(
    lambda row: duration_match(row["tpdb_matches"], row["duration"]),
    axis=1
)

# Use this mask to separate promising matches
df_promising_matches = df_stash_tpdb_possible_matches[promising_matches_mask]

# The rows that don't meet the condition are the poor matches
df_poor_matches = df_stash_tpdb_possible_matches[~promising_matches_mask]

# %%
df_poor_matches
# Out:
#        id        title code  \
# 17  15171  Prey On Ass
#
#                                               details  \
# 17  Karla Kush gets her ass toyed and fucked befor...
#
#                                      urls        date  duration  \
# 17  [https://holed.com/video/prey-on-ass]  2020-02-18   2717.82
#
#               created_at            updated_at             phash  \
# 17  2024-03-08T07:34:56Z  2024-04-09T06:55:09Z  bb617ad5409db8a1
#
#                                             stash_ids  \
# 17  [{'endpoint': 'https://stashdb.org/graphql', '...
#
#                                          tpdb_matches
# 17  [{'id': '26274449-6c36-4c3c-b2f9-5c8c8940719d'...

# %%
df_promising_matches["tpdb_matches"].values
# Out:
# array([list([{'id': 'cf17698c-27e4-4f7e-8489-d1e36c694df0', 'title': 'Early Orgasm', 'details': '', 'date': '2014-10-10', 'urls': [{'url': 'https://thelifeerotic.com/model/charlotta-phillip/movie/20141010/EARLY_ORGASM', 'site': None}], 'performers': [{'performer': {'id': '55f40383-9c9d-4220-8d1d-267a6a122bda', 'name': 'Charlotta Phillip', 'gender': 'FEMALE'}, 'as': 'Charlotta Phillip'}], 'duration': 771, 'director': None, 'code': '20141010_early_orgasm', 'deleted': False, 'created': '2021-09-04T12:03:17+00:00', 'updated': '2024-03-07T05:36:46+00:00', 'fingerprints': [{'hash': '8e47626ecfd20695', 'algorithm': 'PHASH', 'duration': 770}]}]),
#        list([{'id': 'bec93462-c864-4737-9291-f9c6cc6e8129', 'title': 'Under Your Skin 2', 'details': '', 'date': '2023-06-29', 'urls': [{'url': 'https://straplez.com/model/casey-nohrman-and-bonnie-dolce/movie/20230629/UNDER_YOUR_SKIN_2', 'site': None}], 'performers': [{'performer': {'id': '85e222e0-f27d-4923-afc7-75f7376a2bfe', 'name': 'Bonnie Dolce', 'gender': 'FEMALE'}, 'as': 'Bonnie Dolce'}, {'performer': {'id': '69a87e77-ccae-4f28-8518-fa67eaf8eaf5', 'name': 'Casey Nohrman', 'gender': 'FEMALE'}, 'as': 'Casey Nohrman'}], 'duration': 1785, 'director': None, 'code': '20230629_under_your_skin_2', 'deleted': False, 'created': '2023-06-29T15:03:41+00:00', 'updated': '2024-02-16T09:54:28+00:00', 'fingerprints': [{'hash': '815555dff68255a4', 'algorithm': 'PHASH', 'duration': 1785}, {'hash': '8155559ff68275a4', 'algorithm': 'PHASH', 'duration': 1785}]}]),
#        list([{'id': '90484f5c-c1f4-4f37-9f3d-7bcb0c5b271f', 'title': 'The Catch 2', 'details': '', 'date': '2022-12-15', 'urls': [{'url': 'https://straplez.com/model/tiffany-tatum-and-zazie-skymm/movie/20221215/THE_CATCH_2', 'site': None}], 'performers': [{'performer': {'id': 'ca9ec170-5992-4eb6-a263-fe63d7e14e97', 'name': 'Tiffany Tatum', 'gender': 'FEMALE'}, 'as': 'Tiffany Tatum'}, {'performer': {'id': '964b24e7-bb02-4ad8-a248-4bb356e0ae3a', 'name': 'Zazie Skymm', 'gender': 'FEMALE'}, 'as': 'Zazie Skymm'}], 'duration': 1696, 'director': None, 'code': '20221215_THE_CATCH_2', 'deleted': False, 'created': '2022-12-16T01:40:39+00:00', 'updated': '2024-03-07T06:09:31+00:00', 'fingerprints': [{'hash': 'ce780e75680fb741', 'algorithm': 'PHASH', 'duration': 1696}, {'hash': 'ce780e75680f9749', 'algorithm': 'PHASH', 'duration': 1696}, {'hash': 'ce7c0e75680f9741', 'algorithm': 'PHASH', 'duration': 1696}, {'hash': 'cf680e75680f9749', 'algorithm': 'PHASH', 'duration': 1696}]}]),
#        list([{'id': '4de41359-9682-49a4-886e-95357d6dfb6b', 'title': 'Melissa Moore', 'details': "I travel a lot and every now and then I find myself in a room next to a couple that can't stop fucking.  It's always been my fantasy to have the girl invite me over and let me fuck her.  Today, I get to live out that fantasy by having Melissa Moore come over and role playing that fantasy just for me.", 'date': '2016-12-23', 'urls': [{'url': 'https://tonightsgirlfriend.com/scene/melissa-moore-22125', 'site': None}], 'performers': [{'performer': {'id': 'e584b40e-3161-4f4a-a89e-e3d8900ed6ee', 'name': 'Melissa Moore', 'gender': 'FEMALE'}, 'as': 'Melissa Moore'}], 'duration': 2577, 'director': None, 'code': 'melissa-moore-22125', 'deleted': False, 'created': '2021-05-02T01:39:08+00:00', 'updated': '2023-02-14T15:21:07+00:00', 'fingerprints': [{'hash': 'be33ba457cc0f580', 'algorithm': 'PHASH', 'duration': 2573}, {'hash': 'be7338652cc6b588', 'algorithm': 'PHASH', 'duration': 2573}, {'hash': 'be733a457cc0f580', 'algorithm': 'PHASH', 'duration': 2573}, {'hash': 'fe733c4dacc0b580', 'algorithm': 'PHASH', 'duration': 2577}, {'hash': 'ff733e450cc4b580', 'algorithm': 'PHASH', 'duration': 2577}]}]),
#        list([{'id': '9c1bdfbb-d0ca-422c-9126-575dd6f288b2', 'title': '1853 Casey Norhman', 'details': 'In the Cunt Tree Side.\nInitially Casey’s loose hanging knit gown hides a lot of her curves but we soon get inside of it for some naughty views. It’s only a few minutes before she is all naked and we spend the rest of the clip ogling her bare pussy and ass. The hammock may seem like an awkward place to pose but she manages it expertly and gives us a beautiful up the butt view in the bend over position near the end.\nNorhman Rock While Panting.\nCasey does the fist part of her masturbation session with her butt dangling in mid air hanging off the edge of the hammock. This is all finger masturbation pussy rubbing leaving plenty of exposure for pussy and ass ogling. Later she turns doggy style with her ass high giving the best possible view up her ass in the heat of the action.\nHopalong Casey.\nCasey puts her own stamp on the walking scene with lots of playfulness, skipping, crawling and even running as she goes. It’s more of a frolic, not so elegant but definitely with lots of character.', 'date': '2023-08-23', 'urls': [{'url': 'https://inthecrack.com/Collection/1874', 'site': None}], 'performers': [{'performer': {'id': '69a87e77-ccae-4f28-8518-fa67eaf8eaf5', 'name': 'Casey Nohrman', 'gender': 'FEMALE'}, 'as': 'Casey Norhman'}], 'duration': 1972, 'director': None, 'code': '1874', 'deleted': False, 'created': '2023-08-23T18:31:19+00:00', 'updated': '2024-02-16T10:49:57+00:00', 'fingerprints': [{'hash': 'e6c6448173baf5a4', 'algorithm': 'PHASH', 'duration': 1972}, {'hash': 'e6c6449163baf5a4', 'algorithm': 'PHASH', 'duration': 1972}]}]),
#        list([{'id': '20843eec-6e96-421e-8347-4a5c83bd6e03', 'title': '1767 Casey Norhman', 'details': "You're Under a Rust.\\\nCasey’s rust red lingerie is matched not only by the rug but also a hint of left over red dye in her hair. She does a beautiful squat on top of your face while fiddling with her panties.\\\nPerfectly Norhmal.\\\nShe is all nude now except for the garter and shoes with the pussy and ass out for inspection. Once again the low angle views are outstanding with Casey often squatting on top of you and/or parking her butt on your face. She finds an interesting way to crabwalk with her butt high up on the back of the chair.\\\nSo Fucking Chair Full.\\\nCasey uses a soft vibrator toy in her pussy while lying back on the green chair. She gets all the best positions with her ass out in the open letting it all be seen. Once again she finds a great crab walk position high up on the chair with her pussy hovering over your face. Though she never spews any goo she does get a little creamy and her pussy opens up quite nicely.\\\nSitty Dweller.\\\nThe smaller red chair is the perfect prop for Casey to show off her back side while sitting backwards on the chair. The underside views are outstanding with a beautiful ass hole and pussy squatting almost right on your face. She momentarily goes for a doggy stye pose on the chair before returning to the outstanding backward sitting pose. Her excellent butthole flexing is also mixed in from time to time.", 'date': '2022-06-19', 'urls': [{'url': 'https://inthecrack.com/Collection/1788', 'site': None}], 'performers': [{'performer': {'id': '69a87e77-ccae-4f28-8518-fa67eaf8eaf5', 'name': 'Casey Nohrman', 'gender': 'FEMALE'}, 'as': 'Casey Norhman'}], 'duration': 2014, 'director': None, 'code': '1788', 'deleted': False, 'created': '2022-10-02T12:59:24+00:00', 'updated': '2023-01-01T21:31:20+00:00', 'fingerprints': [{'hash': '99f68fa7109497a1', 'algorithm': 'PHASH', 'duration': 2014}, {'hash': 'd9f60fa7109497a1', 'algorithm': 'PHASH', 'duration': 2014}, {'hash': '9bf60fa7109497a1', 'algorithm': 'PHASH', 'duration': 2014}]}]),
#        list([{'id': 'fcc9dc1a-aa42-4ed3-bf83-81aed3de3135', 'title': 'Wanna Fuck My Girlfriend', 'details': 'Beautiful redhead Holly Molly is busy deepthroating her boyfriend’s dick in the Fake Hostel. Unbeknownst to the couple, their pervy host, Steve Q, is spying on them while masturbating! After entering their room, the grey-haired hunk is invited by the raunchy pair to join in the fun: while Holly gags on Steve’s thick dick, her boyfriend Mark Zane bangs her tight pussy in a sexy side fuck, and then the flame-haired stunner spreads her legs so that Steve can slide his cock inside her missionary-style. Afterwards, Steve gives Holly an intense fingering until she screams in euphoria and squirts her orgasm everywhere! Next, the naughty minx treats her lovers to a sloppy double blowjob before riding Mark in reverse as Steve fucks her pretty face, and then she gets on all fours to take a doggystyle pounding from her handsome, dark-haired boyfriend. Once the well-hung dudes have had their fill of Holly, they pull out and jerk themselves off until the Russian slut is dripping in their cum!', 'date': '2023-05-30', 'urls': [{'url': 'https://fakehostel.com/scene/8765871/wanna-fuck-my-girlfriend', 'site': None}], 'performers': [{'performer': {'id': '12366daa-8b76-47c2-b30d-abca5a6ee652', 'name': 'Holly Molly', 'gender': 'FEMALE'}, 'as': 'Holly Molly'}, {'performer': {'id': '34b26269-430e-4c06-a58d-3dba800776e4', 'name': 'Steve Q', 'gender': 'MALE'}, 'as': 'Steve Q'}], 'duration': 1657, 'director': None, 'code': '8765871', 'deleted': False, 'created': '2023-05-30T17:51:13+00:00', 'updated': '2024-02-16T09:24:40+00:00', 'fingerprints': [{'hash': '98f1558b3299c7cc', 'algorithm': 'PHASH', 'duration': 1657}, {'hash': '9cf1518b3299c7cc', 'algorithm': 'PHASH', 'duration': 1657}, {'hash': '98f151cb3299c7cc', 'algorithm': 'PHASH', 'duration': 1657}]}]),
#        list([{'id': '4e4c0e6b-f351-499f-b5c3-5f2ee9369757', 'title': 'True Lesbian - Show Me Your Room', 'details': "Masie (Jay Taylor) is a suburban wife trapped in her own personal hell. She's been married to her husband for two years but the spark is already gone... and the more she thinks about it, the more she wonders if it was ever there to begin with.\n\nOverwhelmed with the need to feel SOMETHING, she tries experimenting with her sexuality in secret. Although she doesn't feel anything for her husband anymore, seeing a sexy woman stirs something deep down that terrifies and excites her. When she can spare a moment, she pops in her earbuds and listens to erotic lesbian audiobooks, but they're not enough... With each passing day, the loneliness and longing for another woman's sensual touch becomes all-consuming.\n\nOne day, her husband announces that his boss will be coming over for dinner -- and that the wife will be tagging along. Masie barely acknowledges his words, other than to mindlessly agree to putting on a pot roast. She really doesn't care about ANY of this anymore and is near her breaking point.\n\nBut when the guests later arrive, Masie's world is unexpectedly turned upside down.\n\nHer husband's boss is a woman who's brought along her gorgeous wife, Andrea (Angela White). Masie wasn't expecting to be hosting lesbians, and she's never seen a woman as breathtaking and confident as Andrea.\n\nAll throughout dinner, Masie barely holds it together, unable to keep her eyes off Andrea. It seems as though Andrea has bedroom eyes for her, too, and there's no denying the chemistry between them. Masie feels more alive now than she has in a long time with each glance across the table and brush of ankles beneath. When Andrea later suggests that Masie show her around the house to leave their spouses to talk shop, Masie's mind races. Is Andrea offering to do what Masie thinks she is?\n\nAlthough she's been wanting to feel something, ANYTHING, for so long, now that she has the chance, Masie's scared. If she gives into these urges with Andrea, there will be no going back...", 'date': '2020-03-16', 'urls': [{'url': 'https://girlsway.com/en/video/True-Lesbian---Show-Me-Your-Room/168278', 'site': None}], 'performers': [{'performer': {'id': 'a6fb1863-b433-4274-ae07-0e1327c854d1', 'name': 'Angela White', 'gender': 'FEMALE'}, 'as': 'Angela White'}, {'performer': {'id': 'bf627c64-46e4-4068-9524-4c7149c06529', 'name': 'Jay Taylor', 'gender': 'FEMALE'}, 'as': 'Jay Taylor'}], 'duration': 3932, 'director': 'Bree Mills', 'code': '168278', 'deleted': False, 'created': '2021-06-14T23:49:51+00:00', 'updated': '2024-02-16T04:22:18+00:00', 'fingerprints': [{'hash': 'cc61b1ed97242d66', 'algorithm': 'PHASH', 'duration': 3932}, {'hash': 'cc61e9a59360bd6a', 'algorithm': 'PHASH', 'duration': 3932}, {'hash': 'c135e12d93243de7', 'algorithm': 'PHASH', 'duration': 3932}, {'hash': 'cc61e1a59364bd6a', 'algorithm': 'PHASH', 'duration': 3932}, {'hash': 'cc61f1a59360bd6a', 'algorithm': 'PHASH', 'duration': 3932}]}]),
#        list([{'id': 'fb2ed2c7-e39c-4d7d-b609-2fad958352da', 'title': 'She Gets Me', 'details': '', 'date': '2018-12-10', 'urls': [{'url': 'https://venus.wowporn.com/film/g5cfd980/she-gets-me', 'site': None}], 'performers': [{'performer': {'id': '44dc6c02-97cc-4570-8b0e-d7634ad46c99', 'name': 'Lexi Dona', 'gender': 'FEMALE'}, 'as': 'Lexi Dona'}, {'performer': {'id': '275480b7-dcd9-4d33-9038-c61d80bac6fb', 'name': 'Sybil Kailena', 'gender': 'FEMALE'}, 'as': 'Sybil'}], 'duration': 2114, 'director': None, 'code': '10129', 'deleted': False, 'created': '2024-04-14T22:12:03+00:00', 'updated': '2024-04-14T22:12:03+00:00', 'fingerprints': [{'hash': 'd3279522ea571c47', 'algorithm': 'PHASH', 'duration': 2114}]}]),
#        list([{'id': '9861699e-0830-419d-b2fa-77deb7a495bb', 'title': 'High on Love', 'details': '', 'date': '2016-05-16', 'urls': [{'url': 'https://venus.wowporn.com/film/z0d00c06/high-on-love', 'site': None}], 'performers': [{'performer': {'id': '1b5898d3-8ae1-4e36-9779-9961a77eb261', 'name': 'Alexis Crystal', 'gender': 'FEMALE'}, 'as': 'Alexis Crystal'}, {'performer': {'id': 'f3103f8a-f80f-4750-8619-e0d90f081966', 'name': 'Kattie Gold', 'gender': 'FEMALE'}, 'as': 'Janice'}], 'duration': 1635, 'director': None, 'code': '8468', 'deleted': False, 'created': '2024-04-14T22:10:06+00:00', 'updated': '2024-04-14T22:10:06+00:00', 'fingerprints': [{'hash': 'df6128137ce46e38', 'algorithm': 'PHASH', 'duration': 1635}]}]),
#        list([{'id': 'bbe68ab3-0ca7-4508-a1e5-c42f74a3ddfe', 'title': 'More Than Enough', 'details': '', 'date': '2016-03-18', 'urls': [{'url': 'https://venus.wowporn.com/film/x271a418/more-than-enough', 'site': None}], 'performers': [{'performer': {'id': '6891e0d8-df89-4c0e-9d8c-2132be18609a', 'name': 'Nina North', 'gender': 'FEMALE'}, 'as': 'Nina North'}, {'performer': {'id': '013593b3-6741-4a9f-bdab-e842dbed2e10', 'name': 'Paula Shy', 'gender': 'FEMALE'}, 'as': 'Paula Shy'}], 'duration': 2234, 'director': None, 'code': '8266', 'deleted': False, 'created': '2024-04-14T22:09:58+00:00', 'updated': '2024-04-14T22:09:58+00:00', 'fingerprints': [{'hash': 'a275f8ff5ea86002', 'algorithm': 'PHASH', 'duration': 2234}]}]),
#        list([{'id': '0d784ae8-a7ee-4fdd-8712-032b64e0a55a', 'title': 'Interaction Can Be Fun', 'details': '', 'date': '2014-07-25', 'urls': [{'url': 'https://venus.wowporn.com/film/jfcfded5/interaction-can-be-fun', 'site': None}], 'performers': [{'performer': {'id': 'bc576cd0-dcb4-4a93-80fa-32e4c84387f7', 'name': 'Krystal Boyd', 'gender': 'FEMALE'}, 'as': 'Anjelica'}, {'performer': {'id': 'b6ff2665-ee43-4743-8e36-af4cb28e05bb', 'name': 'Heidi Romanova', 'gender': 'FEMALE'}, 'as': 'Vanessa'}], 'duration': 1148, 'director': None, 'code': '7296', 'deleted': False, 'created': '2024-04-14T22:08:59+00:00', 'updated': '2024-04-14T22:08:59+00:00', 'fingerprints': [{'hash': 'ad3802f89bd6643e', 'algorithm': 'PHASH', 'duration': 1148}]}]),
#        list([{'id': 'b028a438-be2f-49eb-812c-a9d405c1c358', 'title': 'A Page in My Diary', 'details': '', 'date': '2014-05-30', 'urls': [{'url': 'https://venus.wowporn.com/film/y7ec3f7d/a-page-in-my-diary', 'site': None}], 'performers': [{'performer': {'id': '013593b3-6741-4a9f-bdab-e842dbed2e10', 'name': 'Paula Shy', 'gender': 'FEMALE'}, 'as': 'Paula Shy'}], 'duration': 1399, 'director': None, 'code': '7278', 'deleted': False, 'created': '2024-04-14T22:08:52+00:00', 'updated': '2024-04-14T22:08:52+00:00', 'fingerprints': [{'hash': 'a61a0b074578dfec', 'algorithm': 'PHASH', 'duration': 1399}, {'hash': 'a61e0b074578dfe8', 'algorithm': 'PHASH', 'duration': 1399}]}]),
#        list([{'id': 'fb086ee1-9047-4827-80b2-d33941ec1d62', 'title': 'I Had It Cumming?', 'details': '', 'date': '2014-05-21', 'urls': [{'url': 'https://venus.wowporn.com/film/k31d31d1/i-had-it-cumming', 'site': None}], 'performers': [{'performer': {'id': 'ecbe2d2a-9d6b-4887-a98b-61dafe589325', 'name': 'Miriama Kunkelova', 'gender': 'FEMALE'}, 'as': 'Nancey'}], 'duration': 1731, 'director': None, 'code': '7272', 'deleted': False, 'created': '2024-04-14T22:08:47+00:00', 'updated': '2024-04-14T22:08:47+00:00', 'fingerprints': [{'hash': 'e2aca1d2aabad958', 'algorithm': 'PHASH', 'duration': 1731}]}]),
#        list([{'id': 'd043bb86-a8f9-4b84-9b12-1b5f0a55508b', 'title': 'May I Enter?', 'details': '', 'date': '2014-03-20', 'urls': [{'url': 'https://venus.wowporn.com/film/p3e4c81d/may-i-enter', 'site': None}], 'performers': [{'performer': {'id': '7687ff7c-b36d-44bd-82ee-a154b904db52', 'name': 'Red Fox', 'gender': 'FEMALE'}, 'as': 'Michelle'}], 'duration': 1625, 'director': None, 'code': '7102', 'deleted': False, 'created': '2024-04-14T22:08:33+00:00', 'updated': '2024-04-14T22:08:33+00:00', 'fingerprints': [{'hash': 'aa2206d18baf7fc4', 'algorithm': 'PHASH', 'duration': 1625}]}]),
#        list([{'id': '9ae00575-4f30-4b59-b999-c7cf769ebff6', 'title': 'A Place with a View', 'details': '', 'date': '2014-02-24', 'urls': [{'url': 'https://venus.wowporn.com/film/q256df21/a-place-with-a-view', 'site': None}], 'performers': [{'performer': {'id': '7687ff7c-b36d-44bd-82ee-a154b904db52', 'name': 'Red Fox', 'gender': 'FEMALE'}, 'as': 'Michelle'}, {'performer': {'id': 'ecbe2d2a-9d6b-4887-a98b-61dafe589325', 'name': 'Miriama Kunkelova', 'gender': 'FEMALE'}, 'as': 'Nancey'}], 'duration': 1330, 'director': None, 'code': '7088', 'deleted': False, 'created': '2024-04-14T22:08:28+00:00', 'updated': '2024-04-14T22:08:28+00:00', 'fingerprints': [{'hash': 'e9c5c1b0f6d425a9', 'algorithm': 'PHASH', 'duration': 1330}]}]),
#        list([{'id': 'd1660eaa-908b-4f84-b35a-abe786d2efe3', 'title': 'Romantic Getaway', 'details': '', 'date': '2014-02-21', 'urls': [{'url': 'https://venus.wowporn.com/film/of94c003/romantic-getaway', 'site': None}], 'performers': [{'performer': {'id': 'bbf6fe78-1b1e-4dc2-af44-db078247771d', 'name': 'Connie Carter', 'gender': 'FEMALE'}, 'as': 'Connie'}], 'duration': 1474, 'director': None, 'code': '7086', 'deleted': False, 'created': '2024-04-14T22:08:25+00:00', 'updated': '2024-04-14T22:08:25+00:00', 'fingerprints': [{'hash': 'bf5d9c2b492082cf', 'algorithm': 'PHASH', 'duration': 1474}]}]),
#        list([{'id': '4a443544-796f-481a-a907-b6d9f551dc8a', 'title': 'Are You Hungry?', 'details': '', 'date': '2014-02-01', 'urls': [{'url': 'https://venus.wowporn.com/film/we905a51/are-you-hungry', 'site': None}], 'performers': [{'performer': {'id': '7687ff7c-b36d-44bd-82ee-a154b904db52', 'name': 'Red Fox', 'gender': 'FEMALE'}, 'as': 'Michelle'}], 'duration': 1511, 'director': None, 'code': '7072', 'deleted': False, 'created': '2024-04-14T22:08:20+00:00', 'updated': '2024-04-14T22:08:20+00:00', 'fingerprints': [{'hash': 'a06a15ea97f563a1', 'algorithm': 'PHASH', 'duration': 1511}]}]),
#        list([{'id': 'ece726fa-6e67-410e-ac53-7ccc3145fa92', 'title': 'Read Our Lips', 'details': '', 'date': '2013-12-22', 'urls': [{'url': 'https://venus.wowporn.com/film/z1db25f1/read-our-lips', 'site': None}], 'performers': [{'performer': {'id': '7687ff7c-b36d-44bd-82ee-a154b904db52', 'name': 'Red Fox', 'gender': 'FEMALE'}, 'as': 'Michelle'}, {'performer': {'id': 'd67cd8bc-e31c-46f8-8d38-36afec28deb4', 'name': 'Silvie Deluxe', 'gender': 'FEMALE'}, 'as': 'Silvie'}], 'duration': 1614, 'director': None, 'code': '6990', 'deleted': False, 'created': '2024-04-14T22:08:11+00:00', 'updated': '2024-04-14T22:08:11+00:00', 'fingerprints': [{'hash': 'c022ecb226ed7ed1', 'algorithm': 'PHASH', 'duration': 1614}]}]),
#        list([{'id': '916dfa85-dfeb-426d-bdea-b64e2a564b13', 'title': 'Slam My Puffy Pussy', 'details': '', 'date': '2013-11-26', 'urls': [{'url': 'https://venus.wowporn.com/film/t1a37c63/slam-my-puffy-pussy', 'site': None}], 'performers': [{'performer': {'id': 'bbf6fe78-1b1e-4dc2-af44-db078247771d', 'name': 'Connie Carter', 'gender': 'FEMALE'}, 'as': 'Connie'}], 'duration': 1325, 'director': None, 'code': '6902', 'deleted': False, 'created': '2024-04-14T22:08:07+00:00', 'updated': '2024-04-14T22:08:07+00:00', 'fingerprints': [{'hash': 'c41fc797659283e8', 'algorithm': 'PHASH', 'duration': 1325}]}]),
#        list([{'id': 'e052a018-1310-4fa1-882d-32d64cc725c6', 'title': 'Summer Fling', 'details': '', 'date': '2013-11-19', 'urls': [{'url': 'https://venus.wowporn.com/film/ve004547/summer-fling', 'site': None}], 'performers': [{'performer': {'id': '013593b3-6741-4a9f-bdab-e842dbed2e10', 'name': 'Paula Shy', 'gender': 'FEMALE'}, 'as': 'Paula Shy'}], 'duration': 1650, 'director': None, 'code': '6900', 'deleted': False, 'created': '2024-04-14T22:08:04+00:00', 'updated': '2024-04-14T22:08:04+00:00', 'fingerprints': [{'hash': 'a96aef239ba470a4', 'algorithm': 'PHASH', 'duration': 1650}]}]),
#        list([{'id': '67e13f78-6496-40e4-8e03-495e41d0d00d', 'title': 'Love Me From All Sides', 'details': '', 'date': '2013-10-29', 'urls': [{'url': 'https://venus.wowporn.com/film/qa344440/love-me-from-all-sides', 'site': None}], 'performers': [{'performer': {'id': 'eda907e8-b889-4b0e-91e3-917fa27ed148', 'name': 'Melissa Medisson', 'gender': 'FEMALE'}, 'as': 'Barbara Sweet'}], 'duration': 1381, 'director': None, 'code': '6883', 'deleted': False, 'created': '2024-04-14T22:07:58+00:00', 'updated': '2024-04-14T22:07:58+00:00', 'fingerprints': [{'hash': 'a03a117ab7d7a255', 'algorithm': 'PHASH', 'duration': 1381}]}]),
#        list([{'id': 'c8a93768-8254-4367-851b-2d7752ba06b2', 'title': 'Doris Ivy, Krystal Boyd, Katherine A, Abby C, Ebbi, Kathy I, Krystal Boyd, Anjelica, Abby', 'details': '', 'date': '2018-06-22', 'urls': [{'url': 'https://teendreams.com/t4/trailers/Doris-Ivy-Krystal-Boyd-Katherine-A-Abby-C-Ebbi-Kathy-I-Krystal-Boyd-Anjelica-Abby.html', 'site': None}], 'performers': [{'performer': {'id': 'bc576cd0-dcb4-4a93-80fa-32e4c84387f7', 'name': 'Krystal Boyd', 'gender': 'FEMALE'}, 'as': 'Anjelica'}], 'duration': 1373, 'director': None, 'code': 'doris-ivy-krystal-boyd-katherine-a-abby-c-ebbi-kathy-i-krystal-boyd-anjelica-abby', 'deleted': False, 'created': '2022-02-20T21:11:01+00:00', 'updated': '2024-03-19T01:31:15+00:00', 'fingerprints': [{'hash': 'da1a32bdada4f442', 'algorithm': 'PHASH', 'duration': 1257}, {'hash': 'b3632485c3f2b633', 'algorithm': 'PHASH', 'duration': 1282}, {'hash': '861e059b6bee3073', 'algorithm': 'PHASH', 'duration': 1485}, {'hash': 'e88273ad346349f9', 'algorithm': 'PHASH', 'duration': 1212}, {'hash': 'e666ad337a2b0469', 'algorithm': 'PHASH', 'duration': 1452}, {'hash': 'd7cc6a76d2f22281', 'algorithm': 'PHASH', 'duration': 1416}, {'hash': 'd3594dada1ce4272', 'algorithm': 'PHASH', 'duration': 1059}, {'hash': 'df6bb1c0aca9e091', 'algorithm': 'PHASH', 'duration': 1258}, {'hash': 'ca5798a7a03c633b', 'algorithm': 'PHASH', 'duration': 1223}, {'hash': 'b7a496a57a8a2b62', 'algorithm': 'PHASH', 'duration': 1189}, {'hash': '99216fa4bb997192', 'algorithm': 'PHASH', 'duration': 1614}, {'hash': '98c792eea9e15296', 'algorithm': 'PHASH', 'duration': 1601}, {'hash': 'af42961c6464dbea', 'algorithm': 'PHASH', 'duration': 1369}, {'hash': 'b2d2985bcbd510da', 'algorithm': 'PHASH', 'duration': 1610}, {'hash': 'd0d765d908bacaa3', 'algorithm': 'PHASH', 'duration': 1578}, {'hash': 'd380e4c93bf8d8a5', 'algorithm': 'PHASH', 'duration': 1685}, {'hash': 'ea2d56e9b4173861', 'algorithm': 'PHASH', 'duration': 1537}, {'hash': 'f5386087f6e424dc', 'algorithm': 'PHASH', 'duration': 2638}, {'hash': 'fde2f69504da1b04', 'algorithm': 'PHASH', 'duration': 1682}, {'hash': 'bec79c42ef849298', 'algorithm': 'PHASH', 'duration': 1134}, {'hash': 'c7a081b0f2b7d378', 'algorithm': 'PHASH', 'duration': 1373}, {'hash': 'efdddc8082a3c466', 'algorithm': 'PHASH', 'duration': 2267}, {'hash': 'd0d765d918ba4aa3', 'algorithm': 'PHASH', 'duration': 1578}, {'hash': 'd3514deda1ce4272', 'algorithm': 'PHASH', 'duration': 1059}, {'hash': 'f0f141ebf3e2044d', 'algorithm': 'PHASH', 'duration': 967}, {'hash': 'f1f1d5c588d281d3', 'algorithm': 'PHASH', 'duration': 827}, {'hash': 'd78081b1f2b3d378', 'algorithm': 'PHASH', 'duration': 1373}, {'hash': '8f836ab2c3e132cd', 'algorithm': 'PHASH', 'duration': 1058}, {'hash': 'defe881178e918e1', 'algorithm': 'PHASH', 'duration': 1256}, {'hash': 'a6d3b8448934776b', 'algorithm': 'PHASH', 'duration': 1009}, {'hash': 'ab83a3ddd5c700a6', 'algorithm': 'PHASH', 'duration': 1810}, {'hash': 'af4296146464fbea', 'algorithm': 'PHASH', 'duration': 1369}]}, {'id': '6a91390e-f2a9-4f03-bced-2bca6a516467', 'title': 'A Lonely Stranger', 'details': '', 'date': '2013-06-15', 'urls': [{'url': 'https://venus.wowporn.com/film/k4e42009/a-lonely-stranger', 'site': None}], 'performers': [{'performer': {'id': 'bc576cd0-dcb4-4a93-80fa-32e4c84387f7', 'name': 'Krystal Boyd', 'gender': 'FEMALE'}, 'as': 'Anjelica'}], 'duration': 1059, 'director': None, 'code': '6590', 'deleted': False, 'created': '2024-04-14T22:07:26+00:00', 'updated': '2024-04-14T22:07:26+00:00', 'fingerprints': [{'hash': 'd3594dada1ce4272', 'algorithm': 'PHASH', 'duration': 1059}]}])],
#       dtype=object)

# %%
from datetime import datetime


# Helper function to parse dates and compare them within a certain tolerance, e.g., within 2 days.
def date_match(tpdb_matches, stash_date_str, date_format="%Y-%m-%d", tolerance_days=2):
    if not stash_date_str:
        return False

    stash_date = datetime.strptime(stash_date_str, date_format)

    for match in tpdb_matches:
        tpdb_date_str = match.get("date")  # Assuming each match dict has a 'date' key
        if tpdb_date_str:
            tpdb_date = datetime.strptime(tpdb_date_str, date_format)
            if abs((tpdb_date - stash_date).days) <= tolerance_days:
                return True
    return False

# Assuming 'date' column in df_stash_tpdb_possible_matches is a string in the format "YYYY-MM-DD"
date_matches_mask = df_promising_matches.apply(
    lambda row: date_match(row["tpdb_matches"], row["date"]),
    axis=1
)

# Use this mask to separate promising date matches
df_promising_date_matches = df_promising_matches[date_matches_mask]

# Rows that don't meet the condition are the poor date matches
df_poor_date_matches = df_promising_matches[~date_matches_mask]

# %%
# %pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.25.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.25.1 (from python-Levenshtein)
#   Downloading Levenshtein-0.25.1-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein==0.25.1->python-Levenshtein)
#   Downloading rapidfuzz-3.8.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Downloading python_Levenshtein-0.25.1-py3-none-any.whl (9.4 kB)
# Downloading Levenshtein-0.25.1-cp312-cp312-win_amd64.whl (98 kB)
#    ---------------------------------------- 0.0/98.6 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/98.6 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/98.6 kB 660.6 kB/s eta 0:00:01
#    ------------------------ --------------- 61.4/98.6 kB 656.4 kB/s eta 0:00:01
#    ------------------------ --------------- 61.4/98.6 kB 656.4 kB/s eta 0:00:01
#    ---------------------------------------- 98.6/98.6 kB 566.3 kB/s eta 0:00:00
# Downloading rapidfuzz-3.8.1-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.6 MB 991.0 kB/s eta 0:00:02
#    - -------------------------------------- 0.1/1.6 MB 825.8 kB/s eta 0:00:02
#    - -------------------------------------- 0.1/1.6 MB 770.8 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.6 MB 656.4 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.6 MB 654.9 kB/s eta 0:00:03
#    --- ------------------------------------ 0.2/1.6 MB 704.6 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.6 MB 695.5 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.6 MB 724.0 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.6 MB 754.9 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.6 MB 754.9 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.6 MB 754.9 kB/s eta 0:00:02
#    ------ --------------------------------- 0.3/1.6 MB 632.7 kB/s eta 0:00:03
#    ------- -------------------------------- 0.3/1.6 MB 634.5 kB/s eta 0:00:03
#    -------- ------------------------------- 0.3/1.6 MB 636.3 kB/s eta 0:00:03
#    -------- ------------------------------- 0.4/1.6 MB 655.2 kB/s eta 0:00:02
#    --------- ------------------------------ 0.4/1.6 MB 690.9 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.4/1.6 MB 706.2 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.5/1.6 MB 720.0 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.5/1.6 MB 720.0 kB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.6 MB 684.6 kB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.6 MB 697.5 kB/s eta 0:00:02
#    ------------- -------------------------- 0.6/1.6 MB 694.9 kB/s eta 0:00:02
#    -------------- ------------------------- 0.6/1.6 MB 692.6 kB/s eta 0:00:02
#    -------------- ------------------------- 0.6/1.6 MB 703.3 kB/s eta 0:00:02
#    --------------- ------------------------ 0.7/1.6 MB 724.9 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.7/1.6 MB 721.3 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.7/1.6 MB 719.9 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.7/1.6 MB 718.0 kB/s eta 0:00:02
#    ------------------ --------------------- 0.8/1.6 MB 723.7 kB/s eta 0:00:02
#    ------------------- -------------------- 0.8/1.6 MB 731.4 kB/s eta 0:00:02
#    -------------------- ------------------- 0.8/1.6 MB 738.7 kB/s eta 0:00:02
#    -------------------- ------------------- 0.8/1.6 MB 746.4 kB/s eta 0:00:02
#    --------------------- ------------------ 0.9/1.6 MB 733.3 kB/s eta 0:00:02
#    ---------------------- ----------------- 0.9/1.6 MB 739.8 kB/s eta 0:00:01
#    ---------------------- ----------------- 0.9/1.6 MB 745.5 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.6 MB 750.0 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.6 MB 750.0 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.6 MB 750.0 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.6 MB 750.0 kB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.6 MB 684.1 kB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.6 MB 690.6 kB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.6 MB 703.1 kB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.6 MB 688.4 kB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.6 MB 694.9 kB/s eta 0:00:01
#    --------------------------- ------------ 1.1/1.6 MB 693.7 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.2/1.6 MB 692.6 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.2/1.6 MB 698.2 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.2/1.6 MB 691.4 kB/s eta 0:00:01
#    ------------------------------ --------- 1.2/1.6 MB 696.2 kB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.6 MB 700.9 kB/s eta 0:00:01
#    ------------------------------- -------- 1.3/1.6 MB 706.4 kB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 711.2 kB/s eta 0:00:01
#    -------------------------------- ------- 1.4/1.6 MB 715.4 kB/s eta 0:00:01
#    --------------------------------- ------ 1.4/1.6 MB 708.4 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.4/1.6 MB 712.8 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.5/1.6 MB 721.9 kB/s eta 0:00:01
#    ------------------------------------ --- 1.5/1.6 MB 725.4 kB/s eta 0:00:01
#    ------------------------------------- -- 1.5/1.6 MB 739.2 kB/s eta 0:00:01
#    -------------------------------------- - 1.6/1.6 MB 742.9 kB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 745.7 kB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 747.9 kB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
#   Attempting uninstall: rapidfuzz
#     Found existing installation: rapidfuzz 3.6.1
#     Uninstalling rapidfuzz-3.6.1:
#       Successfully uninstalled rapidfuzz-3.6.1
#   Attempting uninstall: Levenshtein
#     Found existing installation: Levenshtein 0.23.0
#     Uninstalling Levenshtein-0.23.0:
#       Successfully uninstalled Levenshtein-0.23.0
# Successfully installed Levenshtein-0.25.1 python-Levenshtein-0.25.1 rapidfuzz-3.8.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000220611133B0>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network')': /packages/72/8e/559c539e76bc0b1defec3da39a047fe151258efc9b215bf41db41e2c7922/python_Levenshtein-0.25.1-py3-none-any.whl.metadata

# %%
# TODO: broken

from Levenshtein import distance as levenshtein_distance


# Define a function to find the closest TPDB title to the Stash title based on Levenshtein distance
def closest_title_match(tpdb_matches, stash_title, max_distance=5):
    closest_match = None
    min_distance = float("inf")

    for match in tpdb_matches:
        tpdb_title = match.get("title")
        if tpdb_title:
            dist = levenshtein_distance(stash_title, tpdb_title)
            if dist < min_distance:
                min_distance = dist
                closest_match = tpdb_title

    return closest_match if min_distance <= max_distance else None

# Apply this function to each row in the DataFrame
df_promising_date_matches["closest_title_match"] = df_promising_date_matches
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_76700\2323799567.py in ?()
#      15
#      16     return closest_match if min_distance <= max_distance else None
#      17
#      18 # Apply this function to each row in the DataFrame
# ---> 19 df_promising_date_matches['closest_title_match'] = df_promising_date_matches
#
# c:\Users\thardas\miniconda3\envs\pandas\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4077             self._setitem_frame(key, value)
#    4078         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4079             self._setitem_array(key, value)
#    4080         elif isinstance(value, DataFrame):
# -> 4081             self._set_item_frame_value(key, value)
#    4082         elif (
#    4083             is_list_like(value)
#    4084             and not self.columns.is_unique
#
# c:\Users\thardas\miniconda3\envs\pandas\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4235
#    4236             return self.isetitem(locs, value)
#    4237
#    4238         if len(value.columns) != 1:
# -> 4239             raise ValueError(
#    4240                 "Cannot set a DataFrame with multiple columns to the single "
#    4241                 f"column {key}"
#    4242             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column closest_title_match

# %%
df_promising_date_matches
# Out:
#        id                             title                              code  \
# 1   14867                      Early Orgasm
# 4   15182                 Under Your Skin 2  0E6B659277F50124F50401A92EBB3B27
# 5   15205                       The Catch 2
# 6   15194      Melissa Moore - Role Playing
# 19  15166          Wanna Fuck My Girlfriend                           8765871
# 24  15183  True Lesbian - Show Me Your Room
# 28  15971                       She Gets Me
# 47    622                      High On Love                          z0d00c06
# 49   2044                  More Than Enough                          x271a418
# 56  16304            Interaction Can Be Fun
# 62  15593                A Page In My Diary                          y7ec3f7d
# 64  16300                 I Had It Cumming?                          k31d31d1
# 67   1844                      May I Enter?                          p3e4c81d
# 71   1836               A Place With A View                          q256df21
# 72   1162                  Romantic Getaway
# 74   1843                   Are You Hungry?                          we905a51
# 77  16297                     Read Our Lips                          z1db25f1
# 80   1161               Slam My Puffy Pussy
# 81   2101                      Summer Fling
# 83    891            Love me from all sides
# 97  15968                 A Lonely Stranger
#
#                                               details  \
# 1
# 4
# 5
# 6   I travel a lot and every now and then I find m...
# 19  Beautiful redhead Holly Molly is busy deepthro...
# 24  Masie (Jay Taylor) is a suburban wife trapped ...
# 28
# 47
# 49
# 56
# 62  Hot and very naughty cutie Paula Shy is having...
# 64
# 67
# 71
# 72
# 74  This long-legged Swedish bitch came only to st...
# 77  Michelle and Silvie Read Our Lips at Wow Porn....
# 80  Slam My Puffy Pussy with this sexy big tits br...
# 81
# 83  Slender and beautiful girl Barbara Sweet is a ...
# 97
#
#                                                  urls        date  duration  \
# 1   [https://www.thelifeerotic.com/model/charlotta...  2014-10-10    770.76
# 4   [https://www.straplez.com/model/casey-nohrman-...  2023-06-29   1785.02
# 5   [https://www.straplez.com/model/tiffany-tatum-...  2022-12-15   1696.28
# 6   [https://www.tonightsgirlfriend.com/scene/meli...  2016-12-23   2577.57
# 19  [https://www.fakehostel.com/scene/8765871/wann...  2023-05-30   1657.45
# 24  [https://www.girlsway.com/en/video/True-Lesbia...  2020-03-16   3932.76
# 28  [https://venus.wowgirls.com/film/g5cfd980/she-...  2018-12-10   2114.38
# 47  [https://venus.wowporn.com/film/z0d00c06/high-...  2016-05-16   1635.68
# 49  [https://venus.wowporn.com/film/x271a418/more-...  2016-03-18   2234.27
# 56  [https://venus.wowporn.com/film/jfcfded5/inter...  2014-07-25   1148.44
# 62  [https://venus.wowporn.com/film/y7ec3f7d/a-pag...  2014-05-30   1399.37
# 64  [https://venus.wowporn.com/film/k31d31d1/i-had...  2014-05-21   1731.74
# 67  [https://venus.wowporn.com/film/p3e4c81d/may-i...  2014-03-20   1625.44
# 71  [https://venus.wowporn.com/film/q256df21/a-pla...  2014-02-24   1330.69
# 72  [https://venus.wowporn.com/film/of94c003/roman...  2014-02-21   1474.93
# 74  [https://venus.wowporn.com/film/we905a51/are-y...  2014-02-01   1511.11
# 77  [https://venus.wowporn.com/film/z1db25f1/read-...  2013-12-22   1614.58
# 80  [https://venus.wowporn.com/film/t1a37c63/slam-...  2013-11-26   1325.59
# 81  [https://venus.wowporn.com/film/ve004547/summe...  2013-11-19   1650.92
# 83  [https://www.indexxx.com/set/603459/wowporn-ba...  2013-10-29   1381.91
# 97  [https://venus.wowporn.com/film/k4e42009/a-lon...  2013-06-15   1059.12
#
#               created_at            updated_at             phash  \
# 1   2024-02-20T06:19:58Z  2024-02-26T05:51:15Z  8e47626ecfd20695
# 4   2024-03-08T07:35:06Z  2024-03-08T13:40:26Z  815555dff68255a4
# 5   2024-03-08T08:53:00Z  2024-03-08T13:28:23Z  ce780e75680fb741
# 6   2024-03-08T07:35:11Z  2024-03-08T16:11:05Z  fe733c4dacc0b580
# 19  2024-03-08T07:34:55Z  2024-04-09T06:55:13Z  98f1558b3299c7cc
# 24  2024-03-08T07:35:07Z  2024-03-08T13:40:35Z  cc61b1ed97242d66
# 28  2024-03-17T04:29:56Z  2024-04-12T10:58:27Z  d3279522ea571c47
# 47  2023-01-25T10:06:55Z  2024-01-31T05:52:10Z  df6128137ce46e38
# 49  2023-01-25T12:23:21Z  2024-04-23T13:27:23Z  a275f8ff5ea86002
# 56  2024-03-21T12:08:05Z  2024-03-31T05:06:33Z  ad3802f89bd6643e
# 62  2024-03-11T12:05:31Z  2024-03-11T16:24:54Z  a61e0b074578dfe8
# 64  2024-03-21T12:08:04Z  2024-03-27T04:05:01Z  e2aca1d2aabad958
# 67  2023-01-25T12:21:10Z  2024-02-15T11:48:31Z  aa2206d18baf7fc4
# 71  2023-01-25T12:21:07Z  2024-02-15T11:48:34Z  e9c5c1b0f6d425a9
# 72  2023-01-25T12:14:25Z  2023-01-25T14:33:39Z  bf5d9c2b492082cf
# 74  2023-01-25T12:21:10Z  2024-02-15T11:48:32Z  a06a15ea97f563a1
# 77  2024-03-21T12:08:04Z  2024-03-27T04:04:39Z  c022ecb226ed7ed1
# 80  2023-01-25T12:14:24Z  2023-02-28T08:24:52Z  c41fc797659283e8
# 81  2023-01-25T12:23:53Z  2024-02-15T11:48:16Z  a96aef239ba470a4
# 83  2023-01-25T10:10:25Z  2024-04-27T03:35:30Z  a03a117ab7d7a255
# 97  2024-03-17T04:29:55Z  2024-04-12T10:58:32Z  d3594dada1ce4272
#
#                                             stash_ids  \
# 1   [{'endpoint': 'https://stashdb.org/graphql', '...
# 4   [{'endpoint': 'https://stashdb.org/graphql', '...
# 5   [{'endpoint': 'https://stashdb.org/graphql', '...
# 6   [{'endpoint': 'https://stashdb.org/graphql', '...
# 19  [{'endpoint': 'https://stashdb.org/graphql', '...
# 24  [{'endpoint': 'https://stashdb.org/graphql', '...
# 28  [{'endpoint': 'https://stashdb.org/graphql', '...
# 47  [{'endpoint': 'https://stashdb.org/graphql', '...
# 49  [{'endpoint': 'https://stashdb.org/graphql', '...
# 56  [{'endpoint': 'https://stashdb.org/graphql', '...
# 62  [{'endpoint': 'https://stashdb.org/graphql', '...
# 64  [{'endpoint': 'https://stashdb.org/graphql', '...
# 67  [{'endpoint': 'https://stashdb.org/graphql', '...
# 71  [{'endpoint': 'https://stashdb.org/graphql', '...
# 72  [{'endpoint': 'https://stashdb.org/graphql', '...
# 74  [{'endpoint': 'https://stashdb.org/graphql', '...
# 77  [{'endpoint': 'https://stashdb.org/graphql', '...
# 80  [{'endpoint': 'https://stashdb.org/graphql', '...
# 81  [{'endpoint': 'https://stashdb.org/graphql', '...
# 83  [{'endpoint': 'https://stashdb.org/graphql', '...
# 97  [{'endpoint': 'https://stashdb.org/graphql', '...
#
#                                          tpdb_matches
# 1   [{'id': 'cf17698c-27e4-4f7e-8489-d1e36c694df0'...
# 4   [{'id': 'bec93462-c864-4737-9291-f9c6cc6e8129'...
# 5   [{'id': '90484f5c-c1f4-4f37-9f3d-7bcb0c5b271f'...
# 6   [{'id': '4de41359-9682-49a4-886e-95357d6dfb6b'...
# 19  [{'id': 'fcc9dc1a-aa42-4ed3-bf83-81aed3de3135'...
# 24  [{'id': '4e4c0e6b-f351-499f-b5c3-5f2ee9369757'...
# 28  [{'id': 'fb2ed2c7-e39c-4d7d-b609-2fad958352da'...
# 47  [{'id': '9861699e-0830-419d-b2fa-77deb7a495bb'...
# 49  [{'id': 'bbe68ab3-0ca7-4508-a1e5-c42f74a3ddfe'...
# 56  [{'id': '0d784ae8-a7ee-4fdd-8712-032b64e0a55a'...
# 62  [{'id': 'b028a438-be2f-49eb-812c-a9d405c1c358'...
# 64  [{'id': 'fb086ee1-9047-4827-80b2-d33941ec1d62'...
# 67  [{'id': 'd043bb86-a8f9-4b84-9b12-1b5f0a55508b'...
# 71  [{'id': '9ae00575-4f30-4b59-b999-c7cf769ebff6'...
# 72  [{'id': 'd1660eaa-908b-4f84-b35a-abe786d2efe3'...
# 74  [{'id': '4a443544-796f-481a-a907-b6d9f551dc8a'...
# 77  [{'id': 'ece726fa-6e67-410e-ac53-7ccc3145fa92'...
# 80  [{'id': '916dfa85-dfeb-426d-bdea-b64e2a564b13'...
# 81  [{'id': 'e052a018-1310-4fa1-882d-32d64cc725c6'...
# 83  [{'id': '67e13f78-6496-40e4-8e03-495e41d0d00d'...
# 97  [{'id': 'c8a93768-8254-4367-851b-2d7752ba06b2'...

# %%
df_promising_date_matches
# Out:
#        id                             title                              code  \
# 1   14867                      Early Orgasm
# 4   15182                 Under Your Skin 2  0E6B659277F50124F50401A92EBB3B27
# 5   15205                       The Catch 2
# 6   15194      Melissa Moore - Role Playing
# 19  15166          Wanna Fuck My Girlfriend                           8765871
# 24  15183  True Lesbian - Show Me Your Room
# 28  15971                       She Gets Me
# 47    622                      High On Love                          z0d00c06
# 49   2044                  More Than Enough                          x271a418
# 56  16304            Interaction Can Be Fun
# 62  15593                A Page In My Diary                          y7ec3f7d
# 64  16300                 I Had It Cumming?                          k31d31d1
# 67   1844                      May I Enter?                          p3e4c81d
# 71   1836               A Place With A View                          q256df21
# 72   1162                  Romantic Getaway
# 74   1843                   Are You Hungry?                          we905a51
# 77  16297                     Read Our Lips                          z1db25f1
# 80   1161               Slam My Puffy Pussy
# 81   2101                      Summer Fling
# 83    891            Love me from all sides
# 97  15968                 A Lonely Stranger
#
#                                               details  \
# 1
# 4
# 5
# 6   I travel a lot and every now and then I find m...
# 19  Beautiful redhead Holly Molly is busy deepthro...
# 24  Masie (Jay Taylor) is a suburban wife trapped ...
# 28
# 47
# 49
# 56
# 62  Hot and very naughty cutie Paula Shy is having...
# 64
# 67
# 71
# 72
# 74  This long-legged Swedish bitch came only to st...
# 77  Michelle and Silvie Read Our Lips at Wow Porn....
# 80  Slam My Puffy Pussy with this sexy big tits br...
# 81
# 83  Slender and beautiful girl Barbara Sweet is a ...
# 97
#
#                                                  urls        date  duration  \
# 1   [https://www.thelifeerotic.com/model/charlotta...  2014-10-10    770.76
# 4   [https://www.straplez.com/model/casey-nohrman-...  2023-06-29   1785.02
# 5   [https://www.straplez.com/model/tiffany-tatum-...  2022-12-15   1696.28
# 6   [https://www.tonightsgirlfriend.com/scene/meli...  2016-12-23   2577.57
# 19  [https://www.fakehostel.com/scene/8765871/wann...  2023-05-30   1657.45
# 24  [https://www.girlsway.com/en/video/True-Lesbia...  2020-03-16   3932.76
# 28  [https://venus.wowgirls.com/film/g5cfd980/she-...  2018-12-10   2114.38
# 47  [https://venus.wowporn.com/film/z0d00c06/high-...  2016-05-16   1635.68
# 49  [https://venus.wowporn.com/film/x271a418/more-...  2016-03-18   2234.27
# 56  [https://venus.wowporn.com/film/jfcfded5/inter...  2014-07-25   1148.44
# 62  [https://venus.wowporn.com/film/y7ec3f7d/a-pag...  2014-05-30   1399.37
# 64  [https://venus.wowporn.com/film/k31d31d1/i-had...  2014-05-21   1731.74
# 67  [https://venus.wowporn.com/film/p3e4c81d/may-i...  2014-03-20   1625.44
# 71  [https://venus.wowporn.com/film/q256df21/a-pla...  2014-02-24   1330.69
# 72  [https://venus.wowporn.com/film/of94c003/roman...  2014-02-21   1474.93
# 74  [https://venus.wowporn.com/film/we905a51/are-y...  2014-02-01   1511.11
# 77  [https://venus.wowporn.com/film/z1db25f1/read-...  2013-12-22   1614.58
# 80  [https://venus.wowporn.com/film/t1a37c63/slam-...  2013-11-26   1325.59
# 81  [https://venus.wowporn.com/film/ve004547/summe...  2013-11-19   1650.92
# 83  [https://www.indexxx.com/set/603459/wowporn-ba...  2013-10-29   1381.91
# 97  [https://venus.wowporn.com/film/k4e42009/a-lon...  2013-06-15   1059.12
#
#               created_at            updated_at             phash  \
# 1   2024-02-20T06:19:58Z  2024-02-26T05:51:15Z  8e47626ecfd20695
# 4   2024-03-08T07:35:06Z  2024-03-08T13:40:26Z  815555dff68255a4
# 5   2024-03-08T08:53:00Z  2024-03-08T13:28:23Z  ce780e75680fb741
# 6   2024-03-08T07:35:11Z  2024-03-08T16:11:05Z  fe733c4dacc0b580
# 19  2024-03-08T07:34:55Z  2024-04-09T06:55:13Z  98f1558b3299c7cc
# 24  2024-03-08T07:35:07Z  2024-03-08T13:40:35Z  cc61b1ed97242d66
# 28  2024-03-17T04:29:56Z  2024-04-12T10:58:27Z  d3279522ea571c47
# 47  2023-01-25T10:06:55Z  2024-01-31T05:52:10Z  df6128137ce46e38
# 49  2023-01-25T12:23:21Z  2024-04-23T13:27:23Z  a275f8ff5ea86002
# 56  2024-03-21T12:08:05Z  2024-03-31T05:06:33Z  ad3802f89bd6643e
# 62  2024-03-11T12:05:31Z  2024-03-11T16:24:54Z  a61e0b074578dfe8
# 64  2024-03-21T12:08:04Z  2024-03-27T04:05:01Z  e2aca1d2aabad958
# 67  2023-01-25T12:21:10Z  2024-02-15T11:48:31Z  aa2206d18baf7fc4
# 71  2023-01-25T12:21:07Z  2024-02-15T11:48:34Z  e9c5c1b0f6d425a9
# 72  2023-01-25T12:14:25Z  2023-01-25T14:33:39Z  bf5d9c2b492082cf
# 74  2023-01-25T12:21:10Z  2024-02-15T11:48:32Z  a06a15ea97f563a1
# 77  2024-03-21T12:08:04Z  2024-03-27T04:04:39Z  c022ecb226ed7ed1
# 80  2023-01-25T12:14:24Z  2023-02-28T08:24:52Z  c41fc797659283e8
# 81  2023-01-25T12:23:53Z  2024-02-15T11:48:16Z  a96aef239ba470a4
# 83  2023-01-25T10:10:25Z  2024-04-27T03:35:30Z  a03a117ab7d7a255
# 97  2024-03-17T04:29:55Z  2024-04-12T10:58:32Z  d3594dada1ce4272
#
#                                             stash_ids  \
# 1   [{'endpoint': 'https://stashdb.org/graphql', '...
# 4   [{'endpoint': 'https://stashdb.org/graphql', '...
# 5   [{'endpoint': 'https://stashdb.org/graphql', '...
# 6   [{'endpoint': 'https://stashdb.org/graphql', '...
# 19  [{'endpoint': 'https://stashdb.org/graphql', '...
# 24  [{'endpoint': 'https://stashdb.org/graphql', '...
# 28  [{'endpoint': 'https://stashdb.org/graphql', '...
# 47  [{'endpoint': 'https://stashdb.org/graphql', '...
# 49  [{'endpoint': 'https://stashdb.org/graphql', '...
# 56  [{'endpoint': 'https://stashdb.org/graphql', '...
# 62  [{'endpoint': 'https://stashdb.org/graphql', '...
# 64  [{'endpoint': 'https://stashdb.org/graphql', '...
# 67  [{'endpoint': 'https://stashdb.org/graphql', '...
# 71  [{'endpoint': 'https://stashdb.org/graphql', '...
# 72  [{'endpoint': 'https://stashdb.org/graphql', '...
# 74  [{'endpoint': 'https://stashdb.org/graphql', '...
# 77  [{'endpoint': 'https://stashdb.org/graphql', '...
# 80  [{'endpoint': 'https://stashdb.org/graphql', '...
# 81  [{'endpoint': 'https://stashdb.org/graphql', '...
# 83  [{'endpoint': 'https://stashdb.org/graphql', '...
# 97  [{'endpoint': 'https://stashdb.org/graphql', '...
#
#                                          tpdb_matches
# 1   [{'id': 'cf17698c-27e4-4f7e-8489-d1e36c694df0'...
# 4   [{'id': 'bec93462-c864-4737-9291-f9c6cc6e8129'...
# 5   [{'id': '90484f5c-c1f4-4f37-9f3d-7bcb0c5b271f'...
# 6   [{'id': '4de41359-9682-49a4-886e-95357d6dfb6b'...
# 19  [{'id': 'fcc9dc1a-aa42-4ed3-bf83-81aed3de3135'...
# 24  [{'id': '4e4c0e6b-f351-499f-b5c3-5f2ee9369757'...
# 28  [{'id': 'fb2ed2c7-e39c-4d7d-b609-2fad958352da'...
# 47  [{'id': '9861699e-0830-419d-b2fa-77deb7a495bb'...
# 49  [{'id': 'bbe68ab3-0ca7-4508-a1e5-c42f74a3ddfe'...
# 56  [{'id': '0d784ae8-a7ee-4fdd-8712-032b64e0a55a'...
# 62  [{'id': 'b028a438-be2f-49eb-812c-a9d405c1c358'...
# 64  [{'id': 'fb086ee1-9047-4827-80b2-d33941ec1d62'...
# 67  [{'id': 'd043bb86-a8f9-4b84-9b12-1b5f0a55508b'...
# 71  [{'id': '9ae00575-4f30-4b59-b999-c7cf769ebff6'...
# 72  [{'id': 'd1660eaa-908b-4f84-b35a-abe786d2efe3'...
# 74  [{'id': '4a443544-796f-481a-a907-b6d9f551dc8a'...
# 77  [{'id': 'ece726fa-6e67-410e-ac53-7ccc3145fa92'...
# 80  [{'id': '916dfa85-dfeb-426d-bdea-b64e2a564b13'...
# 81  [{'id': 'e052a018-1310-4fa1-882d-32d64cc725c6'...
# 83  [{'id': '67e13f78-6496-40e4-8e03-495e41d0d00d'...
# 97  [{'id': 'c8a93768-8254-4367-851b-2d7752ba06b2'...

# %%
df_promising_date_matches["tpdb_matches"].values
# Out:
# array([list([{'id': 'cf17698c-27e4-4f7e-8489-d1e36c694df0', 'title': 'Early Orgasm', 'details': '', 'date': '2014-10-10', 'urls': [{'url': 'https://thelifeerotic.com/model/charlotta-phillip/movie/20141010/EARLY_ORGASM', 'site': None}], 'performers': [{'performer': {'id': '55f40383-9c9d-4220-8d1d-267a6a122bda', 'name': 'Charlotta Phillip', 'gender': 'FEMALE'}, 'as': 'Charlotta Phillip'}], 'duration': 771, 'director': None, 'code': '20141010_early_orgasm', 'deleted': False, 'created': '2021-09-04T12:03:17+00:00', 'updated': '2024-03-07T05:36:46+00:00', 'fingerprints': [{'hash': '8e47626ecfd20695', 'algorithm': 'PHASH', 'duration': 770}]}]),
#        list([{'id': 'bec93462-c864-4737-9291-f9c6cc6e8129', 'title': 'Under Your Skin 2', 'details': '', 'date': '2023-06-29', 'urls': [{'url': 'https://straplez.com/model/casey-nohrman-and-bonnie-dolce/movie/20230629/UNDER_YOUR_SKIN_2', 'site': None}], 'performers': [{'performer': {'id': '85e222e0-f27d-4923-afc7-75f7376a2bfe', 'name': 'Bonnie Dolce', 'gender': 'FEMALE'}, 'as': 'Bonnie Dolce'}, {'performer': {'id': '69a87e77-ccae-4f28-8518-fa67eaf8eaf5', 'name': 'Casey Nohrman', 'gender': 'FEMALE'}, 'as': 'Casey Nohrman'}], 'duration': 1785, 'director': None, 'code': '20230629_under_your_skin_2', 'deleted': False, 'created': '2023-06-29T15:03:41+00:00', 'updated': '2024-02-16T09:54:28+00:00', 'fingerprints': [{'hash': '815555dff68255a4', 'algorithm': 'PHASH', 'duration': 1785}, {'hash': '8155559ff68275a4', 'algorithm': 'PHASH', 'duration': 1785}]}]),
#        list([{'id': '90484f5c-c1f4-4f37-9f3d-7bcb0c5b271f', 'title': 'The Catch 2', 'details': '', 'date': '2022-12-15', 'urls': [{'url': 'https://straplez.com/model/tiffany-tatum-and-zazie-skymm/movie/20221215/THE_CATCH_2', 'site': None}], 'performers': [{'performer': {'id': 'ca9ec170-5992-4eb6-a263-fe63d7e14e97', 'name': 'Tiffany Tatum', 'gender': 'FEMALE'}, 'as': 'Tiffany Tatum'}, {'performer': {'id': '964b24e7-bb02-4ad8-a248-4bb356e0ae3a', 'name': 'Zazie Skymm', 'gender': 'FEMALE'}, 'as': 'Zazie Skymm'}], 'duration': 1696, 'director': None, 'code': '20221215_THE_CATCH_2', 'deleted': False, 'created': '2022-12-16T01:40:39+00:00', 'updated': '2024-03-07T06:09:31+00:00', 'fingerprints': [{'hash': 'ce780e75680fb741', 'algorithm': 'PHASH', 'duration': 1696}, {'hash': 'ce780e75680f9749', 'algorithm': 'PHASH', 'duration': 1696}, {'hash': 'ce7c0e75680f9741', 'algorithm': 'PHASH', 'duration': 1696}, {'hash': 'cf680e75680f9749', 'algorithm': 'PHASH', 'duration': 1696}]}]),
#        list([{'id': '4de41359-9682-49a4-886e-95357d6dfb6b', 'title': 'Melissa Moore', 'details': "I travel a lot and every now and then I find myself in a room next to a couple that can't stop fucking.  It's always been my fantasy to have the girl invite me over and let me fuck her.  Today, I get to live out that fantasy by having Melissa Moore come over and role playing that fantasy just for me.", 'date': '2016-12-23', 'urls': [{'url': 'https://tonightsgirlfriend.com/scene/melissa-moore-22125', 'site': None}], 'performers': [{'performer': {'id': 'e584b40e-3161-4f4a-a89e-e3d8900ed6ee', 'name': 'Melissa Moore', 'gender': 'FEMALE'}, 'as': 'Melissa Moore'}], 'duration': 2577, 'director': None, 'code': 'melissa-moore-22125', 'deleted': False, 'created': '2021-05-02T01:39:08+00:00', 'updated': '2023-02-14T15:21:07+00:00', 'fingerprints': [{'hash': 'be33ba457cc0f580', 'algorithm': 'PHASH', 'duration': 2573}, {'hash': 'be7338652cc6b588', 'algorithm': 'PHASH', 'duration': 2573}, {'hash': 'be733a457cc0f580', 'algorithm': 'PHASH', 'duration': 2573}, {'hash': 'fe733c4dacc0b580', 'algorithm': 'PHASH', 'duration': 2577}, {'hash': 'ff733e450cc4b580', 'algorithm': 'PHASH', 'duration': 2577}]}]),
#        list([{'id': 'fcc9dc1a-aa42-4ed3-bf83-81aed3de3135', 'title': 'Wanna Fuck My Girlfriend', 'details': 'Beautiful redhead Holly Molly is busy deepthroating her boyfriend’s dick in the Fake Hostel. Unbeknownst to the couple, their pervy host, Steve Q, is spying on them while masturbating! After entering their room, the grey-haired hunk is invited by the raunchy pair to join in the fun: while Holly gags on Steve’s thick dick, her boyfriend Mark Zane bangs her tight pussy in a sexy side fuck, and then the flame-haired stunner spreads her legs so that Steve can slide his cock inside her missionary-style. Afterwards, Steve gives Holly an intense fingering until she screams in euphoria and squirts her orgasm everywhere! Next, the naughty minx treats her lovers to a sloppy double blowjob before riding Mark in reverse as Steve fucks her pretty face, and then she gets on all fours to take a doggystyle pounding from her handsome, dark-haired boyfriend. Once the well-hung dudes have had their fill of Holly, they pull out and jerk themselves off until the Russian slut is dripping in their cum!', 'date': '2023-05-30', 'urls': [{'url': 'https://fakehostel.com/scene/8765871/wanna-fuck-my-girlfriend', 'site': None}], 'performers': [{'performer': {'id': '12366daa-8b76-47c2-b30d-abca5a6ee652', 'name': 'Holly Molly', 'gender': 'FEMALE'}, 'as': 'Holly Molly'}, {'performer': {'id': '34b26269-430e-4c06-a58d-3dba800776e4', 'name': 'Steve Q', 'gender': 'MALE'}, 'as': 'Steve Q'}], 'duration': 1657, 'director': None, 'code': '8765871', 'deleted': False, 'created': '2023-05-30T17:51:13+00:00', 'updated': '2024-02-16T09:24:40+00:00', 'fingerprints': [{'hash': '98f1558b3299c7cc', 'algorithm': 'PHASH', 'duration': 1657}, {'hash': '9cf1518b3299c7cc', 'algorithm': 'PHASH', 'duration': 1657}, {'hash': '98f151cb3299c7cc', 'algorithm': 'PHASH', 'duration': 1657}]}]),
#        list([{'id': '4e4c0e6b-f351-499f-b5c3-5f2ee9369757', 'title': 'True Lesbian - Show Me Your Room', 'details': "Masie (Jay Taylor) is a suburban wife trapped in her own personal hell. She's been married to her husband for two years but the spark is already gone... and the more she thinks about it, the more she wonders if it was ever there to begin with.\n\nOverwhelmed with the need to feel SOMETHING, she tries experimenting with her sexuality in secret. Although she doesn't feel anything for her husband anymore, seeing a sexy woman stirs something deep down that terrifies and excites her. When she can spare a moment, she pops in her earbuds and listens to erotic lesbian audiobooks, but they're not enough... With each passing day, the loneliness and longing for another woman's sensual touch becomes all-consuming.\n\nOne day, her husband announces that his boss will be coming over for dinner -- and that the wife will be tagging along. Masie barely acknowledges his words, other than to mindlessly agree to putting on a pot roast. She really doesn't care about ANY of this anymore and is near her breaking point.\n\nBut when the guests later arrive, Masie's world is unexpectedly turned upside down.\n\nHer husband's boss is a woman who's brought along her gorgeous wife, Andrea (Angela White). Masie wasn't expecting to be hosting lesbians, and she's never seen a woman as breathtaking and confident as Andrea.\n\nAll throughout dinner, Masie barely holds it together, unable to keep her eyes off Andrea. It seems as though Andrea has bedroom eyes for her, too, and there's no denying the chemistry between them. Masie feels more alive now than she has in a long time with each glance across the table and brush of ankles beneath. When Andrea later suggests that Masie show her around the house to leave their spouses to talk shop, Masie's mind races. Is Andrea offering to do what Masie thinks she is?\n\nAlthough she's been wanting to feel something, ANYTHING, for so long, now that she has the chance, Masie's scared. If she gives into these urges with Andrea, there will be no going back...", 'date': '2020-03-16', 'urls': [{'url': 'https://girlsway.com/en/video/True-Lesbian---Show-Me-Your-Room/168278', 'site': None}], 'performers': [{'performer': {'id': 'a6fb1863-b433-4274-ae07-0e1327c854d1', 'name': 'Angela White', 'gender': 'FEMALE'}, 'as': 'Angela White'}, {'performer': {'id': 'bf627c64-46e4-4068-9524-4c7149c06529', 'name': 'Jay Taylor', 'gender': 'FEMALE'}, 'as': 'Jay Taylor'}], 'duration': 3932, 'director': 'Bree Mills', 'code': '168278', 'deleted': False, 'created': '2021-06-14T23:49:51+00:00', 'updated': '2024-02-16T04:22:18+00:00', 'fingerprints': [{'hash': 'cc61b1ed97242d66', 'algorithm': 'PHASH', 'duration': 3932}, {'hash': 'cc61e9a59360bd6a', 'algorithm': 'PHASH', 'duration': 3932}, {'hash': 'c135e12d93243de7', 'algorithm': 'PHASH', 'duration': 3932}, {'hash': 'cc61e1a59364bd6a', 'algorithm': 'PHASH', 'duration': 3932}, {'hash': 'cc61f1a59360bd6a', 'algorithm': 'PHASH', 'duration': 3932}]}]),
#        list([{'id': 'fb2ed2c7-e39c-4d7d-b609-2fad958352da', 'title': 'She Gets Me', 'details': '', 'date': '2018-12-10', 'urls': [{'url': 'https://venus.wowporn.com/film/g5cfd980/she-gets-me', 'site': None}], 'performers': [{'performer': {'id': '44dc6c02-97cc-4570-8b0e-d7634ad46c99', 'name': 'Lexi Dona', 'gender': 'FEMALE'}, 'as': 'Lexi Dona'}, {'performer': {'id': '275480b7-dcd9-4d33-9038-c61d80bac6fb', 'name': 'Sybil Kailena', 'gender': 'FEMALE'}, 'as': 'Sybil'}], 'duration': 2114, 'director': None, 'code': '10129', 'deleted': False, 'created': '2024-04-14T22:12:03+00:00', 'updated': '2024-04-14T22:12:03+00:00', 'fingerprints': [{'hash': 'd3279522ea571c47', 'algorithm': 'PHASH', 'duration': 2114}]}]),
#        list([{'id': '9861699e-0830-419d-b2fa-77deb7a495bb', 'title': 'High on Love', 'details': '', 'date': '2016-05-16', 'urls': [{'url': 'https://venus.wowporn.com/film/z0d00c06/high-on-love', 'site': None}], 'performers': [{'performer': {'id': '1b5898d3-8ae1-4e36-9779-9961a77eb261', 'name': 'Alexis Crystal', 'gender': 'FEMALE'}, 'as': 'Alexis Crystal'}, {'performer': {'id': 'f3103f8a-f80f-4750-8619-e0d90f081966', 'name': 'Kattie Gold', 'gender': 'FEMALE'}, 'as': 'Janice'}], 'duration': 1635, 'director': None, 'code': '8468', 'deleted': False, 'created': '2024-04-14T22:10:06+00:00', 'updated': '2024-04-14T22:10:06+00:00', 'fingerprints': [{'hash': 'df6128137ce46e38', 'algorithm': 'PHASH', 'duration': 1635}]}]),
#        list([{'id': 'bbe68ab3-0ca7-4508-a1e5-c42f74a3ddfe', 'title': 'More Than Enough', 'details': '', 'date': '2016-03-18', 'urls': [{'url': 'https://venus.wowporn.com/film/x271a418/more-than-enough', 'site': None}], 'performers': [{'performer': {'id': '6891e0d8-df89-4c0e-9d8c-2132be18609a', 'name': 'Nina North', 'gender': 'FEMALE'}, 'as': 'Nina North'}, {'performer': {'id': '013593b3-6741-4a9f-bdab-e842dbed2e10', 'name': 'Paula Shy', 'gender': 'FEMALE'}, 'as': 'Paula Shy'}], 'duration': 2234, 'director': None, 'code': '8266', 'deleted': False, 'created': '2024-04-14T22:09:58+00:00', 'updated': '2024-04-14T22:09:58+00:00', 'fingerprints': [{'hash': 'a275f8ff5ea86002', 'algorithm': 'PHASH', 'duration': 2234}]}]),
#        list([{'id': '0d784ae8-a7ee-4fdd-8712-032b64e0a55a', 'title': 'Interaction Can Be Fun', 'details': '', 'date': '2014-07-25', 'urls': [{'url': 'https://venus.wowporn.com/film/jfcfded5/interaction-can-be-fun', 'site': None}], 'performers': [{'performer': {'id': 'bc576cd0-dcb4-4a93-80fa-32e4c84387f7', 'name': 'Krystal Boyd', 'gender': 'FEMALE'}, 'as': 'Anjelica'}, {'performer': {'id': 'b6ff2665-ee43-4743-8e36-af4cb28e05bb', 'name': 'Heidi Romanova', 'gender': 'FEMALE'}, 'as': 'Vanessa'}], 'duration': 1148, 'director': None, 'code': '7296', 'deleted': False, 'created': '2024-04-14T22:08:59+00:00', 'updated': '2024-04-14T22:08:59+00:00', 'fingerprints': [{'hash': 'ad3802f89bd6643e', 'algorithm': 'PHASH', 'duration': 1148}]}]),
#        list([{'id': 'b028a438-be2f-49eb-812c-a9d405c1c358', 'title': 'A Page in My Diary', 'details': '', 'date': '2014-05-30', 'urls': [{'url': 'https://venus.wowporn.com/film/y7ec3f7d/a-page-in-my-diary', 'site': None}], 'performers': [{'performer': {'id': '013593b3-6741-4a9f-bdab-e842dbed2e10', 'name': 'Paula Shy', 'gender': 'FEMALE'}, 'as': 'Paula Shy'}], 'duration': 1399, 'director': None, 'code': '7278', 'deleted': False, 'created': '2024-04-14T22:08:52+00:00', 'updated': '2024-04-14T22:08:52+00:00', 'fingerprints': [{'hash': 'a61a0b074578dfec', 'algorithm': 'PHASH', 'duration': 1399}, {'hash': 'a61e0b074578dfe8', 'algorithm': 'PHASH', 'duration': 1399}]}]),
#        list([{'id': 'fb086ee1-9047-4827-80b2-d33941ec1d62', 'title': 'I Had It Cumming?', 'details': '', 'date': '2014-05-21', 'urls': [{'url': 'https://venus.wowporn.com/film/k31d31d1/i-had-it-cumming', 'site': None}], 'performers': [{'performer': {'id': 'ecbe2d2a-9d6b-4887-a98b-61dafe589325', 'name': 'Miriama Kunkelova', 'gender': 'FEMALE'}, 'as': 'Nancey'}], 'duration': 1731, 'director': None, 'code': '7272', 'deleted': False, 'created': '2024-04-14T22:08:47+00:00', 'updated': '2024-04-14T22:08:47+00:00', 'fingerprints': [{'hash': 'e2aca1d2aabad958', 'algorithm': 'PHASH', 'duration': 1731}]}]),
#        list([{'id': 'd043bb86-a8f9-4b84-9b12-1b5f0a55508b', 'title': 'May I Enter?', 'details': '', 'date': '2014-03-20', 'urls': [{'url': 'https://venus.wowporn.com/film/p3e4c81d/may-i-enter', 'site': None}], 'performers': [{'performer': {'id': '7687ff7c-b36d-44bd-82ee-a154b904db52', 'name': 'Red Fox', 'gender': 'FEMALE'}, 'as': 'Michelle'}], 'duration': 1625, 'director': None, 'code': '7102', 'deleted': False, 'created': '2024-04-14T22:08:33+00:00', 'updated': '2024-04-14T22:08:33+00:00', 'fingerprints': [{'hash': 'aa2206d18baf7fc4', 'algorithm': 'PHASH', 'duration': 1625}]}]),
#        list([{'id': '9ae00575-4f30-4b59-b999-c7cf769ebff6', 'title': 'A Place with a View', 'details': '', 'date': '2014-02-24', 'urls': [{'url': 'https://venus.wowporn.com/film/q256df21/a-place-with-a-view', 'site': None}], 'performers': [{'performer': {'id': '7687ff7c-b36d-44bd-82ee-a154b904db52', 'name': 'Red Fox', 'gender': 'FEMALE'}, 'as': 'Michelle'}, {'performer': {'id': 'ecbe2d2a-9d6b-4887-a98b-61dafe589325', 'name': 'Miriama Kunkelova', 'gender': 'FEMALE'}, 'as': 'Nancey'}], 'duration': 1330, 'director': None, 'code': '7088', 'deleted': False, 'created': '2024-04-14T22:08:28+00:00', 'updated': '2024-04-14T22:08:28+00:00', 'fingerprints': [{'hash': 'e9c5c1b0f6d425a9', 'algorithm': 'PHASH', 'duration': 1330}]}]),
#        list([{'id': 'd1660eaa-908b-4f84-b35a-abe786d2efe3', 'title': 'Romantic Getaway', 'details': '', 'date': '2014-02-21', 'urls': [{'url': 'https://venus.wowporn.com/film/of94c003/romantic-getaway', 'site': None}], 'performers': [{'performer': {'id': 'bbf6fe78-1b1e-4dc2-af44-db078247771d', 'name': 'Connie Carter', 'gender': 'FEMALE'}, 'as': 'Connie'}], 'duration': 1474, 'director': None, 'code': '7086', 'deleted': False, 'created': '2024-04-14T22:08:25+00:00', 'updated': '2024-04-14T22:08:25+00:00', 'fingerprints': [{'hash': 'bf5d9c2b492082cf', 'algorithm': 'PHASH', 'duration': 1474}]}]),
#        list([{'id': '4a443544-796f-481a-a907-b6d9f551dc8a', 'title': 'Are You Hungry?', 'details': '', 'date': '2014-02-01', 'urls': [{'url': 'https://venus.wowporn.com/film/we905a51/are-you-hungry', 'site': None}], 'performers': [{'performer': {'id': '7687ff7c-b36d-44bd-82ee-a154b904db52', 'name': 'Red Fox', 'gender': 'FEMALE'}, 'as': 'Michelle'}], 'duration': 1511, 'director': None, 'code': '7072', 'deleted': False, 'created': '2024-04-14T22:08:20+00:00', 'updated': '2024-04-14T22:08:20+00:00', 'fingerprints': [{'hash': 'a06a15ea97f563a1', 'algorithm': 'PHASH', 'duration': 1511}]}]),
#        list([{'id': 'ece726fa-6e67-410e-ac53-7ccc3145fa92', 'title': 'Read Our Lips', 'details': '', 'date': '2013-12-22', 'urls': [{'url': 'https://venus.wowporn.com/film/z1db25f1/read-our-lips', 'site': None}], 'performers': [{'performer': {'id': '7687ff7c-b36d-44bd-82ee-a154b904db52', 'name': 'Red Fox', 'gender': 'FEMALE'}, 'as': 'Michelle'}, {'performer': {'id': 'd67cd8bc-e31c-46f8-8d38-36afec28deb4', 'name': 'Silvie Deluxe', 'gender': 'FEMALE'}, 'as': 'Silvie'}], 'duration': 1614, 'director': None, 'code': '6990', 'deleted': False, 'created': '2024-04-14T22:08:11+00:00', 'updated': '2024-04-14T22:08:11+00:00', 'fingerprints': [{'hash': 'c022ecb226ed7ed1', 'algorithm': 'PHASH', 'duration': 1614}]}]),
#        list([{'id': '916dfa85-dfeb-426d-bdea-b64e2a564b13', 'title': 'Slam My Puffy Pussy', 'details': '', 'date': '2013-11-26', 'urls': [{'url': 'https://venus.wowporn.com/film/t1a37c63/slam-my-puffy-pussy', 'site': None}], 'performers': [{'performer': {'id': 'bbf6fe78-1b1e-4dc2-af44-db078247771d', 'name': 'Connie Carter', 'gender': 'FEMALE'}, 'as': 'Connie'}], 'duration': 1325, 'director': None, 'code': '6902', 'deleted': False, 'created': '2024-04-14T22:08:07+00:00', 'updated': '2024-04-14T22:08:07+00:00', 'fingerprints': [{'hash': 'c41fc797659283e8', 'algorithm': 'PHASH', 'duration': 1325}]}]),
#        list([{'id': 'e052a018-1310-4fa1-882d-32d64cc725c6', 'title': 'Summer Fling', 'details': '', 'date': '2013-11-19', 'urls': [{'url': 'https://venus.wowporn.com/film/ve004547/summer-fling', 'site': None}], 'performers': [{'performer': {'id': '013593b3-6741-4a9f-bdab-e842dbed2e10', 'name': 'Paula Shy', 'gender': 'FEMALE'}, 'as': 'Paula Shy'}], 'duration': 1650, 'director': None, 'code': '6900', 'deleted': False, 'created': '2024-04-14T22:08:04+00:00', 'updated': '2024-04-14T22:08:04+00:00', 'fingerprints': [{'hash': 'a96aef239ba470a4', 'algorithm': 'PHASH', 'duration': 1650}]}]),
#        list([{'id': '67e13f78-6496-40e4-8e03-495e41d0d00d', 'title': 'Love Me From All Sides', 'details': '', 'date': '2013-10-29', 'urls': [{'url': 'https://venus.wowporn.com/film/qa344440/love-me-from-all-sides', 'site': None}], 'performers': [{'performer': {'id': 'eda907e8-b889-4b0e-91e3-917fa27ed148', 'name': 'Melissa Medisson', 'gender': 'FEMALE'}, 'as': 'Barbara Sweet'}], 'duration': 1381, 'director': None, 'code': '6883', 'deleted': False, 'created': '2024-04-14T22:07:58+00:00', 'updated': '2024-04-14T22:07:58+00:00', 'fingerprints': [{'hash': 'a03a117ab7d7a255', 'algorithm': 'PHASH', 'duration': 1381}]}]),
#        list([{'id': 'c8a93768-8254-4367-851b-2d7752ba06b2', 'title': 'Doris Ivy, Krystal Boyd, Katherine A, Abby C, Ebbi, Kathy I, Krystal Boyd, Anjelica, Abby', 'details': '', 'date': '2018-06-22', 'urls': [{'url': 'https://teendreams.com/t4/trailers/Doris-Ivy-Krystal-Boyd-Katherine-A-Abby-C-Ebbi-Kathy-I-Krystal-Boyd-Anjelica-Abby.html', 'site': None}], 'performers': [{'performer': {'id': 'bc576cd0-dcb4-4a93-80fa-32e4c84387f7', 'name': 'Krystal Boyd', 'gender': 'FEMALE'}, 'as': 'Anjelica'}], 'duration': 1373, 'director': None, 'code': 'doris-ivy-krystal-boyd-katherine-a-abby-c-ebbi-kathy-i-krystal-boyd-anjelica-abby', 'deleted': False, 'created': '2022-02-20T21:11:01+00:00', 'updated': '2024-03-19T01:31:15+00:00', 'fingerprints': [{'hash': 'da1a32bdada4f442', 'algorithm': 'PHASH', 'duration': 1257}, {'hash': 'b3632485c3f2b633', 'algorithm': 'PHASH', 'duration': 1282}, {'hash': '861e059b6bee3073', 'algorithm': 'PHASH', 'duration': 1485}, {'hash': 'e88273ad346349f9', 'algorithm': 'PHASH', 'duration': 1212}, {'hash': 'e666ad337a2b0469', 'algorithm': 'PHASH', 'duration': 1452}, {'hash': 'd7cc6a76d2f22281', 'algorithm': 'PHASH', 'duration': 1416}, {'hash': 'd3594dada1ce4272', 'algorithm': 'PHASH', 'duration': 1059}, {'hash': 'df6bb1c0aca9e091', 'algorithm': 'PHASH', 'duration': 1258}, {'hash': 'ca5798a7a03c633b', 'algorithm': 'PHASH', 'duration': 1223}, {'hash': 'b7a496a57a8a2b62', 'algorithm': 'PHASH', 'duration': 1189}, {'hash': '99216fa4bb997192', 'algorithm': 'PHASH', 'duration': 1614}, {'hash': '98c792eea9e15296', 'algorithm': 'PHASH', 'duration': 1601}, {'hash': 'af42961c6464dbea', 'algorithm': 'PHASH', 'duration': 1369}, {'hash': 'b2d2985bcbd510da', 'algorithm': 'PHASH', 'duration': 1610}, {'hash': 'd0d765d908bacaa3', 'algorithm': 'PHASH', 'duration': 1578}, {'hash': 'd380e4c93bf8d8a5', 'algorithm': 'PHASH', 'duration': 1685}, {'hash': 'ea2d56e9b4173861', 'algorithm': 'PHASH', 'duration': 1537}, {'hash': 'f5386087f6e424dc', 'algorithm': 'PHASH', 'duration': 2638}, {'hash': 'fde2f69504da1b04', 'algorithm': 'PHASH', 'duration': 1682}, {'hash': 'bec79c42ef849298', 'algorithm': 'PHASH', 'duration': 1134}, {'hash': 'c7a081b0f2b7d378', 'algorithm': 'PHASH', 'duration': 1373}, {'hash': 'efdddc8082a3c466', 'algorithm': 'PHASH', 'duration': 2267}, {'hash': 'd0d765d918ba4aa3', 'algorithm': 'PHASH', 'duration': 1578}, {'hash': 'd3514deda1ce4272', 'algorithm': 'PHASH', 'duration': 1059}, {'hash': 'f0f141ebf3e2044d', 'algorithm': 'PHASH', 'duration': 967}, {'hash': 'f1f1d5c588d281d3', 'algorithm': 'PHASH', 'duration': 827}, {'hash': 'd78081b1f2b3d378', 'algorithm': 'PHASH', 'duration': 1373}, {'hash': '8f836ab2c3e132cd', 'algorithm': 'PHASH', 'duration': 1058}, {'hash': 'defe881178e918e1', 'algorithm': 'PHASH', 'duration': 1256}, {'hash': 'a6d3b8448934776b', 'algorithm': 'PHASH', 'duration': 1009}, {'hash': 'ab83a3ddd5c700a6', 'algorithm': 'PHASH', 'duration': 1810}, {'hash': 'af4296146464fbea', 'algorithm': 'PHASH', 'duration': 1369}]}, {'id': '6a91390e-f2a9-4f03-bced-2bca6a516467', 'title': 'A Lonely Stranger', 'details': '', 'date': '2013-06-15', 'urls': [{'url': 'https://venus.wowporn.com/film/k4e42009/a-lonely-stranger', 'site': None}], 'performers': [{'performer': {'id': 'bc576cd0-dcb4-4a93-80fa-32e4c84387f7', 'name': 'Krystal Boyd', 'gender': 'FEMALE'}, 'as': 'Anjelica'}], 'duration': 1059, 'director': None, 'code': '6590', 'deleted': False, 'created': '2024-04-14T22:07:26+00:00', 'updated': '2024-04-14T22:07:26+00:00', 'fingerprints': [{'hash': 'd3594dada1ce4272', 'algorithm': 'PHASH', 'duration': 1059}]}])],
#       dtype=object)

# %%
df_promising_date_matches["tpdb_matches_len"] = df_promising_date_matches["tpdb_matches"].apply(lambda x: len(x))
# Out:
# C:\Users\thardas\AppData\Local\Temp\ipykernel_76700\1458365932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_promising_date_matches["tpdb_matches_len"] = df_promising_date_matches["tpdb_matches"].apply(lambda x: len(x))

# %%
def update_stash_ids(row):
    # Get the existing stash IDs from the row
    current_stash_ids = row["stash_ids"]

    # Assuming there's at least one match and we're taking the first match's ID
    # If there could be no matches, you should check before trying to access the ID
    if row["tpdb_matches"]:  # Check if there is at least one tpdb match
        first_tpdb_match_id = str(row["tpdb_matches"][0]["id"])
        new_stash_id = {"endpoint": "https://theporndb.net/graphql", "stash_id": first_tpdb_match_id}

        # Return the updated list
        return current_stash_ids + [new_stash_id]
    # If there are no tpdb matches, return the current stash IDs unchanged
    return current_stash_ids

# Apply the function to each row of the DataFrame
df_promising_date_matches["new_stash_ids"] = df_promising_date_matches.apply(update_stash_ids, axis=1)
# Out:
# C:\Users\thardas\AppData\Local\Temp\ipykernel_76700\3763248948.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_promising_date_matches["new_stash_ids"] = df_promising_date_matches.apply(update_stash_ids, axis=1)

# %%
df_promising_date_matches
# Out:
#       id                                              title    code  \
# 0  15186                   Kyler Worships Your Perfect Dick
# 2  15203  My Stepsister And Her Girlfriend Swallow My Cu...  144063
# 3  15193    Karla Kush fucking in the desk with her tattoos   18533
# 4  14873                                     Sexual Release
# 5  14872                                        Never Alone
# 6  14871                                            My Loft
# 7  14870                                         Mes Perles
# 8  14869                           Sunglasses And Stockings
# 9  14868                                         Sexy Snack
#
#                                              details  \
# 0  Only VRedging can bring you oral action like t...
# 2  Nikki Nutz and his stepsister Zazie hang out t...
# 3  Karla Kush decides it's time to help her boss ...
# 4
# 5
# 6
# 7
# 8
# 9
#
#                                                 urls        date  duration  \
# 0  [https://www.sexlikereal.com/scenes/kyler-wors...  2022-04-29   2002.85
# 2  [https://cumswappingsis.com/video/watch/144063...  2022-03-19   1946.40
# 3  [https://www.naughtyamerica.com/scene/karla-ku...  2014-09-08   2604.31
# 4  [https://www.thelifeerotic.com/model/charlotta...  2015-03-06    928.22
# 5  [https://www.thelifeerotic.com/model/charlotta...  2015-02-22    765.56
# 6  [https://www.thelifeerotic.com/model/charlotta...  2015-02-15    597.01
# 7  [https://www.thelifeerotic.com/model/charlotta...  2015-02-03    764.52
# 8  [https://www.thelifeerotic.com/model/charlotta...  2014-11-09    660.05
# 9  [https://www.thelifeerotic.com/model/charlotta...  2014-10-31    693.35
#
#              created_at            updated_at             phash  \
# 0  2024-03-08T07:35:08Z  2024-03-08T13:42:31Z  dd20758378e6a578
# 2  2024-03-08T08:52:59Z  2024-03-08T13:22:20Z  96e1cbcca6f44992
# 3  2024-03-08T07:35:10Z  2024-03-08T16:10:59Z  a7dd9ec285a099d8
# 4  2024-02-20T06:19:59Z  2024-02-26T05:51:07Z  855c799c569d49a9
# 5  2024-02-20T06:19:59Z  2024-02-26T05:51:09Z  bd3e4e901cccc363
# 6  2024-02-20T06:19:59Z  2024-02-26T05:51:10Z  b036363770d96987
# 7  2024-02-20T06:19:59Z  2024-02-26T05:51:11Z  fc0f8087a9b036cf
# 8  2024-02-20T06:19:59Z  2024-02-26T05:51:12Z  c682f89379d3ac92
# 9  2024-02-20T06:19:59Z  2024-02-26T05:51:14Z  f868c7251a0b45df
#
#                                            stash_ids  \
# 0  [{'endpoint': 'https://stashdb.org/graphql', '...
# 2  [{'endpoint': 'https://stashdb.org/graphql', '...
# 3  [{'endpoint': 'https://stashdb.org/graphql', '...
# 4  [{'endpoint': 'https://stashdb.org/graphql', '...
# 5  [{'endpoint': 'https://stashdb.org/graphql', '...
# 6  [{'endpoint': 'https://stashdb.org/graphql', '...
# 7  [{'endpoint': 'https://stashdb.org/graphql', '...
# 8  [{'endpoint': 'https://stashdb.org/graphql', '...
# 9  [{'endpoint': 'https://stashdb.org/graphql', '...
#
#                                         tpdb_matches  tpdb_matches_len  \
# 0  [{'id': 'acb8a3b3-2608-4c4b-8570-82e679b3816a'...                 1
# 2  [{'id': '61ba6920-9bea-44ea-93fc-34fa2bda75ce'...                 1
# 3  [{'id': '470a8011-3210-49f0-b7ab-6488d2b97333'...                 1
# 4  [{'id': 'bba51fc1-66a9-42b2-ae9d-eeba55a3d638'...                 1
# 5  [{'id': 'dffe1a7d-4729-433e-ae65-71f2e8b0f012'...                 1
# 6  [{'id': 'e22787b9-5fb4-4401-b092-d64ac66e1621'...                 1
# 7  [{'id': '76224670-5d55-47db-b3d7-9b711322f81d'...                 1
# 8  [{'id': '97c64815-f7b5-4fbe-8b4a-131d6bef29ff'...                 1
# 9  [{'id': '84ed3137-7f61-4197-b42f-5655041c9515'...                 1
#
#                                        new_stash_ids
# 0  [{'endpoint': 'https://stashdb.org/graphql', '...
# 2  [{'endpoint': 'https://stashdb.org/graphql', '...
# 3  [{'endpoint': 'https://stashdb.org/graphql', '...
# 4  [{'endpoint': 'https://stashdb.org/graphql', '...
# 5  [{'endpoint': 'https://stashdb.org/graphql', '...
# 6  [{'endpoint': 'https://stashdb.org/graphql', '...
# 7  [{'endpoint': 'https://stashdb.org/graphql', '...
# 8  [{'endpoint': 'https://stashdb.org/graphql', '...
# 9  [{'endpoint': 'https://stashdb.org/graphql', '...

# %%
df_promising_date_matches["new_stash_ids"].values
# Out:
# array([list([{'endpoint': 'https://stashdb.org/graphql', 'stash_id': 'e0f01c63-7548-4963-93ac-6697d39d9bf3'}, {'endpoint': 'https://theporndb.net/graphql', 'stash_id': 'acb8a3b3-2608-4c4b-8570-82e679b3816a'}]),
#        list([{'endpoint': 'https://stashdb.org/graphql', 'stash_id': '38540ce2-316e-4112-b317-a376b6b3b204'}, {'endpoint': 'https://theporndb.net/graphql', 'stash_id': '61ba6920-9bea-44ea-93fc-34fa2bda75ce'}]),
#        list([{'endpoint': 'https://stashdb.org/graphql', 'stash_id': '2146d872-505f-4f55-b742-1c18906c09d6'}, {'endpoint': 'https://theporndb.net/graphql', 'stash_id': '470a8011-3210-49f0-b7ab-6488d2b97333'}]),
#        list([{'endpoint': 'https://stashdb.org/graphql', 'stash_id': '3f3a7e88-5838-428d-a7c3-b1035ad62706'}, {'endpoint': 'https://theporndb.net/graphql', 'stash_id': 'bba51fc1-66a9-42b2-ae9d-eeba55a3d638'}]),
#        list([{'endpoint': 'https://stashdb.org/graphql', 'stash_id': '6bef00cd-b25d-4e57-9197-cfa125a76f66'}, {'endpoint': 'https://theporndb.net/graphql', 'stash_id': 'dffe1a7d-4729-433e-ae65-71f2e8b0f012'}]),
#        list([{'endpoint': 'https://stashdb.org/graphql', 'stash_id': '9ecf3970-91e9-4995-b308-8e660e5e49f0'}, {'endpoint': 'https://theporndb.net/graphql', 'stash_id': 'e22787b9-5fb4-4401-b092-d64ac66e1621'}]),
#        list([{'endpoint': 'https://stashdb.org/graphql', 'stash_id': '1a095621-59f4-4675-8274-c1b8c1d06991'}, {'endpoint': 'https://theporndb.net/graphql', 'stash_id': '76224670-5d55-47db-b3d7-9b711322f81d'}]),
#        list([{'endpoint': 'https://stashdb.org/graphql', 'stash_id': '4dcc3fa6-5da1-44f2-8ff5-f2c225f07d00'}, {'endpoint': 'https://theporndb.net/graphql', 'stash_id': '97c64815-f7b5-4fbe-8b4a-131d6bef29ff'}]),
#        list([{'endpoint': 'https://stashdb.org/graphql', 'stash_id': 'ff6955ed-f0d7-4342-8bdd-7dd179f16343'}, {'endpoint': 'https://theporndb.net/graphql', 'stash_id': '84ed3137-7f61-4197-b42f-5655041c9515'}])],
#       dtype=object)

# %%
for index, row in df_promising_date_matches.iterrows():
    id = row["id"]
    new_stash_ids = row["new_stash_ids"]
    # Now you can call the stash.update_scene method with these values
    stash.update_scene({ "id": id, "stash_ids": new_stash_ids })
