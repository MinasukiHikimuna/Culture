# %%
import struct
import bencodepy
import hashlib
import math
from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
from cryptography.hazmat.backends import default_backend
import binascii

def uint32(data, offset):
    """Reads a 32-bit unsigned integer (little-endian) from the data."""
    return struct.unpack_from("<I", data, offset)[0]

class HAXFile:
    def __init__(self, file_data, keys):
        # Validate header length
        expected_header_length = uint32(file_data, 8)
        if len(file_data) < expected_header_length:
            raise ValueError("Incomplete HAX header")

        # File properties
        self.file_length = uint32(file_data, 4)
        self.header_length = expected_header_length
        self.extra_length = uint32(file_data, 12)

        # Decode metadata (e.g., using Bencode)
        metadata_raw = file_data[16:self.header_length]
        self.meta = bencodepy.decode(metadata_raw)
        
        # Base key
        self.base_key = self.meta[b'baseKey']  # Raw base key

        # Parse segments
        self.segments = []
        for i in range(self.meta[b'segmentCount']):
            offset = uint32(self.meta[b'segments'], i * 8)
            pts = uint32(self.meta[b'segments'], i * 8 + 4)
            self.segments.append({'off': offset, 'pts': pts})
        
        # Add the last segment (end of the file)
        self.segments.append({
            'off': self.file_length,
            'pts': self.meta[b'durationMs']
        })

        # Load decryption keys - convert hex strings to bytes
        self.keys = {int(k): binascii.unhexlify(v) for k, v in keys.items()}

    def segment_bounds(self, segment_index):
        """Returns the byte range for a given segment."""
        if segment_index < 0 or segment_index >= len(self.segments) - 1:
            return None
        return (self.segments[segment_index]['off'], self.segments[segment_index + 1]['off'])
    
    def derive_key(self, index):
        """Derives a cryptographic key for a given index."""
        r = math.ceil(math.log2(index)) if index > 0 else 0
        derived_key = None
        found_i = 0

        # Find the first applicable key by checking each bit position
        for i in range(r + 1):
            key_index = index >> (r - i)  # Shift right to get the key index
            if key_index in self.keys:
                derived_key = self.keys[key_index]
                found_i = i
                break

        if derived_key is None:
            # If no key is found, try using the base key
            if 1 in self.keys:  # Often the base key is stored with index 1
                derived_key = self.keys[1]
                found_i = 0
            else:
                raise ValueError("No applicable key available")

        # Iteratively derive the key using the remaining bits
        for i in range(found_i + 1, r + 1):
            shift_byte = bytes([index >> (r - i) & 0xFF])
            derived_key = hashlib.sha256(derived_key + shift_byte).digest()

        return derived_key

    def decode(self, segment_index, raw_data):
        """Decrypts a segment using its index and raw data."""
        # Compute h as in the JavaScript code
        h = 1 + (1 << (math.ceil(math.log2(len(self.segments))) + 1))

        # Derive the decryption key
        derived_key = self.derive_key(h + segment_index)

        # Pad the data to a multiple of 16 bytes if necessary
        padding_length = (16 - len(raw_data) % 16) % 16
        padded_data = raw_data + bytes([padding_length] * padding_length)

        # Initialize decryption with AES in CBC mode with zero IV
        iv = bytes(16)  # 16 bytes of zeros
        cipher = Cipher(algorithms.AES(derived_key), modes.CBC(iv), backend=default_backend())
        decryptor = cipher.decryptor()

        # Decrypt the data
        decrypted_data = decryptor.update(padded_data) + decryptor.finalize()
        
        # Remove padding
        if padding_length > 0:
            decrypted_data = decrypted_data[:-padding_length]
            
        return decrypted_data

# %%
listen_dict = {
    "url": "https://cdn.hotaudio.net/a/hm6aq9rrzwtt2drebe64hmjf00.hax",
    "length15s": 245797,
    "keys": {
        "32": "2c90525bd6fdc786146e0d239ee1fa73fe19d34b14e251adbd17ed3459b39c91"
    }
}

# %%
with open("hm6aq9rrzwtt2drebe64hmjf00.hax", "rb") as f:
    file_data = f.read()

hax_file = HAXFile(file_data, listen_dict["keys"])

# Check segment bounds
for i in range(len(hax_file.segments) - 1):
    print(f"Segment {i}: {hax_file.segment_bounds(i)}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 with open("hm6aq9rrzwtt2drebe64hmjf00.hax", "rb") as f:
#       2     file_data = f.read()
# ----> 4 hax_file = HAXFile(file_data, listen_dict["keys"])
#       6 # Check segment bounds
#       7 for i in range(len(hax_file.segments) - 1):
#
# Cell In[1], line 30, in HAXFile.__init__(self, file_data, keys)
#      27 self.meta = bencodepy.decode(metadata_raw)
#      29 # Base key
# ---> 30 self.base_key = self.meta[b'baseKey']  # Raw base key
#      32 # Parse segments
#      33 self.segments = []
#
# File c:\Users\thardas\miniconda3\envs\pandas\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_frame.py:1197, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#    1195 if is_line:
#    1196     self.set_suspend(thread, step_cmd, original_step_cmd=info.pydev_original_step_cmd)
# -> 1197     self.do_wait_suspend(thread, frame, event, arg)
#    1198 elif is_return:  # return event
#    1199     back = frame.f_back
#
# File c:\Users\thardas\miniconda3\envs\pandas\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_frame.py:165, in PyDBFrame.do_wait_suspend(self, *args, **kwargs)
#     164 def do_wait_suspend(self, *args, **kwargs):
# --> 165     self._args[0].do_wait_suspend(*args, **kwargs)
#
# File c:\Users\thardas\miniconda3\envs\pandas\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2070, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2067             from_this_thread.append(frame_custom_thread_id)
#    2069     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2070         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2072 frames_list = None
#    2074 if keep_suspended:
#    2075     # This means that we should pause again after a set next statement.
#
# File c:\Users\thardas\miniconda3\envs\pandas\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2106, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2103         self._call_input_hook()
#    2105     self.process_internal_commands()
# -> 2106     time.sleep(0.01)
#    2108 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2110 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
with open("hm6aq9rrzwtt2drebe64hmjf00.hax", "rb") as f:
    file_data = f.read()

hax_file = HAXFile(file_data, listen_dict["keys"])

# Decode a specific segment (replace 0 with the actual segment index)
segment_bounds = hax_file.segment_bounds(0)
raw_data = file_data[segment_bounds[0]:segment_bounds[1]]
decrypted_data = hax_file.decode(0, raw_data)

print(decrypted_data)
# Out:
# b'\xddU\xfe]g\x918H3\xd6\x8f}^W\xbd\xda\x08e\x98\xf9\xc8\xdbApE\xb8V)g\x01)\x8c\xf0\xf7\xe8\xad\xf1v\x8a\xcdky*\xb8\xd3\x8b0o`\xd6Z/\xb1\xde \xca\xf9b\xb5\x05t\x1a\xb0\xd8\xb1\x85\x8eg\xac\x80}VH\x97P\xd3_|BV<\x94c\xbd\x8e\xd4\xbf=\xf4N\xa9\xd3\x08\xb5\xf0\x04c\xb8\xbe\xb1D\xa0#\xb2Pw\x94\xf1k\x05\xa5\xba\x84s,\x96;~7(\xb5\x16\xc6\x1c\xa6\x88]\xe5d\x86\xc87\x83\xd7\x16ew\xbe\x0ef\xae\xa5\x97.w\xb8F\\\xc1\xde\x80\'j&\x1a\x85\xab\x17\x08\xb5\\\x96x\x05@\x13\x17E\xc3q\x92\x86\xf8\xb4\x10Y9\x98t\xaeE\xed\xbb\xe8\x1b\x8b=}\x13\xbc\xc7\xd6\xe6\x14\xd2\x1a\xb0\xfb\x17\xee\xac\xc3\x9c5\xf6\x91\x8c\xdf\x9f\x9c\xa2\xa3\x93\x93zF\xcb\xcc+*v\x0e\xe8\xd7\xd34\xebZI\x93\xf2\x10\xc8\xa2V\xf2\x8dlX\x973 \xc5qNB\x1d\x13\x0c\xd18\xf7N=\x19\xeb\x98T\xbc\xf0\xe3:\xe4\r\xd5\xd2\xa4\xdb\x96\xb7\xed\xeea\xf8@q\xb7M\x97\x02\xbaM\x8c{K\xa0\xe4\xa5f\xdc\x1bh\xe7\x1b^C\xd7\xdd\x85\x0b\xd2\xdd\xd7\x8ae\xbb\xc7\xd0\xe0\x88\ts\xc2\xa7\x88\xd0\t\x19\x87\xc5\xf0>\xd2\xf69\xa5I\xa6\xa8z\xceB\xfc\xf5\xae\x11Eg\xdc\x87\xdd\xa5\xbf \x0c\xd5D\x14\xb7\x0f\xa3\xd0\xbeZc]A\x03\xc9\x85\xa5r\xde\xd6t}b\x83\x19\xcf \t\x80/\xb3\x18Zx\xe9\xcc\xa4\xec\x9a\xc4\x14l\x06@\xaa&\xc3\x91!\xbbq\xe1\x8d\xc98\xb3\x1c\x8a\xc2\x04\xb5)\xb1\xf3\xc2\xca\xf9\xfd\xcdQ\xb3\xd1\x14\xbd\xb6k\x88\xa1\x1d\x8es\xd2{\xb8\xa0\'\x18\xa0\x85\x95nY.\x0f\xcf\xb2\xa2G\xb1\xbd\x93g\x9b\x92"\xe1sZB\xc2\x1bc\x15\xebK!Q.w\xb5\x08\xc0\x84U\xcfR\x895\x83_\x8a\x98n8#\xc7\x85d\xdbT1J\x92\x7f\xfb\xf4\xcd\xd1\x019nr~\x05\\v\xd7h;\xf5B|\xb0 \xf8\x83\x14c\xdcH\x1f\xf0\x94\xe74=L\xeb\xd1|\rtA\xd4\x04D\xe2\xdf\x12\x15\x8bxv\x99;\x03T\xa4\x14-\xde\x90\xd2&:\xdb6\xd0\x96\xd9\xca\xf8H\xaf-Q\x7f\xdf;/\xd8\xd3qjC \xbd}\xa4^\x87l\xbbW\xa9\x99\xae\xe5\xdc\xa9\xed-\xb2\x8f\xc3\x04\x03\x9fe\xd7\xe9\xa9\x1f\xb5q2\xba\x87\x12\xe7\xed\xf1G`)\xff\xae$\xa0@\xc5a\x8a\x9c>\xc2\xa1.\xb2\x07K\x98\xecS\x83\x89\xa0\x15\x1b5m3\xa2\x84\xa0\xf6c\xf0\xaeL\xd9X\xeb3\xaf\xde\x81\xf5,\xdb\x9c(E\xd2\x1f\x07\xbdi3\x14\x13\xf9\x11\xaf:h\x15\xca0S3\x0eU1]\x9fJW\xde\xe3-B\xd4\n\x12e\x95\xc9\xbc\tL`\xff\x19\x8cV\xc8\xbf\xa4\x88\xc9\n\x9b\x08\xd0\xac_\xbb\x94\xd1\xa5\xb5!\x0e\xc8\t\xdcW\x04%[3\xcfk\xd1\xe54\xf1\xe1\x1a\xdbX\xf4\x1dJ\x07\xa4\xcb\xb9\xb7\x93v\x0f\xb9b(\xe1\x97\x88\xfc\x82\xc7=p{\xc4\xfbe\xa8|\xeb\xf4\xd9*\n\xab\x06[\x04\x85\xc7\x98Z\x80\xda\xb6\xda@\xf5\xb9s\xfe\xd4a?\xac\x07\x99\x10c\xd3\xff\xe12I\x93B\x1a\x9cf\x19;=/\x12\xd6s\xeb\xb2\xd9\xbfg\xb6\xf0\xc3\xb5\xda\x1d\xd0o\xa1\x84{6\x14S0\x1e\xed\xd2\xda\xffzm\x8di\x80<gS\xf9V\xfat\xbf\xfa\x1f\n\xda\x17\xc0\x11\xc1\x17\xf3S\x91\xa9\xb3\x80\xa2<\x93dM\xa3:\\\xd8\xd2\xc5dq^\xba\xf2K\xa9\xb7\xfdCZ\x1b^\xd3&=\xb8\x9a\xbcS\xe5\xf8\xf7\xb0\xe1\xe8m@\xe4\xb2*LA\x91i(\x06\x8f\x9e\r\x8b9\xa6\xce\x0e\xe0\xd6\x99\x94\xda\xe0|\xa5\x82\xf2\x96\xf9\xc0*\x88\xeaY\xa9R\x0e\x16~\xa3\x12x\xaa\x06\xe7\x83O%\x19Y/"\x0c\xc31 H\x86\x8aS\xd9\x17\xc9\x1b\xd748\x92N\t\xeb+\xf5\x8f[\xab\x01\xf1\x93t\xed@\xb6s\xde\x93\xbe\xb8\xc0\x183>\x9b\x9ex[%g5\xac\xe5\xee\x1dbp\xba\xc3\xd3\xfb\xbf\xf7\x17&\x1f\x85\xe5\xf4w\x1e\x8d\xa8@\xdc\x94\xba\xd7Y\xdb\xf3\xfdA\xcd]W\x0f%8\xc1\xb6-\xcf\xf4\x89ms\xa0\x06\xc6X>\xf5\xdcXLe\xe9\xd5\x816A\x16\xa9\xa4@\xf8\xcf.\nR\xb5\xd4\xa3\xeae(\x0fr\x11\xfd\xcd\xe5\x985\xe7h\x98\xcc\x8c\xcc`a\x90\xd5e\xa8\x16\xd1\xb2x\x9e.\xbb\x8f\xa2^\x9e\x15\xa4Z\xf7\xbf|\x1c\x15\xa2\xceX\xb5kH\xed\xb73\xd3\xf5QO\xf9[\xe2PG^\x88\x18\xeb,1\x0e\x9b\x1d\xe8\xe4\xf5\xa8\xb7t\x03\xd2T?3\xbd\xa4*\xea\x92\x8fA\xce\xe3\x8a\xca\xdbX\xbcF\xa5,@k\xca\xb6b\xe3\x9f\xd0\x05e\xf3\xdaJ\x9c%H\\\xa1AH\nQ%M\x02\x0f\xc7\x1d\xa6\x81\xcf\xe8\x12\r\xb5>Px\x80\x13%\xd3\xb6?\xf1?\x1a\xbb\x8e_\xb6\x02\xe0&W\r]v\xecr\x82j7\xa4[w\xd0\xd1\x84;\xda\xcf\x12\x8c\xa7\xa1\xf0\xf0A\x9d\x17|\x0fs\xe9T\x83S\x95\n:\x1c\x89\xb5\x8cEb\x02#g<~\x99\x1f\x93\x04\xf4M\xbeP\x02oO\x9c\xb4[\xa34w \x90L\x10\x91J\x06\xb68\xc7\x16\x7fjS\x9fhM\xfeT\xbf\xa0U<bE]k$\xa1\xeb#\xf2]\xb5\xbc\xadY\xc6\xc1\xb4^\x05!\xd7\xfaF#\xdfa\xdc\x88\xc1fK%\x9e\xe9\xa9\x90\xbbG.\xb9y\x9bQC\x14\xe5n\xc6\x9e\xa1\x92\x11\x071\xf1|\xc8~\x07\xe73\xfc\rE\xf1B\xffi\xd5,\x8am\xb ...

# %%
with open("hm6aq9rrzwtt2drebe64hmjf00.hax", "rb") as f:
    file_data = f.read()

hax_file = HAXFile(file_data, listen_dict["keys"])

# Create output AAC file
with open("output.aac", "wb") as out_f:
    # Decode all segments
    for i in range(len(hax_file.segments) - 1):  # -1 because last segment is just end marker
        segment_bounds = hax_file.segment_bounds(i)
        if segment_bounds:
            raw_data = file_data[segment_bounds[0]:segment_bounds[1]]
            try:
                decrypted_data = hax_file.decode(i, raw_data)
                out_f.write(decrypted_data)
                print(f"Decoded segment {i}/{len(hax_file.segments)-2}")
            except Exception as e:
                print(f"Error decoding segment {i}: {e}")
                continue

print("Decoding complete. Output saved to output.aac")
# Out:
# Decoded segment 0/1879
# Decoded segment 1/1879
# Decoded segment 2/1879
# Decoded segment 3/1879
# Decoded segment 4/1879
# Decoded segment 5/1879
# Decoded segment 6/1879
# Decoded segment 7/1879
# Decoded segment 8/1879
# Decoded segment 9/1879
# Decoded segment 10/1879
# Decoded segment 11/1879
# Decoded segment 12/1879
# Decoded segment 13/1879
# Decoded segment 14/1879
# Decoded segment 15/1879
# Decoded segment 16/1879
# Decoded segment 17/1879
# Decoded segment 18/1879
# Decoded segment 19/1879
# Decoded segment 20/1879
# Decoded segment 21/1879
# Decoded segment 22/1879
# Decoded segment 23/1879
# Decoded segment 24/1879
# Decoded segment 25/1879
# Decoded segment 26/1879
# Decoded segment 27/1879
# Decoded segment 28/1879
# Decoded segment 29/1879
# Decoded segment 30/1879
# Decoded segment 31/1879
# Decoded segment 32/1879
# Decoded segment 33/1879
# Decoded segment 34/1879
# Decoded segment 35/1879
# Decoded segment 36/1879
# Decoded segment 37/1879
# Decoded segment 38/1879
# Decoded segment 39/1879
# Decoded segment 40/1879
# Decoded segment 41/1879
# Decoded segment 42/1879
# Decoded segment 43/1879
# Decoded segment 44/1879
# Decoded segment 45/1879
# Decoded segment 46/1879
# Decoded segment 47/1879
# Decoded segment 48/1879
# Decoded segment 49/1879
# Decoded segment 50/1879
# Decoded segment 51/1879
# Decoded segment 52/1879
# Decoded segment 53/1879
# Decoded segment 54/1879
# Decoded segment 55/1879
# Decoded segment 56/1879
# Decoded segment 57/1879
# Decoded segment 58/1879
# Decoded segment 59/1879
# Decoded segment 60/1879
# Decoded segment 61/1879
# Decoded segment 62/1879
# Decoded segment 63/1879
# Decoded segment 64/1879
# Decoded segment 65/1879
# Decoded segment 66/1879
# Decoded segment 67/1879
# Decoded segment 68/1879
# Decoded segment 69/1879
# Decoded segment 70/1879
# Decoded segment 71/1879
# Decoded segment 72/1879
# Decoded segment 73/1879
# Decoded segment 74/1879
# Decoded segment 75/1879
# Decoded segment 76/1879
# Decoded segment 77/1879
# Decoded segment 78/1879
# Decoded segment 79/1879
# Decoded segment 80/1879
# Decoded segment 81/1879
# Decoded segment 82/1879
# Decoded segment 83/1879
# Decoded segment 84/1879
# Decoded segment 85/1879
# Decoded segment 86/1879
# Decoded segment 87/1879
# Decoded segment 88/1879
# Decoded segment 89/1879
# Decoded segment 90/1879
# Decoded segment 91/1879
# Decoded segment 92/1879
# Decoded segment 93/1879
# Decoded segment 94/1879
# Decoded segment 95/1879
# Decoded segment 96/1879
# Decoded segment 97/1879
# Decoded segment 98/1879
# Decoded segment 99/1879
# Decoded segment 100/1879
# Decoded segment 101/1879
# Decoded segment 102/1879
# Decoded segment 103/1879
# Decoded segment 104/1879
# Decoded segment 105/1879
# Decoded segment 106/1879
# Decoded segment 107/1879
# Decoded segment 108/1879
# Decoded segment 109/1879
# Decoded segment 110/1879
# Decoded segment 111/1879
# Decoded segment 112/1879
# Decoded segment 113/1879
# Decoded segment 114/1879
# Decoded segment 115/1879
# Decoded segment 116/1879
# Decoded segment 117/1879
# Decoded segment 118/1879
# Decoded segment 119/1879
# Decoded segment 120/1879
# Decoded segment 121/1879
# Decoded segment 122/1879
# Decoded segment 123/1879
# Decoded segment 124/1879
# Decoded segment 125/1879
# Decoded segment 126/1879
# Error decoding segment 127: No applicable key available
# Error decoding segment 128: No applicable key available
# Error decoding segment 129: No applicable key available
# Error decoding segment 130: No applicable key available
# Error decoding segment 131: No applicable key available
# Error decoding segment 132: No applicable key available
# Error decoding segment 133: No applicable key available
# Error decoding segment 134: No applicable key available
# Error decoding segment 135: No applicable key available
# Error decoding segment 136: No applicable key available
# Error decoding segment 137: No applicable key available
# Error decoding segment 138: No applicable key available
# Error decoding segment 139: No applicable key available
# Error decoding segment 140: No applicable key available
# Error decoding segment 141: No applicable key available
# Error decoding segment 142: No applicable key available
# Error decoding segment 143: No applicable key available
# Error decoding segment 144: No applicable key available
# Error decoding segment 145: No applicable key available
# Error decoding segment 146: No applicable key available
# Error decoding segment 147: No applicable key available
# Error decoding segment 148: No applicable key available
# Error decoding segment 149: No applicable key available
# Error decoding segment 150: No applicable key available
# Error decoding segment 151: No applicable key available
# Error decoding segment 152: No applicable key available
# Error decoding segment 153: No applicable key available
# Error decoding segment 154: No applicable key available
# Error decoding segment 155: No applicable key available
# Error decoding segment 156: No applicable key available
# Error decoding segment 157: No applicable key available
# Error decoding segment 158: No applicable key available
# Error decoding segment 159: No applicable key available
# Error decoding segment 160: No applicable key available
# Error decoding segment 161: No applicable key available
# Error decoding segment 162: No applicable key available
# Error decoding segment 163: No applicable key available
# Error decoding segment 164: No applicable key available
# Error decoding segment 165: No applicable key available
# Error decoding segment 166: No applicable key available
# Error decoding segment 167: No applicable key available
# Error decoding segment 168: No applicable key available
# Error decoding segment 169: No applicable key available
# Error decoding segment 170: No applicable key available
# Error decoding segment 171: No applicable key available
# Error decoding segment 172: No applicable key available
# Error decoding segment 173: No applicable key available
# Error decoding segment 174: No applicable key available
# Error decoding segment 175: No applicable key available
# Error decoding segment 176: No applicable key available
# Error decoding segment 177: No applicable key available
# Error decoding segment 178: No applicable key available
# Error decoding segment 179: No applicable key available
# Error decoding segment 180: No applicable key available
# Error decoding segment 181: No applicable key available
# Error decoding segment 182: No applicable key available
# Error decoding segment 183: No applicable key available
# Error decoding segment 184: No applicable key available
# Error decoding segment 185: No applicable key available
# Error decoding segment 186: No applicable key available
# Error decoding segment 187: No applicable key available
# Error decoding segment 188: No applicable key available
# Error decoding segment 189: No applicable key available
# Error decoding segment 190: No applicable key available
# Error decoding segment 191: No applicable key available
# Error decoding segment 192: No applicable key available
# Error decoding segment 193: No applicable key available
# Error decoding segment 194: No applicable key available
# Error decoding segment 195: No applicable key available
# Error decoding segment 196: No applicable key available
# Error decoding segment 197: No applicable key available
# Error decoding segment 198: No applicable key available
# Error decoding segment 199: No applicable key available
# Error decoding segment 200: No applicable key available
# Error decoding segment 201: No applicable key available
# Error decoding segment 202: No applicable key available
# Error decoding segment 203: No applicable key available
# Error decoding segment 204: No applicable key available
# Error decoding segment 205: No applicable key available
# Error decoding segment 206: No applicable key available
# Error decoding segment 207: No applicable key available
# Error decoding segment 208: No applicable key available
# Error decoding segment 209: No applicable key available
# Error decoding segment 210: No applicable key available
# Error decoding segment 211: No applicable key available
# Error decoding segment 212: No applicable key available
# Error decoding segment 213: No applicable key available
# Error decoding segment 214: No applicable key available
# Error decoding segment 215: No applicable key available
# Error decoding segment 216: No applicable key available
# Error decoding segment 217: No applicable key available
# Error decoding segment 218: No applicable key available
# Error decoding segment 219: No applicable key available
# Error decoding segment 220: No applicable key available
# Error decoding segment 221: No applicable key available
# Error decoding segment 222: No applicable key available
# Error decoding segment 223: No applicable key available
# Error decoding segment 224: No applicable key available
# Error decoding segment 225: No applicable key available
# Error decoding segment 226: No applicable key available
# Error decoding segment 227: No applicable key available
# Error decoding segment 228: No applicable key available
# Error decoding segment 229: No applicable key available
# Error decoding segment 230: No applicable key available
# Error decoding segment 231: No applicable key available
# Error decoding segment 232: No applicable key available
# Error decoding segment 233: No applicable key available
# Error decoding segment 234: No applicable key available
# Error decoding segment 235: No applicable key available
# Error decoding segment 236: No applicable key available
# Error decoding segment 237: No applicable key available
# Error decoding segment 238: No applicable key available
# Error decoding segment 239: No applicable key available
# Error decoding segment 240: No applicable key available
# Error decoding segment 241: No applicable key available
# Error decoding segment 242: No applicable key available
# Error decoding segment 243: No applicable key available
# Error decoding segment 244: No applicable key available
# Error decoding segment 245: No applicable key available
# Error decoding segment 246: No applicable key available
# Error decoding segment 247: No applicable key available
# Error decoding segment 248: No applicable key available
# Error decoding segment 249: No applicable key available
# Error decoding segment 250: No applicable key available
# Error decoding segment 251: No applicable key available
# Error decoding segment 252: No applicable key available
# Error decoding segment 253: No applicable key available
# Error decoding segment 254: No applicable key available
# Error decoding segment 255: No applicable key available
# Error decoding segment 256: No applicable key available
# Error decoding segment 257: No applicable key available
# Error decoding segment 258: No applicable key available
# Error decoding segment 259: No applicable key available
# Error decoding segment 260: No applicable key available
# Error decoding segment 261: No applicable key available
# Error decoding segment 262: No applicable key available
# Error decoding segment 263: No applicable key available
# Error decoding segment 264: No applicable key available
# Error decoding segment 265: No applicable key available
# Error decoding segment 266: No applicable key available
# Error decoding segment 267: No applicable key available
# Error decoding segment 268: No applicable key available
# Error decoding segment 269: No applicable key available
# Error decoding segment 270: No applicable key available
# Error decoding segment 271: No applicable key available
# Error decoding segment 272: No applicable key available
# Error decoding segment 273: No applicable key available
# Error decoding segment 274: No applicable key available
# Error decoding segment 275: No applicable key available
# Error decoding segment 276: No applicable key available
# Error decoding segment 277: No applicable key available
# Error decoding segment 278: No applicable key available
# Error decoding segment 279: No applicable key available
# Error decoding segment 280: No applicable key available
# Error decoding segment 281: No applicable key available
# Error decoding segment 282: No applicable key available
# Error decoding segment 283: No applicable key available
# Error decoding segment 284: No applicable key available
# Error decoding segment 285: No applicable key available
# Error decoding segment 286: No applicable key available
# Error decoding segment 287: No applicable key available
# Error decoding segment 288: No applicable key available
# Error decoding segment 289: No applicable key available
# Error decoding segment 290: No applicable key available
# Error decoding segment 291: No applicable key available
# Error decoding segment 292: No applicable key available
# Error decoding segment 293: No applicable key available
# Error decoding segment 294: No applicable key available
# Error decoding segment 295: No applicable key available
# Error decoding segment 296: No applicable key available
# Error decoding segment 297: No applicable key available
# Error decoding segment 298: No applicable key available
# Error decoding segment 299: No applicable key available
# Error decoding segment 300: No applicable key available
# Error decoding segment 301: No applicable key available
# Error decoding segment 302: No applicable key available
# Error decoding segment 303: No applicable key available
# Error decoding segment 304: No applicable key available
# Error decoding segment 305: No applicable key available
# Error decoding segment 306: No applicable key available
# Error decoding segment 307: No applicable key available
# Error decoding segment 308: No applicable key available
# Error decoding segment 309: No applicable key available
# Error decoding segment 310: No applicable key available
# Error decoding segment 311: No applicable key available
# Error decoding segment 312: No applicable key available
# Error decoding segment 313: No applicable key available
# Error decoding segment 314: No applicable key available
# Error decoding segment 315: No applicable key available
# Error decoding segment 316: No applicable key available
# Error decoding segment 317: No applicable key available
# Error decoding segment 318: No applicable key available
# Error decoding segment 319: No applicable key available
# Error decoding segment 320: No applicable key available
# Error decoding segment 321: No applicable key available
# Error decoding segment 322: No applicable key available
# Error decoding segment 323: No applicable key available
# Error decoding segment 324: No applicable key available
# Error decoding segment 325: No applicable key available
# Error decoding segment 326: No applicable key available
# Error decoding segment 327: No applicable key available
# Error decoding segment 328: No applicable key available
# Error decoding segment 329: No applicable key available
# Error decoding segment 330: No applicable key available
# Error decoding segment 331: No applicable key available
# Error decoding segment 332: No applicable key available
# Error decoding segment 333: No applicable key available
# Error decoding segment 334: No applicable key available
# Error decoding segment 335: No applicable key available
# Error decoding segment 336: No applicable key available
# Error decoding segment 337: No applicable key available
# Error decoding segment 338: No applicable key available
# Error decoding segment 339: No applicable key available
# Error decoding segment 340: No applicable key available
# Error decoding segment 341: No applicable key available
# Error decoding segment 342: No applicable key available
# Error decoding segment 343: No applicable key available
# Error decoding segment 344: No applicable key available
# Error decoding segment 345: No applicable key available
# Error decoding segment 346: No applicable key available
# Error decoding segment 347: No applicable key available
# Error decoding segment 348: No applicable key available
# Error decoding segment 349: No applicable key available
# Error decoding segment 350: No applicable key available
# Error decoding segment 351: No applicable key available
# Error decoding segment 352: No applicable key available
# Error decoding segment 353: No applicable key available
# Error decoding segment 354: No applicable key available
# Error decoding segment 355: No applicable key available
# Error decoding segment 356: No applicable key available
# Error decoding segment 357: No applicable key available
# Error decoding segment 358: No applicable key available
# Error decoding segment 359: No applicable key available
# Error decoding segment 360: No applicable key available
# Error decoding segment 361: No applicable key available
# Error decoding segment 362: No applicable key available
# Error decoding segment 363: No applicable key available
# Error decoding segment 364: No applicable key available
# Error decoding segment 365: No applicable key available
# Error decoding segment 366: No applicable key available
# Error decoding segment 367: No applicable key available
# Error decoding segment 368: No applicable key available
# Error decoding segment 369: No applicable key available
# Error decoding segment 370: No applicable key available
# Error decoding segment 371: No applicable key available
# Error decoding segment 372: No applicable key available
# Error decoding segment 373: No applicable key available
# Error decoding segment 374: No applicable key available
# Error decoding segment 375: No applicable key available
# Error decoding segment 376: No applicable key available
# Error decoding segment 377: No applicable key available
# Error decoding segment 378: No applicable key available
# Error decoding segment 379: No applicable key available
# Error decoding segment 380: No applicable key available
# Error decoding segment 381: No applicable key available
# Error decoding segment 382: No applicable key available
# Error decoding segment 383: No applicable key available
# Error decoding segment 384: No applicable key available
# Error decoding segment 385: No applicable key available
# Error decoding segment 386: No applicable key available
# Error decoding segment 387: No applicable key available
# Error decoding segment 388: No applicable key available
# Error decoding segment 389: No applicable key available
# Error decoding segment 390: No applicable key available
# Error decoding segment 391: No applicable key available
# Error decoding segment 392: No applicable key available
# Error decoding segment 393: No applicable key available
# Error decoding segment 394: No applicable key available
# Error decoding segment 395: No applicable key available
# Error decoding segment 396: No applicable key available
# Error decoding segment 397: No applicable key available
# Error decoding segment 398: No applicable key available
# Error decoding segment 399: No applicable key available
# Error decoding segment 400: No applicable key available
# Error decoding segment 401: No applicable key available
# Error decoding segment 402: No applicable key available
# Error decoding segment 403: No applicable key available
# Error decoding segment 404: No applicable key available
# Error decoding segment 405: No applicable key available
# Error decoding segment 406: No applicable key available
# Error decoding segment 407: No applicable key available
# Error decoding segment 408: No applicable key available
# Error decoding segment 409: No applicable key available
# Error decoding segment 410: No applicable key available
# Error decoding segment 411: No applicable key available
# Error decoding segment 412: No applicable key available
# Error decoding segment 413: No applicable key available
# Error decoding segment 414: No applicable key available
# Error decoding segment 415: No applicable key available
# Error decoding segment 416: No applicable key available
# Error decoding segment 417: No applicable key available
# Error decoding segment 418: No applicable key available
# Error decoding segment 419: No applicable key available
# Error decoding segment 420: No applicable key available
# Error decoding segment 421: No applicable key available
# Error decoding segment 422: No applicable key available
# Error decoding segment 423: No applicable key available
# Error decoding segment 424: No applicable key available
# Error decoding segment 425: No applicable key available
# Error decoding segment 426: No applicable key available
# Error decoding segment 427: No applicable key available
# Error decoding segment 428: No applicable key available
# Error decoding segment 429: No applicable key available
# Error decoding segment 430: No applicable key available
# Error decoding segment 431: No applicable key available
# Error decoding segment 432: No applicable key available
# Error decoding segment 433: No applicable key available
# Error decoding segment 434: No applicable key available
# Error decoding segment 435: No applicable key available
# Error decoding segment 436: No applicable key available
# Error decoding segment 437: No applicable key available
# Error decoding segment 438: No applicable key available
# Error decoding segment 439: No applicable key available
# Error decoding segment 440: No applicable key available
# Error decoding segment 441: No applicable key available
# Error decoding segment 442: No applicable key available
# Error decoding segment 443: No applicable key available
# Error decoding segment 444: No applicable key available
# Error decoding segment 445: No applicable key available
# Error decoding segment 446: No applicable key available
# Error decoding segment 447: No applicable key available
# Error decoding segment 448: No applicable key available
# Error decoding segment 449: No applicable key available
# Error decoding segment 450: No applicable key available
# Error decoding segment 451: No applicable key available
# Error decoding segment 452: No applicable key available
# Error decoding segment 453: No applicable key available
# Error decoding segment 454: No applicable key available
# Error decoding segment 455: No applicable key available
# Error decoding segment 456: No applicable key available
# Error decoding segment 457: No applicable key available
# Error decoding segment 458: No applicable key available
# Error decoding segment 459: No applicable key available
# Error decoding segment 460: No applicable key available
# Error decoding segment 461: No applicable key available
# Error decoding segment 462: No applicable key available
# Error decoding segment 463: No applicable key available
# Error decoding segment 464: No applicable key available
# Error decoding segment 465: No applicable key available
# Error decoding segment 466: No applicable key available
# Error decoding segment 467: No applicable key available
# Error decoding segment 468: No applicable key available
# Error decoding segment 469: No applicable key available
# Error decoding segment 470: No applicable key available
# Error decoding segment 471: No applicable key available
# Error decoding segment 472: No applicable key available
# Error decoding segment 473: No applicable key available
# Error decoding segment 474: No applicable key available
# Error decoding segment 475: No applicable key available
# Error decoding segment 476: No applicable key available
# Error decoding segment 477: No applicable key available
# Error decoding segment 478: No applicable key available
# Error decoding segment 479: No applicable key available
# Error decoding segment 480: No applicable key available
# Error decoding segment 481: No applicable key available
# Error decoding segment 482: No applicable key available
# Error decoding segment 483: No applicable key available
# Error decoding segment 484: No applicable key available
# Error decoding segment 485: No applicable key available
# Error decoding segment 486: No applicable key available
# Error decoding segment 487: No applicable key available
# Error decoding segment 488: No applicable key available
# Error decoding segment 489: No applicable key available
# Error decoding segment 490: No applicable key available
# Error decoding segment 491: No applicable key available
# Error decoding segment 492: No applicable key available
# Error decoding segment 493: No applicable key available
# Error decoding segment 494: No applicable key available
# Error decoding segment 495: No applicable key available
# Error decoding segment 496: No applicable key available
# Error decoding segment 497: No applicable key available
# Error decoding segment 498: No applicable key available
# Error decoding segment 499: No applicable key available
# Error decoding segment 500: No applicable key available
# Error decoding segment 501: No applicable key available
# Error decoding segment 502: No applicable key available
# Error decoding segment 503: No applicable key available
# Error decoding segment 504: No applicable key available
# Error decoding segment 505: No applicable key available
# Error decoding segment 506: No applicable key available
# Error decoding segment 507: No applicable key available
# Error decoding segment 508: No applicable key available
# Error decoding segment 509: No applicable key available
# Error decoding segment 510: No applicable key available
# Error decoding segment 511: No applicable key available
# Error decoding segment 512: No applicable key available
# Error decoding segment 513: No applicable key available
# Error decoding segment 514: No applicable key available
# Error decoding segment 515: No applicable key available
# Error decoding segment 516: No applicable key available
# Error decoding segment 517: No applicable key available
# Error decoding segment 518: No applicable key available
# Error decoding segment 519: No applicable key available
# Error decoding segment 520: No applicable key available
# Error decoding segment 521: No applicable key available
# Error decoding segment 522: No applicable key available
# Error decoding segment 523: No applicable key available
# Error decoding segment 524: No applicable key available
# Error decoding segment 525: No applicable key available
# Error decoding segment 526: No applicable key available
# Error decoding segment 527: No applicable key available
# Error decoding segment 528: No applicable key available
# Error decoding segment 529: No applicable key available
# Error decoding segment 530: No applicable key available
# Error decoding segment 531: No applicable key available
# Error decoding segment 532: No applicable key available
# Error decoding segment 533: No applicable key available
# Error decoding segment 534: No applicable key available
# Error decoding segment 535: No applicable key available
# Error decoding segment 536: No applicable key available
# Error decoding segment 537: No applicable key available
# Error decoding segment 538: No applicable key available
# Error decoding segment 539: No applicable key available
# Error decoding segment 540: No applicable key available
# Error decoding segment 541: No applicable key available
# Error decoding segment 542: No applicable key available
# Error decoding segment 543: No applicable key available
# Error decoding segment 544: No applicable key available
# Error decoding segment 545: No applicable key available
# Error decoding segment 546: No applicable key available
# Error decoding segment 547: No applicable key available
# Error decoding segment 548: No applicable key available
# Error decoding segment 549: No applicable key available
# Error decoding segment 550: No applicable key available
# Error decoding segment 551: No applicable key available
# Error decoding segment 552: No applicable key available
# Error decoding segment 553: No applicable key available
# Error decoding segment 554: No applicable key available
# Error decoding segment 555: No applicable key available
# Error decoding segment 556: No applicable key available
# Error decoding segment 557: No applicable key available
# Error decoding segment 558: No applicable key available
# Error decoding segment 559: No applicable key available
# Error decoding segment 560: No applicable key available
# Error decoding segment 561: No applicable key available
# Error decoding segment 562: No applicable key available
# Error decoding segment 563: No applicable key available
# Error decoding segment 564: No applicable key available
# Error decoding segment 565: No applicable key available
# Error decoding segment 566: No applicable key available
# Error decoding segment 567: No applicable key available
# Error decoding segment 568: No applicable key available
# Error decoding segment 569: No applicable key available
# Error decoding segment 570: No applicable key available
# Error decoding segment 571: No applicable key available
# Error decoding segment 572: No applicable key available
# Error decoding segment 573: No applicable key available
# Error decoding segment 574: No applicable key available
# Error decoding segment 575: No applicable key available
# Error decoding segment 576: No applicable key available
# Error decoding segment 577: No applicable key available
# Error decoding segment 578: No applicable key available
# Error decoding segment 579: No applicable key available
# Error decoding segment 580: No applicable key available
# Error decoding segment 581: No applicable key available
# Error decoding segment 582: No applicable key available
# Error decoding segment 583: No applicable key available
# Error decoding segment 584: No applicable key available
# Error decoding segment 585: No applicable key available
# Error decoding segment 586: No applicable key available
# Error decoding segment 587: No applicable key available
# Error decoding segment 588: No applicable key available
# Error decoding segment 589: No applicable key available
# Error decoding segment 590: No applicable key available
# Error decoding segment 591: No applicable key available
# Error decoding segment 592: No applicable key available
# Error decoding segment 593: No applicable key available
# Error decoding segment 594: No applicable key available
# Error decoding segment 595: No applicable key available
# Error decoding segment 596: No applicable key available
# Error decoding segment 597: No applicable key available
# Error decoding segment 598: No applicable key available
# Error decoding segment 599: No applicable key available
# Error decoding segment 600: No applicable key available
# Error decoding segment 601: No applicable key available
# Error decoding segment 602: No applicable key available
# Error decoding segment 603: No applicable key available
# Error decoding segment 604: No applicable key available
# Error decoding segment 605: No applicable key available
# Error decoding segment 606: No applicable key available
# Error decoding segment 607: No applicable key available
# Error decoding segment 608: No applicable key available
# Error decoding segment 609: No applicable key available
# Error decoding segment 610: No applicable key available
# Error decoding segment 611: No applicable key available
# Error decoding segment 612: No applicable key available
# Error decoding segment 613: No applicable key available
# Error decoding segment 614: No applicable key available
# Error decoding segment 615: No applicable key available
# Error decoding segment 616: No applicable key available
# Error decoding segment 617: No applicable key available
# Error decoding segment 618: No applicable key available
# Error decoding segment 619: No applicable key available
# Error decoding segment 620: No applicable key available
# Error decoding segment 621: No applicable key available
# Error decoding segment 622: No applicable key available
# Error decoding segment 623: No applicable key available
# Error decoding segment 624: No applicable key available
# Error decoding segment 625: No applicable key available
# Error decoding segment 626: No applicable key available
# Error decoding segment 627: No applicable key available
# Error decoding segment 628: No applicable key available
# Error decoding segment 629: No applicable key available
# Error decoding segment 630: No applicable key available
# Error decoding segment 631: No applicable key available
# Error decoding segment 632: No applicable key available
# Error decoding segment 633: No applicable key available
# Error decoding segment 634: No applicable key available
# Error decoding segment 635: No applicable key available
# Error decoding segment 636: No applicable key available
# Error decoding segment 637: No applicable key available
# Error decoding segment 638: No applicable key available
# Error decoding segment 639: No applicable key available
# Error decoding segment 640: No applicable key available
# Error decoding segment 641: No applicable key available
# Error decoding segment 642: No applicable key available
# Error decoding segment 643: No applicable key available
# Error decoding segment 644: No applicable key available
# Error decoding segment 645: No applicable key available
# Error decoding segment 646: No applicable key available
# Error decoding segment 647: No applicable key available
# Error decoding segment 648: No applicable key available
# Error decoding segment 649: No applicable key available
# Error decoding segment 650: No applicable key available
# Error decoding segment 651: No applicable key available
# Error decoding segment 652: No applicable key available
# Error decoding segment 653: No applicable key available
# Error decoding segment 654: No applicable key available
# Error decoding segment 655: No applicable key available
# Error decoding segment 656: No applicable key available
# Error decoding segment 657: No applicable key available
# Error decoding segment 658: No applicable key available
# Error decoding segment 659: No applicable key available
# Error decoding segment 660: No applicable key available
# Error decoding segment 661: No applicable key available
# Error decoding segment 662: No applicable key available
# Error decoding segment 663: No applicable key available
# Error decoding segment 664: No applicable key available
# Error decoding segment 665: No applicable key available
# Error decoding segment 666: No applicable key available
# Error decoding segment 667: No applicable key available
# Error decoding segment 668: No applicable key available
# Error decoding segment 669: No applicable key available
# Error decoding segment 670: No applicable key available
# Error decoding segment 671: No applicable key available
# Error decoding segment 672: No applicable key available
# Error decoding segment 673: No applicable key available
# Error decoding segment 674: No applicable key available
# Error decoding segment 675: No applicable key available
# Error decoding segment 676: No applicable key available
# Error decoding segment 677: No applicable key available
# Error decoding segment 678: No applicable key available
# Error decoding segment 679: No applicable key available
# Error decoding segment 680: No applicable key available
# Error decoding segment 681: No applicable key available
# Error decoding segment 682: No applicable key available
# Error decoding segment 683: No applicable key available
# Error decoding segment 684: No applicable key available
# Error decoding segment 685: No applicable key available
# Error decoding segment 686: No applicable key available
# Error decoding segment 687: No applicable key available
# Error decoding segment 688: No applicable key available
# Error decoding segment 689: No applicable key available
# Error decoding segment 690: No applicable key available
# Error decoding segment 691: No applicable key available
# Error decoding segment 692: No applicable key available
# Error decoding segment 693: No applicable key available
# Error decoding segment 694: No applicable key available
# Error decoding segment 695: No applicable key available
# Error decoding segment 696: No applicable key available
# Error decoding segment 697: No applicable key available
# Error decoding segment 698: No applicable key available
# Error decoding segment 699: No applicable key available
# Error decoding segment 700: No applicable key available
# Error decoding segment 701: No applicable key available
# Error decoding segment 702: No applicable key available
# Error decoding segment 703: No applicable key available
# Error decoding segment 704: No applicable key available
# Error decoding segment 705: No applicable key available
# Error decoding segment 706: No applicable key available
# Error decoding segment 707: No applicable key available
# Error decoding segment 708: No applicable key available
# Error decoding segment 709: No applicable key available
# Error decoding segment 710: No applicable key available
# Error decoding segment 711: No applicable key available
# Error decoding segment 712: No applicable key available
# Error decoding segment 713: No applicable key available
# Error decoding segment 714: No applicable key available
# Error decoding segment 715: No applicable key available
# Error decoding segment 716: No applicable key available
# Error decoding segment 717: No applicable key available
# Error decoding segment 718: No applicable key available
# Error decoding segment 719: No applicable key available
# Error decoding segment 720: No applicable key available
# Error decoding segment 721: No applicable key available
# Error decoding segment 722: No applicable key available
# Error decoding segment 723: No applicable key available
# Error decoding segment 724: No applicable key available
# Error decoding segment 725: No applicable key available
# Error decoding segment 726: No applicable key available
# Error decoding segment 727: No applicable key available
# Error decoding segment 728: No applicable key available
# Error decoding segment 729: No applicable key available
# Error decoding segment 730: No applicable key available
# Error decoding segment 731: No applicable key available
# Error decoding segment 732: No applicable key available
# Error decoding segment 733: No applicable key available
# Error decoding segment 734: No applicable key available
# Error decoding segment 735: No applicable key available
# Error decoding segment 736: No applicable key available
# Error decoding segment 737: No applicable key available
# Error decoding segment 738: No applicable key available
# Error decoding segment 739: No applicable key available
# Error decoding segment 740: No applicable key available
# Error decoding segment 741: No applicable key available
# Error decoding segment 742: No applicable key available
# Error decoding segment 743: No applicable key available
# Error decoding segment 744: No applicable key available
# Error decoding segment 745: No applicable key available
# Error decoding segment 746: No applicable key available
# Error decoding segment 747: No applicable key available
# Error decoding segment 748: No applicable key available
# Error decoding segment 749: No applicable key available
# Error decoding segment 750: No applicable key available
# Error decoding segment 751: No applicable key available
# Error decoding segment 752: No applicable key available
# Error decoding segment 753: No applicable key available
# Error decoding segment 754: No applicable key available
# Error decoding segment 755: No applicable key available
# Error decoding segment 756: No applicable key available
# Error decoding segment 757: No applicable key available
# Error decoding segment 758: No applicable key available
# Error decoding segment 759: No applicable key available
# Error decoding segment 760: No applicable key available
# Error decoding segment 761: No applicable key available
# Error decoding segment 762: No applicable key available
# Error decoding segment 763: No applicable key available
# Error decoding segment 764: No applicable key available
# Error decoding segment 765: No applicable key available
# Error decoding segment 766: No applicable key available
# Error decoding segment 767: No applicable key available
# Error decoding segment 768: No applicable key available
# Error decoding segment 769: No applicable key available
# Error decoding segment 770: No applicable key available
# Error decoding segment 771: No applicable key available
# Error decoding segment 772: No applicable key available
# Error decoding segment 773: No applicable key available
# Error decoding segment 774: No applicable key available
# Error decoding segment 775: No applicable key available
# Error decoding segment 776: No applicable key available
# Error decoding segment 777: No applicable key available
# Error decoding segment 778: No applicable key available
# Error decoding segment 779: No applicable key available
# Error decoding segment 780: No applicable key available
# Error decoding segment 781: No applicable key available
# Error decoding segment 782: No applicable key available
# Error decoding segment 783: No applicable key available
# Error decoding segment 784: No applicable key available
# Error decoding segment 785: No applicable key available
# Error decoding segment 786: No applicable key available
# Error decoding segment 787: No applicable key available
# Error decoding segment 788: No applicable key available
# Error decoding segment 789: No applicable key available
# Error decoding segment 790: No applicable key available
# Error decoding segment 791: No applicable key available
# Error decoding segment 792: No applicable key available
# Error decoding segment 793: No applicable key available
# Error decoding segment 794: No applicable key available
# Error decoding segment 795: No applicable key available
# Error decoding segment 796: No applicable key available
# Error decoding segment 797: No applicable key available
# Error decoding segment 798: No applicable key available
# Error decoding segment 799: No applicable key available
# Error decoding segment 800: No applicable key available
# Error decoding segment 801: No applicable key available
# Error decoding segment 802: No applicable key available
# Error decoding segment 803: No applicable key available
# Error decoding segment 804: No applicable key available
# Error decoding segment 805: No applicable key available
# Error decoding segment 806: No applicable key available
# Error decoding segment 807: No applicable key available
# Error decoding segment 808: No applicable key available
# Error decoding segment 809: No applicable key available
# Error decoding segment 810: No applicable key available
# Error decoding segment 811: No applicable key available
# Error decoding segment 812: No applicable key available
# Error decoding segment 813: No applicable key available
# Error decoding segment 814: No applicable key available
# Error decoding segment 815: No applicable key available
# Error decoding segment 816: No applicable key available
# Error decoding segment 817: No applicable key available
# Error decoding segment 818: No applicable key available
# Error decoding segment 819: No applicable key available
# Error decoding segment 820: No applicable key available
# Error decoding segment 821: No applicable key available
# Error decoding segment 822: No applicable key available
# Error decoding segment 823: No applicable key available
# Error decoding segment 824: No applicable key available
# Error decoding segment 825: No applicable key available
# Error decoding segment 826: No applicable key available
# Error decoding segment 827: No applicable key available
# Error decoding segment 828: No applicable key available
# Error decoding segment 829: No applicable key available
# Error decoding segment 830: No applicable key available
# Error decoding segment 831: No applicable key available
# Error decoding segment 832: No applicable key available
# Error decoding segment 833: No applicable key available
# Error decoding segment 834: No applicable key available
# Error decoding segment 835: No applicable key available
# Error decoding segment 836: No applicable key available
# Error decoding segment 837: No applicable key available
# Error decoding segment 838: No applicable key available
# Error decoding segment 839: No applicable key available
# Error decoding segment 840: No applicable key available
# Error decoding segment 841: No applicable key available
# Error decoding segment 842: No applicable key available
# Error decoding segment 843: No applicable key available
# Error decoding segment 844: No applicable key available
# Error decoding segment 845: No applicable key available
# Error decoding segment 846: No applicable key available
# Error decoding segment 847: No applicable key available
# Error decoding segment 848: No applicable key available
# Error decoding segment 849: No applicable key available
# Error decoding segment 850: No applicable key available
# Error decoding segment 851: No applicable key available
# Error decoding segment 852: No applicable key available
# Error decoding segment 853: No applicable key available
# Error decoding segment 854: No applicable key available
# Error decoding segment 855: No applicable key available
# Error decoding segment 856: No applicable key available
# Error decoding segment 857: No applicable key available
# Error decoding segment 858: No applicable key available
# Error decoding segment 859: No applicable key available
# Error decoding segment 860: No applicable key available
# Error decoding segment 861: No applicable key available
# Error decoding segment 862: No applicable key available
# Error decoding segment 863: No applicable key available
# Error decoding segment 864: No applicable key available
# Error decoding segment 865: No applicable key available
# Error decoding segment 866: No applicable key available
# Error decoding segment 867: No applicable key available
# Error decoding segment 868: No applicable key available
# Error decoding segment 869: No applicable key available
# Error decoding segment 870: No applicable key available
# Error decoding segment 871: No applicable key available
# Error decoding segment 872: No applicable key available
# Error decoding segment 873: No applicable key available
# Error decoding segment 874: No applicable key available
# Error decoding segment 875: No applicable key available
# Error decoding segment 876: No applicable key available
# Error decoding segment 877: No applicable key available
# Error decoding segment 878: No applicable key available
# Error decoding segment 879: No applicable key available
# Error decoding segment 880: No applicable key available
# Error decoding segment 881: No applicable key available
# Error decoding segment 882: No applicable key available
# Error decoding segment 883: No applicable key available
# Error decoding segment 884: No applicable key available
# Error decoding segment 885: No applicable key available
# Error decoding segment 886: No applicable key available
# Error decoding segment 887: No applicable key available
# Error decoding segment 888: No applicable key available
# Error decoding segment 889: No applicable key available
# Error decoding segment 890: No applicable key available
# Error decoding segment 891: No applicable key available
# Error decoding segment 892: No applicable key available
# Error decoding segment 893: No applicable key available
# Error decoding segment 894: No applicable key available
# Error decoding segment 895: No applicable key available
# Error decoding segment 896: No applicable key available
# Error decoding segment 897: No applicable key available
# Error decoding segment 898: No applicable key available
# Error decoding segment 899: No applicable key available
# Error decoding segment 900: No applicable key available
# Error decoding segment 901: No applicable key available
# Error decoding segment 902: No applicable key available
# Error decoding segment 903: No applicable key available
# Error decoding segment 904: No applicable key available
# Error decoding segment 905: No applicable key available
# Error decoding segment 906: No applicable key available
# Error decoding segment 907: No applicable key available
# Error decoding segment 908: No applicable key available
# Error decoding segment 909: No applicable key available
# Error decoding segment 910: No applicable key available
# Error decoding segment 911: No applicable key available
# Error decoding segment 912: No applicable key available
# Error decoding segment 913: No applicable key available
# Error decoding segment 914: No applicable key available
# Error decoding segment 915: No applicable key available
# Error decoding segment 916: No applicable key available
# Error decoding segment 917: No applicable key available
# Error decoding segment 918: No applicable key available
# Error decoding segment 919: No applicable key available
# Error decoding segment 920: No applicable key available
# Error decoding segment 921: No applicable key available
# Error decoding segment 922: No applicable key available
# Error decoding segment 923: No applicable key available
# Error decoding segment 924: No applicable key available
# Error decoding segment 925: No applicable key available
# Error decoding segment 926: No applicable key available
# Error decoding segment 927: No applicable key available
# Error decoding segment 928: No applicable key available
# ...
# Error decoding segment 1601: No applicable key available
# Error decoding segment 1602: No applicable key available
# Error decoding segment 1603: No applicable key available
# Error decoding segment 1604: No applicable key available
# Error decoding segment 1605: No applicable key available
# Error decoding segment 1606: No applicable key available
# Error decoding segment 1607: No applicable key available
# Error decoding segment 1608: No applicable key available
# Error decoding segment 1609: No applicable key available
# Error decoding segment 1610: No applicable key available
# Error decoding segment 1611: No applicable key available
# Error decoding segment 1612: No applicable key available
# Error decoding segment 1613: No applicable key available
# Error decoding segment 1614: No applicable key available
# Error decoding segment 1615: No applicable key available
# Error decoding segment 1616: No applicable key available
# Error decoding segment 1617: No applicable key available
# Error decoding segment 1618: No applicable key available
# Error decoding segment 1619: No applicable key available
# Error decoding segment 1620: No applicable key available
# Error decoding segment 1621: No applicable key available
# Error decoding segment 1622: No applicable key available
# Error decoding segment 1623: No applicable key available
# Error decoding segment 1624: No applicable key available
# Error decoding segment 1625: No applicable key available
# Error decoding segment 1626: No applicable key available
# Error decoding segment 1627: No applicable key available
# Error decoding segment 1628: No applicable key available
# Error decoding segment 1629: No applicable key available
# Error decoding segment 1630: No applicable key available
# Error decoding segment 1631: No applicable key available
# Error decoding segment 1632: No applicable key available
# Error decoding segment 1633: No applicable key available
# Error decoding segment 1634: No applicable key available
# Error decoding segment 1635: No applicable key available
# Error decoding segment 1636: No applicable key available
# Error decoding segment 1637: No applicable key available
# Error decoding segment 1638: No applicable key available
# Error decoding segment 1639: No applicable key available
# Error decoding segment 1640: No applicable key available
# Error decoding segment 1641: No applicable key available
# Error decoding segment 1642: No applicable key available
# Error decoding segment 1643: No applicable key available
# Error decoding segment 1644: No applicable key available
# Error decoding segment 1645: No applicable key available
# Error decoding segment 1646: No applicable key available
# Error decoding segment 1647: No applicable key available
# Error decoding segment 1648: No applicable key available
# Error decoding segment 1649: No applicable key available
# Error decoding segment 1650: No applicable key available
# Error decoding segment 1651: No applicable key available
# Error decoding segment 1652: No applicable key available
# Error decoding segment 1653: No applicable key available
# Error decoding segment 1654: No applicable key available
# Error decoding segment 1655: No applicable key available
# Error decoding segment 1656: No applicable key available
# Error decoding segment 1657: No applicable key available
# Error decoding segment 1658: No applicable key available
# Error decoding segment 1659: No applicable key available
# Error decoding segment 1660: No applicable key available
# Error decoding segment 1661: No applicable key available
# Error decoding segment 1662: No applicable key available
# Error decoding segment 1663: No applicable key available
# Error decoding segment 1664: No applicable key available
# Error decoding segment 1665: No applicable key available
# Error decoding segment 1666: No applicable key available
# Error decoding segment 1667: No applicable key available
# Error decoding segment 1668: No applicable key available
# Error decoding segment 1669: No applicable key available
# Error decoding segment 1670: No applicable key available
# Error decoding segment 1671: No applicable key available
# Error decoding segment 1672: No applicable key available
# Error decoding segment 1673: No applicable key available
# Error decoding segment 1674: No applicable key available
# Error decoding segment 1675: No applicable key available
# Error decoding segment 1676: No applicable key available
# Error decoding segment 1677: No applicable key available
# Error decoding segment 1678: No applicable key available
# Error decoding segment 1679: No applicable key available
# Error decoding segment 1680: No applicable key available
# Error decoding segment 1681: No applicable key available
# Error decoding segment 1682: No applicable key available
# Error decoding segment 1683: No applicable key available
# Error decoding segment 1684: No applicable key available
# Error decoding segment 1685: No applicable key available
# Error decoding segment 1686: No applicable key available
# Error decoding segment 1687: No applicable key available
# Error decoding segment 1688: No applicable key available
# Error decoding segment 1689: No applicable key available
# Error decoding segment 1690: No applicable key available
# Error decoding segment 1691: No applicable key available
# Error decoding segment 1692: No applicable key available
# Error decoding segment 1693: No applicable key available
# Error decoding segment 1694: No applicable key available
# Error decoding segment 1695: No applicable key available
# Error decoding segment 1696: No applicable key available
# Error decoding segment 1697: No applicable key available
# Error decoding segment 1698: No applicable key available
# Error decoding segment 1699: No applicable key available
# Error decoding segment 1700: No applicable key available
# Error decoding segment 1701: No applicable key available
# Error decoding segment 1702: No applicable key available
# Error decoding segment 1703: No applicable key available
# Error decoding segment 1704: No applicable key available
# Error decoding segment 1705: No applicable key available
# Error decoding segment 1706: No applicable key available
# Error decoding segment 1707: No applicable key available
# Error decoding segment 1708: No applicable key available
# Error decoding segment 1709: No applicable key available
# Error decoding segment 1710: No applicable key available
# Error decoding segment 1711: No applicable key available
# Error decoding segment 1712: No applicable key available
# Error decoding segment 1713: No applicable key available
# Error decoding segment 1714: No applicable key available
# Error decoding segment 1715: No applicable key available
# Error decoding segment 1716: No applicable key available
# Error decoding segment 1717: No applicable key available
# Error decoding segment 1718: No applicable key available
# Error decoding segment 1719: No applicable key available
# Error decoding segment 1720: No applicable key available
# Error decoding segment 1721: No applicable key available
# Error decoding segment 1722: No applicable key available
# Error decoding segment 1723: No applicable key available
# Error decoding segment 1724: No applicable key available
# Error decoding segment 1725: No applicable key available
# Error decoding segment 1726: No applicable key available
# Error decoding segment 1727: No applicable key available
# Error decoding segment 1728: No applicable key available
# Error decoding segment 1729: No applicable key available
# Error decoding segment 1730: No applicable key available
# Error decoding segment 1731: No applicable key available
# Error decoding segment 1732: No applicable key available
# Error decoding segment 1733: No applicable key available
# Error decoding segment 1734: No applicable key available
# Error decoding segment 1735: No applicable key available
# Error decoding segment 1736: No applicable key available
# Error decoding segment 1737: No applicable key available
# Error decoding segment 1738: No applicable key available
# Error decoding segment 1739: No applicable key available
# Error decoding segment 1740: No applicable key available
# Error decoding segment 1741: No applicable key available
# Error decoding segment 1742: No applicable key available
# Error decoding segment 1743: No applicable key available
# Error decoding segment 1744: No applicable key available
# Error decoding segment 1745: No applicable key available
# Error decoding segment 1746: No applicable key available
# Error decoding segment 1747: No applicable key available
# Error decoding segment 1748: No applicable key available
# Error decoding segment 1749: No applicable key available
# Error decoding segment 1750: No applicable key available
# Error decoding segment 1751: No applicable key available
# Error decoding segment 1752: No applicable key available
# Error decoding segment 1753: No applicable key available
# Error decoding segment 1754: No applicable key available
# Error decoding segment 1755: No applicable key available
# Error decoding segment 1756: No applicable key available
# Error decoding segment 1757: No applicable key available
# Error decoding segment 1758: No applicable key available
# Error decoding segment 1759: No applicable key available
# Error decoding segment 1760: No applicable key available
# Error decoding segment 1761: No applicable key available
# Error decoding segment 1762: No applicable key available
# Error decoding segment 1763: No applicable key available
# Error decoding segment 1764: No applicable key available
# Error decoding segment 1765: No applicable key available
# Error decoding segment 1766: No applicable key available
# Error decoding segment 1767: No applicable key available
# Error decoding segment 1768: No applicable key available
# Error decoding segment 1769: No applicable key available
# Error decoding segment 1770: No applicable key available
# Error decoding segment 1771: No applicable key available
# Error decoding segment 1772: No applicable key available
# Error decoding segment 1773: No applicable key available
# Error decoding segment 1774: No applicable key available
# Error decoding segment 1775: No applicable key available
# Error decoding segment 1776: No applicable key available
# Error decoding segment 1777: No applicable key available
# Error decoding segment 1778: No applicable key available
# Error decoding segment 1779: No applicable key available
# Error decoding segment 1780: No applicable key available
# Error decoding segment 1781: No applicable key available
# Error decoding segment 1782: No applicable key available
# Error decoding segment 1783: No applicable key available
# Error decoding segment 1784: No applicable key available
# Error decoding segment 1785: No applicable key available
# Error decoding segment 1786: No applicable key available
# Error decoding segment 1787: No applicable key available
# Error decoding segment 1788: No applicable key available
# Error decoding segment 1789: No applicable key available
# Error decoding segment 1790: No applicable key available
# Error decoding segment 1791: No applicable key available
# Error decoding segment 1792: No applicable key available
# Error decoding segment 1793: No applicable key available
# Error decoding segment 1794: No applicable key available
# Error decoding segment 1795: No applicable key available
# Error decoding segment 1796: No applicable key available
# Error decoding segment 1797: No applicable key available
# Error decoding segment 1798: No applicable key available
# Error decoding segment 1799: No applicable key available
# Error decoding segment 1800: No applicable key available
# Error decoding segment 1801: No applicable key available
# Error decoding segment 1802: No applicable key available
# Error decoding segment 1803: No applicable key available
# Error decoding segment 1804: No applicable key available
# Error decoding segment 1805: No applicable key available
# Error decoding segment 1806: No applicable key available
# Error decoding segment 1807: No applicable key available
# Error decoding segment 1808: No applicable key available
# Error decoding segment 1809: No applicable key available
# Error decoding segment 1810: No applicable key available
# Error decoding segment 1811: No applicable key available
# Error decoding segment 1812: No applicable key available
# Error decoding segment 1813: No applicable key available
# Error decoding segment 1814: No applicable key available
# Error decoding segment 1815: No applicable key available
# Error decoding segment 1816: No applicable key available
# Error decoding segment 1817: No applicable key available
# Error decoding segment 1818: No applicable key available
# Error decoding segment 1819: No applicable key available
# Error decoding segment 1820: No applicable key available
# Error decoding segment 1821: No applicable key available
# Error decoding segment 1822: No applicable key available
# Error decoding segment 1823: No applicable key available
# Error decoding segment 1824: No applicable key available
# Error decoding segment 1825: No applicable key available
# Error decoding segment 1826: No applicable key available
# Error decoding segment 1827: No applicable key available
# Error decoding segment 1828: No applicable key available
# Error decoding segment 1829: No applicable key available
# Error decoding segment 1830: No applicable key available
# Error decoding segment 1831: No applicable key available
# Error decoding segment 1832: No applicable key available
# Error decoding segment 1833: No applicable key available
# Error decoding segment 1834: No applicable key available
# Error decoding segment 1835: No applicable key available
# Error decoding segment 1836: No applicable key available
# Error decoding segment 1837: No applicable key available
# Error decoding segment 1838: No applicable key available
# Error decoding segment 1839: No applicable key available
# Error decoding segment 1840: No applicable key available
# Error decoding segment 1841: No applicable key available
# Error decoding segment 1842: No applicable key available
# Error decoding segment 1843: No applicable key available
# Error decoding segment 1844: No applicable key available
# Error decoding segment 1845: No applicable key available
# Error decoding segment 1846: No applicable key available
# Error decoding segment 1847: No applicable key available
# Error decoding segment 1848: No applicable key available
# Error decoding segment 1849: No applicable key available
# Error decoding segment 1850: No applicable key available
# Error decoding segment 1851: No applicable key available
# Error decoding segment 1852: No applicable key available
# Error decoding segment 1853: No applicable key available
# Error decoding segment 1854: No applicable key available
# Error decoding segment 1855: No applicable key available
# Error decoding segment 1856: No applicable key available
# Error decoding segment 1857: No applicable key available
# Error decoding segment 1858: No applicable key available
# Error decoding segment 1859: No applicable key available
# Error decoding segment 1860: No applicable key available
# Error decoding segment 1861: No applicable key available
# Error decoding segment 1862: No applicable key available
# Error decoding segment 1863: No applicable key available
# Error decoding segment 1864: No applicable key available
# Error decoding segment 1865: No applicable key available
# Error decoding segment 1866: No applicable key available
# Error decoding segment 1867: No applicable key available
# Error decoding segment 1868: No applicable key available
# Error decoding segment 1869: No applicable key available
# Error decoding segment 1870: No applicable key available
# Error decoding segment 1871: No applicable key available
# Error decoding segment 1872: No applicable key available
# Error decoding segment 1873: No applicable key available
# Error decoding segment 1874: No applicable key available
# Error decoding segment 1875: No applicable key available
# Error decoding segment 1876: No applicable key available
# Error decoding segment 1877: No applicable key available
# Error decoding segment 1878: No applicable key available
# Error decoding segment 1879: No applicable key available
# Decoding complete. Output saved to output.aac
